# %% [markdown]
# # Data Cleaning and Put into SQL

# %%
import pandas as pd
import sqlite3
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import bs4
import time
import random
import numpy as np

# %% [markdown]
# ## Clean author_article.csv

# %%
# clean author_article
df_art_au = pd.read_csv("author_article.csv", encoding = "utf-8-sig").drop_duplicates()
df_art_au.to_csv("author_article.csv", encoding = "utf-8-sig", index = False)
df_art_au.to_csv("author_article_no_header.csv", encoding = "utf-8-sig", index = False, header = False)

# %% [markdown]
# ## Clean article.csv

# %%
# select valid records with valid doi, issue format, and not duplicated
def select_valid(df):
    df_s = df[(df["doi"].str[:3] == "10.") & (df["volume"].str.contains("Supplement") == False) & 
              (df["volume"].str.contains("_Part_") == False) & 
              (df["volume"].str.contains("S1") == False) & 
              (df["volume"].str.contains("issue ") == True)].drop_duplicates(subset=["doi"]).reset_index(drop = True)
    return df_s

# convert volume to date
def conv_volume_to_date(v,freq):
    v_list = v.split(", ")
    year = v_list[0]
    issue = v_list[2].replace("issue ","")
    if freq == 4:
        return year+"-"+str(int(issue)*3-1)+"-15"
    elif freq == 6 or freq == 5:
        return year+"-"+str(int(issue)*2)+"-01"
    elif freq == 12:
        return year+"-"+issue+"-15"
    elif freq == 3:
        return year+"-"+str(int(issue)*3)+"-01"
    elif freq == 2:
        return year+"-"+str(int(issue)*6-2)+"-01"
    elif freq == 1:
        return year+"-"+str(7)+"-01"
    
# calculate issue frequency
def cal_freq(vs):
    dict = {}
    years = [int(v.split(", ")[0]) for v in vs]
    unique_years = set(years)
    issues = [int(v.split(", ")[2].replace("issue ","")) for v in vs]
    for unique_year in unique_years:
        max_issue = 0
        for i in range(len(years)):
            if unique_year == years[i]:
                if issues[i] > max_issue:
                    max_issue = issues[i]
        dict[unique_year] = max_issue

    return dict

# %%
# clean rfs
df_rfs = pd.read_csv("data/journals/raw_data/rfs.csv", encoding = "utf-8-sig")
df_rfs_s = select_valid(df_rfs)
freq = cal_freq(df_rfs_s["volume"])

dates = []
for idx in df_rfs_s.index:
    year = int(df_rfs_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_rfs_s.loc[idx,"volume"],freq[year]))

df_rfs_s["date"] = dates
df_rfs_s.head()
# Out:
#                        journal  \
# 0  Review of Financial Studies
# 1  Review of Financial Studies
# 2  Review of Financial Studies
# 3  Review of Financial Studies
# 4  Review of Financial Studies
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                              authors  \
# 0                ['Jerome Detemple', 'Angel Serrat']
# 1               ['Wayne Ferson', 'Andrew F. Siegel']
# 2                ['Gurdip Bakshi', 'Nikunj Kapadia']
# 3                  ['Harrison Hong', 'Jeremy Stein']
# 4  ['Dong-Hyun Ahn', 'Jennifer Conrad', 'Robert D...
#
#                             volume jel  \
# 0  2003, vol. 16, issue 2, 597-629  []
# 1  2003, vol. 16, issue 2, 567-595  []
# 2  2003, vol. 16, issue 2, 527-566  []
# 3  2003, vol. 16, issue 2, 487-525  []
# 4  2003, vol. 16, issue 2, 459-485  []
#
#                                             abstract  \
# 0  Abstract: This article studies an intertempora...
# 1  Abstract: Hansen and Jagannathan (1991) (herea...
# 2  Abstract: We investigate whether the volatilit...
# 3  Abstract: We develop a theory of market crashe...
# 4  Abstract: We assess the profitability of momen...
#
#                                                  url                 doi  \
# 0  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg003
# 1  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg004
# 2  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg002
# 3  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg006
# 4  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg001
#
#         date
# 0  2003-5-15
# 1  2003-5-15
# 2  2003-5-15
# 3  2003-5-15
# 4  2003-5-15

# %%
# clean res
df_res = pd.read_csv("data/journals/raw_data/res.csv", encoding = "utf-8-sig")
df_res_s = select_valid(df_res)
freq = cal_freq(df_res_s["volume"])

dates = []
for idx in df_res_s.index:
    year = int(df_res_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_res_s.loc[idx,"volume"],freq[year]))

df_res_s["date"] = dates
df_res_s.head()
# Out:
#                       journal  \
# 0  Review of Economic Studies
# 1  Review of Economic Studies
# 2  Review of Economic Studies
# 3  Review of Economic Studies
# 4  Review of Economic Studies
#
#                                                title  \
# 0  The Dynamics of Return Migration, Human Capita...
# 1  The Impact of Car Pollution on Infant and Chil...
# 2  The Welfare Effects of Transportation Infrastr...
# 3  Subjective Models of the Macroeconomy: Evidenc...
# 4   Product Life Cycle, Learning, and Nominal Shocks
#
#                                              authors  \
# 0  ['Jerome Adda', 'Christian Dustmann', 'Joseph-...
# 1             ['Diane Alexander', 'Hannes Schwandt']
# 2                 ['Treb Allen', 'Costas Arkolakis']
# 3  ['Peter Andrebriq', 'Carlo Pizzinelli', 'Chris...
# 4                      ['David Argente', 'Chen Yeh']
#
#                               volume jel  \
# 0  2022, vol. 89, issue 6, 2841-2871  []
# 1  2022, vol. 89, issue 6, 2872-2910  []
# 2  2022, vol. 89, issue 6, 2911-2957  []
# 3  2022, vol. 89, issue 6, 2958-2991  []
# 4  2022, vol. 89, issue 6, 2992-3054  []
#
#                                             abstract  \
# 0  Abstract: This article develops and estimates ...
# 1  Abstract: In 2008, Volkswagen introduced a new...
# 2  Abstract: Each year in the US, hundreds of bil...
# 3  Abstract: We study people’s subjective models ...
# 4  Abstract: This article documents a new set of ...
#
#                                                  url                     doi  \
# 0  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac003
# 1  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac007
# 2  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac001
# 3  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac008
# 4  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac004
#
#          date
# 0  2022-12-01
# 1  2022-12-01
# 2  2022-12-01
# 3  2022-12-01
# 4  2022-12-01

# %%
# clean qje
df_qje = pd.read_csv("data/journals/raw_data/qje.csv", encoding = "utf-8-sig")
df_qje_s = select_valid(df_qje)
freq = cal_freq(df_qje_s["volume"])

dates = []
for idx in df_qje_s.index:
    year = int(df_qje_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_qje_s.loc[idx,"volume"],freq[year]))

df_qje_s["date"] = dates
df_qje_s.head()
# Out:
#                               journal  \
# 0  The Quarterly Journal of Economics
# 1  The Quarterly Journal of Economics
# 2  The Quarterly Journal of Economics
# 3  The Quarterly Journal of Economics
# 4  The Quarterly Journal of Economics
#
#                                                title  \
# 0  Systemic Discrimination Among Large U.S. Emplo...
# 1  Valuing the Global Mortality Consequences of C...
# 2  Reshaping Global Trade: The Immediate and Long...
# 3  Sexual Harassment and Gender Inequality in the...
# 4  The Quality and Efficiency of Public and Priva...
#
#                                              authors  \
# 0  ['Patrick Kline', 'Evan K Rose', 'Christopher ...
# 1  ['Tamma Carleton', 'Amir Jina', 'Michael Delga...
# 2                                      ['Chenzi Xu']
# 3                   ['Olle Folke', 'Johanna Rickne']
# 4              ['Daniel Knutsson', 'Björn Tyrefors']
#
#                                volume jel  \
# 0  2022, vol. 137, issue 4, 1963-2036  []
# 1  2022, vol. 137, issue 4, 2037-2105  []
# 2  2022, vol. 137, issue 4, 2107-2161  []
# 3  2022, vol. 137, issue 4, 2163-2212  []
# 4  2022, vol. 137, issue 4, 2213-2262  []
#
#                                             abstract  \
# 0  Abstract: We study the results of a massive na...
# 1  Abstract: Using 40 countries’ subnational data...
# 2  Abstract: I show that a disruption to the fina...
# 3  Abstract: We describe how sexual harassment co...
# 4  Abstract: Economic theory predicts that outsou...
#
#                                                  url                  doi  \
# 0  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac024
# 1  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac020
# 2  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac016
# 3  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac018
# 4  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac014
#
#          date
# 0  2022-11-15
# 1  2022-11-15
# 2  2022-11-15
# 3  2022-11-15
# 4  2022-11-15

# %%
# clean jpe
df_jpe = pd.read_csv("data/journals/raw_data/jpe.csv", encoding = "utf-8-sig")
df_jpe["doi"] = df_jpe["doi"].apply(lambda x: x.replace("http://dx.doi.org/",""))
df_jpe_s = select_valid(df_jpe)
freq = cal_freq(df_jpe_s["volume"])

dates = []
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_jpe_s.loc[idx,"volume"],freq[year]))

df_jpe_s["date"] = dates

# modify date for 2023
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_jpe_s.loc[idx, "date"] = conv_volume_to_date(df_jpe_s.loc[idx,"volume"],12)

df_jpe_s.head()
# Out:
#                         journal  \
# 0  Journal of Political Economy
# 1  Journal of Political Economy
# 2  Journal of Political Economy
# 3  Journal of Political Economy
# 4  Journal of Political Economy
#
#                                                title  \
# 0                        Collective Brand Reputation
# 1         The Mechanics of the Industrial Revolution
# 2  Optimal Cooperative Taxation in the Global Eco...
# 3          Personalized Pricing and Consumer Welfare
# 4  A Semistructural Methodology for Policy Counte...
#
#                                              authors  \
# 0                 ['Volker Nocke', 'Roland Strausz']
# 1   ['Morgan Kelly', 'Joel Mokyr', 'Cormac Ó Gráda']
# 2  ['V. V. Chari', 'Juan Pablo Nicolini', 'Pedro ...
# 3               ['Jean-Pierre Dubé', 'Sanjog Misra']
# 4                                  ['Martin Beraja']
#
#                                volume jel  \
# 0     2023, vol. 131, issue 1, 1 - 58  []
# 1    2023, vol. 131, issue 1, 59 - 94  []
# 2   2023, vol. 131, issue 1, 95 - 130  []
# 3  2023, vol. 131, issue 1, 131 - 189  []
# 4  2023, vol. 131, issue 1, 190 - 201  []
#
#                                             abstract  \
# 0  Abstract: We develop a theory of collective br...
# 1  Abstract: Although there are many competing ex...
# 2  Abstract: How should countries cooperate in se...
# 3  Abstract: We study the welfare implications of...
# 4  Abstract: I propose a methodology for construc...
#
#                                                  url             doi  \
# 0  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720986
# 1  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720890
# 2  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720889
# 3  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720793
# 4  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720982
#
#         date
# 0  2023-1-15
# 1  2023-1-15
# 2  2023-1-15
# 3  2023-1-15
# 4  2023-1-15

# %%
for v in df_jpe_s.volume:
    print(v)

# %%
# concatenate journals
df = pd.concat([df_rfs_s,df_res_s,df_qje_s,df_jpe_s]).reset_index(drop=True)
len(df)
# Out:
# 14201

# %%
df.nunique()
# Out:
# journal         4
# title       14047
# authors     10586
# volume      14201
# jel           624
# abstract     8959
# url         14201
# doi         14201
# date         1057
# dtype: int64

# %%
df_selected = df[["doi","journal","volume","date","title","abstract","url"]]
df_selected.head()
# Out:
#                   doi                      journal  \
# 0  10.1093/rfs/hhg003  Review of Financial Studies
# 1  10.1093/rfs/hhg004  Review of Financial Studies
# 2  10.1093/rfs/hhg002  Review of Financial Studies
# 3  10.1093/rfs/hhg006  Review of Financial Studies
# 4  10.1093/rfs/hhg001  Review of Financial Studies
#
#                             volume       date  \
# 0  2003, vol. 16, issue 2, 597-629  2003-5-15
# 1  2003, vol. 16, issue 2, 567-595  2003-5-15
# 2  2003, vol. 16, issue 2, 527-566  2003-5-15
# 3  2003, vol. 16, issue 2, 487-525  2003-5-15
# 4  2003, vol. 16, issue 2, 459-485  2003-5-15
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                             abstract  \
# 0  Abstract: This article studies an intertempora...
# 1  Abstract: Hansen and Jagannathan (1991) (herea...
# 2  Abstract: We investigate whether the volatilit...
# 3  Abstract: We develop a theory of market crashe...
# 4  Abstract: We assess the profitability of momen...
#
#                                                  url
# 0  https://econpapers.repec.org/article/ouprfinst...
# 1  https://econpapers.repec.org/article/ouprfinst...
# 2  https://econpapers.repec.org/article/ouprfinst...
# 3  https://econpapers.repec.org/article/ouprfinst...
# 4  https://econpapers.repec.org/article/ouprfinst...

# %%
# save article
df_selected.to_csv("article.csv", index = False, encoding = "utf-8-sig")
df_selected.to_csv("article_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Clean and update author.csv, email_affiliation.csv, affiliation.csv

# %%
# clean author
df_email = pd.read_csv("email_affiliation.csv", encoding = "utf-8-sig").replace(np.NaN,"")
emaildict = df_email.to_dict("list")
df_au = pd.read_csv("author.csv", encoding = "utf-8-sig")

# %%
# open chrome service
chromedriver_path = "D:/chromedriver.exe"
s = Service(chromedriver_path)
driver = webdriver.Chrome(service=s)

# %%
base_url = "https://scholar.google.com/scholar?hl=zh-CN&q="
start_idx = 1
for i, e in enumerate(sorted(df_au["emailsuffix"].unique())[start_idx:]):
    if e not in list(df_email.subemail):
        driver.get(base_url+e)
        driver.refresh()
        soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
        try:
            h3 = soup.find("div", class_ = "gs_r").h3
            if h3.text == "以下机构的用户个人学术档案：":
                div = soup.find("div", class_ = "gs_r").div
                name = div.a.text
                email = div.span.text.replace(" - ", "")
                time.sleep(random.randrange(5,10))
            else:
                raise ValueError("x")
        except:
            try:
                h2 = soup.find("div", class_ = "gs_r").h2
                if "显示的是以下查询字词的结果：" in h2.text.strip():
                    driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                    driver.refresh()
                    soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                    div = soup.find("div", class_ = "gs_r").div
                    name = div.a.text
                    email = div.span.text.replace(" - ", "")
                    time.sleep(random.randrange(5,10))
                else:
                    raise ValueError("x")
            except:
                driver.get(base_url+".".join(e.split(".")[1:]))
                driver.refresh()
                soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                try:
                    h3 = soup.find("div", class_ = "gs_r").h3
                    if h3.text == "以下机构的用户个人学术档案：":
                        div = soup.find("div", class_ = "gs_r").div
                        name = div.a.text
                        email = div.span.text.replace(" - ", "")
                        time.sleep(random.randrange(5,10))
                    else:
                        raise ValueError("x")
                except:
                    try:
                        h2 = soup.find("div", class_ = "gs_r").h2
                        if "显示的是以下查询字词的结果：" in h2.text.strip():
                            driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                            driver.refresh()
                            soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                            div = soup.find("div", class_ = "gs_r").div
                            name = div.a.text
                            email = div.span.text.replace(" - ", "")
                            time.sleep(random.randrange(5,10))
                        else:
                            raise ValueError("x")
                    except:
                        try:
                            if soup.find("h1").text == "请进行人机身份验证":
                                print("Blocked!!!")
                                break
                            else:
                                name = ""
                                email = ""
                            time.sleep(random.randrange(5,10))
                        except:
                            name = ""
                            email = ""
                            time.sleep(random.randrange(5,10))
        # append info
        try:
            affid = "".join([w[0] for w in name.lower().split(" ")])+"."+email
        except:
            affid = ""

        emaildict["name"].append(name)
        emaildict["email"].append(email)
        emaildict["subemail"].append(e)
        emaildict["affiliationid"].append(affid)
        print(i+start_idx, e, name, email, affid)
# Out:
# 5 adelaide.edu.au University of Adelaide adelaide.edu.au uoa.adelaide.edu.au
# 27 ankura.com
# 32 artsci.wustl.edu Washington University in St. Louis wustl.edu wuisl.wustl.edu
# 93 brookes.ac.uk Oxford Brookes University brookes.ac.uk obu.brookes.ac.uk
# 159 cirano.qc.ca
# 184 crai.com
# 197 curtin.edu.au Curtin University curtin.edu.au cu.curtin.edu.au
# 279 emu.edu.tr Eastern Mediterranean University emu.edu.tr emu.emu.edu.tr
# 280 engr.und.edu University of North Dakota und.edu uond.und.edu
# 294 estellejames.com
# 354 gsd.harvard.edu Harvard University harvard.edu hu.harvard.edu
# 528 math.ethz.ch ETH Zürich ethz.ch ez.ethz.ch
# 586 niskanencenter.org
# 739 soas.ac.uk School of Oriental and African Studies, London soas.ac.uk sooaasl.soas.ac.uk
# 751 stat.harvard.edu Harvard University harvard.edu hu.harvard.edu
# 1011 wedefineapps.com

# %%
len(emaildict["name"])
# Out:
# 1048

# %%
df_email = pd.DataFrame(emaildict).drop_duplicates(subset=["subemail"],keep="last")
len(df_email)
# Out:
# 1048

# %%
affids = []
for idx in df_email.index:
    if df_email.loc[idx,"name"] != "":
        affids.append("".join([w[0] for w in df_email.loc[idx,"name"].lower().split(" ")])+"."+df_email.loc[idx,"email"])
    else:
        affids.append("")

# %%
df_email["affiliationid"] = affids

# %%
df_email.nunique()
# Out:
# name              580
# email             579
# subemail         1048
# affiliationid     580
# dtype: int64

# %%
df_aff = df_email[["affiliationid","name","email"]].drop_duplicates()
len(df_aff)
# Out:
# 580

# %%
# add affiliationid to author
for idx in df_au.index:
    try:
        df_au.loc[idx, "affiliationid"] = df_email.set_index("subemail").loc[df_au.loc[idx, "emailsuffix"],"affiliationid"]
    except:
        df_au.loc[idx, "affiliationid"] = ""

# %%
df_email.to_csv("email_affiliation.csv", index = False, encoding = "utf-8-sig")
df_email.to_csv("email_affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation.csv", index = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_au.to_csv("author.csv", index = False, encoding = "utf-8-sig")
df_au.to_csv("author_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Database

# %%
# use this line to run the script directly in Jupyter
! sqlite3 econtop.db < create-econtop.sql

# %%
conn = sqlite3.connect("econtop.db")
cur = conn.cursor()

# %% [markdown]
# ### University Level

# %%
# select university level of publications
q = """
    SELECT af.affiliationid, af.name, art.journal, aa.doi
    FROM author_article AS aa JOIN author AS au JOIN article AS art JOIN affiliation AS af
    ON aa.authorid = au.authorid AND
    aa.doi = art.doi AND
    au.affiliationid = af.affiliationid
    WHERE art.date < '2010-01-01'
    """

# q = " SELECT authorid FROM author"
df_af_art = pd.read_sql_query(q, conn).set_index("doi")
len(df_af_art)
# Out:
# 5657

# %%
# show top appearance

# %%
id_pair = {}
name_pair = {}

for doi in df_af_art.index:
    try:
        df_af_art.loc[doi][0]
    except:
        df_af_art_new = df_af_art.loc[doi].sort_values("affiliationid")
        length = len(df_af_art_new)
        for i in range(length-1):
            for j in range(length-1-i):
                if df_af_art_new["affiliationid"][i] != "" and df_af_art_new["affiliationid"][i+j+1] != "":
                    try:
                        id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] += 1
                        name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] += 1
                    except:
                        id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] = 0
                        name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] = 0

# %%
name_pair_sorted = sorted(name_pair.items(), key=lambda x:x[1], reverse = True)
name_pair_sorted
# Out:
# [('Harvard University+Harvard University', 40),
#  ('Harvard University+Massachusetts Institute of Technology', 35),
#  ('Massachusetts Institute of Technology+Massachusetts Institute of Technology',
#   32),
#  ('Stanford University+Stanford University', 31),
#  ('Northwestern University+Princeton University', 26),
#  ('Massachusetts Institute of Technology+University of Chicago', 20),
#  ('University of Pennsylvania+University of Pennsylvania', 19),
#  ('University of Chicago+University of Chicago', 18),
#  ('Columbia University+Columbia University', 18),
#  ('Harvard University+University of California, Berkeley', 18),
#  ('Columbia University+University of Chicago', 16),
#  ('Harvard University+Yale University', 16),
#  ('Princeton University+University of California, Berkeley', 15),
#  ('Massachusetts Institute of Technology+Stanford University', 15),
#  ('Harvard University+Princeton University', 15),
#  ('New York University+Princeton University', 15),
#  ('Harvard University+New York University', 14),
#  ('Northwestern University+University of Chicago', 14),
#  ('New York University+University of Michigan', 14),
#  ('Harvard University+Stanford University', 14),
#  ('Bocconi University+London School of Economics', 13),
#  ('Hebrew University of Jerusalem+Tel Aviv University', 13),
#  ('Princeton University+Princeton University', 13),
#  ('Harvard University+University of Chicago', 13),
#  ('Northwestern University+University of California, Los Angeles', 13),
#  ('Harvard University+London School of Economics', 12),
#  ('Brown University+University of Warwick', 11),
#  ('University of California, Berkeley+University of California, Davis', 10),
#  ('HEC Paris+Toulouse School of Economics', 10),
#  ('Cornell University+Cornell University', 10),
#  ('Columbia University+University College London', 10),
#  ('London School of Economics+Massachusetts Institute of Technology', 10),
#  ('Northwestern University+Stanford University', 9),
#  ('London School of Economics+Northwestern University', 9),
#  ('Boston University+Massachusetts Institute of Technology', 9),
#  ('Duke University+Duke University', 9),
#  ('Columbia University+Princeton University', 9),
#  ('Northwestern University+Northwestern University', 9),
#  ('Brown University+Yale University', 9),
#  ('Stanford University+University of Minnesota', 9),
#  ('Brown University+London School of Economics', 9),
#  ('Princeton University+University of Chicago', 8),
#  ('University of Amsterdam+University of Amsterdam', 8),
#  ('Ohio State University+University of Pennsylvania', 8),
#  ('Yale University+Yale University', 8),
#  ('Hebrew University of Jerusalem+Stanford University', 8),
#  ('Boston University+Hebrew University of Jerusalem', 8),
#  ('New York University+New York University', 8),
#  ('Boston University+Columbia University', 8),
#  ('Pennsylvania State University+University of Wisconsin-Madison', 8),
#  ('Cornell University+London School of Economics', 8),
#  ('Massachusetts Institute of Technology+Toulouse School of Economics', 8),
#  ('University of Southern California+University of Southern California', 7),
#  ('University of Houston+University of Minnesota', 7),
#  ('Stanford University+University of California, Los Angeles', 7),
#  ('New York University+University of California, Berkeley', 7),
#  ('University of Michigan+University of Michigan', 7),
#  ('University of Chicago+University of Pennsylvania', 7),
#  ('Massachusetts Institute of Technology+Yale University', 7),
#  ('Massachusetts Institute of Technology+University of California, Berkeley',
#   7),
#  ('University of Lausanne+University of Zurich', 7),
#  ('London School of Economics+University of Pennsylvania', 7),
#  ('University of California, Berkeley+University of California, Berkeley', 7),
#  ('London School of Economics+University College London', 7),
#  ('University of California, Berkeley+University of Maryland', 7),
#  ('Brown University+SKEMA Business School', 7),
#  ('London School of Economics+London School of Economics', 7),
#  ('Massachusetts Institute of Technology+University of Southern California',
#   7),
#  ('Columbia University+New York University', 6),
#  ('Georgetown University+New York University', 6),
#  ('Bocconi University+Stockholm University', 6),
#  ('University of Chicago+University of California, Berkeley', 6),
#  ('Rice University+Seoul National University', 5),
#  ('Rice University+University of North Carolina at Chapel Hill', 5),
#  ('Seoul National University+University of North Carolina at Chapel Hill', 5),
#  ('University of California, Los Angeles+Yale University', 5),
#  ('Brigham Young University+Santa Clara University', 5),
#  ('London Business School+New York University', 5),
#  ('Singapore Management University+Washington University in St. Louis', 5),
#  ('London School of Economics+Princeton University', 5),
#  ('Hebrew University of Jerusalem+University of Rochester', 5),
#  ('Cornell University+Ohio State University', 5),
#  ('North Carolina State University+Pennsylvania State University', 5),
#  ('Georgetown University+Ohio State University', 5),
#  ('Duke University+清华大学', 5),
#  ('New York University+University of Oklahoma', 5),
#  ('McGill University+New York University', 5),
#  ('Brown University+University of Houston', 5),
#  ('University of Houston+University of Warwick', 5),
#  ('Stockholm University+University of Pennsylvania', 5),
#  ('Duke University+Pennsylvania State University', 5),
#  ('Georgetown University+VU University Amsterdam', 5),
#  ('Columbia University+Imperial College London', 5),
#  ('Imperial College London+Princeton University', 5),
#  ('Tel Aviv University+Tel Aviv University', 5),
#  ('Hebrew University of Jerusalem+University of Michigan', 5),
#  ('Stanford University+Yale University', 5),
#  ('Carnegie Mellon University+University of Virginia', 5),
#  ('Aalto University+University of Oregon', 5),
#  ('Northwestern University+Pennsylvania State University', 5),
#  ('Northwestern University+University of Wisconsin-Madison', 5),
#  ('Bocconi University+Rutgers University', 5),
#  ('London School of Economics+Rutgers University', 5),
#  ('Brandeis University+Stanford University', 5),
#  ('Columbia University+Georgetown University', 5),
#  ('Princeton University+University College London', 5),
#  ('University of Chicago+Yale University', 5),
#  ('Stockholm School of Economics+Stockholm University', 5),
#  ('University of British Columbia+University of California, Berkeley', 5),
#  ('Stanford University+University of Chicago', 5),
#  ('University College London+University of Pennsylvania', 5),
#  ('London School of Economics+University of California, Los Angeles', 5),
#  ('Boston University+Carnegie Mellon University', 5),
#  ('INSEAD+Stanford University', 5),
#  ('INSEAD+University College London', 5),
#  ('Stanford University+University College London', 5),
#  ('Dartmouth College+University of Chicago', 5),
#  ('Boston College+Harvard University', 5),
#  ('University of California, Los Angeles+University of California, Los Angeles',
#   5),
#  ('University of California, Los Angeles+University of Southern California',
#   5),
#  ('Bocconi University+HEC Paris', 5),
#  ('HEC Paris+London School of Economics', 5),
#  ('Princeton University+University of Pennsylvania', 5),
#  ('Harvard University+Hebrew University of Jerusalem', 5),
#  ('Massachusetts Institute of Technology+University of Pennsylvania', 5),
#  ('Ball State University+Cornell University', 5),
#  ('University of Missouri-Kansas City+Virginia Commonwealth University', 5),
#  ('Hebrew University of Jerusalem+Hebrew University of Jerusalem', 4),
#  ('London Business School+London Business School', 4),
#  ('Duke University+Medical University of South Carolina', 4),
#  ('INSEAD+Michigan State University', 4),
#  ('Columbia University+London School of Economics', 4),
#  ('Emory University+Interdisciplinary Center, Herzliya', 4),
#  ('Brigham Young University+Brigham Young University', 4),
#  ('EDHEC Business School+University of British Columbia', 4),
#  ('Duke University+University of Pennsylvania', 4),
#  ('Columbia University+Yale University', 4),
#  ('Stanford University+University of Rochester', 4),
#  ('INSEAD+University of Illinois at Chicago', 4),
#  ('University of California, Irvine+University of Texas at Austin', 4),
#  ('University of California, Berkeley+University of North Carolina at Chapel Hill',
#   4),
#  ('HEC Paris+Massachusetts Institute of Technology', 4),
#  ('HEC Paris+Harvard University', 4),
#  ('Harvard University+London Business School', 4),
#  ('Massachusetts Institute of Technology+Northwestern University', 4),
#  ('Columbia University+Toulouse School of Economics', 4),
#  ('Georgetown University+Georgetown University', 4),
#  ('University of British Columbia+香港大学', 4),
#  ('University of Toronto+香港大学', 4),
#  ('California Institute of Technology+HEC Paris', 4),
#  ('University of California, Berkeley+World Bank', 4),
#  ('Brown University+Cornell University', 4),
#  ('University of Wisconsin-Madison+Yale University', 4),
#  ('Pennsylvania State University+University of Iowa', 4),
#  ('CGIAR: Consultative Group for International Agricultural Research+University of Florida',
#   4),
#  ('London School of Economics+University of Chicago', 4),
#  ('University of Bonn+University of Zurich', 4),
#  ('Boston University+Federal Reserve Bank of Richmond', 4),
#  ('University of California, San Diego+University of Michigan', 4),
#  ('Northwestern University+University of Pennsylvania', 4),
#  ('Massachusetts Institute of Technology+Princeton University', 4),
#  ('Pennsylvania State University+Princeton University', 4),
#  ('Emory University+University of Georgia', 4),
#  ('Columbia University+Harvard University', 3),
#  ('American University+University of California, Davis', 3),
#  ('University of Texas at San Antonio+University of Utah', 3),
#  ('Tulane University+University of Pittsburgh', 3),
#  ('University of California, Los Angeles+南洋理工大学', 3),
#  ('Copenhagen Business School+Washington University in St. Louis', 3),
#  ('Emory University+Federal Reserve Bank of New York', 3),
#  ('Singapore Management University+Yale University', 3),
#  ('Columbia University+University of California, Berkeley', 3),
#  ('Imperial College London+Pompeu Fabra University', 3),
#  ('Korea Advanced Institute of Science and Technology+University of Illinois at Urbana-Champaign',
#   3),
#  ('Emory University+University at Buffalo', 3),
#  ('London Business School+Massachusetts Institute of Technology', 3),
#  ('Interdisciplinary Center, Herzliya+New York University', 3),
#  ('Columbia University+Stanford University', 3),
#  ('Duke University+University of California, Los Angeles', 3),
#  ('Copenhagen Business School+Simon Fraser University', 3),
#  ('New York University+University of Pennsylvania', 3),
#  ('Imperial College London+Johns Hopkins University', 3),
#  ('Paris School of Economics+University of Oxford', 3),
#  ('Federal Reserve Bank of New York+University of Bern', 3),
#  ('University of California, Berkeley+University of California, San Diego', 3),
#  ('香港中文大学+香港大学', 3),
#  ('Bocconi University+Harvard University', 3),
#  ('Georgetown University+University of Cambridge', 3),
#  ('Johns Hopkins University+University of California, Berkeley', 3),
#  ('University of Minnesota+University of Pennsylvania', 3),
#  ('University of California, San Diego+University of California, San Diego',
#   3),
#  ('Harvard University+University of Auckland', 3),
#  ('University College London+University of California, Berkeley', 3),
#  ('Princeton University+Toulouse School of Economics', 3),
#  ('Autonomous University of Barcelona+Universidad Carlos III de Madrid', 3),
#  ('Boston University+New York University', 3),
#  ('California Institute of Technology+Stanford University', 3),
#  ('Columbia University+Paris School of Economics', 3),
#  ("Queen's University+University of Illinois at Urbana-Champaign", 3),
#  ('London Business School+Pennsylvania State University', 3),
#  ('London School of Economics+Yale University', 3),
#  ('Aalto University+Yale University', 3),
#  ('Ecole des Ponts ParisTech+University of Bonn', 3),
#  ('Imperial College London+Yale University', 3),
#  ('University of California, Los Angeles+University of Pennsylvania', 3),
#  ('INSEAD+Imperial College London', 3),
#  ('Carnegie Mellon University+Duke University', 3),
#  ('Stanford University+University of California, San Diego', 3),
#  ('Michigan State University+Michigan State University', 3),
#  ('University of Padova+Yale University', 3),
#  ('Harvard University+University of Pennsylvania', 3),
#  ('Georgia Institute of Technology+University of Notre Dame', 3),
#  ('New York University+Stanford University', 3),
#  ('London School of Economics+Paris School of Economics', 3),
#  ('Johns Hopkins University+Pennsylvania State University', 3),
#  ('ENSAE ParisTech+University College London', 3),
#  ('London School of Economics+University of Mannheim', 3),
#  ('University of Peradeniya+World Bank', 3),
#  ('INSEAD+University of California, Berkeley', 3),
#  ('Harvard University+University of Maryland', 3),
#  ('University of Alabama+University of Chicago', 3),
#  ('University of Alabama+University of Georgia', 3),
#  ('University of Alabama+University of Hamburg', 3),
#  ('University of Chicago+University of Georgia', 3),
#  ('University of Chicago+University of Hamburg', 3),
#  ('University of Georgia+University of Hamburg', 3),
#  ('New York University+University of California, Los Angeles', 3),
#  ('Stanford University+University of California, Berkeley', 3),
#  ('Bocconi University+New York University', 3),
#  ('London School of Economics+SKEMA Business School', 3),
#  ('Autonomous University of Barcelona+Stanford University', 3),
#  ('London School of Economics+Stanford University', 3),
#  ('Cornell University+Massachusetts Institute of Technology', 3),
#  ('Harvard University+Resources for the Future, Washington DC', 3),
#  ('Harvard University+University of California, Los Angeles', 3),
#  ('Imperial College London+University of California, Berkeley', 3),
#  ('California Institute of Technology+Carnegie Mellon University', 3),
#  ('Dartmouth College+Harvard University', 3),
#  ('University of Maryland+University of Notre Dame', 3),
#  ('Harvard University+Johns Hopkins University', 3),
#  ('Federal Reserve Bank of Chicago+Massachusetts Institute of Technology', 3),
#  ('Northwestern University+University of Minnesota', 3),
#  ('Bar-Ilan University+McGill University', 3),
#  ('University of Cyprus+University of Guelph', 3),
#  ('University of Stavanger+Yale University', 3),
#  ('European University Institute+University of Oxford', 3),
#  ('Washington University in St. Louis+Washington University in St. Louis', 3),
#  ('Aston University+George Mason University', 3),
#  ('Aston University+London School of Economics', 3),
#  ('George Mason University+London School of Economics', 3),
#  ('Columbia University+Massachusetts Institute of Technology', 3),
#  ('Toulouse School of Economics+University of Minnesota', 3),
#  ('Duke University+Northwestern University', 3),
#  ('University of New South Wales+University of Western Ontario', 3),
#  ('New York University+Washington University in St. Louis', 3),
#  ('Federal Reserve Bank of Dallas+University of Pennsylvania', 3),
#  ('University of Pennsylvania+Washington University in St. Louis', 3),
#  ('Columbia University+HEC Paris', 2),
#  ('Columbia University+University of Virginia', 2),
#  ('HEC Paris+University of Virginia', 2),
#  ('Lancaster University+University of Lausanne', 2),
#  ('Lancaster University+University of Manchester', 2),
#  ('University of Lausanne+University of Manchester', 2),
#  ('Babson College+University of Alabama', 2),
#  ('Babson College+University of Colorado, Boulder', 2),
#  ('University of Alabama+University of Colorado, Boulder', 2),
#  ('University of California, Irvine+University of Oregon', 2),
#  ('University of California, Irvine+University of Texas at Dallas', 2),
#  ('University of Oregon+University of Texas at Dallas', 2),
#  ('London Business School+University of Michigan', 2),
#  ('London Business School+University of Texas at Austin', 2),
#  ('University of Michigan+University of Texas at Austin', 2),
#  ('Bank for International Settlements+Imperial College London', 2),
#  ('Bank for International Settlements+Massachusetts Institute of Technology',
#   2),
#  ('Imperial College London+Massachusetts Institute of Technology', 2),
#  ('Emory University+University of Lausanne', 2),
#  ('Interdisciplinary Center, Herzliya+University of Lausanne', 2),
#  ('Rice University+University of California, Davis', 2),
#  ('California Institute of Technology+EDHEC Business School', 2),
#  ('California Institute of Technology+University of British Columbia', 2),
#  ('Ohio State University+University of Melbourne', 2),
#  ('Ohio State University+University of Texas at Austin', 2),
#  ('University of Melbourne+University of Texas at Austin', 2),
#  ('Claremont McKenna College+Rice University', 2),
#  ('Claremont McKenna College+University of California, Los Angeles', 2),
#  ('Rice University+University of California, Los Angeles', 2),
#  ('Medical University of South Carolina+University of Pennsylvania', 2),
#  ('University of Minnesota+University of Minnesota', 2),
#  ('HEC Paris+University of Mannheim', 2),
#  ('Cornell University+Singapore Management University', 2),
#  ('Cornell University+Washington University in St. Louis', 2),
#  ('Columbia University+清华大学', 2),
#  ('Yale University+清华大学', 2),
#  ('Boston University+California Institute of Technology', 2),
#  ('California Institute of Technology+Hebrew University of Jerusalem', 2),
#  ('Arizona State University+Duke University', 2),
#  ('Arizona State University+University of Oxford', 2),
#  ('Duke University+University of Oxford', 2),
#  ('Texas A&M University+University of Houston', 2),
#  ('Texas A&M University+Wichita State University', 2),
#  ('University of Houston+Wichita State University', 2),
#  ('University of Oregon+Vienna University of Economics and Business', 2),
#  ('University of Oregon+Vienna University of Technology', 2),
#  ('Vienna University of Economics and Business+Vienna University of Technology',
#   2),
#  ('Indian School of Business+Michigan State University', 2),
#  ('Indian School of Business+University of Oxford', 2),
#  ('Michigan State University+University of Oxford', 2),
#  ('University of British Columbia+上海交通大学', 2),
#  ('Pennsylvania State University+Pennsylvania State University', 2),
#  ('University of Basel+University of Zurich', 2),
#  ('Imperial College London+University of California, Irvine', 2),
#  ('Imperial College London+University of Texas at Austin', 2),
#  ('Princeton University+University of North Carolina at Chapel Hill', 2),
#  ('University of California, Berkeley+上海交通大学', 2),
#  ('University of California, Davis+上海交通大学', 2),
#  ('HEC Paris+HEC Paris', 2),
#  ('Texas A&M University+University of Iowa', 2),
#  ('Texas A&M University+University of Mississippi', 2),
#  ('University of Iowa+University of Mississippi', 2),
#  ('New York University+University of Notre Dame', 2),
#  ('Rice University+University of Alabama', 2),
#  ('Rice University+University of Tennessee', 2),
#  ('University of Alabama+University of Tennessee', 2),
#  ('Southern Methodist University+University of Georgia', 2),
#  ('Southern Methodist University+University of South Florida', 2),
#  ('University of Georgia+University of South Florida', 2),
#  ('University of Chicago+University of Utah', 2),
#  ('University of Chicago+University of Virginia', 2),
#  ('University of Utah+University of Virginia', 2),
#  ('International Institute for Management Development, Lausanne+University of Calgary',
#   2),
#  ('Ohio State University+Ohio State University', 2),
#  ('London Business School+University of Oxford', 2),
#  ('Hebrew University of Jerusalem+University of California, San Diego', 2),
#  ('University of California, San Diego+University of Rochester', 2),
#  ('Imperial College London+University of Cambridge', 2),
#  ('Imperial College London+University of Guelph', 2),
#  ('University of Cambridge+University of Guelph', 2),
#  ('Case Western Reserve University+Singapore Management University', 2),
#  ('Case Western Reserve University+Washington University in St. Louis', 2),
#  ('Ohio State University+University of California, Berkeley', 2),
#  ('Michigan State University+University of Illinois at Chicago', 2),
#  ('HEC Paris+London Business School', 2),
#  ('Arizona State University+Georgetown University', 2),
#  ('Arizona State University+New York University', 2),
#  ('HEC Paris+University of California, Berkeley', 2),
#  ('International Monetary Fund+Princeton University', 2),
#  ('International Monetary Fund+University of Minnesota', 2),
#  ('Princeton University+University of Minnesota', 2),
#  ('Stockholm University+Stockholm University', 2),
#  ('Boston University+University of Chicago', 2),
#  ('HEC Paris+Sciences Po', 2),
#  ('Sciences Po+Toulouse School of Economics', 2),
#  ('Toulouse School of Economics+University College London', 2),
#  ('Erasmus University Rotterdam+University of Lausanne', 2),
#  ('Erasmus University Rotterdam+University of Zurich', 2),
#  ('University of British Columbia+University of Toronto', 2),
#  ('Emory University+Seoul National University', 2),
#  ('Emory University+University of Cambridge', 2),
#  ('Seoul National University+University of Cambridge', 2),
#  ('Keio University+University of Notre Dame', 2),
#  ('Keio University+University of Texas at Dallas', 2),
#  ('University of Notre Dame+University of Texas at Dallas', 2),
#  ('Carnegie Mellon University+Carnegie Mellon University', 2),
#  ('Harvard University+University of Cambridge', 2),
#  ('University of Cambridge+Yale University', 2),
#  ('California Institute of Technology+University of Zurich', 2),
#  ('HEC Paris+University of Zurich', 2),
#  ('Brandeis University+Massachusetts Institute of Technology', 2),
#  ("Indiana University+Queen's University", 2),
#  ('Indiana University+University of California, Davis', 2),
#  ("Queen's University+University of California, Davis", 2),
#  ('National Institute of Economic and Social Research+University of Pittsburgh',
#   2),
#  ('University of California, Berkeley+University of California, Santa Cruz',
#   2),
#  ('EDHEC Business School+Harvard University', 2),
#  ('EDHEC Business School+Stockholm School of Economics', 2),
#  ('Harvard University+Stockholm School of Economics', 2),
#  ('Central European University+Harvard University', 2),
#  ('Central European University+University of California, Berkeley', 2),
#  ('New York University+Stockholm School of Economics', 2),
#  ('New York University+University of California, San Diego', 2),
#  ('Stockholm School of Economics+University of California, San Diego', 2),
#  ('Dartmouth College+University of Michigan', 2),
#  ('Dartmouth College+University of Utah', 2),
#  ('University of Michigan+University of Utah', 2),
#  ('Brookings Institution+Massachusetts Institute of Technology', 2),
#  ('University of Bonn+University of Lausanne', 2),
#  ('Stockholm University+University of Amsterdam', 2),
#  ('Stockholm University+University of Gothenburg', 2),
#  ('University of Amsterdam+University of Gothenburg', 2),
#  ('Brown University+Center for Monetary and Financial Studies (CEMFI)', 2),
#  ('Center for Monetary and Financial Studies (CEMFI)+London School of Economics',
#   2),
#  ('Brandeis University+Harvard University', 2),
#  ('New York University+Queen Mary University of London', 2),
#  ('New York University+University College London', 2),
#  ('Queen Mary University of London+University College London', 2),
#  ('Center for Monetary and Financial Studies (CEMFI)+New York University', 2),
#  ('Center for Monetary and Financial Studies (CEMFI)+Simon Fraser University',
#   2),
#  ('New York University+Simon Fraser University', 2),
#  ('Boston College+Boston College', 2),
#  ('Graduate Institute of International and Development Studies+Hebrew University of Jerusalem',
#   2),
#  ('Graduate Institute of International and Development Studies+International Monetary Fund',
#   2),
#  ('Hebrew University of Jerusalem+International Monetary Fund', 2),
#  ('Monash University+Texas A&M University', 2),
#  ('Monash University+Virginia Polytechnic Institute and State University', 2),
#  ('Texas A&M University+Virginia Polytechnic Institute and State University',
#   2),
#  ('Centre de Recerca en Economia Internacional+Columbia University', 2),
#  ('Centre de Recerca en Economia Internacional+New York University', 2),
#  ('Boston University+Federal Reserve Bank of Philadelphia', 2),
#  ('Federal Reserve Bank of Philadelphia+Federal Reserve Bank of Richmond', 2),
#  ('Dartmouth College+Massachusetts Institute of Technology', 2),
#  ('Dartmouth College+Wellesley College', 2),
#  ('Massachusetts Institute of Technology+Wellesley College', 2),
#  ('London School of Economics+University of California, San Diego', 2),
#  ('London School of Economics+University of Michigan', 2),
#  ('Birkbeck, University of London+University of Nottingham', 2),
#  ('Birkbeck, University of London+University of Southern California', 2),
#  ('University of Nottingham+University of Southern California', 2),
#  ('Bocconi University+University of California, Berkeley', 2),
#  ('Stockholm University+University of California, Berkeley', 2),
#  ('Bar-Ilan University+University of Minnesota', 2),
#  ('Bar-Ilan University+University of Southern California', 2),
#  ('University of Minnesota+University of Southern California', 2),
#  ('National Graduate Institute for Policy Studies+University of Exeter', 2),
#  ('National Graduate Institute for Policy Studies+University of KwaZulu-Natal',
#   2),
#  ('University of Exeter+University of KwaZulu-Natal', 2),
#  ('University of California, San Diego+University of Wisconsin-Madison', 2),
#  ('University of Kentucky+University of Notre Dame', 2),
#  ('Pennsylvania State University+Wayne State University', 2),
#  ('University of Iowa+Wayne State University', 2),
#  ('Columbia University+Georgia State University', 2),
#  ('Georgia State University+London School of Economics', 2),
#  ('Pennsylvania State University+University of Colorado, Boulder', 2),
#  ('Princeton University+University of Colorado, Boulder', 2),
#  ('CGIAR: Consultative Group for International Agricultural Research+University of Maryland',
#   2),
#  ('University of Florida+University of Maryland', 2),
#  ('National Research Council of Italy+Sapienza University of Rome', 2),
#  ('National Research Council of Italy+University of Bari', 2),
#  ('Sapienza University of Rome+University of Bari', 2),
#  ('Boston College+University College London', 2),
#  ('Boston College+University of Maryland', 2),
#  ('University College London+University of Maryland', 2),
#  ('Pennsylvania State University+University of Bristol', 2),
#  ('University of Bristol+University of Wisconsin-Madison', 2),
#  ('Corvinus University of Budapest+George Mason University', 2),
#  ('Corvinus University of Budapest+U.S. Census Bureau', 2),
#  ('George Mason University+U.S. Census Bureau', 2),
#  ('LUISS Guido Carli+Stanford University', 2),
#  ('Erasmus University Rotterdam+University of Amsterdam', 2),
#  ('Erasmus University Rotterdam+University of New South Wales', 2),
#  ('University of Amsterdam+University of New South Wales', 2),
#  ('Michigan State University+University of Wisconsin-Madison', 2),
#  ('Michigan State University+Yale University', 2),
#  ('Massachusetts Institute of Technology+Ohio State University', 2),
#  ('London School of Economics+University of California, Berkeley', 2),
#  ('Australian National University+Monash University', 2),
#  ('Australian National University+University of Toronto', 2),
#  ('Monash University+University of Toronto', 2),
#  ('University of Florida+University of Pittsburgh', 2),
#  ('University of Florida+University of Pennsylvania', 2),
#  ('University of Pittsburgh+University of Pennsylvania', 2),
#  ('International Monetary Fund+University of California, Berkeley', 2),
#  ('International Monetary Fund+World Bank', 2),
#  ('Emory University+University of Iowa', 2),
#  ('Johns Hopkins University+University of New South Wales', 2),
#  ('Virginia Commonwealth University+Virginia Commonwealth University', 2),
#  ('Temple University+University of Massachusetts, Amherst', 1),
#  ('Carnegie Mellon University+University of California, Berkeley', 1),
#  ('EDHEC Business School+Santa Clara University', 1),
#  ('Indiana University+University of North Carolina at Charlotte', 1),
#  ('Stevens Institute of Technology+University of Texas at Dallas', 1),
#  ('New York University+University of Texas at Austin', 1),
#  ('Rice University+Rice University', 1),
#  ('Kobe University+University of California, Riverside', 1),
#  ('Emory University+Vanderbilt University', 1),
#  ('Ohio State University+Yale University', 1),
#  ('Hebrew University of Jerusalem+Nazarbayev University', 1),
#  ('Northern Illinois University+University of North Carolina at Chapel Hill',
#   1),
#  ('Nova School of Business and Economics+University of Lausanne', 1),
#  ('Dartmouth College+香港科技大学', 1),
#  ('Harvard University+Santa Clara University', 1),
#  ('Washington State University+York University', 1),
#  ('HEC Paris+Washington University in St. Louis', 1),
#  ('Duke University+New York University', 1),
#  ('Hebrew University of Jerusalem+University of Colorado, Boulder', 1),
#  ('University of Amsterdam+Washington University in St. Louis', 1),
#  ('Northwestern University+University of Maryland', 1),
#  ('Kennesaw State University+University of Oxford', 1),
#  ('Boston College+University of Southern California', 1),
#  ('Rutgers University+Tulane University', 1),
#  ('International Institute for Management Development, Lausanne+Purdue University',
#   1),
#  ('University of Tennessee+University of Virginia', 1),
#  ('Hanken School of Economics+University of Michigan', 1),
#  ('Federal Reserve Bank of Cleveland+Federal Reserve Bank of Philadelphia', 1),
#  ('Michigan State University+University of Illinois at Urbana-Champaign', 1),
#  ('Goethe University Frankfurt+New York University', 1),
#  ('HEC Paris+University of Lugano', 1),
#  ('Cornell University+University of Illinois at Urbana-Champaign', 1),
#  ('Boston University+London Business School', 1),
#  ('University of Pittsburgh+University of Pittsburgh', 1),
#  ('University of California, Riverside+University of Michigan', 1),
#  ('US Federal Reserve Board+University of Michigan', 1),
#  ('Stanford University+Washington University in St. Louis', 1),
#  ('Northwestern University+Washington University in St. Louis', 1),
#  ('Imperial College London+London Business School', 1),
#  ('Claremont McKenna College+INSEAD', 1),
#  ('上海交通大学+香港科技大学', 1),
#  ('University of Montreal+University of Massachusetts, Amherst', 1),
#  ('Harvard University+Imperial College London', 1),
#  ('Bocconi University+University of California, San Diego', 1),
#  ('Duke University+Federal Reserve Bank of Atlanta', 1),
#  ('University of Naples Federico II+Vienna University of Economics and Business',
#   1),
#  ('European Commission, Joint Research Centre+University of California, Berkeley',
#   1),
#  ('Albert Einstein College of Medicine+Rutgers University', 1),
#  ('Rice University+University of Houston', 1),
#  ('Arizona State University+Brigham Young University', 1),
#  ('University of Lugano+University of Lugano', 1),
#  ('George Washington University+World Bank', 1),
#  ('Cornell University+Iowa State University', 1),
#  ('Tilburg University+University of Notre Dame', 1),
#  ('London School of Economics+Rice University', 1),
#  ('Georgia Institute of Technology+University of Chicago', 1),
#  ('Johns Hopkins University+University of Southern California', 1),
#  ('Lehigh University+Singapore Management University', 1),
#  ('University of Texas at Dallas+Washington University in St. Louis', 1),
#  ('University of California, Davis+北京大学', 1),
#  ('University of North Carolina at Chapel Hill+University of Texas at Austin',
#   1),
#  ('Harvard University+Tel Aviv University', 1),
#  ('Duke University+Rice University', 1),
#  ('City University of New York+New York University', 1),
#  ('Columbia University+Indiana University', 1),
#  ('Korea University+University of California, Davis', 1),
#  ('INSEAD+INSEAD', 1),
#  ('Bank for International Settlements+Brandeis University', 1),
#  ('Pontifical Catholic University of Chile+Universidad de los Andes, Santiago',
#   1),
#  ('National University of Singapore+University of Toronto', 1),
#  ('University of Pennsylvania+University of Virginia', 1),
#  ('IESE Business School+Nova School of Business and Economics', 1),
#  ('Interdisciplinary Center, Herzliya+University of Victoria', 1),
#  ('EDHEC Business School+Imperial College London', 1),
#  ('Copenhagen Business School+Princeton University', 1),
#  ('New York University+Rutgers University', 1),
#  ('BI Norwegian Business School+University of Haifa', 1),
#  ('Arizona State University+University of Michigan', 1),
#  ('Georgia Institute of Technology+University of California, Berkeley', 1),
#  ('Texas A&M University+University of South Carolina', 1),
#  ('INSEAD+University of California, Davis', 1),
#  ('Singapore Management University+University of Tennessee', 1),
#  ('Arizona State University+University of Arizona', 1),
#  ('European Commission, Joint Research Centre+Stockholm School of Economics',
#   1),
#  ('DePaul University+Princeton University', 1),
#  ('Chapman University+Swiss Federal Institute of Technology in Lausanne', 1),
#  ('International Monetary Fund+University of Washington', 1),
#  ('Indiana University+London School of Economics', 1),
#  ('University of Iowa+University of Iowa', 1),
#  ('Indiana University+University of North Carolina at Chapel Hill', 1),
#  ('Columbia University+University of California, Los Angeles', 1),
#  ('Babson College+Texas Christian University', 1),
#  ('North Carolina State University+Vanderbilt University', 1),
#  ('Chung-Ang University+Indiana University', 1),
#  ('Boston University+University of Minnesota', 1),
#  ('University of California, Santa Barbara+University of California, Santa Cruz',
#   1),
#  ('Tilburg University+Tilburg University', 1),
#  ('Yale University+香港中文大学', 1),
#  ('Pompeu Fabra University+University College London', 1),
#  ('George Mason University+Stanford University', 1),
#  ('Pompeu Fabra University+University of Munich', 1),
#  ('American University of Sharjah+London School of Economics', 1),
#  ('University of Toronto+Washington University in St. Louis', 1),
#  ('Birkbeck, University of London+University College London', 1),
#  ('Northwestern University+Tel Aviv University', 1),
#  ('World Bank+World Bank', 1),
#  ('Johns Hopkins University+Northwestern University', 1),
#  ('Johns Hopkins University+University of Chicago', 1),
#  ('European University Institute+Federal Reserve Bank of San Francisco', 1),
#  ('Pennsylvania State University+University of Mannheim', 1),
#  ('National University of Singapore+University of Wisconsin-Madison', 1),
#  ('Toulouse School of Economics+University of Pennsylvania', 1),
#  ('Duke University+University of Wisconsin-Madison', 1),
#  ('Google Inc.+University of Texas at Austin', 1),
#  ('Northwestern University+University College London', 1),
#  ('New York University+University of Texas at Dallas', 1),
#  ('McGill University+Stanford University', 1),
#  ('University of Texas at Austin+University of Texas at Austin', 1),
#  ('University of New South Wales+Washington University in St. Louis', 1),
#  ('Boston College+University of Rochester', 1),
#  ('Dartmouth College+Princeton University', 1),
#  ('Universidad Carlos III de Madrid+University of Southern California', 1),
#  ('Bocconi University+Princeton University', 1),
#  ('University of St. Gallen+University of Zurich', 1),
#  ('Brandeis University+University of Southern California', 1),
#  ('Monash University+University of California, Irvine', 1),
#  ('HEC Paris+Politecnico di Torino', 1),
#  ('Monash University+University of Auckland', 1),
#  ('University of California, Davis+University of Mannheim', 1),
#  ('LUISS Guido Carli+University of Texas at Austin', 1),
#  ('London Business School+University of Bonn', 1),
#  ('University of Pittsburgh+University of Rochester', 1),
#  ("Imperial College London+King's College London", 1),
#  ('Massachusetts Institute of Technology+University of Tokyo', 1),
#  ('University of Murcia+Washington University in St. Louis', 1),
#  ('Collegio Carlo Alberto+International Monetary Fund', 1),
#  ('Bocconi University+Centre de Recerca en Economia Internacional', 1),
#  ('Cornell University+Kansas State University', 1),
#  ('Hebrew University of Jerusalem+University of Chicago', 1),
#  ('Bocconi University+University of Bologna', 1),
#  ('KTH Royal Institute of Technology+Statistics Norway', 1),
#  ('University College London+Yale University', 1),
#  ('University of Tokyo+University of Warwick', 1),
#  ('Brown University+Iowa State University', 1),
#  ('University of Basel+University of California, Irvine', 1),
#  ('University of Florence+University of Florence', 1),
#  ('Ecole des Ponts ParisTech+Ecole des Ponts ParisTech', 1),
#  ('Stanford University+University of Washington', 1),
#  ('Sciences Po+University of Western Ontario', 1),
#  ('Boston College+University of California, Los Angeles', 1),
#  ('Rutgers University+Williams College', 1),
#  ('University of Minnesota+University of Pittsburgh', 1),
#  ('University of British Columbia+University of Wisconsin-Madison', 1),
#  ('Swiss Federal Institute of Technology in Lausanne+Washington University in St. Louis',
#   1),
#  ('University of British Columbia+Yale-NUS College', 1),
#  ('Simon Fraser University+Simon Fraser University', 1),
#  ('Duke University+State University of New York at Stony Brook', 1),
#  ('University College London+University of Surrey', 1),
#  ('Boston College+Tufts University', 1),
#  ('University of California, Berkeley+University of Edinburgh', 1),
#  ('Katholieke Universiteit, Leuven+Yale University', 1),
#  ('Northwestern University+香港科技大学', 1),
#  ('Paris School of Economics+Queen Mary University of London', 1),
#  ('University of Pennsylvania+University of Rochester', 1),
#  ('University of British Columbia+University of Victoria', 1),
#  ('University of California, Berkeley+University of Nottingham', 1),
#  ('Toulouse School of Economics+University of Southern California', 1),
#  ('London School of Economics+Universidad Carlos III de Madrid', 1),
#  ('Brigham Young University+University of Iowa', 1),
#  ('Arizona State University+University of Manchester', 1),
#  ('Federal Reserve Bank of Chicago+University of Chicago', 1),
#  ('Pompeu Fabra University+Washington State University', 1),
#  ('European University Institute+Kyoto University', 1),
#  ('Harvard University+Washington University in St. Louis', 1),
#  ('American University+Columbia University', 1),
#  ('Birkbeck, University of London+University of Birmingham', 1),
#  ('Northwestern University+University of Tokyo', 1),
#  ('American University of Beirut+Carnegie Mellon University', 1),
#  ('National University of Singapore+World Bank', 1),
#  ('IESE Business School+Korea University', 1),
#  ('Brown University+Pennsylvania State University', 1),
#  ('Boston College+University of Oxford', 1),
#  ('Northwestern University+University at Buffalo', 1),
#  ('McGill University+University of Toronto', 1),
#  ('Weierstrass Institute for Applied Analysis and Stochastics+Weierstrass Institute for Applied Analysis and Stochastics',
#   1),
#  ('University of British Columbia+University of Montreal', 1),
#  ('Northwestern University+New York University', 1),
#  ('Massachusetts Institute of Technology+University of Wisconsin-Madison', 1),
#  ('McMaster University+University of Notre Dame', 1),
#  ('Harvard University+Universidad Carlos III de Madrid', 1),
#  ('Centre de Recerca en Economia Internacional+London School of Economics', 1),
#  ('Federal Reserve Bank of Philadelphia+Pennsylvania State University', 1),
#  ('Indiana University+Texas A&M University', 1),
#  ('University of Bath+University of Oxford', 1),
#  ('Massachusetts Institute of Technology+Stockholm School of Economics', 1),
#  ('New York University+University of Warwick', 1),
#  ('Center for Monetary and Financial Studies (CEMFI)+Yale University', 1),
#  ('Massachusetts Institute of Technology+University of Minnesota', 1),
#  ('Johns Hopkins University+Rutgers University', 1),
#  ('University of Bern+University of California, San Diego', 1),
#  ('University of Michigan+University of Montreal', 1),
#  ('Indian Statistical Institute+University of Warwick', 1),
#  ('Center for Monetary and Financial Studies (CEMFI)+Massachusetts Institute of Technology',
#   1),
#  ('University of Birmingham+University of Warwick', 1),
#  ('Tilburg University+University of Basel', 1),
#  ('Northwestern University+University of Melbourne', 1),
#  ('University of Guelph+University of Minnesota', 1),
#  ('Ben-Gurion University of the Negev+University of Pennsylvania', 1),
#  ('University of British Columbia+University of New Orleans', 1),
#  ('University of California, Irvine+Vassar College', 1),
#  ('California Institute of Technology+University of California, San Diego', 1),
#  ('Erasmus University Rotterdam+Monash University', 1),
#  ('Boston University+University of Oxford', 1),
#  ('University of East Anglia+University of Warwick', 1),
#  ('IESE Business School+University of Toronto', 1),
#  ('Ohio State University+University of Missouri', 1),
#  ('Pompeu Fabra University+Toulouse School of Economics', 1),
#  ('Bocconi University+Graduate Institute of International and Development Studies',
#   1),
#  ('Arizona State University+Columbia University', 1),
#  ('Pennsylvania State University+University of British Columbia', 1),
#  ('University of Chicago+University of Florida', 1),
#  ('University of British Columbia+University of British Columbia', 1),
#  ('University College London+University of Zurich', 1),
#  ('University of Maryland+University of Maryland', 1),
#  ("McGill University+Queen's University", 1),
#  ('University of California, Berkeley+University of Illinois at Urbana-Champaign',
#   1),
#  ('McGill University+Simon Fraser University', 1),
#  ('University of Warwick+Washington University in St. Louis', 1),
#  ('Princeton University+University of Warwick', 1),
#  ('University of Oxford+University of Southampton', 1),
#  ('Harvard University+University of Warwick', 1),
#  ('University of Cambridge+University of Cambridge', 1),
#  ('Stanford University+University of Western Ontario', 1),
#  ('Indiana University+University of Oxford', 1),
#  ('Simon Fraser University+University of Melbourne', 1),
#  ('Columbia University+Cornell University', 1),
#  ('Columbia University+Stockholm University', 1),
#  ('Microsoft Corporation+University of Michigan', 1),
#  ('University of California, Los Angeles+University of Melbourne', 1),
#  ('Case Western Reserve University+Harvard University', 1),
#  ('Microsoft Corporation+Northwestern University', 1),
#  ('Monash University+University of Munich', 1),
#  ('Duke University+University of Gothenburg', 1),
#  ('Federal Reserve Bank of St. Louis+University of California, Los Angeles',
#   1),
#  ('California Institute of Technology+Texas A&M University', 1),
#  ('Montana State University+University of Chicago', 1),
#  ('International Monetary Fund+Massachusetts Institute of Technology', 1),
#  ('Cornell University+University of Pennsylvania', 1),
#  ('Massachusetts Institute of Technology+University of Notre Dame', 1),
#  ('Federal Reserve Bank of Boston+U.S. Census Bureau', 1),
#  ('Stanford University+University of Pittsburgh', 1),
#  ('Dartmouth College+London School of Economics', 1),
#  ('Cornell University+University of Chicago', 1),
#  ('Central European University+London School of Economics', 1),
#  ('Monash University+University of Rochester', 1),
#  ('Columbia University+IE University', 1),
#  ('Columbia University+University College Dublin', 1),
#  ('IE University+University of Chicago', 1),
#  ('University of California, Santa Barbara+University of Toronto', 1),
#  ('Boston University+Harvard University', 1),
#  ('Harvard University+IE University', 1),
#  ('Dartmouth College+Google Inc.', 1),
#  ('Boston College+Dartmouth College', 1),
#  ('George Mason University+University of Missouri', 1),
#  ('Centre de Recerca en Economia Internacional+Harvard University', 1),
#  ('Harvard University+University of Nottingham', 1),
#  ('Purdue University+Rutgers University', 1),
#  ('Harvard University+University of Washington', 1),
#  ('Goethe University Frankfurt+Goethe University Frankfurt', 1),
#  ('Pompeu Fabra University+University of Calgary', 1),
#  ('Harvard University+University of California, Davis', 1),
#  ('Boston College+Federal Reserve Bank of New York', 1),
#  ('University of Murcia+University of Mannheim', 1),
#  ('Aalto University+Stockholm University', 1),
#  ('Carnegie Mellon University+Cornell University', 1),
#  ('Harvard University+SKEMA Business School', 1),
#  ('D. E. Shaw Research+Massachusetts Institute of Technology', 1),
#  ('ENSAE ParisTech+University of Chicago', 1),
#  ('University of British Columbia+University of Namur', 1),
#  ('US Federal Reserve Board+University of Illinois at Urbana-Champaign', 1),
#  ('Central European University+Massachusetts Institute of Technology', 1),
#  ('University of Minnesota+Yale University', 1),
#  ('European University Institute+Federal Reserve Bank of New York', 1),
#  ('Dartmouth College+Stanford University', 1),
#  ('University of Chicago+University of California, Irvine', 1),
#  ('Tel Aviv University+University of California, San Diego', 1),
#  ('Centre de Recerca en Economia Internacional+World Bank', 1),
#  ('Massachusetts Institute of Technology+University of Lausanne', 1),
#  ('Central European University+Santa Fe Institute', 1),
#  ('Duke University+Georgetown University', 1),
#  ('University of California, San Diego+University of Minnesota', 1),
#  ('European University Institute+Yale University', 1),
#  ('Brown University+Harvard University', 1),
#  ('University of Chicago+University of Wisconsin-Madison', 1),
#  ('Columbia University+Washington University in St. Louis', 1),
#  ('Harvard University+Ohio State University', 1),
#  ('Tel Aviv University+University of Melbourne', 1),
#  ('INSEAD+Massachusetts Institute of Technology', 1),
#  ('Hebrew University of Jerusalem+Massachusetts Institute of Technology', 1),
#  ('Pennsylvania State University+University of North Carolina at Chapel Hill',
#   1),
#  ('Boston College+Brown University', 1),
#  ('Florida State University+Georgetown University', 1),
#  ('London School of Economics+University of Warwick', 1),
#  ('Ohio State University+Yonsei University', 1),
#  ('University College London+University College London', 1),
#  ('Columbia University+University of Naples Federico II', 1),
#  ('Inter-American Development Bank+World Bank', 1),
#  ('Federal Reserve Bank of Chicago+University of Colorado, Boulder', 1),
#  ('Brown University+Southern Methodist University', 1),
#  ('Columbia University+Vanderbilt University', 1),
#  ('Dartmouth College+University of Warwick', 1),
#  ('Harvard University+University of California, San Diego', 1),
#  ('Princeton University+Wellesley College', 1),
#  ('American Enterprise Institute+University of California, Berkeley', 1),
#  ('University of Naples Federico II+University of Naples Federico II', 1),
#  ('Drake University+Stanford University', 1),
#  ("Queen's University+University of British Columbia", 1),
#  ('U.S. Census Bureau+University of British Columbia', 1),
#  ('Pennsylvania State University+University of Maryland', 1),
#  ('Hitotsubashi University+Princeton University', 1),
#  ('Urban Institute+University of Michigan', 1),
#  ('University of California, Irvine+University of South Carolina', 1),
#  ('Baylor University+US Federal Reserve Board', 1),
#  ('University of Cyprus+University of Warwick', 1),
#  ('Carnegie Mellon University+Massachusetts Institute of Technology', 1),
#  ('University of Kansas+University of Pennsylvania', 1),
#  ('University of Bologna+University of Bologna', 1),
#  ('Northwestern University+University of Texas at Austin', 1),
#  ('Georgia State University+University of Washington', 1),
#  ('University of Maryland+Washington University in St. Louis', 1),
#  ('Rutgers University+University of California, Berkeley', 1),
#  ('Cornell University+University of Maryland', 1),
#  ('Georgetown University+Harvard University', 1),
#  ('Boston University+University of Illinois at Urbana-Champaign', 1),
#  ('Florida State University+University of Arizona', 1),
#  ('Pennsylvania State University+University of Melbourne', 1),
#  ('Imperial College London+University of California, Davis', 1),
#  ('University of Florida+University of Florida', 1),
#  ('Florida State University+Indiana University', 1),
#  ('Stockholm University+Uppsala University', 1),
#  ('University of Toronto+Yale University', 1),
#  ('University of Texas at Dallas+University of Wyoming', 1),
#  ('Pennsylvania State University+Washington University in St. Louis', 1),
#  ('Tulane University+Vanderbilt University', 1),
#  ('Clark University+University of California, San Diego', 1),
#  ('Boston University+University of Nottingham', 1),
#  ('Technion+University of California, San Diego', 1),
#  ("Queen's University+Santa Clara University", 1),
#  ('Pennsylvania State University+University of Washington', 1),
#  ('Cornell University+University of California, Berkeley', 1),
#  ('Columbia University+George Washington University', 1),
#  ('Iowa State University+University of Alabama', 1),
#  ('University of Richmond+University of Virginia', 1),
#  ('University of Texas at Dallas+University of York', 1),
#  ('Columbia University+University of California, Riverside', 1),
#  ('Cornell University+George Washington University', 1),
#  ('University of California, Berkeley+University of Stavanger', 1),
#  ('California Institute of Technology+Chapman University', 1),
#  ('University of Belgrade+University of Newcastle', 1),
#  ('Autonomous University of Barcelona+University of Barcelona', 1),
#  ('Ohio State University+University of Michigan', 1),
#  ('Amazon Inc.+Hebrew University of Jerusalem', 1),
#  ('University of California, Berkeley+University of Utah', 1),
#  ('University of Pennsylvania+University of Southern California', 1),
#  ('Massachusetts Institute of Technology+World Bank', 1),
#  ('Georgia State University+University of California, Berkeley', 1),
#  ('Santa Clara University+US Federal Reserve Board', 1),
#  ('Federal Reserve Bank of Atlanta+University of Miami', 1),
#  ('University of Wisconsin-Madison+University of Wisconsin-Madison', 1),
#  ('Federal Reserve Bank of Atlanta+Federal Reserve Bank of San Francisco', 1),
#  ('Northwestern University+Yale University', 1),
#  ('University of California, Davis+University of California, Santa Cruz', 1),
#  ('Massachusetts Institute of Technology+University of British Columbia', 1),
#  ('University of Chicago+上海交通大学', 1),
#  ('University of New South Wales+University of Pennsylvania', 1),
#  ('Columbia University+University of Exeter', 1),
#  ('National University of Singapore+University of Nevada, Reno', 1),
#  ('Boston University+University of California, Berkeley', 1),
#  ('University of Toronto+World Bank', 1),
#  ('European University Institute+Universidad Carlos III de Madrid', 1),
#  ('Center for Monetary and Financial Studies (CEMFI)+University of California, Los Angeles',
#   1),
#  ('European University Institute+New York University', 1),
#  ('University of Amsterdam+University of Cambridge', 1),
#  ('University of Amsterdam+University of Mannheim', 1),
#  ('University of Chicago+University of Washington', 1),
#  ('Princeton University+University of Notre Dame', 1),
#  ('Harvard University+Toulouse School of Economics', 1),
#  ('New York University+University of Wisconsin-Madison', 1),
#  ('Ecole des Ponts ParisTech+Washington University in St. Louis', 1),
#  ('Brown University+University of Arkansas', 1),
#  ('Purdue University+University of Wyoming', 1),
#  ('Johns Hopkins University+Kyung Hee University', 1),
#  ('Boise State University+University of California, Santa Barbara', 1),
#  ('Carnegie Mellon University+University of Oslo', 1),
#  ('George Washington University+University of Chicago', 1),
#  ('American University+Clark University', 1),
#  ('Columbia University+University of Wisconsin-Madison', 1),
#  ('ETH Zürich+Toulouse School of Economics', 1),
#  ('City University of New York+University of Minnesota', 1),
#  ('Stanford University+University of Maryland', 1),
#  ('City University of New York+University of Amsterdam', 1),
#  ('Federal Reserve Bank of St. Louis+University of Western Ontario', 1),
#  ('Johns Hopkins University+University of British Columbia', 1),
#  ('ENSAE ParisTech+ENSAE ParisTech', 1),
#  ('Imperial College London+New York University', 1),
#  ('Federal Reserve Bank of San Francisco+University of California, San Diego',
#   1),
#  ('Tel Aviv University+University of Maryland', 1),
#  ('INSEAD+University of Melbourne', 1),
#  ('BI Norwegian Business School+University of Houston', 1),
#  ('Cardiff University+University of Exeter', 1),
#  ('Harvard University+Wake Forest University', 1),
#  ('Georgetown University+University of California, Berkeley', 1),
#  ('Brown University+New York University', 1),
#  ('Massachusetts Institute of Technology+Wabash College', 1),
#  ('Duke University+Washington University in St. Louis', 1),
#  ('New York University+Wilfrid Laurier University', 1),
#  ('Qatar University+Vanderbilt University', 1),
#  ('Resources for the Future, Washington DC+University of Maryland', 1),
#  ('Federal Reserve Bank of New York+New York University', 1),
#  ('Carnegie Mellon University+Smith College', 1),
#  ('University of Chicago+University of Namur', 1),
#  ('Princeton University+University of Illinois at Urbana-Champaign', 1),
#  ('Bocconi University+Pennsylvania State University', 1),
#  ('London School of Economics+U.S. Census Bureau', 1),
#  ('University of California, Los Angeles+University of Zurich', 1),
#  ('University of California, Berkeley+University of Virginia', 1),
#  ('Massachusetts Institute of Technology+University of Kentucky', 1),
#  ('Stanford University+University of Michigan', 1),
#  ('Montana State University+University of California, Irvine', 1),
#  ('Brown University+University of Pennsylvania', 1),
#  ('Texas A&M University+University of Washington', 1),
#  ('Bates College+University of Michigan', 1),
#  ('Carleton University+University of New Brunswick', 1),
#  ('Claremont Graduate University+University of Kentucky', 1),
#  ('Harvard University+Michigan State University', 1),
#  ('Ohio State University+University of New Hampshire', 1),
#  ('Stockholm University+Yale University', 1),
#  ('Brown University+CGIAR: Consultative Group for International Agricultural Research',
#   1),
#  ('Harvard University+Keio University', 1),
#  ('University of New South Wales+University of Virginia', 1),
#  ('Emory University+University of Pennsylvania', 1),
#  ('Pennsylvania State University+University of California, Berkeley', 1),
#  ('National Graduate Institute for Policy Studies+Yale University', 1),
#  ('London Business School+Yale University', 1),
#  ('Citadel+University of Mississippi', 1),
#  ('University of Oxford+University of Oxford', 1),
#  ('Arizona State University+University of Florida', 1),
#  ('Boston College+INSEAD', 1),
#  ('INSEAD+Toulouse School of Economics', 1),
#  ('Fordham University+Washington University in St. Louis', 1),
#  ('Tufts University+University of California, Los Angeles', 1),
#  ('Carnegie Mellon University+University of Florida', 1),
#  ('Columbia University+Dartmouth College', 1),
#  ('Montana State University+North Carolina State University', 1),
#  ('University of North Texas+University of Texas at Austin', 1),
#  ('University of Pennsylvania+Yale University', 1),
#  ('University at Buffalo+University at Buffalo', 1),
#  ('Boston University+National University of Singapore', 1),
#  ('Hong Kong Baptist University+香港大学', 1),
#  ('University of California, Santa Barbara+Washington University in St. Louis',
#   1),
#  ('Princeton University+University of California, Los Angeles', 1),
#  ('University of California, Davis+University of Michigan', 1),
#  ('University of California, Berkeley+University of Colorado, Boulder', 1),
#  ('Boston College+McGill University', 1),
#  ('Federal Reserve Bank of Philadelphia+University of Wisconsin-Madison', 1),
#  ('University of California, Los Angeles+University of Minnesota', 1),
#  ('University of Illinois at Urbana-Champaign+University of Victoria', 1),
#  ('Lehigh University+Temple University', 1),
#  ('Columbia University+University of Rochester', 1),
#  ('Duke University+University of Southern California', 1),
#  ('Pennsylvania State University+Vanderbilt University', 1),
#  ('Princeton University+Simon Fraser University', 1),
#  ('Johns Hopkins University+New York University', 1),
#  ('Ohio State University+University of Miami', 1),
#  ('University of Chicago+University of Pittsburgh', 1),
#  ('Brown University+Columbia University', 1),
#  ('Harvard University+University of Colorado, Boulder', 1),
#  ('University of Warsaw+Yale University', 1),
#  ('Federal Reserve Bank of Chicago+Harvard University', 1),
#  ('University of Glasgow+Yale University', 1),
#  ('University of Colorado, Boulder+Wilfrid Laurier University', 1),
#  ('Northwestern University+Southern Methodist University', 1),
#  ('Princeton University+Universidad Carlos III de Madrid', 1),
#  ('Georgia State University+University of Stavanger', 1),
#  ('University of California, Berkeley+University of Newcastle', 1),
#  ('Syracuse University+Texas A&M University', 1),
#  ('Clemson University+University of Missouri', 1),
#  ('Indiana University+University of Guelph', 1),
#  ('IESE Business School+University of Pennsylvania', 1),
#  ('University of California, Riverside+University of Pennsylvania', 1),
#  ('Purdue University+University of Nebraska-Lincoln', 1),
#  ('Tilburg University+University of Southern California', 1),
#  ('Northwestern University+University of Haifa', 1),
#  ('Texas A&M University+University of California, Santa Barbara', 1),
#  ('University of North Carolina at Charlotte+University of North Carolina at Charlotte',
#   1),
#  ('University of Colorado, Boulder+Washington University in St. Louis', 1),
#  ('Chapman University+Florida State University', 1),
#  ('San Diego State University+University of New Mexico', 1),
#  ('Kansas State University+University at Buffalo', 1),
#  ('University of Texas at Austin+University of Wisconsin-Madison', 1),
#  ('Georgia State University+University of California, Santa Cruz', 1),
#  ('Columbia University+Graduate Institute of International and Development Studies',
#   1),
#  ('Texas A&M University+University of California, Irvine', 1),
#  ('University of Chicago+Washington University in St. Louis', 1),
#  ('Stanford University+University of California, Davis', 1),
#  ('Simon Fraser University+University of York', 1),
#  ('Bloomberg LP+Harvard University', 1),
#  ('Carnegie Mellon University+University of Georgia', 1),
#  ('Columbia University+University of Pennsylvania', 1),
#  ('North Carolina State University+University of Wisconsin-Madison', 1),
#  ('Appalachian State University+Oakland University', 1),
#  ('Louisiana State University+Miami University of Ohio', 1),
#  ('Auburn University+George Mason University', 1),
#  ('Hebrew University of Jerusalem+Princeton University', 1),
#  ('Cornell University+New School for Social Research', 1)]

# %%
conn.close()
