# %% [markdown]
# # Data Cleaning and Put into SQL

# %%
import pandas as pd
import sqlite3
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import bs4
import time
import random
import numpy as np

# %% [markdown]
# ## Clean author_article.csv

# %%
# clean author_article
df_art_au = pd.read_csv("author_article.csv", encoding = "utf-8-sig").drop_duplicates()
df_art_au.to_csv("author_article.csv", encoding = "utf-8-sig", index = False)
df_art_au.to_csv("author_article_no_header.csv", encoding = "utf-8-sig", index = False, header = False)

# %% [markdown]
# ## Clean article.csv

# %%
# select valid records with valid doi, issue format, and not duplicated
def select_valid(df):
    df_s = df[(df["doi"].str[:3] == "10.") & (df["volume"].str.contains("Supplement") == False) & 
              (df["volume"].str.contains("_Part_") == False) & 
              (df["volume"].str.contains("S1") == False) & 
              (df["volume"].str.contains("S2") == False) &
              (df["volume"].str.contains("issue ") == True)].drop_duplicates(subset=["doi"]).reset_index(drop = True)
    return df_s

# convert volume to date
def conv_volume_to_date(v,freq):
    v_list = v.split(", ")
    year = v_list[0]
    issue = v_list[2].replace("issue ","")
    if freq == 4:
        d = year+"-"+str(int(issue)*3-1)+"-15"
    elif freq == 6 or freq == 5:
        d = year+"-"+str(int(issue)*2)+"-01"
    elif freq == 12:
        d = year+"-"+issue+"-15"
    elif freq == 3:
        d = year+"-"+str(int(issue)*3)+"-01"
    elif freq == 2:
        d = year+"-"+str(int(issue)*6-2)+"-01"
    elif freq == 1:
        d = year+"-"+str(7)+"-01"
    
    if len(d) < 10:
        return d.split("-")[0]+"-"+"0"+d.split("-")[1]+"-"+d.split("-")[2]
    else:
        return d
    
# calculate issue frequency
def cal_freq(vs):
    dict = {}
    years = [int(v.split(", ")[0]) for v in vs]
    unique_years = set(years)
    issues = [int(v.split(", ")[2].replace("issue ","")) for v in vs]
    for unique_year in unique_years:
        max_issue = 0
        for i in range(len(years)):
            if unique_year == years[i]:
                if issues[i] > max_issue:
                    max_issue = issues[i]
        dict[unique_year] = max_issue

    return dict

# %% [markdown]
# ### 1. RFS

# %%
# clean rfs
df_rfs = pd.read_csv("data/journals/raw_data/rfs.csv", encoding = "utf-8-sig").astype("str")
df_rfs["abstract"] = df_rfs["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_rfs_s = select_valid(df_rfs)
freq = cal_freq(df_rfs_s["volume"])

dates = []
for idx in df_rfs_s.index:
    year = int(df_rfs_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_rfs_s.loc[idx,"volume"],freq[year]))

df_rfs_s["date"] = dates
df_rfs_s.head()
# Out:
#                        journal  \
# 0  Review of Financial Studies
# 1  Review of Financial Studies
# 2  Review of Financial Studies
# 3  Review of Financial Studies
# 4  Review of Financial Studies
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                              authors  \
# 0                ['Jerome Detemple', 'Angel Serrat']
# 1               ['Wayne Ferson', 'Andrew F. Siegel']
# 2                ['Gurdip Bakshi', 'Nikunj Kapadia']
# 3                  ['Harrison Hong', 'Jeremy Stein']
# 4  ['Dong-Hyun Ahn', 'Jennifer Conrad', 'Robert D...
#
#                             volume jel  \
# 0  2003, vol. 16, issue 2, 597-629  []
# 1  2003, vol. 16, issue 2, 567-595  []
# 2  2003, vol. 16, issue 2, 527-566  []
# 3  2003, vol. 16, issue 2, 487-525  []
# 4  2003, vol. 16, issue 2, 459-485  []
#
#                                             abstract  \
# 0  This article studies an intertemporal economy ...
# 1  Hansen and Jagannathan (1991) (hereafter HJ) d...
# 2  We investigate whether the volatility risk pre...
# 3  We develop a theory of market crashes based on...
# 4  We assess the profitability of momentum strate...
#
#                                                  url                 doi  \
# 0  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg003
# 1  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg004
# 2  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg002
# 3  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg006
# 4  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg001
#
#          date
# 0  2003-05-15
# 1  2003-05-15
# 2  2003-05-15
# 3  2003-05-15
# 4  2003-05-15

# %% [markdown]
# ### 2. RES

# %%
# clean res
df_res = pd.read_csv("data/journals/raw_data/res.csv", encoding = "utf-8-sig").astype("str")
df_res["abstract"] = df_res["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_res_s = select_valid(df_res)
freq = cal_freq(df_res_s["volume"])

dates = []
for idx in df_res_s.index:
    year = int(df_res_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_res_s.loc[idx,"volume"],freq[year]))

df_res_s["date"] = dates
df_res_s.head()
# Out:
#                       journal  \
# 0  Review of Economic Studies
# 1  Review of Economic Studies
# 2  Review of Economic Studies
# 3  Review of Economic Studies
# 4  Review of Economic Studies
#
#                                                title  \
# 0  The Dynamics of Return Migration, Human Capita...
# 1  The Impact of Car Pollution on Infant and Chil...
# 2  The Welfare Effects of Transportation Infrastr...
# 3  Subjective Models of the Macroeconomy: Evidenc...
# 4   Product Life Cycle, Learning, and Nominal Shocks
#
#                                              authors  \
# 0  ['Jerome Adda', 'Christian Dustmann', 'Joseph-...
# 1             ['Diane Alexander', 'Hannes Schwandt']
# 2                 ['Treb Allen', 'Costas Arkolakis']
# 3  ['Peter Andrebriq', 'Carlo Pizzinelli', 'Chris...
# 4                      ['David Argente', 'Chen Yeh']
#
#                               volume jel  \
# 0  2022, vol. 89, issue 6, 2841-2871  []
# 1  2022, vol. 89, issue 6, 2872-2910  []
# 2  2022, vol. 89, issue 6, 2911-2957  []
# 3  2022, vol. 89, issue 6, 2958-2991  []
# 4  2022, vol. 89, issue 6, 2992-3054  []
#
#                                             abstract  \
# 0  This article develops and estimates a dynamic ...
# 1  In 2008, Volkswagen introduced a new generatio...
# 2  Each year in the US, hundreds of billions of d...
# 3  We study people’s subjective models of the mac...
# 4  This article documents a new set of stylized f...
#
#                                                  url                     doi  \
# 0  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac003
# 1  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac007
# 2  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac001
# 3  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac008
# 4  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac004
#
#          date
# 0  2022-12-01
# 1  2022-12-01
# 2  2022-12-01
# 3  2022-12-01
# 4  2022-12-01

# %% [markdown]
# ### 3. QJE

# %%
# clean qje
df_qje = pd.read_csv("data/journals/raw_data/qje.csv", encoding = "utf-8-sig").astype("str")
df_qje["abstract"] = df_qje["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_qje_s = select_valid(df_qje)
freq = cal_freq(df_qje_s["volume"])

dates = []
for idx in df_qje_s.index:
    year = int(df_qje_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_qje_s.loc[idx,"volume"],freq[year]))

df_qje_s["date"] = dates
df_qje_s.head()
# Out:
#                               journal  \
# 0  The Quarterly Journal of Economics
# 1  The Quarterly Journal of Economics
# 2  The Quarterly Journal of Economics
# 3  The Quarterly Journal of Economics
# 4  The Quarterly Journal of Economics
#
#                                                title  \
# 0  Systemic Discrimination Among Large U.S. Emplo...
# 1  Valuing the Global Mortality Consequences of C...
# 2  Reshaping Global Trade: The Immediate and Long...
# 3  Sexual Harassment and Gender Inequality in the...
# 4  The Quality and Efficiency of Public and Priva...
#
#                                              authors  \
# 0  ['Patrick Kline', 'Evan K Rose', 'Christopher ...
# 1  ['Tamma Carleton', 'Amir Jina', 'Michael Delga...
# 2                                      ['Chenzi Xu']
# 3                   ['Olle Folke', 'Johanna Rickne']
# 4              ['Daniel Knutsson', 'Björn Tyrefors']
#
#                                volume jel  \
# 0  2022, vol. 137, issue 4, 1963-2036  []
# 1  2022, vol. 137, issue 4, 2037-2105  []
# 2  2022, vol. 137, issue 4, 2107-2161  []
# 3  2022, vol. 137, issue 4, 2163-2212  []
# 4  2022, vol. 137, issue 4, 2213-2262  []
#
#                                             abstract  \
# 0  We study the results of a massive nationwide c...
# 1  Using 40 countries’ subnational data, we estim...
# 2  I show that a disruption to the financial sect...
# 3  We describe how sexual harassment contributes ...
# 4  Economic theory predicts that outsourcing publ...
#
#                                                  url                  doi  \
# 0  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac024
# 1  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac020
# 2  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac016
# 3  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac018
# 4  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac014
#
#          date
# 0  2022-11-15
# 1  2022-11-15
# 2  2022-11-15
# 3  2022-11-15
# 4  2022-11-15

# %% [markdown]
# ### 4. JPE

# %%
# clean jpe
df_jpe = pd.read_csv("data/journals/raw_data/jpe.csv", encoding = "utf-8-sig").astype("str")
df_jpe["abstract"] = df_jpe["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_jpe["doi"] = df_jpe["doi"].apply(lambda x: x.replace("http://dx.doi.org/",""))
df_jpe_s = select_valid(df_jpe)
freq = cal_freq(df_jpe_s["volume"])

dates = []
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_jpe_s.loc[idx,"volume"],freq[year]))

df_jpe_s["date"] = dates

# modify date for 2023
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_jpe_s.loc[idx, "date"] = conv_volume_to_date(df_jpe_s.loc[idx,"volume"],12)

df_jpe_s.head()
# Out:
#                         journal  \
# 0  Journal of Political Economy
# 1  Journal of Political Economy
# 2  Journal of Political Economy
# 3  Journal of Political Economy
# 4  Journal of Political Economy
#
#                                                title  \
# 0                        Collective Brand Reputation
# 1         The Mechanics of the Industrial Revolution
# 2  Optimal Cooperative Taxation in the Global Eco...
# 3          Personalized Pricing and Consumer Welfare
# 4  A Semistructural Methodology for Policy Counte...
#
#                                              authors  \
# 0                 ['Volker Nocke', 'Roland Strausz']
# 1   ['Morgan Kelly', 'Joel Mokyr', 'Cormac Ó Gráda']
# 2  ['V. V. Chari', 'Juan Pablo Nicolini', 'Pedro ...
# 3               ['Jean-Pierre Dubé', 'Sanjog Misra']
# 4                                  ['Martin Beraja']
#
#                                volume jel  \
# 0     2023, vol. 131, issue 1, 1 - 58  []
# 1    2023, vol. 131, issue 1, 59 - 94  []
# 2   2023, vol. 131, issue 1, 95 - 130  []
# 3  2023, vol. 131, issue 1, 131 - 189  []
# 4  2023, vol. 131, issue 1, 190 - 201  []
#
#                                             abstract  \
# 0  We develop a theory of collective brand reputa...
# 1  Although there are many competing explanations...
# 2  How should countries cooperate in setting fisc...
# 3  We study the welfare implications of personali...
# 4  I propose a methodology for constructing count...
#
#                                                  url             doi  \
# 0  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720986
# 1  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720890
# 2  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720889
# 3  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720793
# 4  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720982
#
#          date
# 0  2023-01-15
# 1  2023-01-15
# 2  2023-01-15
# 3  2023-01-15
# 4  2023-01-15

# %% [markdown]
# ### 5. E

# %%
# clean e
df_e = pd.read_csv("data/journals/raw_data/e.csv", encoding = "utf-8-sig").astype("str")
df_e["abstract"] = df_e["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_e["doi"] = df_e["doi"].apply(lambda x: x.replace("https://doi.org/",""))
df_e_s = select_valid(df_e)
freq = cal_freq(df_e_s["volume"])

dates = []
for idx in df_e_s.index:
    year = int(df_e_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_e_s.loc[idx,"volume"],freq[year]))

df_e_s["date"] = dates

# modify date for 2023
for idx in df_e_s.index:
    year = int(df_e_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_e_s.loc[idx, "date"] = conv_volume_to_date(df_e_s.loc[idx,"volume"],6)

df_e_s.head()
# Out:
#         journal                                              title  \
# 0  Econometrica  Invidious Comparisons: Ranking and Selection a...
# 1  Econometrica  A Comment on: “Invidious Comparisons: Ranking ...
# 2  Econometrica  A Comment on: “Invidious Comparisons: Ranking ...
# 3  Econometrica  A Comment on: “Invidious Comparisons: Ranking ...
# 4  Econometrica  Reply to: Comments on “Invidious Comparisons: ...
#
#                                              authors  \
# 0                    ['Jiaying Gu', 'Roger Koenker']
# 1                                 ['Keisuke Hirano']
# 2                                  ['Patrick Kline']
# 3  ['Magne Mogstad', 'Joseph P. Romano', 'Azeem M...
# 4                    ['Jiaying Gu', 'Roger Koenker']
#
#                           volume jel  \
# 0   2023, vol. 91, issue 1, 1-41  []
# 1  2023, vol. 91, issue 1, 43-46  []
# 2  2023, vol. 91, issue 1, 47-52  []
# 3  2023, vol. 91, issue 1, 53-60  []
# 4  2023, vol. 91, issue 1, 61-66  []
#
#                                             abstract  \
# 0  There is an innate human tendency, one might c...
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                                  url                doi  \
# 0  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA19304
# 1  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20364
# 2  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20322
# 3  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20460
# 4  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20537
#
#          date
# 0  2023-02-01
# 1  2023-02-01
# 2  2023-02-01
# 3  2023-02-01
# 4  2023-02-01

# %% [markdown]
# ### 6. AER

# %%
# clean aer
df_aer = pd.read_csv("data/journals/raw_data/aer.csv", encoding = "utf-8-sig").astype("str")
df_aer["journal"] = df_aer["journal"].apply(lambda x: "American Economic Review")
df_aer["abstract"] = df_aer["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_aer["volume"] = df_aer["volume"].apply(lambda x: x.replace("\n","").replace("\t","").strip())
df_aer = df_aer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_aer.index:
    date_text = df_aer.loc[idx,"volume"].split(",")[2].strip()
    year = date_text.split(" ")[1]
    month_text = date_text.split(" ")[0]
    if month_text == "January":
        month = "01"
    elif month_text == "February":
        month = "02"
    elif month_text == "March":
        month = "03"
    elif month_text == "April":
        month = "04"
    elif month_text == "May":
        month = "05"
    elif month_text == "June":
        month = "06"
    elif month_text == "July":
        month = "07"
    elif month_text == "August":
        month = "08"
    elif month_text == "September":
        month = "09"
    elif month_text == "October":
        month = "10"
    elif month_text == "November":
        month = "11"
    elif month_text == "December":
        month = "12"

    dates.append(year+"-"+month+"-"+"15")

df_aer["date"] = dates
df_aer_s = df_aer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_aer_s.tail()
# Out:
#                        journal  \
# 4799  American Economic Review
# 4800  American Economic Review
# 4801  American Economic Review
# 4802  American Economic Review
# 4803  American Economic Review
#
#                                                   title  \
# 4799  Enabling or Limiting Cognitive Flexibility? Ev...
# 4800  Droughts, Deluges, and (River) Diversions: Val...
# 4801                 Technology Gaps, Trade, and Income
# 4802  Electronic Food Vouchers: Evidence from an At-...
# 4803                       The Voice of Monetary Policy
#
#                                                 authors  \
# 4799  ['\n         Silvia Saccardo    ', '\n        ...
# 4800                      ['\n         Will Rafey    ']
# 4801                  ['\n         Thomas Sampson    ']
# 4802  ['\n         Abhijit Banerjee    ', '\n       ...
# 4803  ['\n         Yuriy Gorodnichenko    ', '\n    ...
#
#                                                  volume  \
# 4799  American Economic Review vol. 113,no. 2, Febru...
# 4800  American Economic Review vol. 113,no. 2, Febru...
# 4801  American Economic Review vol. 113,no. 2, Febru...
# 4802  American Economic Review vol. 113,no. 2, Febru...
# 4803  American Economic Review vol. 113,no. 2, Febru...
#
#                                                     jel  \
# 4799  [('C91', 'Design of Experiments: Laboratory, I...
# 4800  [('D23', 'Organizational Behavior; Transaction...
# 4801  [('D21', 'Firm Behavior: Theory'), ('D24', 'Pr...
# 4802  [('H53', 'National Government Expenditures and...
# 4803  [('D83', 'Search; Learning; Information and Kn...
#
#                                                abstract  \
# 4799  Moral behavior is more prevalent when individu...
# 4800  This paper develops and applies a method to va...
# 4801  This paper quantifies the contribution of tech...
# 4802  We compare how in-kind food assistance and an ...
# 4803  We develop a deep learning model to detect emo...
#
#                                                     url                   doi  \
# 4799  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201333
# 4800  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201434
# 4801  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201940
# 4802  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20210461
# 4803  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20220129
#
#             date
# 4799  2023-02-15
# 4800  2023-02-15
# 4801  2023-02-15
# 4802  2023-02-15
# 4803  2023-02-15

# %% [markdown]
# ### 7. JF

# %%
# clean jf
df_jf = pd.read_csv("data/journals/raw_data/jf.csv", encoding = "utf-8-sig").astype("str")
df_jf["abstract"] = df_jf["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_jf["doi"] = df_jf["doi"].apply(lambda x: x.replace("https://doi.org/",""))
df_jf_s = select_valid(df_jf)
freq = cal_freq(df_jf_s["volume"])

dates = []
for idx in df_jf_s.index:
    year = int(df_jf_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_jf_s.loc[idx,"volume"],freq[year]))

df_jf_s["date"] = dates

# modify date for 2023
for idx in df_jf_s.index:
    year = int(df_jf_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_jf_s.loc[idx, "date"] = conv_volume_to_date(df_jf_s.loc[idx,"volume"],6)

df_jf_s.head()
# Out:
#               journal                                              title  \
# 0  Journal of Finance                Optimal Financial Transaction Taxes
# 1  Journal of Finance  Less Mainstream Credit, More Payday Borrowing?...
# 2  Journal of Finance                      Disruption and Credit Markets
# 3  Journal of Finance               How Risky Are U.S. Corporate Assets?
# 4  Journal of Finance    International Yield Curves and Currency Puzzles
#
#                                              authors  \
# 0                                 ['Eduardo Dávila']
# 1                                  ['Julia Fonseca']
# 2                 ['Bo Becker', 'Victoria Ivashina']
# 3  ['Tetiana Davydiuk', 'Scott Richard', 'Ivan Sh...
# 4                  ['Mikhail Chernov', 'Drew Creal']
#
#                             volume jel  \
# 0     2023, vol. 78, issue 1, 5-61  []
# 1   2023, vol. 78, issue 1, 63-103  []
# 2  2023, vol. 78, issue 1, 105-139  []
# 3  2023, vol. 78, issue 1, 141-208  []
# 4  2023, vol. 78, issue 1, 209-245  []
#
#                                             abstract  \
# 0  This paper characterizes the optimal transacti...
# 1  Governments regulate debt collectors to protec...
# 2  We show that over the past half‐century, innov...
# 3  We use market data on corporate bonds and equi...
# 4  The currency depreciation rate is often comput...
#
#                                                  url                 doi  \
# 0  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13188
# 1  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13189
# 2  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13187
# 3  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13196
# 4  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13191
#
#          date
# 0  2023-02-01
# 1  2023-02-01
# 2  2023-02-01
# 3  2023-02-01
# 4  2023-02-01

# %%
for doi in df_jf.doi:
    print(doi)

# %%
# concatenate journals
df = pd.concat([df_rfs_s,df_res_s,df_qje_s,df_jpe_s,df_e_s,df_aer_s,df_jf_s]).reset_index(drop=True)
len(df)
# Out:
# 22978

# %%
df.nunique()
# Out:
# journal         7
# title       22523
# authors     17813
# volume      18364
# jel          4539
# abstract    14638
# url         22978
# doi         22978
# date         1109
# dtype: int64

# %%
df_selected = df[["doi","journal","volume","date","title","abstract","url"]]
df_selected.head()
# Out:
#                   doi                      journal  \
# 0  10.1093/rfs/hhg003  Review of Financial Studies
# 1  10.1093/rfs/hhg004  Review of Financial Studies
# 2  10.1093/rfs/hhg002  Review of Financial Studies
# 3  10.1093/rfs/hhg006  Review of Financial Studies
# 4  10.1093/rfs/hhg001  Review of Financial Studies
#
#                             volume        date  \
# 0  2003, vol. 16, issue 2, 597-629  2003-05-15
# 1  2003, vol. 16, issue 2, 567-595  2003-05-15
# 2  2003, vol. 16, issue 2, 527-566  2003-05-15
# 3  2003, vol. 16, issue 2, 487-525  2003-05-15
# 4  2003, vol. 16, issue 2, 459-485  2003-05-15
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                             abstract  \
# 0  This article studies an intertemporal economy ...
# 1  Hansen and Jagannathan (1991) (hereafter HJ) d...
# 2  We investigate whether the volatility risk pre...
# 3  We develop a theory of market crashes based on...
# 4  We assess the profitability of momentum strate...
#
#                                                  url
# 0  https://econpapers.repec.org/article/ouprfinst...
# 1  https://econpapers.repec.org/article/ouprfinst...
# 2  https://econpapers.repec.org/article/ouprfinst...
# 3  https://econpapers.repec.org/article/ouprfinst...
# 4  https://econpapers.repec.org/article/ouprfinst...

# %%
# save article
df_selected.to_csv("article.csv", index = False, encoding = "utf-8-sig")
df_selected.to_csv("article_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Clean and update author.csv, email_affiliation.csv, affiliation.csv

# %%
# clean author
df_email = pd.read_csv("email_affiliation.csv", encoding = "utf-8-sig").replace(np.NaN,"")
emaildict = df_email.to_dict("list")
df_au = pd.read_csv("author.csv", encoding = "utf-8-sig")

# %%
# open chrome service
chromedriver_path = "D:/chromedriver.exe"
s = Service(chromedriver_path)
driver = webdriver.Chrome(service=s)

# %%
base_url = "https://scholar.google.com/scholar?hl=zh-CN&q="
start_idx = 1
for i, e in enumerate(sorted(df_au["emailsuffix"].unique())[start_idx:]):
    if e not in list(df_email.subemail):
        driver.get(base_url+e)
        driver.refresh()
        soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
        try:
            h3 = soup.find("div", class_ = "gs_r").h3
            if h3.text == "以下机构的用户个人学术档案：":
                div = soup.find("div", class_ = "gs_r").div
                name = div.a.text
                email = div.span.text.replace(" - ", "")
                time.sleep(random.randrange(5,10))
            else:
                raise ValueError("x")
        except:
            try:
                h2 = soup.find("div", class_ = "gs_r").h2
                if "显示的是以下查询字词的结果：" in h2.text.strip():
                    driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                    driver.refresh()
                    soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                    div = soup.find("div", class_ = "gs_r").div
                    name = div.a.text
                    email = div.span.text.replace(" - ", "")
                    time.sleep(random.randrange(5,10))
                else:
                    raise ValueError("x")
            except:
                driver.get(base_url+".".join(e.split(".")[1:]))
                driver.refresh()
                soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                try:
                    h3 = soup.find("div", class_ = "gs_r").h3
                    if h3.text == "以下机构的用户个人学术档案：":
                        div = soup.find("div", class_ = "gs_r").div
                        name = div.a.text
                        email = div.span.text.replace(" - ", "")
                        time.sleep(random.randrange(5,10))
                    else:
                        raise ValueError("x")
                except:
                    try:
                        h2 = soup.find("div", class_ = "gs_r").h2
                        if "显示的是以下查询字词的结果：" in h2.text.strip():
                            driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                            driver.refresh()
                            soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                            div = soup.find("div", class_ = "gs_r").div
                            name = div.a.text
                            email = div.span.text.replace(" - ", "")
                            time.sleep(random.randrange(5,10))
                        else:
                            raise ValueError("x")
                    except:
                        try:
                            if soup.find("h1").text == "请进行人机身份验证":
                                print("Blocked!!!")
                                break
                            else:
                                name = ""
                                email = ""
                            time.sleep(random.randrange(5,10))
                        except:
                            name = ""
                            email = ""
                            time.sleep(random.randrange(5,10))
        # append info
        try:
            affid = "".join([w[0] for w in name.lower().split(" ")])+"."+email
        except:
            affid = ""

        if "PDF" in affid:
            name = ""
            email = ""
            affid = ""

        emaildict["name"].append(name)
        emaildict["email"].append(email)
        emaildict["subemail"].append(e)
        emaildict["affiliationid"].append(affid)
        print(i+start_idx, e, name, email, affid)
# Out:
# 17 ajou.ac.kr Ajou University ajou.ac.kr au.ajou.ac.kr
# 18 alaska.edu University of Alaska Fairbanks alaska.edu uoaf.alaska.edu
# 19 alaskataxlady.com
# 47 aqr.com
# 48 aqrarbitrage.com
# 108 bilgi.edu.tr
# 139 bsp.gov.ph SEAFARING, MASCULINITIES AND GLOBALIZATION, Minneapolis: University of Minnesota Press, 2011, xii+ 251 pp., $25 保存 smagmuomp2x2p$.保存
# 151 business.queensu.ca Queen's University queensu.ca qu.queensu.ca
# 159 bwl.lmu.de University of Munich lmu.de uom.lmu.de
# 181 ccf.org Cleveland Clinic ccf.org cc.ccf.org
# 200 cfm.fr
# 215 citadel.com
# 225 cm.nsysu.edu.tw National Sun Yat-sen University nsysu.edu.tw nsyu.nsysu.edu.tw
# 240 comm.virginia.edu University of Virginia virginia.edu uov.virginia.edu
# 241 commerce.tanta.edu.eg Tanta University tanta.edu.eg tu.tanta.edu.eg
# 304 dpem.tuc.gr Technical University of Crete tuc.gr tuoc.tuc.gr
# 309 du.se
# 314 e.ntu.edu.sg 南洋理工大学 ntu.edu.sg 南.ntu.edu.sg
# 317 eba.europa.eu European Commission, Joint Research Centre europa.eu ecjrc.europa.eu
# 396 epoch.capital
# 441 fiu.edu Florida International University fiu.edu fiu.fiu.edu
# 460 fulcrumasset.com
# 490 gstt.nhs.uk
# 539 icmacentre.ac.uk
# 548 iesa.edu.ve
# 552 ifm.unibe.ch University of Bern unibe.ch uob.unibe.ch
# 596 ithaca.edu Ithaca College ithaca.edu ic.ithaca.edu
# 657 lancs.ac.uk Lancaster University lancaster.ac.uk lu.lancaster.ac.uk
# 665 law.vanderbilt.edu Vanderbilt University vanderbilt.edu vu.vanderbilt.edu
# 692 lsvasset.com
# 703 mail.fcu.edu.tw Feng Chia University fcu.edu.tw fcu.fcu.edu.tw
# 707 mail.hust.edu.cn Huazhong University of Science and Technology hust.edu.cn huosat.hust.edu.cn
# 727 mat.uniroma2.it University of Rome Tor Vergata uniroma2.it uortv.uniroma2.it
# 758 milkeninstitute.org
# 777 mpib-berlin.mpg.de Max Planck Institute for Human Development mpib-berlin.mpg.de mpifhd.mpib-berlin.mpg.de
# 845 odu.edu Old Dominion University odu.edu odu.odu.edu
# 850 okstate.edu Oklahoma State University okstate.edu osu.okstate.edu
# 854 onehatr.com
# 875 pdx.edu Portland State University pdx.edu psu.pdx.edu
# 905 postech.ac.kr Pohang University of Science and Technology postech.ac.kr puosat.postech.ac.kr
# 913 promontory.com
# 937 randalolson.com
# 974 sacredheart.edu Sacred Heart University sacredheart.edu shu.sacredheart.edu
# 985 saunders.rit.edu Rochester Institute of Technology rit.edu riot.rit.edu
# 1015 sloan.mit.edu Massachusetts Institute of Technology mit.edu miot.mit.edu
# 1066 suss.edu.sg
# 1099 tradefeedr.com
# 1116 twosigma.com
# 1131 uah.edu University of Alabama in Huntsville uah.edu uoaih.uah.edu
# 1139 ub.ac.id Brawijaya University ub.ac.id bu.ub.ac.id
# 1217 umsystem.edu
# 1252 unibe.ch University of Bern unibe.ch uob.unibe.ch
# 1271 union.edu Union College union.edu uc.union.edu
# 1302 unomaha.edu University of Nebraska at Omaha unomaha.edu uonao.unomaha.edu
# 1306 uoc.edu Universitat Oberta de Catalunya uoc.edu uodc.uoc.edu
# 1312 upatras.gr University of Patras upatras.gr uop.upatras.gr
# 1382 vinva.com
# 1388 vuw.ac.nz Victoria University of Wellington vuw.ac.nz vuow.vuw.ac.nz

# %%
len(emaildict["name"])
# Out:
# 1451

# %%
df_email = pd.DataFrame(emaildict).drop_duplicates(subset=["subemail"],keep="last")
len(df_email)
# Out:
# 1451

# %%
df_email.nunique()
# Out:
# name              732
# email             731
# subemail         1451
# affiliationid     732
# dtype: int64

# %%
df_aff = df_email[["affiliationid","name","email"]][df_email["affiliationid"]!=""].drop_duplicates()
len(df_aff)
# Out:
# 731

# %%
# add affiliationid to author
for idx in df_au.index:
    try:
        df_au.loc[idx, "affiliationid"] = df_email.set_index("subemail").loc[df_au.loc[idx, "emailsuffix"],"affiliationid"]
    except:
        df_au.loc[idx, "affiliationid"] = ""

# %%
df_email.to_csv("email_affiliation.csv", index = False, encoding = "utf-8-sig")
df_email.to_csv("email_affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation.csv", index = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_au.to_csv("author.csv", index = False, encoding = "utf-8-sig")
df_au.to_csv("author_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Database

# %%
# use this line to run the script directly in Jupyter
! sqlite3 econtop.db < create-econtop.sql

# %%
conn = sqlite3.connect("econtop.db")
cur = conn.cursor()

# %% [markdown]
# ### University Level

# %%
# select university level of publications
q = """
    SELECT af.affiliationid, af.name, art.journal, aa.doi, art.date
    FROM author_article AS aa JOIN author AS au JOIN article AS art JOIN affiliation AS af
    ON aa.authorid = au.authorid AND
    aa.doi = art.doi AND
    au.affiliationid = af.affiliationid
    WHERE art.date >= '2000-01-01' AND
    art.date < '2005-01-01'
    """

# q = " SELECT authorid FROM author"
df_af_art = pd.read_sql_query(q, conn).set_index("doi")
df_af_art.head()
# Out:
#                      affiliationid                                  name  \
# doi
# 10.1093/rfs/hhg003       bu.bu.edu                     Boston University
# 10.1093/rfs/hhg004    uosc.usc.edu     University of Southern California
# 10.1093/rfs/hhg002  uoma.umass.edu  University of Massachusetts, Amherst
# 10.1093/rfs/hhg002   tu.temple.edu                     Temple University
# 10.1093/rfs/hhg006  hu.harvard.edu                    Harvard University
#
#                                         journal        date
# doi
# 10.1093/rfs/hhg003  Review of Financial Studies  2003-05-15
# 10.1093/rfs/hhg004  Review of Financial Studies  2003-05-15
# 10.1093/rfs/hhg002  Review of Financial Studies  2003-05-15
# 10.1093/rfs/hhg002  Review of Financial Studies  2003-05-15
# 10.1093/rfs/hhg006  Review of Financial Studies  2003-05-15

# %%
len(df_af_art)
# Out:
# 2377

# %%
df_af_art.nunique()
# Out:
# affiliationid    338
# name             338
# journal            6
# date              70
# dtype: int64

# %%
# show top appearance
freq = {}
for doi in df_af_art.index:
    try:
        name = df_af_art.loc[doi][1]
        try:
            freq[name] += 1
        except:
            freq[name] = 1
    except:
        df_af_art_new = df_af_art.loc[doi]
        names = set(list(df_af_art_new.name))
        for name in names:
            try:
                freq[name] += 1
            except:
                freq[name] = 1

# %%
freq_sorted = sorted(freq.items(), key=lambda x:x[1], reverse = True)
freq_sorted
# Out:
# [('Harvard University', 183),
#  ('Massachusetts Institute of Technology', 161),
#  ('University of Chicago', 158),
#  ('Stanford University', 141),
#  ('New York University', 138),
#  ('Columbia University', 128),
#  ('University of California, Berkeley', 128),
#  ('Yale University', 84),
#  ('University of Pennsylvania', 77),
#  ('Duke University', 74),
#  ('University of California, Los Angeles', 72),
#  ('London School of Economics', 66),
#  ('Northwestern University', 64),
#  ('Princeton University', 62),
#  ('University of Michigan', 54),
#  ('University of Minnesota', 51),
#  ('University of British Columbia', 49),
#  ('Brown University', 41),
#  ('Cornell University', 40),
#  ('University of Wisconsin-Madison', 37),
#  ('Boston University', 36),
#  ('University of Southern California', 36),
#  ('University of California, San Diego', 36),
#  ('University of California, Davis', 35),
#  ('University of Toronto', 34),
#  ('Carnegie Mellon University', 33),
#  ('University of Virginia', 32),
#  ('Pennsylvania State University', 32),
#  ('Dartmouth College', 31),
#  ('University of Illinois at Urbana-Champaign', 29),
#  ('World Bank', 27),
#  ('Toulouse School of Economics', 25),
#  ('Georgetown University', 25),
#  ('University of Oxford', 25),
#  ('Boston College', 24),
#  ('University of North Carolina at Chapel Hill', 23),
#  ('University of Texas at Austin', 23),
#  ('University of Maryland', 22),
#  ('University of Rochester', 22),
#  ('University of Zurich', 21),
#  ('SKEMA Business School', 20),
#  ('University of Oregon', 19),
#  ('Washington University in St. Louis', 19),
#  ('University of Notre Dame', 19),
#  ('Hebrew University of Jerusalem', 18),
#  ('University of California, Irvine', 18),
#  ('Bocconi University', 18),
#  ('California Institute of Technology', 18),
#  ('Rice University', 17),
#  ('Swiss Federal Institute of Technology in Lausanne', 17),
#  ('University of Colorado, Boulder', 17),
#  ('Tel Aviv University', 17),
#  ('US Federal Reserve Board', 17),
#  ('香港大学', 17),
#  ('Rutgers University', 16),
#  ('University of Florida', 16),
#  ('Johns Hopkins University', 16),
#  ('Michigan State University', 16),
#  ('Emory University', 16),
#  ('University of Utah', 15),
#  ('Federal Reserve Bank of New York', 15),
#  ('Arizona State University', 15),
#  ('HEC Paris', 14),
#  ('香港科技大学', 14),
#  ('INSEAD', 14),
#  ('Imperial College London', 14),
#  ('Federal Reserve Bank of Chicago', 14),
#  ('London Business School', 14),
#  ('City University of New York', 14),
#  ('Indiana University', 13),
#  ('Ohio State University', 13),
#  ('National University of Singapore', 13),
#  ('University of Arizona', 12),
#  ('University of Washington', 12),
#  ('University of Western Ontario', 12),
#  ('Vanderbilt University', 12),
#  ('University of Nottingham', 12),
#  ('Centre de Recerca en Economia Internacional', 12),
#  ('Purdue University', 12),
#  ('Tulane University', 11),
#  ('University College London', 11),
#  ('University of Melbourne', 11),
#  ('York University', 11),
#  ('Brigham Young University', 10),
#  ('Williams College', 10),
#  ("Queen's University", 10),
#  ('Virginia Polytechnic Institute and State University', 10),
#  ('University of California, Santa Barbara', 10),
#  ('Stockholm School of Economics', 10),
#  ('Drexel University', 10),
#  ('University of Pittsburgh', 9),
#  ('University of Lausanne', 9),
#  ('Brandeis University', 9),
#  ('Brookings Institution', 9),
#  ('University of Wyoming', 9),
#  ('University of Oslo', 9),
#  ('University of Houston', 9),
#  ('Clemson University', 9),
#  ('Bank for International Settlements', 9),
#  ('Federal Reserve Bank of Atlanta', 9),
#  ('University of New Mexico', 9),
#  ('Syracuse University', 9),
#  ('Interdisciplinary Center, Herzliya', 8),
#  ('Stockholm University', 8),
#  ('Simon Fraser University', 8),
#  ('Texas A&M University', 8),
#  ('Louisiana State University', 8),
#  ('Federal Reserve Bank of Dallas', 8),
#  ('Southern Methodist University', 8),
#  ('Temple University', 7),
#  ('南洋理工大学', 7),
#  ('Copenhagen Business School', 7),
#  ('University of Warwick', 7),
#  ('Aalto University', 7),
#  ('Federal Reserve Bank of Richmond', 7),
#  ('Universidad Carlos III de Madrid', 7),
#  ('Katholieke Universiteit, Leuven', 7),
#  ('Paris School of Economics', 7),
#  ('University of Amsterdam', 7),
#  ('Ben-Gurion University of the Negev', 7),
#  ('University of South Florida', 7),
#  ('Seoul National University', 6),
#  ('American University', 6),
#  ('University of Texas at Dallas', 6),
#  ('University of Manchester', 6),
#  ('Ecole des Ponts ParisTech', 6),
#  ('University of Cambridge', 6),
#  ('University of Mannheim', 6),
#  ('Autonomous University of Barcelona', 6),
#  ('ENSAE ParisTech', 6),
#  ('European University Institute', 6),
#  ('Monash University', 6),
#  ('Santa Fe Institute', 6),
#  ('Federal Reserve Bank of St. Louis', 6),
#  ('Georgia Institute of Technology', 6),
#  ('University of Nebraska-Lincoln', 6),
#  ('University of South Dakota', 6),
#  ('University of New South Wales', 6),
#  ('George Mason University', 6),
#  ('Georgia State University', 6),
#  ('College of William and Mary', 6),
#  ('Fordham University', 6),
#  ('Sciences Po', 5),
#  ('Center for Monetary and Financial Studies (CEMFI)', 5),
#  ('Tilburg University', 5),
#  ('State University of New York at Stony Brook', 5),
#  ('Tufts University', 5),
#  ('IE University', 5),
#  ('U.S. Census Bureau', 5),
#  ('University of Kentucky', 5),
#  ('Case Western Reserve University', 5),
#  ('University College Dublin', 5),
#  ('University of Delaware', 5),
#  ('Nature Conservancy', 5),
#  ('University of Queensland', 5),
#  ('Australian National University', 5),
#  ('University of Alabama', 4),
#  ('University of California, Riverside', 4),
#  ('VU University Amsterdam', 4),
#  ('University of Surrey', 4),
#  ('University of Edinburgh', 4),
#  ('University of Iowa', 4),
#  ('George Washington University', 4),
#  ('University of Namur', 4),
#  ('IESE Business School', 4),
#  ('Central European University', 4),
#  ('Wake Forest University', 4),
#  ('香港中文大学', 4),
#  ('Pompeu Fabra University', 4),
#  ('University of Padova', 4),
#  ('University of Colorado Denver', 4),
#  ('Erasmus University Rotterdam', 4),
#  ('University of Montreal', 4),
#  ('Nova School of Business and Economics', 4),
#  ('University of Connecticut', 4),
#  ('University of Hawaii', 3),
#  ('Santa Clara University', 3),
#  ('EDHEC Business School', 3),
#  ('Lancaster University', 3),
#  ('Babson College', 3),
#  ('University of Vienna', 3),
#  ('BI Norwegian Business School', 3),
#  ('Banco de Portugal', 3),
#  ('University of Bern', 3),
#  ('Athens University of Economics and Business', 3),
#  ('Goethe University Frankfurt', 3),
#  ('McGill University', 3),
#  ('International Monetary Fund', 3),
#  ('Graduate Institute of International and Development Studies', 3),
#  ('Wabash College', 3),
#  ('Florida Atlantic University', 3),
#  ('Federal Reserve Bank of San Francisco', 3),
#  ('Cardiff University', 3),
#  ('Ball State University', 3),
#  ('Wilfrid Laurier University', 3),
#  ('Resources for the Future, Washington DC', 3),
#  ('Maastricht University', 3),
#  ('Federal Reserve Bank of Boston', 3),
#  ('Florida State University', 3),
#  ('University of Munich', 3),
#  ('University of Wisconsin-Milwaukee', 3),
#  ('University of Illinois at Chicago', 3),
#  ('University of Groningen', 3),
#  ('American Enterprise Institute', 3),
#  ('Claremont Graduate University', 3),
#  ('Asian Development Bank', 3),
#  ('RAND Corporation', 3),
#  ('Chapman University', 3),
#  ('Wageningen University', 3),
#  ('University of Georgia', 3),
#  ('European Commission, Joint Research Centre', 3),
#  ('University of Cincinnati', 3),
#  ('University of Oklahoma', 3),
#  ('International Institute for Management Development, Lausanne', 3),
#  ('Binghamton University', 3),
#  ('Vienna University of Economics and Business', 3),
#  ('University of Naples Federico II', 3),
#  ('Old Dominion University', 3),
#  ('University of Massachusetts, Amherst', 2),
#  ('University of Texas at San Antonio', 2),
#  ('University of North Carolina at Charlotte', 2),
#  ('Stevens Institute of Technology', 2),
#  ('Kobe University', 2),
#  ('University of Basel', 2),
#  ('University of Florence', 2),
#  ('WZB Berlin Social Science Center', 2),
#  ('Yale-NUS College', 2),
#  ('University of Miami', 2),
#  ('Queen Mary University of London', 2),
#  ('University of Victoria', 2),
#  ('University of Murcia', 2),
#  ('D. E. Shaw Research', 2),
#  ('University of Arkansas', 2),
#  ('Kyung Hee University', 2),
#  ('Boise State University', 2),
#  ('Clark University', 2),
#  ('ETH Zürich', 2),
#  ('University of Exeter', 2),
#  ('Qatar University', 2),
#  ('Smith College', 2),
#  ('US Environmental Protection Agency', 2),
#  ('United Nations', 2),
#  ('Hamilton College', 2),
#  ('Rider University', 2),
#  ('Ursinus College', 2),
#  ('University of Auckland', 2),
#  ('Urban Institute', 2),
#  ('Collegio Carlo Alberto', 2),
#  ('Marshall University', 2),
#  ('Heriot-Watt University', 2),
#  ('Universidad de Alicante', 2),
#  ('Claremont McKenna College', 2),
#  ('Western Kentucky University', 2),
#  ('Virginia Commonwealth University', 2),
#  ('New School for Social Research', 2),
#  ('Northeastern University, Boston', 2),
#  ('University of North Florida', 2),
#  ('University of Waikato', 2),
#  ('University of California, Merced', 2),
#  ('University of New Hampshire', 2),
#  ('University of Waterloo', 2),
#  ('Southern Utah University', 2),
#  ('ESCP Europe', 2),
#  ('Montana State University', 2),
#  ('University of Missouri', 2),
#  ('Google Inc.', 2),
#  ('Federal Reserve Bank of Philadelphia', 2),
#  ('Cleveland Clinic', 2),
#  ('Kennesaw State University', 2),
#  ('Oklahoma State University', 2),
#  ('City University London', 2),
#  ('University of Louisville', 2),
#  ('Max Planck Institute for Human Development', 2),
#  ('University of Central Florida', 2),
#  ('Lehigh University', 2),
#  ('Rochester Institute of Technology', 2),
#  ('上海交通大学', 2),
#  ('University of South Carolina', 2),
#  ('清华大学', 2),
#  ('University of Mississippi', 2),
#  ('Kent State University', 2),
#  ('Portland State University', 2),
#  ('Wichita State University', 2),
#  ('Universitat Oberta de Catalunya', 2),
#  ('Technical University of Crete', 2),
#  ('University of Patras', 2),
#  ('ESSEC Business School', 2),
#  ('Sungkyunkwan University', 2),
#  ('University of Haifa', 2),
#  ('Wayne State University', 2),
#  ('Office of the Comptroller of the Currency', 2),
#  ('McMaster University', 2),
#  ('Southern Illinois University', 1),
#  ('Texas Tech University', 1),
#  ('University of Lugano', 1),
#  ('Oakland University', 1),
#  ('Bar-Ilan University', 1),
#  ('Karlsruhe Institute of Technology', 1),
#  ('Royal Holloway, University of London', 1),
#  ('LUISS Guido Carli', 1),
#  ('University of Trento', 1),
#  ('Waseda University', 1),
#  ('University of Essex', 1),
#  ('Microsoft Corporation', 1),
#  ('Concordia University', 1),
#  ('Aston University', 1),
#  ('University of Calgary', 1),
#  ('Oberlin College', 1),
#  ('Denison University', 1),
#  ('Korea University', 1),
#  ('Carleton University', 1),
#  ('Spanish National Research Council', 1),
#  ('University of Stavanger', 1),
#  ('University of Bonn', 1),
#  ('University of Bologna', 1),
#  ('University of St Andrews', 1),
#  ('RMIT University, Melbourne', 1),
#  ('Centre College', 1),
#  ('University of Sussex', 1),
#  ('University of Copenhagen', 1),
#  ('University of Bergen', 1),
#  ('Rensselaer Polytechnic Institute', 1),
#  ('Johannes Gutenberg University, Mainz', 1),
#  ('Ohio Wesleyan University', 1),
#  ('University of Nottingham Ningbo China', 1),
#  ('University of California, Santa Cruz', 1),
#  ('Western Washington University', 1),
#  ('Miami University of Ohio', 1),
#  ('University of Sydney', 1),
#  ('Sam Houston State University', 1),
#  ('North Carolina State University', 1),
#  ('Centers for Disease Control and Prevention', 1),
#  ('University of East Anglia', 1),
#  ('University of Richmond', 1),
#  ('Victoria University of Wellington', 1),
#  ('University of Texas at Arlington', 1),
#  ('Tanta University', 1),
#  ('University of Alberta', 1)]

# %%
# collaboration freq
id_pair = {}
name_pair = {}

for doi in df_af_art.index:
    try:
        df_af_art.loc[doi][0]
    except:
        df_af_art_new = df_af_art.loc[doi].sort_values("affiliationid")
        length = len(df_af_art_new)
        for i in range(length-1):
            for j in range(length-1-i):
                try:
                    id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] += 1
                    name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] += 1
                except:
                    id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] = 1
                    name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] = 1

# %%
name_pair_sorted = sorted(name_pair.items(), key=lambda x:x[1], reverse = True)
name_pair_sorted
# Out:
# [('University of Minnesota+University of Minnesota', 30),
#  ('University of Chicago+University of Chicago', 29),
#  ('Harvard University+Harvard University', 27),
#  ('Nature Conservancy+University of Minnesota', 20),
#  ('Columbia University+Columbia University', 19),
#  ('Massachusetts Institute of Technology+University of Chicago', 18),
#  ('Massachusetts Institute of Technology+Stanford University', 18),
#  ('Massachusetts Institute of Technology+Massachusetts Institute of Technology',
#   18),
#  ('Brown University+SKEMA Business School', 15),
#  ('University of California, Berkeley+University of California, Davis', 15),
#  ('Columbia University+New York University', 14),
#  ('Harvard University+University of Chicago', 14),
#  ('New York University+University of California, Berkeley', 13),
#  ('Carnegie Mellon University+Carnegie Mellon University', 12),
#  ('Harvard University+SKEMA Business School', 12),
#  ('Brown University+Harvard University', 12),
#  ('University of Colorado, Boulder+University of South Dakota', 12),
#  ('University of British Columbia+University of Toronto', 11),
#  ('Harvard University+Yale University', 10),
#  ('Northwestern University+Princeton University', 10),
#  ('Harvard University+New York University', 10),
#  ('Harvard University+Massachusetts Institute of Technology', 10),
#  ('Columbia University+Harvard University', 9),
#  ('Hebrew University of Jerusalem+Hebrew University of Jerusalem', 9),
#  ('Bocconi University+London School of Economics', 9),
#  ('University of California, Los Angeles+University of California, Los Angeles',
#   9),
#  ('Massachusetts Institute of Technology+University of California, Berkeley',
#   9),
#  ('University of British Columbia+York University', 9),
#  ('University of Toronto+York University', 9),
#  ('Stanford University+University of California, Berkeley', 9),
#  ('Stanford University+University of California, Davis', 9),
#  ('London School of Economics+London School of Economics', 8),
#  ('New York University+University of Michigan', 8),
#  ('University of Nottingham+University of Zurich', 8),
#  ('Duke University+University of Pennsylvania', 8),
#  ('Massachusetts Institute of Technology+Yale University', 8),
#  ('Swiss Federal Institute of Technology in Lausanne+University of Minnesota',
#   8),
#  ('University of California, Los Angeles+Yale University', 7),
#  ('Harvard University+London School of Economics', 7),
#  ('Massachusetts Institute of Technology+University of Southern California',
#   7),
#  ('Dartmouth College+Stanford University', 7),
#  ('Dartmouth College+Harvard University', 7),
#  ('Princeton University+Princeton University', 7),
#  ('Duke University+Northwestern University', 7),
#  ('University of British Columbia+University of British Columbia', 7),
#  ('Carnegie Mellon University+University of Virginia', 6),
#  ('Boston University+New York University', 6),
#  ('Northwestern University+Pennsylvania State University', 6),
#  ('Northwestern University+University of Wisconsin-Madison', 6),
#  ('Pennsylvania State University+University of Wisconsin-Madison', 6),
#  ('Stanford University+University of Minnesota', 6),
#  ('New York University+University of California, Los Angeles', 6),
#  ('University of California, Berkeley+University of California, Berkeley', 6),
#  ('Boston College+Harvard University', 6),
#  ('Boston University+Hebrew University of Jerusalem', 6),
#  ('University of California, Los Angeles+University of Southern California',
#   6),
#  ('Harvard University+University of California, Berkeley', 6),
#  ('New York University+Princeton University', 6),
#  ('University of California, San Diego+University of Minnesota', 6),
#  ('Centre de Recerca en Economia Internacional+Columbia University', 6),
#  ('Centre de Recerca en Economia Internacional+New York University', 6),
#  ('Columbia University+Massachusetts Institute of Technology', 6),
#  ('University of Michigan+University of Michigan', 6),
#  ('Columbia University+University of Chicago', 6),
#  ('Massachusetts Institute of Technology+University of Pennsylvania', 6),
#  ('Ball State University+Cornell University', 6),
#  ('Stanford University+Stanford University', 6),
#  ('London School of Economics+University of California, San Diego', 6),
#  ('Brown University+University of Toronto', 6),
#  ('Carnegie Mellon University+University of Pennsylvania', 6),
#  ('University of Colorado, Boulder+University of Colorado, Boulder', 6),
#  ('Sciences Po+University of British Columbia', 6),
#  ('Rice University+University of Wisconsin-Madison', 6),
#  ('Seoul National University+University of Pennsylvania', 6),
#  ('Federal Reserve Bank of Dallas+Pennsylvania State University', 6),
#  ('Federal Reserve Bank of Dallas+World Bank', 6),
#  ('Pennsylvania State University+World Bank', 6),
#  ('California Institute of Technology+National University of Singapore', 6),
#  ('Drexel University+Fordham University', 6),
#  ('Harvard University+Pennsylvania State University', 6),
#  ('Princeton University+University of California, San Diego', 6),
#  ('University of Chicago+University of New Mexico', 6),
#  ('University of Florida+University of South Florida', 6),
#  ('University of California, Los Angeles+University of North Carolina at Chapel Hill',
#   6),
#  ('Imperial College London+University of California, Los Angeles', 6),
#  ('Georgetown University+New York University', 5),
#  ('Duke University+Georgetown University', 5),
#  ('Northwestern University+University of Pennsylvania', 5),
#  ('Boston University+Carnegie Mellon University', 5),
#  ('Carnegie Mellon University+University of Oslo', 5),
#  ('Cornell University+Cornell University', 5),
#  ('Princeton University+University of Illinois at Urbana-Champaign', 5),
#  ('Boston University+University of California, Berkeley', 5),
#  ('Columbia University+Williams College', 5),
#  ('Federal Reserve Bank of Chicago+Northwestern University', 5),
#  ('University of Wisconsin-Madison+University of Wisconsin-Madison', 5),
#  ('University of New Mexico+University of New Mexico', 5),
#  ('University of Pennsylvania+University of Pennsylvania', 5),
#  ('University of Chicago+University of California, Los Angeles', 5),
#  ('Duke University+Harvard University', 5),
#  ('New York University+University of Maryland', 5),
#  ('Columbia University+Syracuse University', 5),
#  ('University of Florida+University of Florida', 5),
#  ('Columbia University+Tulane University', 5),
#  ('Brown University+University of Warwick', 4),
#  ('University College London+University of California, Berkeley', 4),
#  ('Swiss Federal Institute of Technology in Lausanne+Washington University in St. Louis',
#   4),
#  ('Brown University+Yale University', 4),
#  ('California Institute of Technology+Stanford University', 4),
#  ("Queen's University+University of Illinois at Urbana-Champaign", 4),
#  ('Tel Aviv University+Tel Aviv University', 4),
#  ('Princeton University+University of California, Berkeley', 4),
#  ('Northwestern University+University of Chicago', 4),
#  ('Stanford University+University of Chicago', 4),
#  ('University of British Columbia+University of California, Berkeley', 4),
#  ('University of Chicago+University of Wisconsin-Madison', 4),
#  ('University of California, Los Angeles+University of Pennsylvania', 4),
#  ('Harvard University+Stanford University', 4),
#  ('Toulouse School of Economics+University of Minnesota', 4),
#  ('Federal Reserve Bank of St. Louis+University of Western Ontario', 4),
#  ('Imperial College London+New York University', 4),
#  ('Stanford University+University of California, Los Angeles', 4),
#  ('Boston University+Massachusetts Institute of Technology', 4),
#  ('University of British Columbia+香港大学', 4),
#  ('University of California, Berkeley+University of Virginia', 4),
#  ('Bank for International Settlements+Massachusetts Institute of Technology',
#   4),
#  ('Brown University+Massachusetts Institute of Technology', 4),
#  ('Massachusetts Institute of Technology+SKEMA Business School', 4),
#  ('Stanford University+University of Padova', 4),
#  ('University of Chicago+University of Pennsylvania', 4),
#  ('Stockholm School of Economics+University of Chicago', 4),
#  ('Arizona State University+California Institute of Technology', 4),
#  ('Arizona State University+Harvard University', 4),
#  ('Arizona State University+Santa Fe Institute', 4),
#  ('California Institute of Technology+Harvard University', 4),
#  ('California Institute of Technology+Santa Fe Institute', 4),
#  ('Harvard University+Santa Fe Institute', 4),
#  ('University of Arizona+University of Wisconsin-Madison', 4),
#  ('Duke University+London School of Economics', 4),
#  ('New York University+Vanderbilt University', 4),
#  ('Boston College+Columbia University', 4),
#  ('University of Pennsylvania+Yale University', 4),
#  ('US Federal Reserve Board+Yale University', 4),
#  ('University of California, Davis+World Bank', 4),
#  ('Massachusetts Institute of Technology+University of Illinois at Urbana-Champaign',
#   4),
#  ('Columbia University+Louisiana State University', 4),
#  ('University of California, Berkeley+University of Western Ontario', 4),
#  ('Massachusetts Institute of Technology+Northwestern University', 4),
#  ('Duke University+University of Rochester', 4),
#  ('Federal Reserve Bank of Atlanta+Pennsylvania State University', 4),
#  ('City University of New York+New York University', 4),
#  ('London Business School+University of Toronto', 4),
#  ('Cornell University+香港大学', 4),
#  ('Emory University+Stanford University', 4),
#  ('Rice University+Seoul National University', 3),
#  ('Rice University+University of North Carolina at Chapel Hill', 3),
#  ('Seoul National University+University of North Carolina at Chapel Hill', 3),
#  ('Columbia University+HEC Paris', 3),
#  ('Columbia University+University of Virginia', 3),
#  ('HEC Paris+University of Virginia', 3),
#  ('Lancaster University+University of Lausanne', 3),
#  ('Lancaster University+University of Manchester', 3),
#  ('University of Lausanne+University of Manchester', 3),
#  ('Babson College+University of Alabama', 3),
#  ('Babson College+University of Colorado, Boulder', 3),
#  ('University of Alabama+University of Colorado, Boulder', 3),
#  ('University of California, Irvine+University of Oregon', 3),
#  ('University of California, Irvine+University of Texas at Dallas', 3),
#  ('University of Oregon+University of Texas at Dallas', 3),
#  ('Harvard University+University of Cambridge', 3),
#  ('University of Cambridge+Yale University', 3),
#  ('California Institute of Technology+HEC Paris', 3),
#  ('California Institute of Technology+University of Zurich', 3),
#  ('HEC Paris+University of Zurich', 3),
#  ('Bocconi University+Rutgers University', 3),
#  ('London School of Economics+Rutgers University', 3),
#  ('Brandeis University+Massachusetts Institute of Technology', 3),
#  ('Brandeis University+Stanford University', 3),
#  ('Brown University+London School of Economics', 3),
#  ('London School of Economics+SKEMA Business School', 3),
#  ('Boston College+Boston College', 3),
#  ('Graduate Institute of International and Development Studies+Hebrew University of Jerusalem',
#   3),
#  ('Graduate Institute of International and Development Studies+International Monetary Fund',
#   3),
#  ('Hebrew University of Jerusalem+International Monetary Fund', 3),
#  ('Monash University+Texas A&M University', 3),
#  ('Monash University+Virginia Polytechnic Institute and State University', 3),
#  ('Texas A&M University+Virginia Polytechnic Institute and State University',
#   3),
#  ('Massachusetts Institute of Technology+Ohio State University', 3),
#  ('Ohio State University+University of Pennsylvania', 3),
#  ('London School of Economics+Massachusetts Institute of Technology', 3),
#  ('London School of Economics+University of California, Berkeley', 3),
#  ('University of Zurich+University of Zurich', 3),
#  ('Federal Reserve Bank of Boston+University of Chicago', 3),
#  ('Federal Reserve Bank of Boston+University of Michigan', 3),
#  ('University of Chicago+University of Michigan', 3),
#  ('University of California, San Diego+University of California, San Diego',
#   3),
#  ('University of Toronto+University of Toronto', 3),
#  ('Federal Reserve Bank of Chicago+Washington University in St. Louis', 3),
#  ('Northwestern University+Washington University in St. Louis', 3),
#  ('University of Oslo+University of Pennsylvania', 3),
#  ('Boston University+Federal Reserve Bank of Atlanta', 3),
#  ('Federal Reserve Bank of Atlanta+University of California, Berkeley', 3),
#  ('Dartmouth College+Temple University', 3),
#  ('Stanford University+Temple University', 3),
#  ('Erasmus University Rotterdam+University of Groningen', 3),
#  ('Erasmus University Rotterdam+VU University Amsterdam', 3),
#  ('University of Groningen+VU University Amsterdam', 3),
#  ('Princeton University+University of Oxford', 3),
#  ('University of Illinois at Urbana-Champaign+University of Oxford', 3),
#  ('Columbia University+Dartmouth College', 3),
#  ('Carnegie Mellon University+University of Florida', 3),
#  ('University of Florida+University of Pennsylvania', 3),
#  ('Syracuse University+University of Chicago', 3),
#  ('Syracuse University+University of California, San Diego', 3),
#  ('University of Chicago+University of California, San Diego', 3),
#  ('Boston University+Duke University', 3),
#  ('Carnegie Mellon University+Duke University', 3),
#  ('Asian Development Bank+Massachusetts Institute of Technology', 3),
#  ('Asian Development Bank+Stanford University', 3),
#  ('University of Chicago+Yale University', 3),
#  ('Brigham Young University+Harvard University', 3),
#  ('Brigham Young University+Yale University', 3),
#  ('National University of Singapore+National University of Singapore', 3),
#  ('University of California, Berkeley+University of Pennsylvania', 3),
#  ('University of California, Davis+University of Pennsylvania', 3),
#  ('Brookings Institution+University of Michigan', 3),
#  ('Brookings Institution+Williams College', 3),
#  ('University of Michigan+Williams College', 3),
#  ('University of Pennsylvania+University of Southern California', 3),
#  ('Duke University+University of Illinois at Urbana-Champaign', 3),
#  ('Harvard University+University of Illinois at Urbana-Champaign', 3),
#  ('University College Dublin+University of British Columbia', 3),
#  ('University College Dublin+University of Oregon', 3),
#  ('University of British Columbia+University of Oregon', 3),
#  ('Michigan State University+University of Wyoming', 3),
#  ('Michigan State University+Wageningen University', 3),
#  ('University of Wyoming+Wageningen University', 3),
#  ('New York University+U.S. Census Bureau', 3),
#  ('U.S. Census Bureau+University of Maryland', 3),
#  ('Cornell University+Stanford University', 3),
#  ('Cornell University+University of California, Berkeley', 3),
#  ('New York University+University of Colorado, Boulder', 3),
#  ('University of California, Berkeley+University of Colorado, Boulder', 3),
#  ('Columbia University+University of California, Davis', 3),
#  ('Syracuse University+University of California, Davis', 3),
#  ('Duke University+香港大学', 3),
#  ('University of Pennsylvania+香港大学', 3),
#  ('Bocconi University+Harvard University', 3),
#  ('International Institute for Management Development, Lausanne+Stanford University',
#   3),
#  ('International Institute for Management Development, Lausanne+University of Zurich',
#   3),
#  ('Stanford University+University of Zurich', 3),
#  ('Tilburg University+University of California, San Diego', 3),
#  ('Tilburg University+University of Southern California', 3),
#  ('University of California, San Diego+University of Southern California', 3),
#  ('Tulane University+Williams College', 3),
#  ('Georgetown University+National University of Singapore', 3),
#  ('National University of Singapore+New York University', 3),
#  ('Bank for International Settlements+London School of Economics', 3),
#  ('Bank for International Settlements+University of Queensland', 3),
#  ('London School of Economics+University of Queensland', 3),
#  ('University of North Carolina at Chapel Hill+University of North Carolina at Chapel Hill',
#   3),
#  ('Columbia University+University of Naples Federico II', 3),
#  ('Columbia University+Vienna University of Economics and Business', 3),
#  ('University of Naples Federico II+Vienna University of Economics and Business',
#   3),
#  ('Old Dominion University+State University of New York at Stony Brook', 3),
#  ('Old Dominion University+University of South Florida', 3),
#  ('State University of New York at Stony Brook+University of South Florida',
#   3),
#  ('Duke University+Johns Hopkins University', 3),
#  ('Georgetown University+Johns Hopkins University', 3),
#  ('Stanford University+University of Michigan', 3),
#  ('University of California, Davis+University of Michigan', 3),
#  ('Australian National University+University of North Carolina at Chapel Hill',
#   3),
#  ('Australian National University+南洋理工大学', 3),
#  ('University of North Carolina at Chapel Hill+南洋理工大学', 3),
#  ('Bocconi University+HEC Paris', 3),
#  ('HEC Paris+London School of Economics', 3),
#  ('Temple University+University of Massachusetts, Amherst', 2),
#  ('Carnegie Mellon University+University of California, Berkeley', 2),
#  ('American University+University of California, Davis', 2),
#  ('University of Texas at San Antonio+University of Utah', 2),
#  ('EDHEC Business School+Santa Clara University', 2),
#  ('Tulane University+University of Pittsburgh', 2),
#  ('Indiana University+University of North Carolina at Charlotte', 2),
#  ('Stevens Institute of Technology+University of Texas at Dallas', 2),
#  ('New York University+University of Texas at Austin', 2),
#  ('Rice University+Rice University', 2),
#  ('University of California, Los Angeles+南洋理工大学', 2),
#  ('Copenhagen Business School+Washington University in St. Louis', 2),
#  ('Kobe University+University of California, Riverside', 2),
#  ('University of Basel+University of California, Irvine', 2),
#  ('University of Florence+University of Florence', 2),
#  ('Ecole des Ponts ParisTech+Ecole des Ponts ParisTech', 2),
#  ('Stanford University+University of Washington', 2),
#  ('Sciences Po+University of Western Ontario', 2),
#  ('Boston College+University of California, Los Angeles', 2),
#  ('Rutgers University+Williams College', 2),
#  ('University of Minnesota+University of Pittsburgh', 2),
#  ('Federal Reserve Bank of New York+University of Bern', 2),
#  ('University of British Columbia+University of Wisconsin-Madison', 2),
#  ('Aalto University+University of Oregon', 2),
#  ('Princeton University+Toulouse School of Economics', 2),
#  ('Autonomous University of Barcelona+Universidad Carlos III de Madrid', 2),
#  ('University of British Columbia+Yale-NUS College', 2),
#  ('Simon Fraser University+Simon Fraser University', 2),
#  ('Duke University+State University of New York at Stony Brook', 2),
#  ('Columbia University+Paris School of Economics', 2),
#  ('University College London+University of Surrey', 2),
#  ('Boston College+Tufts University', 2),
#  ('University of California, Berkeley+University of Edinburgh', 2),
#  ('Katholieke Universiteit, Leuven+Yale University', 2),
#  ('Northwestern University+香港科技大学', 2),
#  ('Paris School of Economics+Queen Mary University of London', 2),
#  ('University of Pennsylvania+University of Rochester', 2),
#  ('Cornell University+London School of Economics', 2),
#  ('London Business School+Pennsylvania State University', 2),
#  ('London School of Economics+Yale University', 2),
#  ('University of British Columbia+University of Victoria', 2),
#  ('University of California, Berkeley+University of Nottingham', 2),
#  ('Toulouse School of Economics+University of Southern California', 2),
#  ('London School of Economics+Universidad Carlos III de Madrid', 2),
#  ('Aalto University+Yale University', 2),
#  ('Brigham Young University+University of Iowa', 2),
#  ('Arizona State University+University of Manchester', 2),
#  ('Federal Reserve Bank of Chicago+University of Chicago', 2),
#  ('University of Minnesota+University of Pennsylvania', 2),
#  ('Bocconi University+New York University', 2),
#  ('Boston University+Federal Reserve Bank of Richmond', 2),
#  ('Boston College+Federal Reserve Bank of New York', 2),
#  ('Autonomous University of Barcelona+Stanford University', 2),
#  ('McGill University+New York University', 2),
#  ('INSEAD+University of California, Berkeley', 2),
#  ('University of Murcia+University of Mannheim', 2),
#  ('Aalto University+Stockholm University', 2),
#  ('Carnegie Mellon University+Cornell University', 2),
#  ('Harvard University+London Business School', 2),
#  ('London School of Economics+Stanford University', 2),
#  ('D. E. Shaw Research+Massachusetts Institute of Technology', 2),
#  ('University of Southern California+University of Southern California', 2),
#  ('ENSAE ParisTech+University of Chicago', 2),
#  ('University of British Columbia+University of Namur', 2),
#  ('Johns Hopkins University+University of California, Berkeley', 2),
#  ('Harvard University+Princeton University', 2),
#  ('US Federal Reserve Board+University of Illinois at Urbana-Champaign', 2),
#  ('Central European University+Massachusetts Institute of Technology', 2),
#  ('University of Minnesota+Yale University', 2),
#  ('European University Institute+Federal Reserve Bank of New York', 2),
#  ('University of Chicago+University of California, Irvine', 2),
#  ('Columbia University+Yale University', 2),
#  ('Tel Aviv University+University of California, San Diego', 2),
#  ('Centre de Recerca en Economia Internacional+World Bank', 2),
#  ('Massachusetts Institute of Technology+University of Lausanne', 2),
#  ('Central European University+Santa Fe Institute', 2),
#  ('Dartmouth College+University of Chicago', 2),
#  ('European University Institute+Yale University', 2),
#  ('Columbia University+Washington University in St. Louis', 2),
#  ('Harvard University+Ohio State University', 2),
#  ('Tel Aviv University+University of Melbourne', 2),
#  ('Brown University+University of Arkansas', 2),
#  ('Purdue University+University of Wyoming', 2),
#  ('Johns Hopkins University+Kyung Hee University', 2),
#  ('Boise State University+University of California, Santa Barbara', 2),
#  ('George Washington University+University of Chicago', 2),
#  ('Boston University+Columbia University', 2),
#  ('American University+Clark University', 2),
#  ('Columbia University+University of Wisconsin-Madison', 2),
#  ('ETH Zürich+Toulouse School of Economics', 2),
#  ('University of Chicago+University of California, Berkeley', 2),
#  ('City University of New York+University of Minnesota', 2),
#  ('Stanford University+University of Maryland', 2),
#  ('Washington University in St. Louis+Washington University in St. Louis', 2),
#  ('Northwestern University+Stanford University', 2),
#  ('City University of New York+University of Amsterdam', 2),
#  ('Johns Hopkins University+University of British Columbia', 2),
#  ('Cornell University+Ohio State University', 2),
#  ('ENSAE ParisTech+ENSAE ParisTech', 2),
#  ('Federal Reserve Bank of San Francisco+University of California, San Diego',
#   2),
#  ('Tel Aviv University+University of Maryland', 2),
#  ('INSEAD+University of Melbourne', 2),
#  ('BI Norwegian Business School+University of Houston', 2),
#  ('Cardiff University+University of Exeter', 2),
#  ('Harvard University+Wake Forest University', 2),
#  ('Georgetown University+University of California, Berkeley', 2),
#  ('Brown University+New York University', 2),
#  ('University of California, San Diego+University of Michigan', 2),
#  ('Massachusetts Institute of Technology+Wabash College', 2),
#  ('Duke University+Washington University in St. Louis', 2),
#  ('New York University+Wilfrid Laurier University', 2),
#  ('Qatar University+Vanderbilt University', 2),
#  ('香港中文大学+香港大学', 2),
#  ('Resources for the Future, Washington DC+University of Maryland', 2),
#  ('Federal Reserve Bank of New York+New York University', 2),
#  ('Carnegie Mellon University+Smith College', 2),
#  ('European University Institute+University of Oxford', 2),
#  ('University of Chicago+University of Namur', 2),
#  ('Bocconi University+Pennsylvania State University', 2),
#  ('Columbia University+Toulouse School of Economics', 2),
#  ('Imperial College London+Pompeu Fabra University', 2),
#  ('London School of Economics+U.S. Census Bureau', 2),
#  ('University of Toronto+香港大学', 2),
#  ('University of California, Los Angeles+University of Zurich', 2),
#  ('Columbia University+University of Oxford', 2),
#  ('Harvard University+Indiana University', 2),
#  ('Michigan State University+University of Toronto', 2),
#  ('Harvard University+University of California, Davis', 2),
#  ('Harvard University+University of Southern California', 2),
#  ('US Environmental Protection Agency+University of Illinois at Urbana-Champaign',
#   2),
#  ('University of Michigan+World Bank', 2),
#  ('Dartmouth College+Massachusetts Institute of Technology', 2),
#  ('City University of New York+Duke University', 2),
#  ('University of Chicago+University of Virginia', 2),
#  ('United Nations+University of California, Berkeley', 2),
#  ('Center for Monetary and Financial Studies (CEMFI)+Simon Fraser University',
#   2),
#  ('Columbia University+University of Houston', 2),
#  ('Hamilton College+Hamilton College', 2),
#  ('University of California, Santa Barbara+University of California, Santa Barbara',
#   2),
#  ('Louisiana State University+Rider University', 2),
#  ('Ursinus College+University of Pennsylvania', 2),
#  ('INSEAD+Stanford University', 2),
#  ('Brandeis University+University of Notre Dame', 2),
#  ('Brookings Institution+Duke University', 2),
#  ('Centre de Recerca en Economia Internacional+London School of Economics', 2),
#  ('University of Lausanne+University of Virginia', 2),
#  ('University College Dublin+University College Dublin', 2),
#  ('Stanford University+University of Munich', 2),
#  ('Princeton University+Yale University', 2),
#  ('Tufts University+University of California, Los Angeles', 2),
#  ('Federal Reserve Bank of Chicago+University of Notre Dame', 2),
#  ('US Federal Reserve Board+University of California, Irvine', 2),
#  ('Rutgers University+US Federal Reserve Board', 2),
#  ('Banco de Portugal+Massachusetts Institute of Technology', 2),
#  ('Duke University+Michigan State University', 2),
#  ('Georgia Institute of Technology+University of Notre Dame', 2),
#  ('University of Washington+University of Washington', 2),
#  ('Harvard University+University of Auckland', 2),
#  ('Stanford University+University of Notre Dame', 2),
#  ('New York University+University of Chicago', 2),
#  ('University of Pennsylvania+University of Wisconsin-Madison', 2),
#  ('Urban Institute+University of Colorado Denver', 2),
#  ('Collegio Carlo Alberto+University of Southern California', 2),
#  ('London School of Economics+University of Chicago', 2),
#  ('Cornell University+University of California, Irvine', 2),
#  ('Marshall University+Tulane University', 2),
#  ('Brookings Institution+Harvard University', 2),
#  ('University of Houston+World Bank', 2),
#  ('Rice University+US Federal Reserve Board', 2),
#  ('Federal Reserve Bank of Dallas+Federal Reserve Bank of New York', 2),
#  ('Indiana University+University of California, Berkeley', 2),
#  ('Heriot-Watt University+University of British Columbia', 2),
#  ('Universidad de Alicante+University of Oxford', 2),
#  ('Katholieke Universiteit, Leuven+University of Toronto', 2),
#  ('University of New South Wales+University of Western Ontario', 2),
#  ('Duke University+Duke University', 2),
#  ('University of Michigan+University of Montreal', 2),
#  ('University of Vienna+University of Zurich', 2),
#  ('University of California, Berkeley+University of Michigan', 2),
#  ('University of Colorado Denver+University of Colorado Denver', 2),
#  ('University of New South Wales+University of Virginia', 2),
#  ('New York University+University of Arizona', 2),
#  ('University of New Mexico+University of Oregon', 2),
#  ('Clemson University+Western Kentucky University', 2),
#  ('Duke University+University of Chicago', 2),
#  ('HEC Paris+University of Amsterdam', 2),
#  ('Virginia Commonwealth University+Virginia Commonwealth University', 2),
#  ('National University of Singapore+香港科技大学', 2),
#  ('ENSAE ParisTech+Maastricht University', 2),
#  ('University of British Columbia+University of Chicago', 2),
#  ('New School for Social Research+University of Pennsylvania', 2),
#  ('Harvard University+Northeastern University, Boston', 2),
#  ('University of California, Davis+University of North Florida', 2),
#  ('Duke University+University of Wisconsin-Madison', 2),
#  ('University of Pennsylvania+University of Zurich', 2),
#  ('University of California, Berkeley+University of California, San Diego', 2),
#  ('University of Arizona+University of Wisconsin-Milwaukee', 2),
#  ('Claremont Graduate University+University of Kentucky', 2),
#  ('Stanford University+University of Utah', 2),
#  ('Bocconi University+Yale University', 2),
#  ('University of Oregon+University of Oregon', 2),
#  ('George Mason University+University of Pennsylvania', 2),
#  ('Cornell University+Indiana University', 2),
#  ('Australian National University+University of Queensland', 2),
#  ('American Enterprise Institute+University of California, Berkeley', 2),
#  ('IESE Business School+Katholieke Universiteit, Leuven', 2),
#  ('Ben-Gurion University of the Negev+Ben-Gurion University of the Negev', 2),
#  ('University of Wyoming+University of Wyoming', 2),
#  ('Princeton University+University of Illinois at Chicago', 2),
#  ('Massachusetts Institute of Technology+University of Oxford', 2),
#  ('Autonomous University of Barcelona+Ben-Gurion University of the Negev', 2),
#  ('Copenhagen Business School+Georgia State University', 2),
#  ('Georgia State University+University of Virginia', 2),
#  ('Boston College+University of Michigan', 2),
#  ('Boston College+College of William and Mary', 2),
#  ('University of Arizona+University of Waikato', 2),
#  ('Cornell University+World Bank', 2),
#  ('Ohio State University+University of Iowa', 2),
#  ('Monash University+Purdue University', 2),
#  ('Federal Reserve Bank of Atlanta+Federal Reserve Bank of Atlanta', 2),
#  ('Rutgers University+University of California, Merced', 2),
#  ('Michigan State University+University of New Hampshire', 2),
#  ('University of California, Irvine+University of Illinois at Urbana-Champaign',
#   2),
#  ('George Mason University+Stanford University', 2),
#  ('Carnegie Mellon University+Pennsylvania State University', 2),
#  ('Indiana University+University of Nebraska-Lincoln', 2),
#  ("Queen's University+University of British Columbia", 2),
#  ('Dartmouth College+Federal Reserve Bank of New York', 2),
#  ('Columbia University+Georgetown University', 2),
#  ('University of California, San Diego+University of Oregon', 2),
#  ('Cornell University+London Business School', 2),
#  ('University of California, Santa Barbara+香港中文大学', 2),
#  ('University of Houston+University of Maryland', 2),
#  ('Ben-Gurion University of the Negev+Hebrew University of Jerusalem', 2),
#  ('Copenhagen Business School+New York University', 2),
#  ('Columbia University+University of Pennsylvania', 2),
#  ('US Federal Reserve Board+University of Oslo', 2),
#  ('RAND Corporation+Yale University', 2),
#  ('Princeton University+Swiss Federal Institute of Technology in Lausanne', 2),
#  ('Athens University of Economics and Business+University of Wisconsin-Madison',
#   2),
#  ('University of Michigan+Wake Forest University', 2),
#  ('Massachusetts Institute of Technology+University of California, Davis', 2),
#  ('New York University+University of Wisconsin-Madison', 2),
#  ('Bocconi University+Stockholm University', 2),
#  ('Federal Reserve Bank of Richmond+University of Pennsylvania', 2),
#  ('University of California, Santa Barbara+University of Waterloo', 2),
#  ('Dartmouth College+Dartmouth College', 2),
#  ('College of William and Mary+Southern Utah University', 2),
#  ('Interdisciplinary Center, Herzliya+Yale University', 2),
#  ('ESCP Europe+University of Minnesota', 2),
#  ("Queen's University+University of Southern California", 2),
#  ('IE University+University of Chicago', 2),
#  ('Cornell University+Massachusetts Institute of Technology', 2),
#  ('New York University+University of Notre Dame', 2),
#  ('Florida Atlantic University+University of Nebraska-Lincoln', 2),
#  ('Arizona State University+University of Minnesota', 2),
#  ('University of California, San Diego+University of Texas at Austin', 2),
#  ('College of William and Mary+University of Missouri', 2),
#  ('George Mason University+George Mason University', 2),
#  ('Chapman University+University of Chicago', 2),
#  ('Duke University+New York University', 2),
#  ('Georgia State University+Yale University', 2),
#  ('University of California, Berkeley+University of Melbourne', 2),
#  ('Columbia University+IE University', 2),
#  ('London School of Economics+Stockholm School of Economics', 2),
#  ('Harvard University+Toulouse School of Economics', 2),
#  ('London School of Economics+University of Melbourne', 2),
#  ('Columbia University+World Bank', 2),
#  ('Google Inc.+Georgetown University', 2),
#  ('University of Edinburgh+University of Edinburgh', 2),
#  ('Harvard University+Purdue University', 2),
#  ("Queen's University+University of Notre Dame", 2),
#  ('Ecole des Ponts ParisTech+University of Pennsylvania', 2),
#  ('Princeton University+香港科技大学', 2),
#  ('Federal Reserve Bank of Philadelphia+Federal Reserve Bank of Richmond', 2),
#  ('American University+University of Texas at Austin', 2),
#  ('Cleveland Clinic+Harvard University', 2),
#  ('University of Texas at Austin+University of Texas at Austin', 2),
#  ('Bank for International Settlements+European Commission, Joint Research Centre',
#   2),
#  ('Cornell University+Temple University', 2),
#  ('University of Melbourne+University of Texas at Austin', 2),
#  ('University of North Carolina at Chapel Hill+World Bank', 2),
#  ('Purdue University+University of Pittsburgh', 2),
#  ('Nova School of Business and Economics+University of California, San Diego',
#   2),
#  ('Duke University+University of Michigan', 2),
#  ('University of North Carolina at Chapel Hill+University of Utah', 2),
#  ('Kennesaw State University+University of Oxford', 2),
#  ('Oklahoma State University+Southern Methodist University', 2),
#  ('Case Western Reserve University+Case Western Reserve University', 2),
#  ('Pennsylvania State University+University of Southern California', 2),
#  ('University of Louisville+University of North Carolina at Chapel Hill', 2),
#  ('Binghamton University+Northwestern University', 2),
#  ('Yale University+Yale University', 2),
#  ('Max Planck Institute for Human Development+Michigan State University', 2),
#  ('Goethe University Frankfurt+New York University', 2),
#  ('National University of Singapore+南洋理工大学', 2),
#  ('Center for Monetary and Financial Studies (CEMFI)+University of Texas at Austin',
#   2),
#  ('Emory University+University of Virginia', 2),
#  ('University of Central Florida+Virginia Polytechnic Institute and State University',
#   2),
#  ('University of Connecticut+University of Oklahoma', 2),
#  ('Louisiana State University+Southern Methodist University', 2),
#  ('Lehigh University+Simon Fraser University', 2),
#  ('Rochester Institute of Technology+University of Utah', 2),
#  ('University of California, Los Angeles+上海交通大学', 2),
#  ('Indiana University+University of Cincinnati', 2),
#  ('Boston University+University of Hawaii', 2),
#  ('Boston University+University of Montreal', 2),
#  ('Harvard University+University of South Carolina', 2),
#  ('Arizona State University+Southern Methodist University', 2),
#  ('University of Delaware+University of Washington', 2),
#  ('Duke University+清华大学', 2),
#  ('Brandeis University+Harvard University', 2),
#  ('National University of Singapore+Virginia Polytechnic Institute and State University',
#   2),
#  ('Rice University+香港大学', 2),
#  ('University of Georgia+University of Mississippi', 2),
#  ('Drexel University+University of Rochester', 2),
#  ('University of Florida+University of Pittsburgh', 2),
#  ('Drexel University+Georgia Institute of Technology', 2),
#  ('University of Oregon+University of Washington', 2),
#  ('Clemson University+Duke University', 2),
#  ('Kent State University+University of Connecticut', 2),
#  ('Duke University+Portland State University', 2),
#  ('Texas A&M University+Wichita State University', 2),
#  ('Universidad Carlos III de Madrid+Universitat Oberta de Catalunya', 2),
#  ('Emory University+London Business School', 2),
#  ('Duke University+University of Oxford', 2),
#  ('INSEAD+Johns Hopkins University', 2),
#  ('Purdue University+University of Surrey', 2),
#  ('Boston College+HEC Paris', 2),
#  ('Tel Aviv University+University of Utah', 2),
#  ('Dartmouth College+University of Maryland', 2),
#  ('Nova School of Business and Economics+University of California, Los Angeles',
#   2),
#  ('University of Oregon+Virginia Polytechnic Institute and State University',
#   2),
#  ('University of Cambridge+University of Utah', 2),
#  ('University of California, Los Angeles+University of Texas at Austin', 2),
#  ('New York University+Yale University', 2),
#  ('Technical University of Crete+University of Patras', 2),
#  ('Michigan State University+Tulane University', 2),
#  ('Emory University+Vanderbilt University', 2),
#  ('Swiss Federal Institute of Technology in Lausanne+香港科技大学', 2),
#  ('Emory University+University of California, Los Angeles', 2),
#  ('Federal Reserve Bank of New York+University of Illinois at Urbana-Champaign',
#   2),
#  ('ESSEC Business School+香港科技大学', 2),
#  ('Emory University+University of Texas at Austin', 2),
#  ('Columbia University+香港科技大学', 2),
#  ('Sungkyunkwan University+York University', 2),
#  ('Interdisciplinary Center, Herzliya+New York University', 2),
#  ('Carnegie Mellon University+New York University', 2),
#  ('Clemson University+Rice University', 2),
#  ('Arizona State University+University of North Carolina at Chapel Hill', 2),
#  ('Cornell University+University of California, Riverside', 2),
#  ('Interdisciplinary Center, Herzliya+University of Haifa', 2),
#  ('University of Minnesota+Wayne State University', 2),
#  ('University of Notre Dame+University of Virginia', 2),
#  ('University of Florida+University of New Mexico', 2),
#  ('Duke University+Office of the Comptroller of the Currency', 2),
#  ('Pennsylvania State University+University of North Carolina at Chapel Hill',
#   2),
#  ('University of Amsterdam+Washington University in St. Louis', 2),
#  ('McMaster University+Rutgers University', 2),
#  ('Georgetown University+University of Rochester', 2),
#  ('University of Illinois at Urbana-Champaign+University of Virginia', 2),
#  ('Boston College+City University of New York', 2)]

# %%
conn.close()
