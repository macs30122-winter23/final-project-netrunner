# %% [markdown]
# # Data Cleaning and Put into SQL

# %%
import pandas as pd
import sqlite3
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import bs4
import time
import random
import numpy as np

# %% [markdown]
# ## Clean author_article.csv

# %%
# clean author_article
df_art_au = pd.read_csv("author_article.csv", encoding = "utf-8-sig").drop_duplicates()
df_art_au.to_csv("author_article.csv", encoding = "utf-8-sig", index = False)
df_art_au.to_csv("author_article_no_header.csv", encoding = "utf-8-sig", index = False, header = False)

# %% [markdown]
# ## Clean article.csv

# %%
# select valid records with valid doi, issue format, and not duplicated
def select_valid(df):
    df_s = df[(df["doi"].str[:3] == "10.") & (df["volume"].str.contains("Supplement") == False) & 
              (df["volume"].str.contains("_Part_") == False) & 
              (df["volume"].str.contains("S1") == False) & 
              (df["volume"].str.contains("issue ") == True)].drop_duplicates(subset=["doi"]).reset_index(drop = True)
    return df_s

# convert volume to date
def conv_volume_to_date(v,freq):
    v_list = v.split(", ")
    year = v_list[0]
    issue = v_list[2].replace("issue ","")
    if freq == 4:
        return year+"-"+str(int(issue)*3-1)+"-15"
    elif freq == 6 or freq == 5:
        return year+"-"+str(int(issue)*2)+"-01"
    elif freq == 12:
        return year+"-"+issue+"-15"
    elif freq == 3:
        return year+"-"+str(int(issue)*3)+"-01"
    elif freq == 2:
        return year+"-"+str(int(issue)*6-2)+"-01"
    elif freq == 1:
        return year+"-"+str(7)+"-01"
    
# calculate issue frequency
def cal_freq(vs):
    dict = {}
    years = [int(v.split(", ")[0]) for v in vs]
    unique_years = set(years)
    issues = [int(v.split(", ")[2].replace("issue ","")) for v in vs]
    for unique_year in unique_years:
        max_issue = 0
        for i in range(len(years)):
            if unique_year == years[i]:
                if issues[i] > max_issue:
                    max_issue = issues[i]
        dict[unique_year] = max_issue

    return dict

# %% [markdown]
# ### 1. RFS

# %%
# clean rfs
df_rfs = pd.read_csv("data/journals/raw_data/rfs.csv", encoding = "utf-8-sig").astype("str")
df_rfs["abstract"] = df_rfs["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_rfs_s = select_valid(df_rfs)
freq = cal_freq(df_rfs_s["volume"])

dates = []
for idx in df_rfs_s.index:
    year = int(df_rfs_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_rfs_s.loc[idx,"volume"],freq[year]))

df_rfs_s["date"] = dates
df_rfs_s.head()
# Out:
#                        journal  \
# 0  Review of Financial Studies
# 1  Review of Financial Studies
# 2  Review of Financial Studies
# 3  Review of Financial Studies
# 4  Review of Financial Studies
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                              authors  \
# 0                ['Jerome Detemple', 'Angel Serrat']
# 1               ['Wayne Ferson', 'Andrew F. Siegel']
# 2                ['Gurdip Bakshi', 'Nikunj Kapadia']
# 3                  ['Harrison Hong', 'Jeremy Stein']
# 4  ['Dong-Hyun Ahn', 'Jennifer Conrad', 'Robert D...
#
#                             volume jel  \
# 0  2003, vol. 16, issue 2, 597-629  []
# 1  2003, vol. 16, issue 2, 567-595  []
# 2  2003, vol. 16, issue 2, 527-566  []
# 3  2003, vol. 16, issue 2, 487-525  []
# 4  2003, vol. 16, issue 2, 459-485  []
#
#                                             abstract  \
# 0  This article studies an intertemporal economy ...
# 1  Hansen and Jagannathan (1991) (hereafter HJ) d...
# 2  We investigate whether the volatility risk pre...
# 3  We develop a theory of market crashes based on...
# 4  We assess the profitability of momentum strate...
#
#                                                  url                 doi  \
# 0  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg003
# 1  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg004
# 2  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg002
# 3  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg006
# 4  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg001
#
#         date
# 0  2003-5-15
# 1  2003-5-15
# 2  2003-5-15
# 3  2003-5-15
# 4  2003-5-15

# %% [markdown]
# ### 2. RES

# %%
# clean res
df_res = pd.read_csv("data/journals/raw_data/res.csv", encoding = "utf-8-sig").astype("str")
df_res["abstract"] = df_res["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_res_s = select_valid(df_res)
freq = cal_freq(df_res_s["volume"])

dates = []
for idx in df_res_s.index:
    year = int(df_res_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_res_s.loc[idx,"volume"],freq[year]))

df_res_s["date"] = dates
df_res_s.head()
# Out:
#                       journal  \
# 0  Review of Economic Studies
# 1  Review of Economic Studies
# 2  Review of Economic Studies
# 3  Review of Economic Studies
# 4  Review of Economic Studies
#
#                                                title  \
# 0  The Dynamics of Return Migration, Human Capita...
# 1  The Impact of Car Pollution on Infant and Chil...
# 2  The Welfare Effects of Transportation Infrastr...
# 3  Subjective Models of the Macroeconomy: Evidenc...
# 4   Product Life Cycle, Learning, and Nominal Shocks
#
#                                              authors  \
# 0  ['Jerome Adda', 'Christian Dustmann', 'Joseph-...
# 1             ['Diane Alexander', 'Hannes Schwandt']
# 2                 ['Treb Allen', 'Costas Arkolakis']
# 3  ['Peter Andrebriq', 'Carlo Pizzinelli', 'Chris...
# 4                      ['David Argente', 'Chen Yeh']
#
#                               volume jel  \
# 0  2022, vol. 89, issue 6, 2841-2871  []
# 1  2022, vol. 89, issue 6, 2872-2910  []
# 2  2022, vol. 89, issue 6, 2911-2957  []
# 3  2022, vol. 89, issue 6, 2958-2991  []
# 4  2022, vol. 89, issue 6, 2992-3054  []
#
#                                             abstract  \
# 0  This article develops and estimates a dynamic ...
# 1  In 2008, Volkswagen introduced a new generatio...
# 2  Each year in the US, hundreds of billions of d...
# 3  We study people’s subjective models of the mac...
# 4  This article documents a new set of stylized f...
#
#                                                  url                     doi  \
# 0  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac003
# 1  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac007
# 2  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac001
# 3  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac008
# 4  https://econpapers.repec.org/article/ouprestud...  10.1093/restud/rdac004
#
#          date
# 0  2022-12-01
# 1  2022-12-01
# 2  2022-12-01
# 3  2022-12-01
# 4  2022-12-01

# %% [markdown]
# ### 3. QJE

# %%
# clean qje
df_qje = pd.read_csv("data/journals/raw_data/qje.csv", encoding = "utf-8-sig").astype("str")
df_qje["abstract"] = df_qje["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_qje_s = select_valid(df_qje)
freq = cal_freq(df_qje_s["volume"])

dates = []
for idx in df_qje_s.index:
    year = int(df_qje_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_qje_s.loc[idx,"volume"],freq[year]))

df_qje_s["date"] = dates
df_qje_s.head()
# Out:
#                               journal  \
# 0  The Quarterly Journal of Economics
# 1  The Quarterly Journal of Economics
# 2  The Quarterly Journal of Economics
# 3  The Quarterly Journal of Economics
# 4  The Quarterly Journal of Economics
#
#                                                title  \
# 0  Systemic Discrimination Among Large U.S. Emplo...
# 1  Valuing the Global Mortality Consequences of C...
# 2  Reshaping Global Trade: The Immediate and Long...
# 3  Sexual Harassment and Gender Inequality in the...
# 4  The Quality and Efficiency of Public and Priva...
#
#                                              authors  \
# 0  ['Patrick Kline', 'Evan K Rose', 'Christopher ...
# 1  ['Tamma Carleton', 'Amir Jina', 'Michael Delga...
# 2                                      ['Chenzi Xu']
# 3                   ['Olle Folke', 'Johanna Rickne']
# 4              ['Daniel Knutsson', 'Björn Tyrefors']
#
#                                volume jel  \
# 0  2022, vol. 137, issue 4, 1963-2036  []
# 1  2022, vol. 137, issue 4, 2037-2105  []
# 2  2022, vol. 137, issue 4, 2107-2161  []
# 3  2022, vol. 137, issue 4, 2163-2212  []
# 4  2022, vol. 137, issue 4, 2213-2262  []
#
#                                             abstract  \
# 0  We study the results of a massive nationwide c...
# 1  Using 40 countries’ subnational data, we estim...
# 2  I show that a disruption to the financial sect...
# 3  We describe how sexual harassment contributes ...
# 4  Economic theory predicts that outsourcing publ...
#
#                                                  url                  doi  \
# 0  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac024
# 1  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac020
# 2  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac016
# 3  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac018
# 4  https://econpapers.repec.org/article/oupqjecon...  10.1093/qje/qjac014
#
#          date
# 0  2022-11-15
# 1  2022-11-15
# 2  2022-11-15
# 3  2022-11-15
# 4  2022-11-15

# %% [markdown]
# ### 4. JPE

# %%
# clean jpe
df_jpe = pd.read_csv("data/journals/raw_data/jpe.csv", encoding = "utf-8-sig").astype("str")
df_jpe["abstract"] = df_jpe["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_jpe["doi"] = df_jpe["doi"].apply(lambda x: x.replace("http://dx.doi.org/",""))
df_jpe_s = select_valid(df_jpe)
freq = cal_freq(df_jpe_s["volume"])

dates = []
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_jpe_s.loc[idx,"volume"],freq[year]))

df_jpe_s["date"] = dates

# modify date for 2023
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_jpe_s.loc[idx, "date"] = conv_volume_to_date(df_jpe_s.loc[idx,"volume"],12)

df_jpe_s.head()
# Out:
#                         journal  \
# 0  Journal of Political Economy
# 1  Journal of Political Economy
# 2  Journal of Political Economy
# 3  Journal of Political Economy
# 4  Journal of Political Economy
#
#                                                title  \
# 0                        Collective Brand Reputation
# 1         The Mechanics of the Industrial Revolution
# 2  Optimal Cooperative Taxation in the Global Eco...
# 3          Personalized Pricing and Consumer Welfare
# 4  A Semistructural Methodology for Policy Counte...
#
#                                              authors  \
# 0                 ['Volker Nocke', 'Roland Strausz']
# 1   ['Morgan Kelly', 'Joel Mokyr', 'Cormac Ó Gráda']
# 2  ['V. V. Chari', 'Juan Pablo Nicolini', 'Pedro ...
# 3               ['Jean-Pierre Dubé', 'Sanjog Misra']
# 4                                  ['Martin Beraja']
#
#                                volume jel  \
# 0     2023, vol. 131, issue 1, 1 - 58  []
# 1    2023, vol. 131, issue 1, 59 - 94  []
# 2   2023, vol. 131, issue 1, 95 - 130  []
# 3  2023, vol. 131, issue 1, 131 - 189  []
# 4  2023, vol. 131, issue 1, 190 - 201  []
#
#                                             abstract  \
# 0  We develop a theory of collective brand reputa...
# 1  Although there are many competing explanations...
# 2  How should countries cooperate in setting fisc...
# 3  We study the welfare implications of personali...
# 4  I propose a methodology for constructing count...
#
#                                                  url             doi  \
# 0  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720986
# 1  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720890
# 2  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720889
# 3  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720793
# 4  https://econpapers.repec.org/article/ucpjpolec...  10.1086/720982
#
#         date
# 0  2023-1-15
# 1  2023-1-15
# 2  2023-1-15
# 3  2023-1-15
# 4  2023-1-15

# %% [markdown]
# ### 5. E

# %%
# clean e
df_e = pd.read_csv("data/journals/raw_data/e.csv", encoding = "utf-8-sig").astype("str")
df_e["abstract"] = df_e["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_e["doi"] = df_e["doi"].apply(lambda x: x.replace("https://doi.org/",""))
df_e_s = select_valid(df_e)
freq = cal_freq(df_e_s["volume"])

dates = []
for idx in df_e_s.index:
    year = int(df_e_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_e_s.loc[idx,"volume"],freq[year]))

df_e_s["date"] = dates

# modify date for 2023
for idx in df_e_s.index:
    year = int(df_e_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_e_s.loc[idx, "date"] = conv_volume_to_date(df_e_s.loc[idx,"volume"],6)

df_e_s.head()
# Out:
#         journal                                              title  \
# 0  Econometrica  Invidious Comparisons: Ranking and Selection a...
# 1  Econometrica  A Comment on: “Invidious Comparisons: Ranking ...
# 2  Econometrica  A Comment on: “Invidious Comparisons: Ranking ...
# 3  Econometrica  A Comment on: “Invidious Comparisons: Ranking ...
# 4  Econometrica  Reply to: Comments on “Invidious Comparisons: ...
#
#                                              authors  \
# 0                    ['Jiaying Gu', 'Roger Koenker']
# 1                                 ['Keisuke Hirano']
# 2                                  ['Patrick Kline']
# 3  ['Magne Mogstad', 'Joseph P. Romano', 'Azeem M...
# 4                    ['Jiaying Gu', 'Roger Koenker']
#
#                           volume jel  \
# 0   2023, vol. 91, issue 1, 1-41  []
# 1  2023, vol. 91, issue 1, 43-46  []
# 2  2023, vol. 91, issue 1, 47-52  []
# 3  2023, vol. 91, issue 1, 53-60  []
# 4  2023, vol. 91, issue 1, 61-66  []
#
#                                             abstract  \
# 0  There is an innate human tendency, one might c...
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                                  url                doi  \
# 0  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA19304
# 1  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20364
# 2  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20322
# 3  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20460
# 4  https://econpapers.repec.org/article/wlyemetrp...  10.3982/ECTA20537
#
#         date
# 0  2023-2-01
# 1  2023-2-01
# 2  2023-2-01
# 3  2023-2-01
# 4  2023-2-01

# %% [markdown]
# ### 6. AER

# %%
# clean aer
df_aer = pd.read_csv("data/journals/raw_data/aer.csv", encoding = "utf-8-sig").astype("str")
df_aer["journal"] = df_aer["journal"].apply(lambda x: "American Economic Review")
df_aer["abstract"] = df_aer["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_aer["volume"] = df_aer["volume"].apply(lambda x: x.replace("\n","").replace("\t","").strip())
df_aer = df_aer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_aer.index:
    date_text = df_aer.loc[idx,"volume"].split(",")[2].strip()
    year = date_text.split(" ")[1]
    month_text = date_text.split(" ")[0]
    if month_text == "January":
        month = "01"
    elif month_text == "February":
        month = "02"
    elif month_text == "March":
        month = "03"
    elif month_text == "April":
        month = "04"
    elif month_text == "May":
        month = "05"
    elif month_text == "June":
        month = "06"
    elif month_text == "July":
        month = "07"
    elif month_text == "August":
        month = "08"
    elif month_text == "September":
        month = "09"
    elif month_text == "October":
        month = "10"
    elif month_text == "November":
        month = "11"
    elif month_text == "December":
        month = "12"

    dates.append(year+"-"+month+"-"+"15")

df_aer["date"] = dates
df_aer_s = df_aer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_aer_s.tail()
# Out:
#                        journal  \
# 4799  American Economic Review
# 4800  American Economic Review
# 4801  American Economic Review
# 4802  American Economic Review
# 4803  American Economic Review
#
#                                                   title  \
# 4799  Enabling or Limiting Cognitive Flexibility? Ev...
# 4800  Droughts, Deluges, and (River) Diversions: Val...
# 4801                 Technology Gaps, Trade, and Income
# 4802  Electronic Food Vouchers: Evidence from an At-...
# 4803                       The Voice of Monetary Policy
#
#                                                 authors  \
# 4799  ['\n         Silvia Saccardo    ', '\n        ...
# 4800                      ['\n         Will Rafey    ']
# 4801                  ['\n         Thomas Sampson    ']
# 4802  ['\n         Abhijit Banerjee    ', '\n       ...
# 4803  ['\n         Yuriy Gorodnichenko    ', '\n    ...
#
#                                                  volume  \
# 4799  American Economic Review vol. 113,no. 2, Febru...
# 4800  American Economic Review vol. 113,no. 2, Febru...
# 4801  American Economic Review vol. 113,no. 2, Febru...
# 4802  American Economic Review vol. 113,no. 2, Febru...
# 4803  American Economic Review vol. 113,no. 2, Febru...
#
#                                                     jel  \
# 4799  [('C91', 'Design of Experiments: Laboratory, I...
# 4800  [('D23', 'Organizational Behavior; Transaction...
# 4801  [('D21', 'Firm Behavior: Theory'), ('D24', 'Pr...
# 4802  [('H53', 'National Government Expenditures and...
# 4803  [('D83', 'Search; Learning; Information and Kn...
#
#                                                abstract  \
# 4799  Moral behavior is more prevalent when individu...
# 4800  This paper develops and applies a method to va...
# 4801  This paper quantifies the contribution of tech...
# 4802  We compare how in-kind food assistance and an ...
# 4803  We develop a deep learning model to detect emo...
#
#                                                     url                   doi  \
# 4799  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201333
# 4800  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201434
# 4801  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201940
# 4802  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20210461
# 4803  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20220129
#
#             date
# 4799  2023-02-15
# 4800  2023-02-15
# 4801  2023-02-15
# 4802  2023-02-15
# 4803  2023-02-15

# %%
for v in df_aer.volume:
    print(v)

# %%
# concatenate journals
df = pd.concat([df_rfs_s,df_res_s,df_qje_s,df_jpe_s,df_e_s,df_aer_s]).reset_index(drop=True)
len(df)
# Out:
# 20010

# %%
df.nunique()
# Out:
# journal         6
# title       19683
# authors     15532
# volume      15396
# jel          4539
# abstract    12895
# url         20010
# doi         20010
# date         1213
# dtype: int64

# %%
df_selected = df[["doi","journal","volume","date","title","abstract","url"]]
df_selected.head()
# Out:
#                   doi                      journal  \
# 0  10.1093/rfs/hhg003  Review of Financial Studies
# 1  10.1093/rfs/hhg004  Review of Financial Studies
# 2  10.1093/rfs/hhg002  Review of Financial Studies
# 3  10.1093/rfs/hhg006  Review of Financial Studies
# 4  10.1093/rfs/hhg001  Review of Financial Studies
#
#                             volume       date  \
# 0  2003, vol. 16, issue 2, 597-629  2003-5-15
# 1  2003, vol. 16, issue 2, 567-595  2003-5-15
# 2  2003, vol. 16, issue 2, 527-566  2003-5-15
# 3  2003, vol. 16, issue 2, 487-525  2003-5-15
# 4  2003, vol. 16, issue 2, 459-485  2003-5-15
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                             abstract  \
# 0  This article studies an intertemporal economy ...
# 1  Hansen and Jagannathan (1991) (hereafter HJ) d...
# 2  We investigate whether the volatility risk pre...
# 3  We develop a theory of market crashes based on...
# 4  We assess the profitability of momentum strate...
#
#                                                  url
# 0  https://econpapers.repec.org/article/ouprfinst...
# 1  https://econpapers.repec.org/article/ouprfinst...
# 2  https://econpapers.repec.org/article/ouprfinst...
# 3  https://econpapers.repec.org/article/ouprfinst...
# 4  https://econpapers.repec.org/article/ouprfinst...

# %%
# save article
df_selected.to_csv("article.csv", index = False, encoding = "utf-8-sig")
df_selected.to_csv("article_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Clean and update author.csv, email_affiliation.csv, affiliation.csv

# %%
# clean author
df_email = pd.read_csv("email_affiliation.csv", encoding = "utf-8-sig").replace(np.NaN,"")
emaildict = df_email.to_dict("list")
df_au = pd.read_csv("author.csv", encoding = "utf-8-sig")

# %%
# open chrome service
chromedriver_path = "D:/chromedriver.exe"
s = Service(chromedriver_path)
driver = webdriver.Chrome(service=s)

# %%
base_url = "https://scholar.google.com/scholar?hl=zh-CN&q="
start_idx = 1
for i, e in enumerate(sorted(df_au["emailsuffix"].unique())[start_idx:]):
    if e not in list(df_email.subemail):
        driver.get(base_url+e)
        driver.refresh()
        soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
        try:
            h3 = soup.find("div", class_ = "gs_r").h3
            if h3.text == "以下机构的用户个人学术档案：":
                div = soup.find("div", class_ = "gs_r").div
                name = div.a.text
                email = div.span.text.replace(" - ", "")
                time.sleep(random.randrange(5,10))
            else:
                raise ValueError("x")
        except:
            try:
                h2 = soup.find("div", class_ = "gs_r").h2
                if "显示的是以下查询字词的结果：" in h2.text.strip():
                    driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                    driver.refresh()
                    soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                    div = soup.find("div", class_ = "gs_r").div
                    name = div.a.text
                    email = div.span.text.replace(" - ", "")
                    time.sleep(random.randrange(5,10))
                else:
                    raise ValueError("x")
            except:
                driver.get(base_url+".".join(e.split(".")[1:]))
                driver.refresh()
                soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                try:
                    h3 = soup.find("div", class_ = "gs_r").h3
                    if h3.text == "以下机构的用户个人学术档案：":
                        div = soup.find("div", class_ = "gs_r").div
                        name = div.a.text
                        email = div.span.text.replace(" - ", "")
                        time.sleep(random.randrange(5,10))
                    else:
                        raise ValueError("x")
                except:
                    try:
                        h2 = soup.find("div", class_ = "gs_r").h2
                        if "显示的是以下查询字词的结果：" in h2.text.strip():
                            driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                            driver.refresh()
                            soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                            div = soup.find("div", class_ = "gs_r").div
                            name = div.a.text
                            email = div.span.text.replace(" - ", "")
                            time.sleep(random.randrange(5,10))
                        else:
                            raise ValueError("x")
                    except:
                        try:
                            if soup.find("h1").text == "请进行人机身份验证":
                                print("Blocked!!!")
                                break
                            else:
                                name = ""
                                email = ""
                            time.sleep(random.randrange(5,10))
                        except:
                            name = ""
                            email = ""
                            time.sleep(random.randrange(5,10))
        # append info
        try:
            affid = "".join([w[0] for w in name.lower().split(" ")])+"."+email
        except:
            affid = ""

        if "PDF" in affid:
            name = ""
            email = ""
            affid = ""

        emaildict["name"].append(name)
        emaildict["email"].append(email)
        emaildict["subemail"].append(e)
        emaildict["affiliationid"].append(affid)
        print(i+start_idx, e, name, email, affid)
# Out:
# 5 adb.org Asian Development Bank adb.org adb.adb.org
# 8 adobe.com Adobe Inc adobe.com ai.adobe.com
# 10 aercafrica.org
# 12 afpc.org
# 13 agroparistech.fr AgroParisTech agroparistech.fr a.agroparistech.fr
# 14 aier.org
# 15 air.org American Institutes for Research air.org aifr.air.org
# 17 albany.edu University at Albany albany.edu uaa.albany.edu
# 19 alexander-ludwig.com
# 28 alumni.eui.eu European University Institute eui.eu eui.eui.eu
# 30 alumni.princeton.edu Princeton University princeton.edu pu.princeton.edu
# 42 aph.gov.au
# 47 asapp.com
# 48 asb.dk Aarhus University au.dk au.au.dk
# 49 ashoka.edu.in
# 53 atmosfera.unam.mx
# 62 avl.com
# 69 bangla.net
# 78 barclays.com
# 79 barnard.edu Columbia University columbia.edu cu.columbia.edu
# 88 bbva.com
# 99 bgsu.edu Bowling Green State University bgsu.edu bgsu.bgsu.edu
# 103 bilkent.edu.tr Bilkent University bilkent.edu.tr bu.bilkent.edu.tr
# 109 bls.gov US Bureau of Labor Statistics bls.gov ubols.bls.gov
# 110 bof.fi
# 111 bofa.com
# 112 boi.org.il
# 117 boun.edu.tr Bogazici University boun.edu.tr bu.boun.edu.tr
# 118 bowiestate.edu Bowie State University bowiestate.edu bsu.bowiestate.edu
# 120 bracu.ac.bd BRAC University bracu.ac.bd bu.bracu.ac.bd
# 132 bsg.ox.ac.uk University of Oxford ox.ac.uk uoo.ox.ac.uk
# 161 carleton.edu Carleton College carleton.edu cc.carleton.edu
# 168 cbb.gov.bh
# 172 ccs.neu.edu Northeastern University, Boston neu.edu nub.neu.edu
# 183 centre.edu Centre College centre.edu cc.centre.edu
# 189 cfaes.osu.edu Ohio State University osu.edu osu.osu.edu
# 191 cgdev.org Center for Global Development cgdev.org cfgd.cgdev.org
# 203 cis.upenn.edu University of Pennsylvania upenn.edu uop.upenn.edu
# 208 clarkson.edu Clarkson University clarkson.edu cu.clarkson.edu
# 212 cliometrie.org
# 214 cmich.edu Central Michigan University cmich.edu cmu.cmich.edu
# 217 cns.nyu.edu New York University nyu.edu nyu.nyu.edu
# 219 coleridgeinitiative.org
# 220 colgate.edu Colgate University colgate.edu cu.colgate.edu
# 222 colmex.mx
# 227 compas.ox.ac.uk University of Oxford ox.ac.uk uoo.ox.ac.uk
# 233 core.ucl.ac.be
# 240 creativedestructionlab.com
# 246 csi.cuny.edu City University of New York cuny.edu cuony.cuny.edu
# 248 csp.edu
# 249 csrsr.ncu.edu.tw National Central University, Taiwan ncu.edu.tw ncut.ncu.edu.tw
# 253 ctrpfp.ac.in
# 257 cunef.edu
# 263 danariely.com
# 272 demogr.mpg.de Max Planck Institute for Demographic Research demogr.mpg.de mpifdr.demogr.mpg.de
# 273 denison.edu Denison University denison.edu du.denison.edu
# 277 design.upenn.edu University of Pennsylvania upenn.edu uop.upenn.edu
# 278 dial.prd.fr
# 288 dnb.nl Nederlandsche Bank dnb.nl nb.dnb.nl
# 306 eco.unibs.it University of Brescia unibs.it uob.unibs.it
# 311 econ.core.hu
# 313 econ.gatech.edu Georgia Institute of Technology gatech.edu giot.gatech.edu
# 326 econ.ubc.ca University of British Columbia ubc.ca uobc.ubc.ca
# 329 econ.uib.no University of Bergen uib.no uob.uib.no
# 339 econhist.vwl.uni-muenchen.de
# 341 econo.unlp.edu.ar National University of La Plata unlp.edu.ar nuolp.unlp.edu.ar
# 348 edf.org Environmental Defense Fund edf.org edf.edf.org
# 356 ejb.rutgers.edu Rutgers University rutgers.edu ru.rutgers.edu
# 357 ekh.lu.se Lund University lu.se lu.lu.se
# 359 elmarmertens.com
# 374 epa.gov US Environmental Protection Agency epa.gov uepa.epa.gov
# 377 epri.com Electric Power Research Institute epri.com epri.epri.com
# 378 equitablegrowth.org
# 380 ers.usda.gov US Department of Agriculture usda.gov udoa.usda.gov
# 382 escp.eu
# 385 eshpm.eur.nl Erasmus University Rotterdam eur.nl eur.eur.nl
# 386 esmt.org ESMT European School of Management and Technology esmt.org eesomat.esmt.org
# 395 ex.ac.uk University of Exeter exeter.ac.uk uoe.exeter.ac.uk
# 405 fau.de University of Erlangen-Nuremberg uni-erlangen.de uoe.uni-erlangen.de
# 407 fb.com Facebook Inc. fb.com fi.fb.com
# 410 fdic.gov
# 414 feweb.vu.nl VU University Amsterdam vu.nl vua.vu.nl
# 426 foundationmedicine.com
# 428 fpce.up.pt University of Porto up.pt uop.up.pt
# 431 frisch.uio.no University of Oslo uio.no uoo.uio.no
# 437 fucam.ac.be
# 439 fullerton.edu California State University, Fullerton fullerton.edu csuf.fullerton.edu
# 443 g.rit.edu Rochester Institute of Technology rit.edu riot.rit.edu
# 448 gate.cnrs.fr
# 452 ge.com General Electric ge.com ge.ge.com
# 469 gvsu.edu Grand Valley State University gvsu.edu gvsu.gvsu.edu
# 473 hamilton.edu Hamilton College hamilton.edu hc.hamilton.edu
# 487 hertie-school.org Hertie School of Governance hertie-school.org hsog.hertie-school.org
# 489 hhu.de
# 497 honor.education
# 498 howard.edu Howard University howard.edu hu.howard.edu
# 507 huynh.tv
# 508 hw.ac.uk Heriot-Watt University hw.ac.uk hu.hw.ac.uk
# 514 ibero.mx
# 518 idinsight.org
# 523 ier.hit-u.ac.jp Hitotsubashi University hit-u.ac.jp hu.hit-u.ac.jp
# 525 ieseg.fr IESEG School of Management ieseg.fr isom.ieseg.fr
# 533 iima.ac.in
# 536 iir.hit-u.ac.jp Hitotsubashi University hit-u.ac.jp hu.hit-u.ac.jp
# 539 ilstu.edu Illinois State University ilstu.edu isu.ilstu.edu
# 543 imfs-frankfurt.de
# 549 inebraska.com
# 553 ioe.ac.uk Institute of Education ioe.ac.uk ioe.ioe.ac.uk
# 555 ip.mpg.de
# 557 ipp.eu
# 567 ist.ucf.edu University of Central Florida ucf.edu uocf.ucf.edu
# 571 iucn.org International Union for Conservation of Nature iucn.org iufcon.iucn.org
# 580 jcsuarez.com
# 581 jec.senate.gov
# 584 jhmi.edu Johns Hopkins University jhu.edu jhu.jhu.edu
# 586 jjay.cuny.edu City University of New York cuny.edu cuony.cuny.edu
# 589 jnu.edu.cn Jinan University jnu.edu.cn ju.jnu.edu.cn
# 590 jpmchase.com
# 605 kenyon.edu Kenyon College kenyon.edu kc.kenyon.edu
# 613 kof.ethz.ch ETH Zürich ethz.ch ez.ethz.ch
# 614 kolsrud.se
# 624 kumc.edu University of Kansas ku.edu uok.ku.edu
# 627 lafollette.wisc.edu University of Wisconsin-Madison wisc.edu uow.wisc.edu
# 628 lahoreschool.edu.pk
# 631 law.columbia.edu Columbia University columbia.edu cu.columbia.edu
# 632 law.duke.edu Duke University duke.edu du.duke.edu
# 641 lboro.ac.uk Loughborough University lboro.ac.uk lu.lboro.ac.uk
# 644 leeds.ac.uk University of Leeds leeds.ac.uk uol.leeds.ac.uk
# 646 leicester.ac.uk University of Leicester le.ac.uk uol.le.ac.uk
# 647 lemoyne.edu Le Moyne College lemoyne.edu lmc.lemoyne.edu
# 648 lingayasuniversity.edu.in
# 652 lls.edu Loyola Marymount University lmu.edu lmu.lmu.edu
# 654 lmu.edu Loyola Marymount University lmu.edu lmu.lmu.edu
# 668 macalester.edu Macalester College macalester.edu mc.macalester.edu
# 674 mail.house.gov
# 685 mail.xidian.edu.cn Xidian University xidian.edu.cn xu.xidian.edu.cn
# 686 mailbox.sc.edu University of South Carolina sc.edu uosc.sc.edu
# 689 manhattan-institute.org
# 691 marshall.edu Marshall University marshall.edu mu.marshall.edu
# 693 mason.wm.edu College of William and Mary wm.edu cowam.wm.edu
# 699 math.toronto.edu University of Toronto utoronto.ca uot.utoronto.ca
# 703 maths.ox.ac.uk University of Oxford ox.ac.uk uoo.ox.ac.uk
# 705 mathstat.dal.ca Dalhousie University dal.ca du.dal.ca
# 707 mayo.edu Mayo Clinic mayo.edu mc.mayo.edu
# 714 mea.mpisoc.mpg.de
# 715 med.umich.edu University of Michigan umich.edu uom.umich.edu
# 717 med.uvm.edu University of Vermont uvm.edu uov.uvm.edu
# 718 memphis.edu University of Memphis memphis.edu uom.memphis.edu
# 719 merton.ox.ac.uk University of Oxford ox.ac.uk uoo.ox.ac.uk
# 731 mku.edu.tr
# 734 mof.gov.ae
# 735 mojo.com
# 739 morgan.edu Morgan State University morgan.edu msu.morgan.edu
# 740 morganstanley.com
# 745 mscc.huji.ac.il Hebrew University of Jerusalem huji.ac.il huoj.huji.ac.il
# 746 mskcc.org Memorial Sloan Kettering Cancer Center mskcc.org mskcc.mskcc.org
# 760 nccu.edu.tw National Chengchi University nccu.edu.tw ncu.nccu.edu.tw
# 761 ncnu.edu.tw National Chi Nan University ncnu.edu.tw ncnu.ncnu.edu.tw
# 768 neoma-bs.fr NEOMA Business School neoma-bs.fr nbs.neoma-bs.fr
# 769 nera.com
# 773 newark.rutgers.edu Rutgers University rutgers.edu ru.rutgers.edu
# 784 nmbu.no Norwegian University of Life Sciences umb.no nuols.umb.no
# 789 nottingham.edu.cn University of Nottingham Ningbo China nottingham.edu.cn uonnc.nottingham.edu.cn
# 792 nrc.ca National Research Council, Canada nrc-cnrc.gc.ca nrcc.nrc-cnrc.gc.ca
# 797 nu.edu.eg
# 800 nuigalway.ie National University of Ireland, Galway nuigalway.ie nuoig.nuigalway.ie
# 808 oberlin.edu Oberlin College oberlin.edu oc.oberlin.edu
# 813 ohio.edu Ohio University ohio.edu ou.ohio.edu
# 816 omar.ec
# 818 openphilanthropy.org
# 824 ouce.ox.ac.uk University of Oxford ox.ac.uk uoo.ox.ac.uk
# 826 owenscorning.com
# 827 owu.edu Ohio Wesleyan University owu.edu owu.owu.edu
# 828 oxfordmartin.ox.ac.uk University of Oxford ox.ac.uk uoo.ox.ac.uk
# 838 peds.ufl.edu University of Florida ufl.edu uof.ufl.edu
# 840 penquest.com
# 842 perfectrec.com
# 855 polisci.ucla.edu University of California, Los Angeles ucla.edu uocla.ucla.edu
# 862 popcouncil.org Population Council popcouncil.org pc.popcouncil.org
# 866 ppic.org
# 869 price.usc.edu University of Southern California usc.edu uosc.usc.edu
# 875 psi.gov.et
# 878 psy.gu.se University of Gothenburg gu.se uog.gu.se
# 879 psych.duhs.duke.edu
# 880 psych.upenn.edu University of Pennsylvania upenn.edu uop.upenn.edu
# 883 qc.cuny.edu City University of New York cuny.edu cuony.cuny.edu
# 896 randeurope.org
# 901 reed.edu Reed College reed.edu rc.reed.edu
# 902 res.otaru-uc.ac.jp
# 911 rider.edu Rider University rider.edu ru.rider.edu
# 916 rmcsinc.com
# 917 rmit.edu.au RMIT University, Melbourne rmit.edu.au rum.rmit.edu.au
# 928 ruralinnovation.us
# 935 salisbury.edu Salisbury University salisbury.edu su.salisbury.edu
# 949 scipolicy.com
# 950 scrippscollege.edu
# 952 sdsu.edu San Diego State University sdsu.edu sdsu.sdsu.edu
# 956 seattleu.edu Seattle University seattleu.edu su.seattleu.edu
# 961 sh.se
# 963 shsu.edu Sam Houston State University shsu.edu shsu.shsu.edu
# 979 social.mpg.de
# 980 socialresearch.no
# 985 spbu.ru
# 988 ssa.gov
# 992 sssup.it Scuola Superiore Sant'Anna sssup.it sss.sssup.it
# 993 st-and.ac.uk University of St Andrews st-andrews.ac.uk uosa.st-andrews.ac.uk
# 995 staff.ui.ac.id University of Indonesia ui.ac.id uoi.ui.ac.id
# 996 standish.com
# 1001 statistik.tu-dortmund.de
# 1005 stcloudstate.edu St. Cloud State University stcloudstate.edu scsu.stcloudstate.edu
# 1009 stlawu.edu St. Lawrence University stlawu.edu slu.stlawu.edu
# 1018 sunrun.com
# 1019 surgery.bsd.uchicago.edu
# 1022 suu.edu Southern Utah University suu.edu suu.suu.edu
# 1023 swan.ac.uk Swansea University swansea.ac.uk su.swansea.ac.uk
# 1025 swin.edu.au Swinburne University of Technology swin.edu.au suot.swin.edu.au
# 1029 symmetryinvestments.com
# 1035 tax.mpg.de
# 1041 teagasc.ie Teagasc teagasc.ie t.teagasc.ie
# 1043 tedu.edu.tr TED University tedu.edu.tr tu.tedu.edu.tr
# 1044 telecom-paris.fr
# 1046 texasheart.org
# 1047 theigc.org
# 1048 thinkbrg.com
# 1049 tias.edu
# 1051 tnc.org Nature Conservancy tnc.org nc.tnc.org
# 1059 tu-berlin.de
# 1062 tudelft.nl Delft University of Technology tudelft.nl duot.tudelft.nl
# 1068 twitter.com Twitter Inc twitter.com ti.twitter.com
# 1070 u-bourgogne.fr
# 1073 u-psud.fr University of Paris-Sud u-psud.fr uop.u-psud.fr
# 1077 ua.es Universidad de Alicante ua.es uda.ua.es
# 1078 uaa.alaska.edu University of Alaska Fairbanks alaska.edu uoaf.alaska.edu
# 1080 uab.edu University of Alabama at Birmingham uab.edu uoaab.uab.edu
# 1081 uab.es Autonomous University of Barcelona uab.cat auob.uab.cat
# 1083 uai.cl
# 1085 uam.es
# 1087 uantwerp.be University of Antwerp uantwerpen.be uoa.uantwerpen.be
# 1093 uber.com
# 1097 uca.fr
# 1104 ucema.edu.ar
# 1106 uchastings.edu
# 1127 udg.es
# 1130 ufc.br
# 1137 ugm.ac.id
# 1140 uib.no University of Bergen uib.no uob.uib.no
# 1144 uigm.ac.id
# 1148 uji.es Universitat Jaume I uji.es uji.uji.es
# 1166 umsl.edu University of Missouri-St. Louis umsl.edu uoml.umsl.edu
# 1176 uncw.edu University of North Carolina, Wilmington uncw.edu uoncw.uncw.edu
# 1177 unf.edu University of North Florida unf.edu uonf.unf.edu
# 1179 uni-bamberg.de
# 1185 uni-goettingen.de University of Göttingen uni-goettingen.de uog.uni-goettingen.de
# 1186 uni-graz.at
# 1192 uni-mainz.de Johannes Gutenberg University, Mainz uni-mainz.de jgum.uni-mainz.de
# 1195 uni-vechta.de
# 1204 unibs.it University of Brescia unibs.it uob.unibs.it
# 1205 unibw.de
# 1209 unifi.it University of Florence unifi.it uof.unifi.it
# 1218 unine.ch
# 1224 unipv.it University of Pavia unipv.it uop.unipv.it
# 1228 unisalento.it
# 1235 univ-lille.fr
# 1255 uow.edu.au University of Wollongong uow.edu.au uow.uow.edu.au
# 1256 up.edu.pe
# 1259 uphs.upenn.edu University of Pennsylvania upenn.edu uop.upenn.edu
# 1265 ur.de
# 1269 urmc.rochester.edu University of Rochester rochester.edu uor.rochester.edu
# 1271 ursinus.edu Ursinus College ursinus.edu uc.ursinus.edu
# 1272 us.es Universidad de Sevilla us.es uds.us.es
# 1276 usd.edu University of South Dakota usd.edu uosd.usd.edu
# 1282 usna.edu United States Naval Academy usna.edu usna.usna.edu
# 1287 ut.edu University of Tampa ut.edu uot.ut.edu
# 1288 ut.ee University of Tartu ut.ee uot.ut.ee
# 1297 utpa.edu University of Texas-Pan American utpa.edu uota.utpa.edu
# 1323 veracode.com
# 1332 vwl.uni-freiburg.de University of Freiburg uni-freiburg.de uof.uni-freiburg.de
# 1334 vwl1.rwth-aachen.de RWTH Aachen University rwth-aachen.de rau.rwth-aachen.de
# 1345 wcu.edu Western Carolina University wcu.edu wcu.wcu.edu
# 1346 wcupa.edu West Chester University wcupa.edu wcu.wcupa.edu
# 1354 wheaton.edu Wheaton College, Wheaton wheaton.edu wcw.wheaton.edu
# 1357 wi.tum.de Technical University of Munich tum.de tuom.tum.de
# 1360 wifa.uni-leipzig.de University of Leipzig uni-leipzig.de uol.uni-leipzig.de
# 1369 wku.edu Western Kentucky University wku.edu wku.wku.edu
# 1371 wlu.edu Washington and Lee University wlu.edu walu.wlu.edu
# 1373 wmich.edu Western Michigan University wmich.edu wmu.wmich.edu
# 1375 wne.uw.edu.pl University of Warsaw uw.edu.pl uow.uw.edu.pl
# 1379 wur.nl Wageningen University wur.nl wu.wur.nl
# 1390 zew.de ZEW Mannheim zew.de zm.zew.de

# %%
len(emaildict["name"])
# Out:
# 1393

# %%
df_email = pd.DataFrame(emaildict).drop_duplicates(subset=["subemail"],keep="last")
len(df_email)
# Out:
# 1393

# %%
df_email.nunique()
# Out:
# name              709
# email             709
# subemail         1393
# affiliationid     709
# dtype: int64

# %%
df_aff = df_email[["affiliationid","name","email"]][df_email["affiliationid"]!=""].drop_duplicates()
len(df_aff)
# Out:
# 708

# %%
# add affiliationid to author
for idx in df_au.index:
    try:
        df_au.loc[idx, "affiliationid"] = df_email.set_index("subemail").loc[df_au.loc[idx, "emailsuffix"],"affiliationid"]
    except:
        df_au.loc[idx, "affiliationid"] = ""

# %%
df_email.to_csv("email_affiliation.csv", index = False, encoding = "utf-8-sig")
df_email.to_csv("email_affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation.csv", index = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_au.to_csv("author.csv", index = False, encoding = "utf-8-sig")
df_au.to_csv("author_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Database

# %%
# use this line to run the script directly in Jupyter
! sqlite3 econtop.db < create-econtop.sql

# %%
conn = sqlite3.connect("econtop.db")
cur = conn.cursor()

# %% [markdown]
# ### University Level

# %%
# select university level of publications
q = """
    SELECT af.affiliationid, af.name, art.journal, aa.doi
    FROM author_article AS aa JOIN author AS au JOIN article AS art JOIN affiliation AS af
    ON aa.authorid = au.authorid AND
    aa.doi = art.doi AND
    au.affiliationid = af.affiliationid
    """

# q = " SELECT authorid FROM author"
df_af_art = pd.read_sql_query(q, conn).set_index("doi")
df_af_art.head()
# Out:
#                       affiliationid                                  name  \
# doi
# 10.1093/rfs/hhg003        bu.bu.edu                     Boston University
# 10.1093/rfs/hhg004     uosc.usc.edu     University of Southern California
# 10.1093/rfs/hhg002    tu.temple.edu                     Temple University
# 10.1093/rfs/hhg002   uoma.umass.edu  University of Massachusetts, Amherst
# 10.1093/rfs/hhg006  cu.columbia.edu                   Columbia University
#
#                                         journal
# doi
# 10.1093/rfs/hhg003  Review of Financial Studies
# 10.1093/rfs/hhg004  Review of Financial Studies
# 10.1093/rfs/hhg002  Review of Financial Studies
# 10.1093/rfs/hhg002  Review of Financial Studies
# 10.1093/rfs/hhg006  Review of Financial Studies

# %%
# show top appearance
freq = {}
for doi in df_af_art.index:
    try:
        name = df_af_art.loc[doi][1]
        try:
            freq[name] += 1
        except:
            freq[name] = 1
    except:
        df_af_art_new = df_af_art.loc[doi]
        names = set(list(df_af_art_new.name))
        for name in names:
            try:
                freq[name] += 1
            except:
                freq[name] = 1

# %%
freq_sorted = sorted(freq.items(), key=lambda x:x[1], reverse = True)
freq_sorted
# Out:
# [('Harvard University', 890),
#  ('Massachusetts Institute of Technology', 822),
#  ('University of Chicago', 780),
#  ('Stanford University', 711),
#  ('Columbia University', 623),
#  ('University of California, Berkeley', 599),
#  ('Yale University', 537),
#  ('New York University', 523),
#  ('Princeton University', 513),
#  ('Northwestern University', 479),
#  ('University of Pennsylvania', 451),
#  ('London School of Economics', 448),
#  ('University of California, Los Angeles', 412),
#  ('Duke University', 273),
#  ('Cornell University', 268),
#  ('Boston University', 247),
#  ('University of Michigan', 244),
#  ('Washington University in St. Louis', 218),
#  ('University of Wisconsin-Madison', 213),
#  ('University of Southern California', 208),
#  ('University of Minnesota', 206),
#  ('Bocconi University', 198),
#  ('University College London', 198),
#  ('University of Toronto', 197),
#  ('University of Oxford', 196),
#  ('University of California, San Diego', 193),
#  ('University of British Columbia', 170),
#  ('University of Texas at Austin', 167),
#  ('Pennsylvania State University', 165),
#  ('Ohio State University', 163),
#  ('Toulouse School of Economics', 159),
#  ('London Business School', 155),
#  ('Boston College', 154),
#  ('Brown University', 147),
#  ('Georgetown University', 143),
#  ('Dartmouth College', 138),
#  ('Hebrew University of Jerusalem', 135),
#  ('Imperial College London', 135),
#  ('University of Maryland', 134),
#  ('University of Washington', 134),
#  ('INSEAD', 126),
#  ('University of Warwick', 126),
#  ('US Federal Reserve Board', 123),
#  ('University of Zurich', 115),
#  ('HEC Paris', 114),
#  ('Johns Hopkins University', 111),
#  ('University of Virginia', 108),
#  ('University of California, Irvine', 108),
#  ('Stockholm University', 108),
#  ('Carnegie Mellon University', 107),
#  ('Indiana University', 107),
#  ('University of North Carolina at Chapel Hill', 106),
#  ('University of Illinois at Urbana-Champaign', 105),
#  ('University of Utah', 103),
#  ('Arizona State University', 102),
#  ('Stockholm School of Economics', 100),
#  ('University of Notre Dame', 99),
#  ('University of California, Davis', 95),
#  ('Pompeu Fabra University', 92),
#  ('California Institute of Technology', 88),
#  ('Tel Aviv University', 87),
#  ('National University of Singapore', 87),
#  ('University of New South Wales', 86),
#  ('University of Rochester', 84),
#  ('University of Pittsburgh', 81),
#  ('McGill University', 81),
#  ('Rice University', 79),
#  ('Emory University', 78),
#  ('World Bank', 77),
#  ('香港大学', 76),
#  ('University of Cambridge', 75),
#  ('University of Bonn', 73),
#  ('Swiss Federal Institute of Technology in Lausanne', 71),
#  ('Federal Reserve Bank of New York', 69),
#  ('University of Colorado, Boulder', 67),
#  ('Federal Reserve Bank of Chicago', 67),
#  ('University of Mannheim', 66),
#  ('University of Texas at Dallas', 64),
#  ('Texas A&M University', 64),
#  ('Purdue University', 63),
#  ('University of Melbourne', 60),
#  ('George Washington University', 60),
#  ('香港中文大学', 60),
#  ('University of Houston', 59),
#  ('Sciences Po', 59),
#  ('Simon Fraser University', 58),
#  ('Erasmus University Rotterdam', 58),
#  ('University of Lugano', 57),
#  ('Singapore Management University', 57),
#  ('Michigan State University', 57),
#  ('International Monetary Fund', 57),
#  ('University of California, Santa Barbara', 57),
#  ('Brigham Young University', 56),
#  ('Vanderbilt University', 56),
#  ('University of Arizona', 55),
#  ('Tilburg University', 55),
#  ('Federal Reserve Bank of Philadelphia', 53),
#  ('University of Lausanne', 51),
#  ('Queen Mary University of London', 51),
#  ('University of Oslo', 51),
#  ('University of Amsterdam', 50),
#  ('University of Miami', 50),
#  ('University of Georgia', 50),
#  ('European University Institute', 48),
#  ('Universidad Carlos III de Madrid', 47),
#  ('Center for Monetary and Financial Studies (CEMFI)', 47),
#  ('University of Western Ontario', 47),
#  ('Rutgers University', 46),
#  ('IESE Business School', 45),
#  ('Chapman University', 45),
#  ('香港科技大学', 42),
#  ('University of Oregon', 42),
#  ('Centre de Recerca en Economia Internacional', 42),
#  ('Copenhagen Business School', 41),
#  ('Goethe University Frankfurt', 40),
#  ('University of Florida', 40),
#  ('Drexel University', 38),
#  ('Frankfurt School of Finance & Management', 38),
#  ('University of Nottingham', 38),
#  ('University of Munich', 38),
#  ('Paris School of Economics', 38),
#  ('Federal Reserve Bank of Atlanta', 37),
#  ('Georgia State University', 37),
#  ('University of Kentucky', 37),
#  ('Federal Reserve Bank of San Francisco', 36),
#  ('Monash University', 36),
#  ('Central European University', 36),
#  ("Queen's University", 36),
#  ('Federal Reserve Bank of Dallas', 35),
#  ('ENSAE ParisTech', 35),
#  ('Tulane University', 34),
#  ('City University London', 33),
#  ('Nova School of Business and Economics', 32),
#  ('清华大学', 32),
#  ('University of Illinois at Chicago', 32),
#  ('City University of New York', 32),
#  ('European Commission, Joint Research Centre', 31),
#  ('VU University Amsterdam', 31),
#  ('University of Copenhagen', 31),
#  ('Interdisciplinary Center, Herzliya', 30),
#  ('North Carolina State University', 30),
#  ('Southern Methodist University', 30),
#  ('University of Connecticut', 30),
#  ('Federal Reserve Bank of St. Louis', 30),
#  ('Bank for International Settlements', 29),
#  ('George Mason University', 29),
#  ('Microsoft Corporation', 29),
#  ('Santa Clara University', 28),
#  ('University of Delaware', 28),
#  ('University of St. Gallen', 28),
#  ('EDHEC Business School', 27),
#  ('University of Iowa', 27),
#  ('University of Geneva', 27),
#  ('Iowa State University', 27),
#  ('Katholieke Universiteit, Leuven', 27),
#  ('University of Glasgow', 27),
#  ('University of Edinburgh', 26),
#  ('Aalto University', 26),
#  ('University of Exeter', 26),
#  ('Aarhus University', 26),
#  ('Seoul National University', 25),
#  ('University at Buffalo', 25),
#  ('BI Norwegian Business School', 25),
#  ('Uppsala University', 25),
#  ('University of Manchester', 24),
#  ('Bar-Ilan University', 24),
#  ('University of Bern', 24),
#  ('University of Stavanger', 24),
#  ('University of Massachusetts, Amherst', 23),
#  ('Georgia Institute of Technology', 23),
#  ('Brandeis University', 23),
#  ('University of Montreal', 22),
#  ('北京大学', 22),
#  ('DePaul University', 22),
#  ('McMaster University', 22),
#  ('Baylor University', 22),
#  ('University of Essex', 22),
#  ('University of Bristol', 22),
#  ('University of Missouri', 21),
#  ('University of California, Santa Cruz', 21),
#  ('University of Tokyo', 21),
#  ('Clemson University', 21),
#  ('Indian School of Business', 20),
#  ('Australian National University', 20),
#  ('University of Luxembourg', 20),
#  ('Federal Reserve Bank of Richmond', 20),
#  ('U.S. Census Bureau', 20),
#  ('American University', 19),
#  ('南洋理工大学', 19),
#  ('York University', 19),
#  ('Amazon Inc.', 19),
#  ('University of Calgary', 19),
#  ('University of Sydney', 19),
#  ("King's College London", 19),
#  ('Temple University', 18),
#  ('上海交通大学', 18),
#  ('University of Naples Federico II', 18),
#  ('Claremont McKenna College', 18),
#  ('Vienna University of Economics and Business', 18),
#  ('Virginia Polytechnic Institute and State University', 18),
#  ('University of Bologna', 18),
#  ('CGIAR: Consultative Group for International Agricultural Research', 18),
#  ('University of Alabama', 17),
#  ('Medical University of South Carolina', 17),
#  ('University of Vienna', 17),
#  ('Lehigh University', 17),
#  ('University of Oklahoma', 17),
#  ('国立台湾大学', 17),
#  ('LUISS Guido Carli', 17),
#  ('Maastricht University', 17),
#  ('Ecole des Ponts ParisTech', 17),
#  ('Babson College', 16),
#  ('University of Tennessee', 16),
#  ('University of Guelph', 16),
#  ('University of Queensland', 16),
#  ('University of North Carolina at Charlotte', 15),
#  ('University of California, Riverside', 15),
#  ('香港理工大学', 15),
#  ('Syracuse University', 15),
#  ('Wellesley College', 15),
#  ('University of Technology Sydney', 15),
#  ('Washington State University', 14),
#  ('Korea Advanced Institute of Science and Technology', 14),
#  ('University of South Carolina', 14),
#  ('Collegio Carlo Alberto', 14),
#  ('Bank of Canada', 14),
#  ('University College Dublin', 14),
#  ('香港城市大学', 14),
#  ('IE University', 14),
#  ('Montana State University', 14),
#  ('Google Inc.', 14),
#  ('Tufts University', 14),
#  ('University of Cincinnati', 13),
#  ('University of Basel', 13),
#  ('Auburn University', 13),
#  ('Renmin University of China', 13),
#  ('SKEMA Business School', 13),
#  ('Ecole Polytechnique', 13),
#  ('Kyoto University', 13),
#  ('Autonomous University of Barcelona', 13),
#  ('Florida State University', 13),
#  ('Texas Christian University', 12),
#  ('Louisiana State University', 12),
#  ('Korea University', 12),
#  ('Case Western Reserve University', 12),
#  ('Shanghai University of Finance and Economics', 12),
#  ('复旦大学', 12),
#  ('Durham University', 12),
#  ('Wake Forest University', 12),
#  ('Royal Holloway, University of London', 12),
#  ('University of Kansas', 11),
#  ('Pontifical Catholic University of Chile', 11),
#  ('University of Arkansas', 11),
#  ('University of Liverpool', 11),
#  ('Carleton University', 11),
#  ('Brookings Institution', 11),
#  ('National Graduate Institute for Policy Studies', 11),
#  ('University of Wisconsin-Milwaukee', 10),
#  ('State University of New York at Stony Brook', 10),
#  ('Wilfrid Laurier University', 10),
#  ('Bank of England', 10),
#  ('ESSEC Business School', 10),
#  ('University of Alberta', 10),
#  ('Technion', 10),
#  ('Inter-American Development Bank', 10),
#  ('Waseda University', 10),
#  ('University of York', 10),
#  ('University of Cyprus', 10),
#  ('Stevens Institute of Technology', 9),
#  ('Nazarbayev University', 9),
#  ('International Institute for Management Development, Lausanne', 9),
#  ('University of Mississippi', 9),
#  ('Williams College', 9),
#  ('University of Colorado Denver', 9),
#  ('University of Nebraska-Lincoln', 9),
#  ('Federal Reserve Bank of Boston', 9),
#  ('Fordham University', 9),
#  ('University of Southampton', 9),
#  ('Xiamen University', 9),
#  ('Kansas State University', 9),
#  ('CERGE-EI', 9),
#  ('Birkbeck, University of London', 9),
#  ('University of Auckland', 9),
#  ('University of East Anglia', 9),
#  ('University of Missouri-Kansas City', 9),
#  ('Northeastern University, Boston', 8),
#  ('Macquarie University', 8),
#  ('Heidelberg University', 8),
#  ('Federal Reserve Bank of Kansas City', 8),
#  ('Yonsei University', 8),
#  ('Miami University of Ohio', 8),
#  ('Lund University', 8),
#  ('Bloomberg LP', 8),
#  ('Oakland University', 7),
#  ('Federal Reserve Bank of Cleveland', 7),
#  ('Ghent University', 7),
#  ('University of Wyoming', 7),
#  ('University of Groningen', 7),
#  ('Rensselaer Polytechnic Institute', 7),
#  ('Villanova University', 7),
#  ('ETH Zürich', 7),
#  ('Concordia University', 7),
#  ('University of California, Merced', 7),
#  ('University of Waterloo', 7),
#  ('University of Peradeniya', 7),
#  ('Keio University', 7),
#  ('WZB Berlin Social Science Center', 7),
#  ('University of Birmingham', 7),
#  ('University of Padova', 7),
#  ('Graduate Institute of International and Development Studies', 7),
#  ('New School for Social Research', 7),
#  ('University of Gothenburg', 7),
#  ('Albert Einstein College of Medicine', 6),
#  ('University of Victoria', 6),
#  ('University of Rome Tor Vergata', 6),
#  ('Loyola University Chicago', 6),
#  ('Office of the Comptroller of the Currency', 6),
#  ('University of Konstanz', 6),
#  ('Colorado State University', 6),
#  ('WHU - Otto Beisheim School of Management', 6),
#  ('University of Hamburg', 6),
#  ('University of Innsbruck', 6),
#  ('Hitotsubashi University', 6),
#  ('University of Würzburg', 6),
#  ('Amherst College', 6),
#  ('College of William and Mary', 6),
#  ('University of Southern Denmark', 6),
#  ('University of Milan', 6),
#  ('Statistics Norway', 6),
#  ('Ben-Gurion University of the Negev', 6),
#  ('Claremont Graduate University', 6),
#  ('Trinity College Dublin', 6),
#  ('Spanish National Research Council', 6),
#  ('New Economic School', 6),
#  ('Santa Fe Institute', 6),
#  ('Resources for the Future, Washington DC', 6),
#  ('Osaka University', 6),
#  ('Lancaster University', 5),
#  ('Northern Illinois University', 5),
#  ('Vienna University of Technology', 5),
#  ('University of South Florida', 5),
#  ('University of Lethbridge', 5),
#  ('Auckland University of Technology', 5),
#  ('Deutsche Bundesbank', 5),
#  ('Ozyegin University', 5),
#  ('University of North Texas', 5),
#  ('University of Sussex', 5),
#  ('University of Strathclyde', 5),
#  ('Norwegian University of Science and Technology', 5),
#  ('Banco Central do Brasil', 5),
#  ('Institute for the Study of Labor', 5),
#  ('University of São Paulo', 5),
#  ('中国科学技术大学', 5),
#  ('University of Bayreuth', 5),
#  ('Middlebury College', 5),
#  ('Virginia Commonwealth University', 5),
#  ('Texas Tech University', 4),
#  ('University of Texas at San Antonio', 4),
#  ('Karlsruhe Institute of Technology', 4),
#  ('Kennesaw State University', 4),
#  ('Universidad de los Andes, Santiago', 4),
#  ('University of Haifa', 4),
#  ('Thammasat University', 4),
#  ('Hofstra University', 4),
#  ('Central University of Finance and Economics', 4),
#  ('Netflix', 4),
#  ('University of North Carolina at Greensboro', 4),
#  ('Oregon State University', 4),
#  ('Southwestern University of Finance and Economics', 4),
#  ('Ifo Institute', 4),
#  ('Naval Postgraduate School', 4),
#  ('University of Murcia', 4),
#  ('University of Central Florida', 4),
#  ('Hong Kong Baptist University', 4),
#  ('Sapienza University of Rome', 4),
#  ('University of Namur', 4),
#  ('American Enterprise Institute', 4),
#  ('Clark University', 4),
#  ('University of Newcastle', 4),
#  ('Wesleyan University', 4),
#  ('Eindhoven University of Technology', 4),
#  ('Aston University', 4),
#  ('Bielefeld University', 4),
#  ('Southern Illinois University', 3),
#  ('Kobe University', 3),
#  ('Wichita State University', 3),
#  ('ESCP Europe', 3),
#  ('University of Denver', 3),
#  ('Bentley University', 3),
#  ('Elon University', 3),
#  ('Chung-Ang University', 3),
#  ('Sabanci University', 3),
#  ('Sogang University', 3),
#  ('Georgia College', 3),
#  ('Technical University of Munich', 3),
#  ('Seattle Pacific University', 3),
#  ('Organisation for Economic Co-operation and Development', 3),
#  ('国立清华大学', 3),
#  ('University of Louisville', 3),
#  ('Utah State University', 3),
#  ('West Virginia University', 3),
#  ('University of Dayton', 3),
#  ('Radboud University, Nijmegen', 3),
#  ('University of Danang', 3),
#  ('Jacksonville University', 3),
#  ('Institute for Advanced Study', 3),
#  ('University of Surrey', 3),
#  ('University of Ottawa', 3),
#  ('Open University of Israel', 3),
#  ('Norwegian Institute of Public Health', 3),
#  ('Indiana University Purdue University', 3),
#  ('Athens University of Economics and Business', 3),
#  ('Indian Statistical Institute', 3),
#  ('Vassar College', 3),
#  ('Cardiff University', 3),
#  ('University of Kent', 3),
#  ('Tallinn University of Technology', 3),
#  ('Kiel Institute for the World Economy', 3),
#  ('Free University of Bozen-Bolzano', 3),
#  ('Royal Society for the Protection of Birds', 3),
#  ('University of Ghana', 3),
#  ('University of KwaZulu-Natal', 3),
#  ('Urban Institute', 3),
#  ('Wayne State University', 3),
#  ('University of St Andrews', 3),
#  ('University of Massachusetts, Lowell', 3),
#  ('Prof. Hester Eisenstein hester1@ prodigy. net Soc. 83300–GENDER and GLOBALIZATION {23377} Tuesdays, 11: 45–1: 45 pm, Room TBA, 3 credits',
#   3),
#  ('National Research Council of Italy', 3),
#  ('University of Bari', 3),
#  ('Chonbuk National University', 3),
#  ('Corvinus University of Budapest', 3),
#  ('Wabash College', 3),
#  ('Ball State University', 3),
#  ('Citadel', 3),
#  ('University of New Hampshire', 3),
#  ('San Diego State University', 3),
#  ('Indian Institute of Management, Calcutta', 3),
#  ('University of Verona', 3),
#  ('Scuola Normale Superiore', 3),
#  ('University of Milano-Bicocca', 3),
#  ('中央研究院', 3),
#  ('Hanken School of Economics', 2),
#  ('Florida Atlantic University', 2),
#  ('University of Texas at Arlington', 2),
#  ('SAS Institute Inc', 2),
#  ('University of International Business and Economics', 2),
#  ('California State University, Northridge', 2),
#  ('Seton Hall University', 2),
#  ('Massey University', 2),
#  ('Shandong University', 2),
#  ('Towson University', 2),
#  ('University of Hohenheim', 2),
#  ('Lingnan University', 2),
#  ("Queen's University Belfast", 2),
#  ('University of Waikato', 2),
#  ('Mississippi State University', 2),
#  ('Wuhan University', 2),
#  ('Nanjing University', 2),
#  ('Potsdam Institute for Climate Impact Research', 2),
#  ('Mahidol University', 2),
#  ('University of Fribourg', 2),
#  ('Suffolk University', 2),
#  ('Grinnell College', 2),
#  ('Aix-Marseille University', 2),
#  ('Universidad del Rosario', 2),
#  ('Universidad de Vigo', 2),
#  ('University of Santiago de Compostela', 2),
#  ('American University of Sharjah', 2),
#  ('Politecnico di Torino', 2),
#  ('KTH Royal Institute of Technology', 2),
#  ('University of Florence', 2),
#  ('Banco de Portugal', 2),
#  ('Yale-NUS College', 2),
#  ('American University of Beirut', 2),
#  ('Weierstrass Institute for Applied Analysis and Stochastics', 2),
#  ('University of Bath', 2),
#  ('University of New Orleans', 2),
#  ('National Institute of Economic and Social Research', 2),
#  ('University of Western Australia', 2),
#  ('Jawaharlal Nehru University', 2),
#  ('University of Valencia', 2),
#  ('Institute for Employment Research', 2),
#  ('US Department of Agriculture', 2),
#  ('ESADE Business School', 2),
#  ('Hungarian Academy of Sciences', 2),
#  ('Polytechnic University of Milan', 2),
#  ('Food and Agriculture Organization', 2),
#  ('D. E. Shaw Research', 2),
#  ('Queensland University of Technology', 2),
#  ('University of Antwerp', 2),
#  ('Ariel University', 2),
#  ('Drake University', 2),
#  ('Soochow University, Taipei', 2),
#  ('University of Richmond', 2),
#  ('Southern Illinois University, Edwardsville', 2),
#  ('Florida Gulf Coast University', 2),
#  ('University of Belgrade', 2),
#  ('University of Perugia', 2),
#  ('University of Barcelona', 2),
#  ('California Polytechnic State University, San Luis Obispo', 2),
#  ('Cleveland State University', 2),
#  ('Linnaeus University', 2),
#  ('Colorado School of Mines', 2),
#  ('RWTH Aachen University', 2),
#  ('California State University East Bay', 2),
#  ('Hanyang University', 2),
#  ('University of San Francisco', 2),
#  ('University of Nevada, Reno', 2),
#  ('Kyung Hee University', 2),
#  ('Boise State University', 2),
#  ('Qatar University', 2),
#  ('Smith College', 2),
#  ('Bates College', 2),
#  ('University of New Brunswick', 2),
#  ('University of Warsaw', 2),
#  ('RAND Corporation', 2),
#  ('University of New Mexico', 2),
#  ('Appalachian State University', 2),
#  ('Saarland University', 2),
#  ('Federal Trade Commission', 2),
#  ('University of Tübingen', 2),
#  ('University of Hawaii', 1),
#  ('Toulouse Business School', 1),
#  ('Dalhousie University', 1),
#  ('Western New England University', 1),
#  ('Charles University in Prague', 1),
#  ('Kwansei Gakuin University', 1),
#  ('Brock University', 1),
#  ('Marquette University', 1),
#  ('University of Stuttgart', 1),
#  ('University of Chinese Academy of Sciences', 1),
#  ('Justus Liebig University Giessen', 1),
#  ('University of Münster', 1),
#  ('Paris Diderot University', 1),
#  ('Utrecht University', 1),
#  ('University of Bergamo', 1),
#  ('United Nations', 1),
#  ('University of Trento', 1),
#  ('Griffith University', 1),
#  ('University of Rhode Island', 1),
#  ('University of Bremen', 1),
#  ('University of Stirling', 1),
#  ('Victoria University', 1),
#  ('Palo Alto Research Center', 1),
#  ('University of Reading', 1),
#  ('Centers for Disease Control and Prevention', 1),
#  ('Tarbiat Modares University', 1),
#  ('University of Leicester', 1),
#  ('Kent State University', 1),
#  ('University of Piraeus', 1),
#  ('University of Strasbourg', 1),
#  ('Dickinson College', 1),
#  ('University of the Basque Country', 1),
#  ('Fairfield University', 1),
#  ('China Europe International Business School', 1),
#  ('Johannes Kepler University, Linz', 1),
#  ('Pomona College', 1),
#  ('University of Nevada, Las Vegas', 1),
#  ('University of Sheffield', 1),
#  ('Western Washington University', 1),
#  ('Lawrence Berkeley National Laboratory', 1),
#  ('Binghamton University', 1),
#  ('National University of Colombia', 1),
#  ('Chongqing University', 1),
#  ('Sungkyunkwan University', 1),
#  ('National University of Ireland, Maynooth', 1),
#  ('University of Massachusetts Boston', 1),
#  ('University of Maine', 1),
#  ('University of South Alabama', 1),
#  ('University of Canterbury', 1),
#  ('University College Cork', 1),
#  ('Stonehill College', 1),
#  ('Canisius College', 1),
#  ('University of Pisa', 1),
#  ('University of Maryland, Baltimore County', 1),
#  ('Universiti Malaysia Kelantan', 1),
#  ('Swarthmore College', 1),
#  ('University of Alabama at Birmingham', 1),
#  ('Lafayette College', 1),
#  ('Universiti Brunei Darussalam', 1),
#  ('School of Oriental and African Studies, London', 1),
#  ('University of Adelaide', 1),
#  ('Curtin University', 1),
#  ('Deakin University', 1)]

# %%
id_pair = {}
name_pair = {}

for doi in df_af_art.index:
    try:
        df_af_art.loc[doi][0]
    except:
        df_af_art_new = df_af_art.loc[doi].sort_values("affiliationid")
        length = len(df_af_art_new)
        for i in range(length-1):
            for j in range(length-1-i):
                try:
                    id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] += 1
                    name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] += 1
                except:
                    id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] = 1
                    name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] = 1

# %%
name_pair_sorted = sorted(name_pair.items(), key=lambda x:x[1], reverse = True)
name_pair_sorted
# Out:
# [('Harvard University+Harvard University', 141),
#  ('Harvard University+Massachusetts Institute of Technology', 117),
#  ('University of Chicago+University of Chicago', 107),
#  ('Massachusetts Institute of Technology+Stanford University', 94),
#  ('Massachusetts Institute of Technology+Massachusetts Institute of Technology',
#   90),
#  ('Stanford University+Stanford University', 89),
#  ('University of California, Berkeley+University of California, Berkeley', 84),
#  ('Harvard University+Stanford University', 78),
#  ('Massachusetts Institute of Technology+University of Chicago', 72),
#  ('Princeton University+University of Chicago', 59),
#  ('Columbia University+Columbia University', 58),
#  ('Stanford University+University of Chicago', 56),
#  ('Northwestern University+University of Chicago', 54),
#  ('Yale University+Yale University', 53),
#  ('Massachusetts Institute of Technology+Yale University', 52),
#  ('Harvard University+University of Chicago', 51),
#  ('Cornell University+Cornell University', 49),
#  ('University of Chicago+Yale University', 49),
#  ('Harvard University+Princeton University', 46),
#  ('Harvard University+University of California, Berkeley', 46),
#  ('Massachusetts Institute of Technology+Northwestern University', 46),
#  ('Northwestern University+Stanford University', 44),
#  ('New York University+New York University', 44),
#  ('Columbia University+University of Chicago', 42),
#  ('University of Chicago+University of California, Berkeley', 38),
#  ('Massachusetts Institute of Technology+University of California, Berkeley',
#   38),
#  ('Duke University+Duke University', 37),
#  ('Harvard University+New York University', 36),
#  ('Columbia University+New York University', 36),
#  ('London School of Economics+London School of Economics', 36),
#  ('Northwestern University+Princeton University', 36),
#  ('Princeton University+University of California, Berkeley', 34),
#  ('Harvard University+Yale University', 33),
#  ('Duke University+Massachusetts Institute of Technology', 33),
#  ('Bocconi University+Harvard University', 33),
#  ('Columbia University+Princeton University', 33),
#  ('Harvard University+London School of Economics', 32),
#  ('Princeton University+Princeton University', 32),
#  ('Northwestern University+Northwestern University', 31),
#  ('Stanford University+Yale University', 31),
#  ('University of California, Los Angeles+University of California, Los Angeles',
#   31),
#  ('New York University+Princeton University', 31),
#  ('New York University+University of Michigan', 31),
#  ('University of Pennsylvania+University of Pennsylvania', 30),
#  ('Columbia University+Massachusetts Institute of Technology', 30),
#  ('New York University+Stanford University', 29),
#  ('Boston University+Massachusetts Institute of Technology', 28),
#  ('Harvard University+University of California, Los Angeles', 27),
#  ('Columbia University+Yale University', 26),
#  ('Bocconi University+Bocconi University', 26),
#  ('London School of Economics+University College London', 26),
#  ('Stanford University+University of Minnesota', 25),
#  ('New York University+Stockholm School of Economics', 23),
#  ('Columbia University+University of Pennsylvania', 23),
#  ('University of Chicago+University of California, Los Angeles', 22),
#  ('University of California, Berkeley+University of California, San Diego',
#   22),
#  ('University of California, Los Angeles+Yale University', 21),
#  ('Columbia University+London School of Economics', 21),
#  ('University of Chicago+University of Pennsylvania', 21),
#  ('London School of Economics+Massachusetts Institute of Technology', 21),
#  ('Northwestern University+University of Pennsylvania', 21),
#  ('London School of Economics+University of California, Berkeley', 21),
#  ('London School of Economics+University of Pennsylvania', 21),
#  ('Stanford University+University of California, Berkeley', 21),
#  ('Duke University+University of Chicago', 21),
#  ('Toulouse School of Economics+Toulouse School of Economics', 21),
#  ('University College London+University College London', 21),
#  ('University of Southern California+University of Southern California', 20),
#  ('HEC Paris+Toulouse School of Economics', 20),
#  ('Stockholm University+University of California, Berkeley', 20),
#  ('Northwestern University+University of California, Los Angeles', 20),
#  ('Columbia University+Stanford University', 19),
#  ('Washington University in St. Louis+Washington University in St. Louis', 19),
#  ('University of California, Los Angeles+University of Pennsylvania', 19),
#  ('New York University+Yale University', 19),
#  ('Massachusetts Institute of Technology+Princeton University', 19),
#  ('Pennsylvania State University+Yale University', 19),
#  ('Bocconi University+London School of Economics', 19),
#  ('Hebrew University of Jerusalem+Tel Aviv University', 19),
#  ('Brigham Young University+Brigham Young University', 18),
#  ('Massachusetts Institute of Technology+University of California, San Diego',
#   18),
#  ('University of British Columbia+University of British Columbia', 18),
#  ('Stockholm School of Economics+Stockholm School of Economics', 18),
#  ('New York University+University of Chicago', 18),
#  ('Massachusetts Institute of Technology+University of Southern California',
#   17),
#  ('Ohio State University+University of Cincinnati', 17),
#  ('University of Zurich+University of Zurich', 17),
#  ('Columbia University+Imperial College London', 17),
#  ('Boston University+Columbia University', 16),
#  ('Massachusetts Institute of Technology+University of Pennsylvania', 16),
#  ('Harvard University+INSEAD', 16),
#  ('Ohio State University+University of Utah', 16),
#  ('Georgetown University+Georgetown University', 16),
#  ('University of Wisconsin-Madison+Yale University', 16),
#  ('Princeton University+University of California, Los Angeles', 16),
#  ('California Institute of Technology+Princeton University', 16),
#  ('Stanford University+University of California, Los Angeles', 15),
#  ('Pennsylvania State University+Pennsylvania State University', 15),
#  ('INSEAD+INSEAD', 15),
#  ('Georgetown University+Ohio State University', 15),
#  ('University of North Carolina at Chapel Hill+University of North Carolina at Chapel Hill',
#   15),
#  ('Stanford University+University of Pennsylvania', 15),
#  ('University of Texas at Austin+University of Texas at Austin', 15),
#  ('University of California, Los Angeles+University of Minnesota', 15),
#  ('New York University+US Federal Reserve Board', 15),
#  ('Harvard University+Northwestern University', 15),
#  ('Centre de Recerca en Economia Internacional+Centre de Recerca en Economia Internacional',
#   15),
#  ('Brown University+Yale University', 15),
#  ('Boston University+University of California, Berkeley', 15),
#  ('Massachusetts Institute of Technology+University of California, Los Angeles',
#   15),
#  ('Massachusetts Institute of Technology+University of Zurich', 15),
#  ('Hebrew University of Jerusalem+Hebrew University of Jerusalem', 14),
#  ('University of Amsterdam+University of Amsterdam', 14),
#  ('Boston University+Hebrew University of Jerusalem', 14),
#  ('University of Michigan+University of Michigan', 14),
#  ('Ohio State University+Ohio State University', 14),
#  ('Columbia University+Cornell University', 14),
#  ('Duke University+Northwestern University', 14),
#  ('Duke University+Stanford University', 14),
#  ('Harvard University+University of Oxford', 14),
#  ('University of Minnesota+University of Pennsylvania', 14),
#  ('Princeton University+Yale University', 14),
#  ('Singapore Management University+Washington University in St. Louis', 13),
#  ('Nova School of Business and Economics+University of Virginia', 13),
#  ('Stanford University+University of Zurich', 13),
#  ('Northwestern University+Yale University', 13),
#  ('Boston College+Boston College', 13),
#  ('Princeton University+香港中文大学', 13),
#  ('New York University+University of California, Los Angeles', 13),
#  ('Princeton University+University of Southern California', 13),
#  ('Harvard University+University of Texas at Austin', 13),
#  ('Bocconi University+University of Oxford', 13),
#  ('California Institute of Technology+California Institute of Technology', 13),
#  ('California Institute of Technology+Yale University', 13),
#  ('Boston College+University of Southern California', 12),
#  ('Duke University+University of Pennsylvania', 12),
#  ('Northwestern University+Washington University in St. Louis', 12),
#  ('University of California, Berkeley+University of California, Davis', 12),
#  ('Boston University+Boston University', 12),
#  ('London Business School+London School of Economics', 12),
#  ('Harvard University+University of Pennsylvania', 12),
#  ('University of Pennsylvania+University of Toronto', 12),
#  ('Carnegie Mellon University+Carnegie Mellon University', 12),
#  ('US Federal Reserve Board+US Federal Reserve Board', 12),
#  ('University of British Columbia+University of California, Berkeley', 12),
#  ('Stockholm University+Stockholm University', 12),
#  ('University of Melbourne+University of Texas at Austin', 11),
#  ('London School of Economics+Northwestern University', 11),
#  ('City University of New York+New York University', 11),
#  ('University of Maryland+University of Maryland', 11),
#  ('University of New South Wales+University of New South Wales', 11),
#  ('Cornell University+Indiana University', 11),
#  ('McGill University+New York University', 11),
#  ('Bocconi University+Rutgers University', 11),
#  ('University of Minnesota+University of Utah', 11),
#  ('Georgetown University+Johns Hopkins University', 11),
#  ('HEC Paris+INSEAD', 11),
#  ('University of Chicago+University of California, San Diego', 11),
#  ('Bocconi University+University College London', 11),
#  ('London School of Economics+University of California, San Diego', 11),
#  ('Brown University+London School of Economics', 11),
#  ('London School of Economics+University of Chicago', 11),
#  ('Columbia University+University of Michigan', 11),
#  ('London School of Economics+Stockholm University', 11),
#  ('Yale University+香港中文大学', 11),
#  ('Princeton University+University of Minnesota', 11),
#  ('Brown University+University of Warwick', 11),
#  ('Pennsylvania State University+University of Wisconsin-Madison', 11),
#  ('University of California, Berkeley+University of Lugano', 11),
#  ('Brown University+Harvard University', 11),
#  ('Johns Hopkins University+University of Pennsylvania', 11),
#  ('Columbia University+University of California, Berkeley', 10),
#  ('Imperial College London+Pompeu Fabra University', 10),
#  ('US Federal Reserve Board+University of Michigan', 10),
#  ('Hebrew University of Jerusalem+Stanford University', 10),
#  ('University of California, Irvine+University of Texas at Austin', 10),
#  ('HEC Paris+HEC Paris', 10),
#  ('University of Bonn+University of Bonn', 10),
#  ('INSEAD+University of Minnesota', 10),
#  ('McGill University+University of Geneva', 10),
#  ('University of Georgia+University of Texas at Austin', 10),
#  ('University of British Columbia+University of Toronto', 10),
#  ('Cornell University+Massachusetts Institute of Technology', 10),
#  ('University of Pennsylvania+University of Southern California', 10),
#  ('University College London+University of Pennsylvania', 10),
#  ('Cornell University+University of Chicago', 10),
#  ('University of Utah+University of Washington', 10),
#  ('University of California, San Diego+University of California, San Diego',
#   10),
#  ('Columbia University+Georgetown University', 10),
#  ('University of California, Berkeley+University of Texas at Austin', 10),
#  ('Uppsala University+Uppsala University', 10),
#  ('Massachusetts Institute of Technology+New York University', 10),
#  ('Columbia University+University College London', 10),
#  ('University College London+University of California, Berkeley', 10),
#  ('Massachusetts Institute of Technology+Toulouse School of Economics', 10),
#  ('Dartmouth College+Harvard University', 10),
#  ('Boston College+Harvard University', 10),
#  ('Stanford University+University of British Columbia', 10),
#  ('Baylor University+University of California, Davis', 10),
#  ('Columbia University+Harvard University', 9),
#  ('University of Houston+University of Minnesota', 9),
#  ('Arizona State University+University of Michigan', 9),
#  ('Stanford University+University College London', 9),
#  ('Princeton University+University of Pennsylvania', 9),
#  ('University of Chicago+University of North Carolina at Chapel Hill', 9),
#  ('Arizona State University+University of Chicago', 9),
#  ('Stockholm School of Economics+Stockholm University', 9),
#  ('University of British Columbia+University of Chicago', 9),
#  ('Ohio State University+University of Washington', 9),
#  ('University of Arizona+University of Utah', 9),
#  ('National University of Singapore+Singapore Management University', 9),
#  ('New York University+University of Wisconsin-Madison', 9),
#  ('Harvard University+Toulouse School of Economics', 9),
#  ('University of Pennsylvania+University of Wisconsin-Madison', 9),
#  ('University of Chicago+University of Pittsburgh', 9),
#  ('Duke University+Pennsylvania State University', 9),
#  ('University College London+University of Oxford', 9),
#  ('Tel Aviv University+Tel Aviv University', 9),
#  ('University of Lausanne+University of Zurich', 9),
#  ('Cornell University+Princeton University', 9),
#  ('University of Notre Dame+University of Pennsylvania', 9),
#  ('Harvard University+University of Zurich', 9),
#  ('London School of Economics+University of California, Los Angeles', 9),
#  ('Dartmouth College+Stanford University', 9),
#  ('University of Chicago+University of Munich', 9),
#  ('University of California, Berkeley+University of Wisconsin-Madison', 9),
#  ('Seoul National University+University of North Carolina at Chapel Hill', 8),
#  ('Ohio State University+University of Pennsylvania', 8),
#  ('University of Minnesota+University of Minnesota', 8),
#  ('HEC Paris+University of Lugano', 8),
#  ('Columbia University+清华大学', 8),
#  ('London School of Economics+Princeton University', 8),
#  ('Stanford University+University of Rochester', 8),
#  ('George Washington University+World Bank', 8),
#  ('University of Texas at Dallas+Washington University in St. Louis', 8),
#  ('Duke University+University of California, Los Angeles', 8),
#  ('University of Chicago+University of Virginia', 8),
#  ('London Business School+University of Oxford', 8),
#  ('New York University+University of Pennsylvania', 8),
#  ('Harvard University+London Business School', 8),
#  ('University of Miami+University of Miami', 8),
#  ('Princeton University+World Bank', 8),
#  ('Dartmouth College+University of California, Davis', 8),
#  ('University of California, Berkeley+University of California, Los Angeles',
#   8),
#  ('Purdue University+University of Manchester', 8),
#  ('University of New South Wales+University of Sydney', 8),
#  ('Columbia University+Shanghai University of Finance and Economics', 8),
#  ('University of California, Berkeley+University of Utah', 8),
#  ('HEC Paris+University of Zurich', 8),
#  ('Ohio State University+University of Minnesota', 8),
#  ('University of Wisconsin-Madison+University of Wisconsin-Madison', 8),
#  ('Indiana University+Indiana University', 8),
#  ('Columbia University+World Bank', 8),
#  ('University of Southern California+University of Toronto', 8),
#  ('香港中文大学+香港中文大学', 8),
#  ('Massachusetts Institute of Technology+University of Michigan', 8),
#  ('Princeton University+Washington University in St. Louis', 8),
#  ('University of Notre Dame+Washington University in St. Louis', 8),
#  ('Federal Reserve Bank of Philadelphia+University of Wisconsin-Madison', 8),
#  ('Northwestern University+University of Texas at Austin', 8),
#  ('Brown University+University of California, Berkeley', 8),
#  ('Imperial College London+Stanford University', 8),
#  ('University of Oslo+University of Oslo', 8),
#  ('University of Pennsylvania+University of Texas at Austin', 8),
#  ('Imperial College London+Princeton University', 8),
#  ('Cornell University+Pompeu Fabra University', 8),
#  ('European University Institute+University of Oxford', 8),
#  ('Stockholm University+University of Pennsylvania', 8),
#  ('Cornell University+London School of Economics', 8),
#  ('Massachusetts Institute of Technology+University of Minnesota', 8),
#  ('Pennsylvania State University+University of Pennsylvania', 8),
#  ('University of Maryland+University of Pennsylvania', 8),
#  ('Brown University+University of Chicago', 8),
#  ('Rice University+University of Chicago', 8),
#  ('Temple University+University of Massachusetts, Amherst', 7),
#  ('University of California, Irvine+University of Oregon', 7),
#  ('London Business School+London Business School', 7),
#  ('Duke University+Medical University of South Carolina', 7),
#  ('Emory University+University of Lausanne', 7),
#  ('Stanford University+Washington University in St. Louis', 7),
#  ('Cornell University+Ohio State University', 7),
#  ('New York University+University of California, Berkeley', 7),
#  ('Tilburg University+University of Notre Dame', 7),
#  ('Johns Hopkins University+University of Southern California', 7),
#  ('Swiss Federal Institute of Technology in Lausanne+University of Lausanne',
#   7),
#  ('Goethe University Frankfurt+Northwestern University', 7),
#  ('University of Connecticut+国立台湾大学', 7),
#  ('California Institute of Technology+HEC Paris', 7),
#  ('Harvard University+World Bank', 7),
#  ('University of California, Irvine+University of California, Los Angeles', 7),
#  ('Duke University+University of Wisconsin-Madison', 7),
#  ('Frankfurt School of Finance & Management+New York University', 7),
#  ('Central University of Finance and Economics+Singapore Management University',
#   7),
#  ('DePaul University+Rice University', 7),
#  ('Central European University+London School of Economics', 7),
#  ('Dartmouth College+Massachusetts Institute of Technology', 7),
#  ('University of Michigan+University of Zurich', 7),
#  ('Dartmouth College+Dartmouth College', 7),
#  ('Stockholm School of Economics+University of Bonn', 7),
#  ('Korea Advanced Institute of Science and Technology+National University of Singapore',
#   7),
#  ('International Monetary Fund+US Federal Reserve Board', 7),
#  ('University of California, Los Angeles+University of Southern California',
#   7),
#  ('University of Innsbruck+VU University Amsterdam', 7),
#  ('University of Innsbruck+Vienna University of Economics and Business', 7),
#  ('Drexel University+Villanova University', 7),
#  ('Pennsylvania State University+University of Georgia', 7),
#  ('Harvard University+University of Washington', 7),
#  ('Ohio State University+University of Arizona', 7),
#  ('University of Arizona+University of Washington', 7),
#  ('New York University+Southwestern University of Finance and Economics', 7),
#  ('Johns Hopkins University+University of Chicago', 7),
#  ('Harvard University+University of Bonn', 7),
#  ('University of Bonn+University of Munich', 7),
#  ('Boston University+University of Chicago', 7),
#  ('Northwestern University+Pennsylvania State University', 7),
#  ('California Institute of Technology+University of California, San Diego', 7),
#  ('Duke University+Yale University', 7),
#  ('ENSAE ParisTech+Toulouse School of Economics', 7),
#  ('Sciences Po+University of Pennsylvania', 7),
#  ('Princeton University+University of California, San Diego', 7),
#  ('Princeton University+香港大学', 7),
#  ('香港中文大学+香港大学', 7),
#  ('HEC Paris+Sciences Po', 7),
#  ('New York University+University College London', 7),
#  ('Duke University+Ohio State University', 7),
#  ('Pompeu Fabra University+University College London', 7),
#  ('University College London+Yale University', 7),
#  ('Boston University+London School of Economics', 7),
#  ('Princeton University+University College London', 7),
#  ('California Institute of Technology+Stanford University', 7),
#  ('Stockholm University+Uppsala University', 7),
#  ('University of California, Berkeley+Yale University', 7),
#  ('London School of Economics+University of Toronto', 7),
#  ('Harvard University+University of California, San Diego', 7),
#  ('London School of Economics+University of Munich', 7),
#  ('Cornell University+Harvard University', 7),
#  ('University of California, Berkeley+Uppsala University', 7),
#  ('Bocconi University+HEC Paris', 7),
#  ('Stockholm School of Economics+University of Cambridge', 7),
#  ('Massachusetts Institute of Technology+University of British Columbia', 7),
#  ('University of California, Berkeley+University of Maryland', 7),
#  ('Brown University+University of Texas at Austin', 7),
#  ('Columbia University+Duke University', 7),
#  ('University of Pennsylvania+Yale University', 7),
#  ('Emory University+University of Chicago', 7),
#  ('INSEAD+University of California, Los Angeles', 7),
#  ('Queen Mary University of London+University of Bristol', 7),
#  ('Michigan State University+Stanford University', 7),
#  ('National University of Singapore+香港中文大学', 7),
#  ('Toulouse School of Economics+University of Zurich', 7),
#  ('Rice University+Rice University', 6),
#  ('European Commission, Joint Research Centre+University of California, Berkeley',
#   6),
#  ('HEC Paris+Harvard University', 6),
#  ('California Institute of Technology+Carnegie Mellon University', 6),
#  ('London Business School+University of California, Berkeley', 6),
#  ('Dartmouth College+University of Southern California', 6),
#  ('Georgetown University+New York University', 6),
#  ('University of California, Irvine+University of California, Irvine', 6),
#  ('University of Chicago+University of Toronto', 6),
#  ('Harvard University+Purdue University', 6),
#  ('Bocconi University+London Business School', 6),
#  ('Bocconi University+University of Wisconsin-Madison', 6),
#  ('Bocconi University+北京大学', 6),
#  ('University of Wisconsin-Madison+北京大学', 6),
#  ('Northwestern University+University of North Carolina at Chapel Hill', 6),
#  ('Columbia University+Dartmouth College', 6),
#  ('Georgetown University+University of Minnesota', 6),
#  ('Maastricht University+University of Amsterdam', 6),
#  ('European University Institute+Universidad Carlos III de Madrid', 6),
#  ('Boston University+University of Illinois at Urbana-Champaign', 6),
#  ('Bocconi University+US Federal Reserve Board', 6),
#  ('London Business School+University of Pennsylvania', 6),
#  ("Bank of Canada+Queen's University", 6),
#  ('University of Pennsylvania+Washington University in St. Louis', 6),
#  ('Stanford University+University of Texas at Austin', 6),
#  ('National University of Singapore+National University of Singapore', 6),
#  ('Indiana University+University of Pennsylvania', 6),
#  ('University of Chicago+University of Michigan', 6),
#  ('Stanford University+University of Amsterdam', 6),
#  ('Federal Reserve Bank of Philadelphia+University of Pennsylvania', 6),
#  ('University of California, Berkeley+University of Toronto', 6),
#  ('University of Bonn+Yale University', 6),
#  ('Arizona State University+Yale University', 6),
#  ('University of Western Ontario+University of Western Ontario', 6),
#  ('University of California, Berkeley+University of Pennsylvania', 6),
#  ('Bocconi University+New York University', 6),
#  ('Federal Reserve Bank of New York+Massachusetts Institute of Technology', 6),
#  ('London School of Economics+University of Warwick', 6),
#  ('Boston University+National University of Singapore', 6),
#  ('Georgetown University+Massachusetts Institute of Technology', 6),
#  ('New York University+University of British Columbia', 6),
#  ('University of Copenhagen+University of Oxford', 6),
#  ('Dartmouth College+Princeton University', 6),
#  ('Boston University+New York University', 6),
#  ('London School of Economics+Yale University', 6),
#  ('Bocconi University+Stockholm University', 6),
#  ('Stockholm University+University of California, San Diego', 6),
#  ('University of Maryland+University of Notre Dame', 6),
#  ('Brown University+SKEMA Business School', 6),
#  ('University of Bologna+University of Bologna', 6),
#  ('Brown University+Brown University', 6),
#  ('Boston University+Princeton University', 6),
#  ('Massachusetts Institute of Technology+World Bank', 6),
#  ('University of Oslo+Yale University', 6),
#  ('University of Oslo+香港中文大学', 6),
#  ('Rice University+Seoul National University', 5),
#  ('Rice University+University of North Carolina at Chapel Hill', 5),
#  ('Tulane University+University of Pittsburgh', 5),
#  ('University of California, Los Angeles+南洋理工大学', 5),
#  ('Copenhagen Business School+Washington University in St. Louis', 5),
#  ('Singapore Management University+Yale University', 5),
#  ('Bank for International Settlements+Imperial College London', 5),
#  ('Brigham Young University+Santa Clara University', 5),
#  ('Michigan State University+University of Illinois at Urbana-Champaign', 5),
#  ('London Business School+New York University', 5),
#  ('Cornell University+Washington University in St. Louis', 5),
#  ('Cornell University+University of Illinois at Urbana-Champaign', 5),
#  ('Claremont McKenna College+INSEAD', 5),
#  ('Hebrew University of Jerusalem+University of Rochester', 5),
#  ('University of Oregon+Vienna University of Economics and Business', 5),
#  ('North Carolina State University+Pennsylvania State University', 5),
#  ('Harvard University+Tel Aviv University', 5),
#  ('Copenhagen Business School+Simon Fraser University', 5),
#  ('University of Chicago+University of Utah', 5),
#  ('University of Utah+University of Virginia', 5),
#  ('Imperial College London+University of Cambridge', 5),
#  ('Columbia University+University of California, Los Angeles', 5),
#  ('Duke University+清华大学', 5),
#  ('New York University+University of Oklahoma', 5),
#  ('Cornell University+Northwestern University', 5),
#  ('Columbia University+Ghent University', 5),
#  ('Columbia University+Tilburg University', 5),
#  ('Ghent University+Tilburg University', 5),
#  ('Lehigh University+University of Southern California', 5),
#  ('London School of Economics+University of Mannheim', 5),
#  ('Boston College+香港理工大学', 5),
#  ('New York University+Washington University in St. Louis', 5),
#  ('Northwestern University+University of Notre Dame', 5),
#  ('University of Notre Dame+University of Notre Dame', 5),
#  ('London School of Economics+Stockholm School of Economics', 5),
#  ('Boston College+University of Virginia', 5),
#  ('Duke University+McMaster University', 5),
#  ('Duke University+Wilfrid Laurier University', 5),
#  ('McMaster University+Wilfrid Laurier University', 5),
#  ('University of Chicago+World Bank', 5),
#  ('Cornell University+Vanderbilt University', 5),
#  ('Indiana University+Vanderbilt University', 5),
#  ('McGill University+University of Houston', 5),
#  ('University of Notre Dame+University of Southern California', 5),
#  ('Columbia University+Singapore Management University', 5),
#  ('Singapore Management University+清华大学', 5),
#  ('London Business School+University of Minnesota', 5),
#  ('Brigham Young University+Ohio State University', 5),
#  ('Cornell University+University of Toronto', 5),
#  ('University of Notre Dame+University of Texas at Dallas', 5),
#  ('Federal Reserve Bank of Dallas+University of Texas at Austin', 5),
#  ('Georgia College+Georgia State University', 5),
#  ('Georgia State University+Georgia State University', 5),
#  ('INSEAD+University of California, Irvine', 5),
#  ('BI Norwegian Business School+Central European University', 5),
#  ('University of Arkansas+香港科技大学', 5),
#  ('香港科技大学+香港科技大学', 5),
#  ('National University of Singapore+University of Miami', 5),
#  ('Pennsylvania State University+University of Utah', 5),
#  ('New York University+University of Cambridge', 5),
#  ('North Carolina State University+University of Pittsburgh', 5),
#  ('Indiana University+University of Wisconsin-Madison', 5),
#  ('Carnegie Mellon University+Columbia University', 5),
#  ('Arizona State University+University of British Columbia', 5),
#  ('University of Pittsburgh+University of Texas at Austin', 5),
#  ('Copenhagen Business School+New York University', 5),
#  ('Frankfurt School of Finance & Management+Frankfurt School of Finance & Management',
#   5),
#  ('Arizona State University+Boston College', 5),
#  ('Dartmouth College+University of Lugano', 5),
#  ('University of California, Los Angeles+University of Delaware', 5),
#  ('Duke University+University of California, Irvine', 5),
#  ('Carnegie Mellon University+University of Lausanne', 5),
#  ('New York University+University of North Carolina at Chapel Hill', 5),
#  ('HEC Paris+University of Oxford', 5),
#  ('Boston University+香港大学', 5),
#  ('Indian School of Business+Johns Hopkins University', 5),
#  ('Indian School of Business+University of Southern California', 5),
#  ('World Bank+World Bank', 5),
#  ('Erasmus University Rotterdam+IESE Business School', 5),
#  ('Erasmus University Rotterdam+New York University', 5),
#  ('IESE Business School+New York University', 5),
#  ('Duke University+Washington University in St. Louis', 5),
#  ('University of Lausanne+University of Lausanne', 5),
#  ('Frankfurt School of Finance & Management+University of Amsterdam', 5),
#  ('Monash University+Texas A&M University', 5),
#  ('Hebrew University of Jerusalem+Interdisciplinary Center, Herzliya', 5),
#  ('Baylor University+Georgia State University', 5),
#  ('Xiamen University+香港科技大学', 5),
#  ('University of Virginia+Washington University in St. Louis', 5),
#  ('Heidelberg University+Tilburg University', 5),
#  ('London School of Economics+University of California, Irvine', 5),
#  ('Indian School of Business+University of Maryland', 5),
#  ('Arizona State University+University of Wisconsin-Madison', 5),
#  ('University of Oklahoma+University of Washington', 5),
#  ('University of California, Los Angeles+University of Maryland', 5),
#  ('Erasmus University Rotterdam+University of Amsterdam', 5),
#  ('New York University+University of Colorado, Boulder', 5),
#  ('Federal Reserve Bank of Chicago+US Federal Reserve Board', 5),
#  ('Massachusetts Institute of Technology+University of Texas at Austin', 5),
#  ('Harvard University+Indiana University', 5),
#  ('McGill University+McMaster University', 5),
#  ('Indiana University+Washington University in St. Louis', 5),
#  ('University of California, Los Angeles+University of Rochester', 5),
#  ('Miami University of Ohio+Pennsylvania State University', 5),
#  ('Bocconi University+University of Virginia', 5),
#  ('Imperial College London+New York University', 5),
#  ('London School of Economics+University of California, Davis', 5),
#  ('Norwegian University of Science and Technology+University of Stavanger', 5),
#  ('Harvard University+Pennsylvania State University', 5),
#  ('University of Amsterdam+University of New South Wales', 5),
#  ('Duke University+Johns Hopkins University', 5),
#  ('University of California, Irvine+University of Toronto', 5),
#  ('Dartmouth College+Yale University', 5),
#  ('Massachusetts Institute of Technology+University College London', 5),
#  ('Harvard University+University of Munich', 5),
#  ('Rice University+University of California, Irvine', 5),
#  ('Centre de Recerca en Economia Internacional+European Commission, Joint Research Centre',
#   5),
#  ('Federal Reserve Bank of San Francisco+Pompeu Fabra University', 5),
#  ('University College London+University of British Columbia', 5),
#  ('Monash University+清华大学', 5),
#  ('Swiss Federal Institute of Technology in Lausanne+University of Chicago',
#   5),
#  ('Swiss Federal Institute of Technology in Lausanne+University of Michigan',
#   5),
#  ('Goethe University Frankfurt+Katholieke Universiteit, Leuven', 5),
#  ('Goethe University Frankfurt+Stockholm School of Economics', 5),
#  ('Katholieke Universiteit, Leuven+Stockholm School of Economics', 5),
#  ('University of Southern California+Yale University', 5),
#  ('Arizona State University+Center for Monetary and Financial Studies (CEMFI)',
#   5),
#  ('Arizona State University+Durham University', 5),
#  ('Center for Monetary and Financial Studies (CEMFI)+Durham University', 5),
#  ('International Monetary Fund+Stockholm University', 5),
#  ('Federal Reserve Bank of New York+Nazarbayev University', 5),
#  ('Federal Reserve Bank of New York+University of California, Los Angeles', 5),
#  ('Nazarbayev University+University of California, Los Angeles', 5),
#  ('London Business School+University of São Paulo', 5),
#  ('Cornell University+VU University Amsterdam', 5),
#  ('Northwestern University+Toulouse School of Economics', 5),
#  ('Dartmouth College+Katholieke Universiteit, Leuven', 5),
#  ('Emory University+University of California, Los Angeles', 5),
#  ('University of Bonn+University of Toronto', 5),
#  ('Paris School of Economics+Toulouse School of Economics', 5),
#  ('Federal Reserve Bank of New York+University of Pennsylvania', 5),
#  ('University of Amsterdam+University of Oslo', 5),
#  ('Universidad Carlos III de Madrid+University of Toronto', 5),
#  ('Brown University+London Business School', 5),
#  ('University of California, Los Angeles+University of Warwick', 5),
#  ('University of Michigan+University of Wisconsin-Madison', 5),
#  ('University of Maryland+University of Zurich', 5),
#  ('HEC Paris+University of California, Los Angeles', 5),
#  ('University of Texas at Austin+Yale University', 5),
#  ('University of Pittsburgh+University of Southern California', 5),
#  ('London School of Economics+University of Southern California', 5),
#  ('University of Minnesota+University of Toronto', 5),
#  ('Johns Hopkins University+University of California, Berkeley', 5),
#  ('University of Lausanne+Yale University', 5),
#  ('University of California, Los Angeles+University of Zurich', 5),
#  ('Columbia University+Seoul National University', 5),
#  ('University College London+University of Milan', 5),
#  ('University of Bonn+University of Pittsburgh', 5),
#  ('London Business School+University of Cambridge', 5),
#  ('Brown University+University of Houston', 5),
#  ('University of Houston+University of Warwick', 5),
#  ('Georgetown University+VU University Amsterdam', 5),
#  ('Hebrew University of Jerusalem+University of Michigan', 5),
#  ('Ecole des Ponts ParisTech+Ecole des Ponts ParisTech', 5),
#  ('Carnegie Mellon University+University of Virginia', 5),
#  ('Harvard University+University of Cambridge', 5),
#  ('Aalto University+University of Oregon', 5),
#  ('Princeton University+Toulouse School of Economics', 5),
#  ('Northwestern University+University of Wisconsin-Madison', 5),
#  ('London School of Economics+Rutgers University', 5),
#  ('Brandeis University+Stanford University', 5),
#  ('Aalto University+Yale University', 5),
#  ('INSEAD+Imperial College London', 5),
#  ('Carnegie Mellon University+Duke University', 5),
#  ('Stanford University+University of California, San Diego', 5),
#  ('Brown University+Stockholm University', 5),
#  ('University of Oxford+Yale University', 5),
#  ('Stockholm University+University of California, Los Angeles', 5),
#  ('Harvard University+U.S. Census Bureau', 5),
#  ('Harvard University+US Federal Reserve Board', 5),
#  ('Royal Society for the Protection of Birds+University College London', 5),
#  ('Bocconi University+University of Chicago', 5),
#  ('Massachusetts Institute of Technology+University of Illinois at Urbana-Champaign',
#   5),
#  ('Columbia University+Pompeu Fabra University', 5),
#  ('Inter-American Development Bank+University College London', 5),
#  ('Spanish National Research Council+University of California, Berkeley', 5),
#  ('New Economic School+New Economic School', 5),
#  ('New Economic School+WZB Berlin Social Science Center', 5),
#  ('National University of Singapore+University of Chicago', 5),
#  ('Bocconi University+University of Lausanne', 5),
#  ('Northwestern University+University of Ghana', 5),
#  ('Microsoft Corporation+Northwestern University', 5),
#  ('Dartmouth College+Georgetown University', 5),
#  ('Boston University+Carnegie Mellon University', 5),
#  ('INSEAD+Stanford University', 5),
#  ('INSEAD+University College London', 5),
#  ('Queen Mary University of London+University College London', 5),
#  ('Dartmouth College+University of Chicago', 5),
#  ('London School of Economics+Stanford University', 5),
#  ('Duke University+Georgetown University', 5),
#  ('HEC Paris+London School of Economics', 5),
#  ('Harvard University+Hebrew University of Jerusalem', 5),
#  ("King's College London+London School of Economics", 5),
#  ('Federal Reserve Bank of New York+US Federal Reserve Board', 5),
#  ('Columbia University+University of Exeter', 5),
#  ('University of Pennsylvania+University of Western Ontario', 5),
#  ('Frankfurt School of Finance & Management+University of Mannheim', 5),
#  ('Brown University+New York University', 5),
#  ('Massachusetts Institute of Technology+North Carolina State University', 5),
#  ('European University Institute+University of Bologna', 5),
#  ('Amazon Inc.+University of California, Berkeley', 5),
#  ('CGIAR: Consultative Group for International Agricultural Research+Harvard University',
#   5),
#  ('CGIAR: Consultative Group for International Agricultural Research+Massachusetts Institute of Technology',
#   5),
#  ('California Institute of Technology+University of Wisconsin-Madison', 5),
#  ('University of Minnesota+University of Wisconsin-Madison', 5),
#  ('Aarhus University+University of Bayreuth', 5),
#  ('Brigham Young University+Stockholm University', 5),
#  ('ENSAE ParisTech+ENSAE ParisTech', 5),
#  ('Ball State University+Cornell University', 5),
#  ('University of Missouri-Kansas City+Virginia Commonwealth University', 5),
#  ('University of Georgia+Yale University', 5),
#  ('Federal Reserve Bank of Chicago+University of Texas at Austin', 5),
#  ('Erasmus University Rotterdam+University of Toronto', 5),
#  ('Boston University+University of Virginia', 5),
#  ('California Institute of Technology+Massachusetts Institute of Technology',
#   5),
#  ('Massachusetts Institute of Technology+香港大学', 5),
#  ('Bocconi University+University of Copenhagen', 5),
#  ('Cornell University+Google Inc.', 5),
#  ('Massachusetts Institute of Technology+New Economic School', 5),
#  ('Duke University+European Commission, Joint Research Centre', 5),
#  ('Bar-Ilan University+Technion', 5),
#  ('Brown University+Williams College', 5),
#  ('Boston University+Cornell University', 5),
#  ('California Institute of Technology+University of Glasgow', 5),
#  ('Boston College+California Institute of Technology', 5),
#  ('Massachusetts Institute of Technology+University of Cambridge', 5),
#  ('University of British Columbia+York University', 5),
#  ('Bocconi University+Tel Aviv University', 5),
#  ('New York University+University of Texas at Austin', 4),
#  ('Lancaster University+University of Manchester', 4),
#  ('University of Michigan+University of Texas at Austin', 4),
#  ('INSEAD+Michigan State University', 4),
#  ('Emory University+Interdisciplinary Center, Herzliya', 4),
#  ('Imperial College London+Massachusetts Institute of Technology', 4),
#  ('EDHEC Business School+University of British Columbia', 4),
#  ('Ohio State University+University of Texas at Austin', 4),
#  ('University of Pittsburgh+University of Pittsburgh', 4),
#  ('Vienna University of Economics and Business+Vienna University of Technology',
#   4),
#  ('INSEAD+University of Illinois at Chicago', 4),
#  ('University of British Columbia+上海交通大学', 4),
#  ('University of California, Berkeley+University of North Carolina at Chapel Hill',
#   4),
#  ('HEC Paris+Massachusetts Institute of Technology', 4),
#  ('University of Pennsylvania+University of Virginia', 4),
#  ('IESE Business School+Nova School of Business and Economics', 4),
#  ('Southern Methodist University+University of Georgia', 4),
#  ('Michigan State University+University of Illinois at Chicago', 4),
#  ('Federal Reserve Bank of St. Louis+Stanford University', 4),
#  ('Cornell University+University of California, Berkeley', 4),
#  ('University of Melbourne+University of Melbourne', 4),
#  ('Arizona State University+University of Utah', 4),
#  ('Brandeis University+Harvard University', 4),
#  ('Indian School of Business+University of Illinois at Urbana-Champaign', 4),
#  ('Imperial College London+University of California, Davis', 4),
#  ('Bank for International Settlements+New York University', 4),
#  ('Drexel University+Drexel University', 4),
#  ('Pompeu Fabra University+University of Warwick', 4),
#  ('Ohio State University+Swiss Federal Institute of Technology in Lausanne',
#   4),
#  ('Arizona State University+University of Texas at Dallas', 4),
#  ('Harvard University+University of Michigan', 4),
#  ('City University London+University of Naples Federico II', 4),
#  ('New York University+University of Toronto', 4),
#  ('European University Institute+University of Vienna', 4),
#  ('University of California, Los Angeles+University of Texas at Austin', 4),
#  ('Federal Reserve Bank of Chicago+Harvard University', 4),
#  ('Michigan State University+Yale University', 4),
#  ('University of Minnesota+University of Washington', 4),
#  ('University of Virginia+University of Virginia', 4),
#  ('Federal Reserve Bank of Philadelphia+Swiss Federal Institute of Technology in Lausanne',
#   4),
#  ('Drexel University+Pennsylvania State University', 4),
#  ('Stockholm School of Economics+University of California, Los Angeles', 4),
#  ('Stockholm School of Economics+University of Illinois at Chicago', 4),
#  ('Bocconi University+University of California, Berkeley', 4),
#  ('University of Oxford+University of Warwick', 4),
#  ('University of Washington+University of Washington', 4),
#  ('National University of Singapore+University of Alberta', 4),
#  ('Duke University+Purdue University', 4),
#  ('Chapman University+University of Washington', 4),
#  ('Emory University+Federal Reserve Bank of Philadelphia', 4),
#  ('Boston University+University of Warwick', 4),
#  ('Duke University+Nova School of Business and Economics', 4),
#  ('University of Mannheim+University of Pittsburgh', 4),
#  ('University of Colorado, Boulder+University of Washington', 4),
#  ('US Federal Reserve Board+University of Pennsylvania', 4),
#  ('University of Chicago+香港城市大学', 4),
#  ('Georgetown University+University of Houston', 4),
#  ('Colorado State University+University of Washington', 4),
#  ('Federal Reserve Bank of Chicago+University of Illinois at Urbana-Champaign',
#   4),
#  ('Babson College+University of Pennsylvania', 4),
#  ('Copenhagen Business School+Columbia University', 4),
#  ('Columbia University+University of Rochester', 4),
#  ('Boston College+Cornell University', 4),
#  ('University of North Texas+University of Texas at Austin', 4),
#  ('Harvard University+Stockholm School of Economics', 4),
#  ('University of California, Irvine+University of South Carolina', 4),
#  ('University of Notre Dame+University of Texas at Austin', 4),
#  ('Federal Reserve Bank of New York+New York University', 4),
#  ('Federal Reserve Bank of New York+Swiss Federal Institute of Technology in Lausanne',
#   4),
#  ('Imperial College London+London School of Economics', 4),
#  ('Tilburg University+Tilburg University', 4),
#  ('Federal Reserve Bank of New York+University of Minnesota', 4),
#  ('Boston College+New York University', 4),
#  ('University of Chicago+University of Wisconsin-Madison', 4),
#  ('Columbia University+George Mason University', 4),
#  ('University of California, Berkeley+University of Michigan', 4),
#  ('University of California, Los Angeles+Washington University in St. Louis',
#   4),
#  ('Federal Reserve Bank of Chicago+Federal Reserve Bank of Chicago', 4),
#  ('University of British Columbia+University of Wisconsin-Madison', 4),
#  ('University of California, Berkeley+香港大学', 4),
#  ('Imperial College London+Imperial College London', 4),
#  ('Ohio State University+Yonsei University', 4),
#  ('University of Rochester+Yale University', 4),
#  ('University of Michigan+University of Pennsylvania', 4),
#  ('Bocconi University+University of North Carolina at Chapel Hill', 4),
#  ('University of Pennsylvania+香港科技大学', 4),
#  ('International Monetary Fund+University of Chicago', 4),
#  ('Frankfurt School of Finance & Management+Institute for the Study of Labor',
#   4),
#  ('University of Texas at Austin+University of Wisconsin-Madison', 4),
#  ('University of Glasgow+University of Minnesota', 4),
#  ('University of Toronto+York University', 4),
#  ('Princeton University+University of Notre Dame', 4),
#  ('London School of Economics+University of Maryland', 4),
#  ('Georgetown University+Princeton University', 4),
#  ('Massachusetts Institute of Technology+University of Liverpool', 4),
#  ('Columbia University+University of California, Davis', 4),
#  ('London School of Economics+University of British Columbia', 4),
#  ('Pennsylvania State University+University of Chicago', 4),
#  ('Federal Reserve Bank of St. Louis+Goethe University Frankfurt', 4),
#  ('BI Norwegian Business School+Stanford University', 4),
#  ('Erasmus University Rotterdam+University of Zurich', 4),
#  ('Harvard University+International Monetary Fund', 4),
#  ('International Monetary Fund+University of California, Los Angeles', 4),
#  ('Purdue University+University of California, Santa Cruz', 4),
#  ('Boston University+Washington University in St. Louis', 4),
#  ('New York University+Pennsylvania State University', 4),
#  ('Federal Reserve Bank of St. Louis+University of Pennsylvania', 4),
#  ('London School of Economics+University of Oxford', 4),
#  ('Emory University+Federal Reserve Bank of Atlanta', 4),
#  ('Columbia University+Toulouse School of Economics', 4),
#  ('Bocconi University+Princeton University', 4),
#  ('University of British Columbia+香港大学', 4),
#  ('University of Toronto+香港大学', 4),
#  ('Stanford University+University of Washington', 4),
#  ('University of California, Berkeley+World Bank', 4),
#  ('Brown University+Cornell University', 4),
#  ('Pennsylvania State University+University of Iowa', 4),
#  ('Princeton University+University of Warwick', 4),
#  ('CGIAR: Consultative Group for International Agricultural Research+University of Florida',
#   4),
#  ('George Washington University+University of Chicago', 4),
#  ('University of California, San Diego+University of Oslo', 4),
#  ('Stockholm University+University of Chicago', 4),
#  ('University of California, Los Angeles+University of Melbourne', 4),
#  ('New York University+University of California, San Diego', 4),
#  ('University of Minnesota+Yale University', 4),
#  ('Harvard University+University of Pittsburgh', 4),
#  ('Harvard University+National University of Singapore', 4),
#  ('Boston University+Northwestern University', 4),
#  ('Harvard University+Pompeu Fabra University', 4),
#  ('University of Michigan+University of Utah', 4),
#  ('University of Bonn+University of Zurich', 4),
#  ('New York University+Simon Fraser University', 4),
#  ('Boston University+Federal Reserve Bank of Richmond', 4),
#  ('University of California, San Diego+University of Michigan', 4),
#  ("Queen's University+University of British Columbia", 4),
#  ('Pennsylvania State University+Princeton University', 4),
#  ('New York University+VU University Amsterdam', 4),
#  ('Carnegie Mellon University+University of California, Los Angeles', 4),
#  ('Technion+Technion', 4),
#  ('Carnegie Mellon University+University of Pennsylvania', 4),
#  ('Northwestern University+University of Cambridge', 4),
#  ('New York University+Rice University', 4),
#  ('International Monetary Fund+University of California, Berkeley', 4),
#  ('Federal Reserve Bank of Atlanta+Federal Reserve Bank of San Francisco', 4),
#  ('Emory University+University of Iowa', 4),
#  ('University of Georgia+University of Wisconsin-Madison', 4),
#  ('University of Chicago+University of Zurich', 4),
#  ('Aarhus University+University of California, Berkeley', 4),
#  ('Queen Mary University of London+Queen Mary University of London', 4),
#  ('Boston College+Swiss Federal Institute of Technology in Lausanne', 4),
#  ('Northwestern University+Queen Mary University of London', 4),
#  ('American University+University of California, Davis', 3),
#  ('University of Texas at San Antonio+University of Utah', 3),
#  ('Emory University+Federal Reserve Bank of New York', 3),
#  ('Duke University+New York University', 3),
#  ('University of Amsterdam+Washington University in St. Louis', 3),
#  ('Northwestern University+University of Maryland', 3),
#  ('Korea Advanced Institute of Science and Technology+University of Illinois at Urbana-Champaign',
#   3),
#  ('Emory University+University at Buffalo', 3),
#  ('London Business School+Massachusetts Institute of Technology', 3),
#  ('Imperial College London+London Business School', 3),
#  ('Bocconi University+University of California, San Diego', 3),
#  ('Rice University+University of Houston', 3),
#  ('Interdisciplinary Center, Herzliya+New York University', 3),
#  ('EDHEC Business School+Imperial College London', 3),
#  ('Texas A&M University+University of South Carolina', 3),
#  ('DePaul University+Princeton University', 3),
#  ('Indiana University+London School of Economics', 3),
#  ('Indiana University+University of North Carolina at Chapel Hill', 3),
#  ('Dartmouth College+Northwestern University', 3),
#  ('University of Pennsylvania+University of Washington', 3),
#  ('Carnegie Mellon University+Imperial College London', 3),
#  ('Harvard University+Ohio State University', 3),
#  ('Purdue University+Rutgers University', 3),
#  ('New York University+University of Maryland', 3),
#  ('Copenhagen Business School+Copenhagen Business School', 3),
#  ('Stanford University+University of Michigan', 3),
#  ('Cornell University+Yale University', 3),
#  ('Massachusetts Institute of Technology+Stockholm School of Economics', 3),
#  ('Imperial College London+University of Chicago', 3),
#  ('INSEAD+清华大学', 3),
#  ('University of Arizona+Yale University', 3),
#  ('Columbia University+Hofstra University', 3),
#  ('Columbia University+Thammasat University', 3),
#  ('Columbia University+香港中文大学', 3),
#  ('Hofstra University+Thammasat University', 3),
#  ('Hofstra University+香港中文大学', 3),
#  ('Thammasat University+香港中文大学', 3),
#  ('Arizona State University+University of New South Wales', 3),
#  ('McGill University+University of Texas at Dallas', 3),
#  ('Swiss Federal Institute of Technology in Lausanne+Swiss Federal Institute of Technology in Lausanne',
#   3),
#  ('Central University of Finance and Economics+Washington University in St. Louis',
#   3),
#  ('Singapore Management University+Singapore Management University', 3),
#  ('Pennsylvania State University+Southern Methodist University', 3),
#  ('Pennsylvania State University+University of Alberta', 3),
#  ('Southern Methodist University+University of Alberta', 3),
#  ('Southern Methodist University+University of Utah', 3),
#  ('University of Alberta+University of Utah', 3),
#  ('Northwestern University+University of Illinois at Chicago', 3),
#  ('Pennsylvania State University+University of Rochester', 3),
#  ('Emory University+University of Texas at Austin', 3),
#  ('Erasmus University Rotterdam+Tilburg University', 3),
#  ('University of Lugano+University of St. Gallen', 3),
#  ('University of California, Berkeley+Washington University in St. Louis', 3),
#  ('University of Kentucky+University of Michigan', 3),
#  ('WHU - Otto Beisheim School of Management+香港大学', 3),
#  ('Georgetown University+INSEAD', 3),
#  ('Georgetown University+University of Texas at Dallas', 3),
#  ('INSEAD+University of Texas at Dallas', 3),
#  ('University of Minnesota+University of Texas at Dallas', 3),
#  ('University of Illinois at Urbana-Champaign+University of Kentucky', 3),
#  ('US Federal Reserve Board+University of Wisconsin-Madison', 3),
#  ('US Federal Reserve Board+北京大学', 3),
#  ('University of Rochester+University of Rochester', 3),
#  ('Singapore Management University+University at Buffalo', 3),
#  ('Singapore Management University+University of Delaware', 3),
#  ('Singapore Management University+University of Washington', 3),
#  ('University at Buffalo+University of Delaware', 3),
#  ('University at Buffalo+University of Washington', 3),
#  ('University of Delaware+University of Washington', 3),
#  ('Harvard University+University of Toronto', 3),
#  ('Princeton University+University of Toronto', 3),
#  ('University of Pennsylvania+University of Rochester', 3),
#  ('University of Innsbruck+University of Innsbruck', 3),
#  ('VU University Amsterdam+Vienna University of Economics and Business', 3),
#  ('ETH Zürich+University of California, San Diego', 3),
#  ('Dartmouth College+London School of Economics', 3),
#  ('Baylor University+University of North Carolina at Chapel Hill', 3),
#  ('Stockholm School of Economics+University of Warwick', 3),
#  ('Renmin University of China+University of Toronto', 3),
#  ('Renmin University of China+复旦大学', 3),
#  ('Renmin University of China+香港理工大学', 3),
#  ('University of Toronto+复旦大学', 3),
#  ('University of Toronto+香港理工大学', 3),
#  ('复旦大学+香港理工大学', 3),
#  ('London School of Economics+Santa Clara University', 3),
#  ('City University London+IESE Business School', 3),
#  ('City University of New York+Southwestern University of Finance and Economics',
#   3),
#  ('University of Southern California+University of Texas at Austin', 3),
#  ('Indiana University+University of Oxford', 3),
#  ('Brown University+Bocconi University', 3),
#  ('University of Bonn+University of Montreal', 3),
#  ('Drexel University+Montana State University', 3),
#  ('Drexel University+University of California, Santa Barbara', 3),
#  ('Drexel University+University of Wisconsin-Madison', 3),
#  ('Montana State University+University of California, Santa Barbara', 3),
#  ('Montana State University+University of Wisconsin-Madison', 3),
#  ('University of California, Santa Barbara+University of Wisconsin-Madison',
#   3),
#  ('Johns Hopkins University+University of Virginia', 3),
#  ('London Business School+University of California, Davis', 3),
#  ('Iowa State University+University of Pittsburgh', 3),
#  ('Sciences Po+Sciences Po', 3),
#  ('McGill University+University of Toronto', 3),
#  ('University of Edinburgh+University of Wisconsin-Madison', 3),
#  ('University of Virginia+Yale University', 3),
#  ('University of St. Gallen+University of Zurich', 3),
#  ('Federal Reserve Bank of Atlanta+Federal Reserve Bank of Atlanta', 3),
#  ('University of Zurich+Wellesley College', 3),
#  ('Australian National University+Columbia University', 3),
#  ('London School of Economics+New York University', 3),
#  ('Federal Reserve Bank of Dallas+University College London', 3),
#  ('Microsoft Corporation+University of Washington', 3),
#  ('Boston University+University of Pennsylvania', 3),
#  ('University of Bern+University of Missouri', 3),
#  ('LUISS Guido Carli+Stanford University', 3),
#  ('Brown University+University of Pennsylvania', 3),
#  ('Columbia University+Federal Reserve Bank of New York', 3),
#  ('Northwestern University+Tel Aviv University', 3),
#  ('University of Toronto+Yale University', 3),
#  ('Imperial College London+Johns Hopkins University', 3),
#  ('Paris School of Economics+University of Oxford', 3),
#  ('Federal Reserve Bank of New York+University of Bern', 3),
#  ('Georgetown University+University of Cambridge', 3),
#  ('Harvard University+University of Auckland', 3),
#  ('Autonomous University of Barcelona+Universidad Carlos III de Madrid', 3),
#  ('Columbia University+Paris School of Economics', 3),
#  ("Queen's University+University of Illinois at Urbana-Champaign", 3),
#  ('London Business School+Pennsylvania State University', 3),
#  ('Federal Reserve Bank of Chicago+University of Chicago', 3),
#  ('Ecole des Ponts ParisTech+University of Bonn', 3),
#  ('Imperial College London+Yale University', 3),
#  ('Northwestern University+New York University', 3),
#  ('Michigan State University+Michigan State University', 3),
#  ('University of Padova+Yale University', 3),
#  ('Georgia Institute of Technology+University of Notre Dame', 3),
#  ('Boston University+University of Oxford', 3),
#  ('London School of Economics+Paris School of Economics', 3),
#  ('Johns Hopkins University+Pennsylvania State University', 3),
#  ('ENSAE ParisTech+University College London', 3),
#  ('University of Cambridge+University of Cambridge', 3),
#  ('Toulouse School of Economics+Yale University', 3),
#  ('Carnegie Mellon University+Massachusetts Institute of Technology', 3),
#  ('Hong Kong Baptist University+香港大学', 3),
#  ('Johns Hopkins University+University of Zurich', 3),
#  ('National University of Singapore+Office of the Comptroller of the Currency',
#   3),
#  ('Centre de Recerca en Economia Internacional+University of California, Los Angeles',
#   3),
#  ('Statistics Norway+University of Oslo', 3),
#  ('University College Dublin+University College Dublin', 3),
#  ('Simon Fraser University+University of British Columbia', 3),
#  ('University of California, Berkeley+University of Colorado, Boulder', 3),
#  ('Emory University+University of Pennsylvania', 3),
#  ('Duke University+University of Gothenburg', 3),
#  ('Boston University+Swiss Federal Institute of Technology in Lausanne', 3),
#  ('University of Peradeniya+World Bank', 3),
#  ('Cornell University+University of Pennsylvania', 3),
#  ('Massachusetts Institute of Technology+University of Notre Dame', 3),
#  ('INSEAD+University of California, Berkeley', 3),
#  ('Harvard University+University of Maryland', 3),
#  ('University of Alabama+University of Chicago', 3),
#  ('University of Alabama+University of Georgia', 3),
#  ('University of Alabama+University of Hamburg', 3),
#  ('University of Chicago+University of Georgia', 3),
#  ('University of Chicago+University of Hamburg', 3),
#  ('University of Georgia+University of Hamburg', 3),
#  ('Autonomous University of Barcelona+Stanford University', 3),
#  ('Harvard University+Resources for the Future, Washington DC', 3),
#  ('Hebrew University of Jerusalem+Massachusetts Institute of Technology', 3),
#  ('Imperial College London+University of California, Berkeley', 3),
#  ('Harvard University+Johns Hopkins University', 3),
#  ('Federal Reserve Bank of Chicago+Massachusetts Institute of Technology', 3),
#  ('Northwestern University+University of Minnesota', 3),
#  ('Bar-Ilan University+McGill University', 3),
#  ('Emory University+University of Georgia', 3),
#  ('University of Cyprus+University of Guelph', 3),
#  ('University of Stavanger+Yale University', 3),
#  ('London School of Economics+University of Colorado, Boulder', 3),
#  ('Federal Reserve Bank of Richmond+Federal Reserve Bank of San Francisco', 3),
#  ('Amazon Inc.+Hebrew University of Jerusalem', 3),
#  ('Carnegie Mellon University+University of Michigan', 3),
#  ('Cornell University+University of Oslo', 3),
#  ('Stockholm University+Yale University', 3),
#  ('Eindhoven University of Technology+Katholieke Universiteit, Leuven', 3),
#  ('Santa Clara University+US Federal Reserve Board', 3),
#  ('Pennsylvania State University+University of California, Berkeley', 3),
#  ('Toulouse School of Economics+University of Minnesota', 3),
#  ('University of New South Wales+University of Western Ontario', 3),
#  ('Federal Reserve Bank of Dallas+University of Pennsylvania', 3),
#  ('Carnegie Mellon University+University of Georgia', 3),
#  ('Stanford University+University of Munich', 3),
#  ('University of Oslo+VU University Amsterdam', 3),
#  ('VU University Amsterdam+Yale University', 3),
#  ('VU University Amsterdam+香港中文大学', 3),
#  ('Northwestern University+US Federal Reserve Board', 3),
#  ('Stanford University+US Federal Reserve Board', 3),
#  ('IESE Business School+IESE Business School', 3),
#  ('London School of Economics+Washington University in St. Louis', 3),
#  ('California Institute of Technology+IESE Business School', 3),
#  ('IESE Business School+Massachusetts Institute of Technology', 3),
#  ('IESE Business School+Princeton University', 3),
#  ('Massachusetts Institute of Technology+Michigan State University', 3),
#  ('EDHEC Business School+University of Cyprus', 3),
#  ('EDHEC Business School+University of Lugano', 3),
#  ('EDHEC Business School+University of North Carolina at Chapel Hill', 3),
#  ('University of Cyprus+University of Lugano', 3),
#  ('University of Cyprus+University of North Carolina at Chapel Hill', 3),
#  ('University of Lugano+University of North Carolina at Chapel Hill', 3),
#  ('Singapore Management University+香港中文大学', 3),
#  ...]

# %%
conn.close()
