# %% [markdown]
# # Data Cleaning and Put into SQL

# %%
import pandas as pd
import sqlite3
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import bs4
import time
import random
import numpy as np

# %% [markdown]
# ## Clean author_article.csv

# %%
# clean author_article
df_art_au = pd.read_csv("author_article.csv", encoding = "utf-8-sig").drop_duplicates()
df_art_au.to_csv("author_article.csv", encoding = "utf-8-sig", index = False)
df_art_au.to_csv("author_article_no_header.csv", encoding = "utf-8-sig", index = False, header = False)

# %% [markdown]
# ## Clean article.csv

# %%
# select valid records with valid doi, issue format, and not duplicated
def select_valid(df):
    df_s = df[(df["doi"].str[:3] == "10.") & (df["volume"].str.contains("Supplement") == False) & 
              (df["volume"].str.contains("_Part_") == False) & 
              (df["volume"].str.contains("S1") == False) & 
              (df["volume"].str.contains("S2") == False) &
              (df["volume"].str.contains("issue ") == True)].drop_duplicates(subset=["doi"]).reset_index(drop = True)
    return df_s

# convert volume to date
def conv_volume_to_date(v,freq):
    v_list = v.split(", ")
    year = v_list[0]
    issue = v_list[2].replace("issue ","")
    if freq == 4:
        d = year+"-"+str(int(issue)*3-1)+"-15"
    elif freq == 6 or freq == 5:
        d = year+"-"+str(int(issue)*2)+"-01"
    elif freq == 12:
        d = year+"-"+issue+"-15"
    elif freq == 3:
        d = year+"-"+str(int(issue)*3)+"-01"
    elif freq == 2:
        d = year+"-"+str(int(issue)*6-2)+"-01"
    elif freq == 1:
        d = year+"-"+str(7)+"-01"
    
    if len(d) < 10:
        return d.split("-")[0]+"-"+"0"+d.split("-")[1]+"-"+d.split("-")[2]
    else:
        return d
    
# calculate issue frequency
def cal_freq(vs):
    dict = {}
    years = [int(v.split(", ")[0]) for v in vs]
    unique_years = set(years)
    issues = [int(v.split(", ")[2].replace("issue ","")) for v in vs]
    for unique_year in unique_years:
        max_issue = 0
        for i in range(len(years)):
            if unique_year == years[i]:
                if issues[i] > max_issue:
                    max_issue = issues[i]
        dict[unique_year] = max_issue

    return dict

# %% [markdown]
# ### 1. RFS

# %%
# clean rfs
df_rfs = pd.read_csv("data/journals/raw_data/rfs.csv", encoding = "utf-8-sig").astype("str")
df_rfs["abstract"] = df_rfs["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_rfs_s = select_valid(df_rfs)
freq = cal_freq(df_rfs_s["volume"])

dates = []
for idx in df_rfs_s.index:
    year = int(df_rfs_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_rfs_s.loc[idx,"volume"],freq[year]))

df_rfs_s["date"] = dates
df_rfs_s.head()
# Out:
#                        journal  \
# 0  Review of Financial Studies
# 1  Review of Financial Studies
# 2  Review of Financial Studies
# 3  Review of Financial Studies
# 4  Review of Financial Studies
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 3  Differences of Opinion, Short-Sales Constraint...
# 4             Risk Adjustment and Trading Strategies
#
#                                              authors  \
# 0                ['Jerome Detemple', 'Angel Serrat']
# 1               ['Wayne Ferson', 'Andrew F. Siegel']
# 2                ['Gurdip Bakshi', 'Nikunj Kapadia']
# 3                  ['Harrison Hong', 'Jeremy Stein']
# 4  ['Dong-Hyun Ahn', 'Jennifer Conrad', 'Robert D...
#
#                             volume jel  \
# 0  2003, vol. 16, issue 2, 597-629  []
# 1  2003, vol. 16, issue 2, 567-595  []
# 2  2003, vol. 16, issue 2, 527-566  []
# 3  2003, vol. 16, issue 2, 487-525  []
# 4  2003, vol. 16, issue 2, 459-485  []
#
#                                             abstract  \
# 0  This article studies an intertemporal economy ...
# 1  Hansen and Jagannathan (1991) (hereafter HJ) d...
# 2  We investigate whether the volatility risk pre...
# 3  We develop a theory of market crashes based on...
# 4  We assess the profitability of momentum strate...
#
#                                                  url                 doi  \
# 0  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg003
# 1  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg004
# 2  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg002
# 3  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg006
# 4  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhg001
#
#          date
# 0  2003-05-15
# 1  2003-05-15
# 2  2003-05-15
# 3  2003-05-15
# 4  2003-05-15

# %% [markdown]
# ### 2. RES

# %%
# clean res
df_res = pd.read_csv("data/journals/raw_data/res.csv", encoding = "utf-8-sig").astype("str")
df_res["abstract"] = df_res["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_res_s = select_valid(df_res)
freq = cal_freq(df_res_s["volume"])

dates = []
for idx in df_res_s.index:
    year = int(df_res_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_res_s.loc[idx,"volume"],freq[year]))

df_res_s["date"] = dates
df_res_s.tail()
# Out:
#                          journal  \
# 3575  Review of Economic Studies
# 3576  Review of Economic Studies
# 3577  Review of Economic Studies
# 3578  Review of Economic Studies
# 3579  Review of Economic Studies
#
#                                                   title  \
# 3575                 Profit in American Economic Theory
# 3576                       I.—A Note on Relative Shares
# 3577              II.—The Diagrammatical Representation
# 3578  III.—The Elasticity of Substitution and the Re...
# 3579                     IV.—A Note on Mr. Kahn's Paper
#
#                      authors                        volume jel  \
# 3575  ['William S. Hopkins']  1933, vol. 1, issue 1, 60-66  []
# 3576        ['P. M. Sweezy']  1933, vol. 1, issue 1, 67-68  []
# 3577        ['A. P. Lerner']  1933, vol. 1, issue 1, 68-71  []
# 3578          ['R. F. Kahn']  1933, vol. 1, issue 1, 72-78  []
# 3579          ['John Hicks']  1933, vol. 1, issue 1, 78-80  []
#
#                                                abstract  \
# 3575  DURING the past sixty years, there has been a ...
# 3576                                                nan
# 3577                                                nan
# 3578  WE owe to Dr. Hicks the extremely interesting ...
# 3579                                                nan
#
#                                                     url  \
# 3575  https://econpapers.repec.org/article/ouprestud...
# 3576  https://econpapers.repec.org/article/ouprestud...
# 3577  https://econpapers.repec.org/article/ouprestud...
# 3578  https://econpapers.repec.org/article/ouprestud...
# 3579  https://econpapers.repec.org/article/ouprestud...
#
#                         doi        date
# 3575        10.2307/2967438  1933-07-01
# 3576        10.2307/2967439  1933-07-01
# 3577        10.2307/2967440  1933-07-01
# 3578  10.2307/restud/1.1.72  1933-07-01
# 3579        10.2307/2967442  1933-07-01

# %% [markdown]
# ### 3. QJE

# %%
# clean qje
df_qje = pd.read_csv("data/journals/raw_data/qje.csv", encoding = "utf-8-sig").astype("str")
df_qje["abstract"] = df_qje["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_qje_s = select_valid(df_qje)
freq = cal_freq(df_qje_s["volume"])

dates = []
for idx in df_qje_s.index:
    year = int(df_qje_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_qje_s.loc[idx,"volume"],freq[year]))

df_qje_s["date"] = dates
df_qje_s.tail()
# Out:
#                                  journal  \
# 5415  The Quarterly Journal of Economics
# 5416  The Quarterly Journal of Economics
# 5417  The Quarterly Journal of Economics
# 5418  The Quarterly Journal of Economics
# 5419  The Quarterly Journal of Economics
#
#                                               title               authors  \
# 5415           Private Monopolies and Public Rights  ['Arthur T. Hadley']
# 5416                 Silver Before Congress in 1886    ['S. Dana Horton']
# 5417  The Arithmetic, Geometric, and Harmonic Means     ['F. Coggeshall']
# 5418              Legislation for Labor Arbitration    ['H. M. Williams']
# 5419                                 Correspondence     ['Arthur Mangin']
#
#                              volume jel  \
# 5415   1886, vol. 1, issue 1, 28-44  []
# 5416   1886, vol. 1, issue 1, 45-75  []
# 5417   1886, vol. 1, issue 1, 83-86  []
# 5418   1886, vol. 1, issue 1, 86-91  []
# 5419  1886, vol. 1, issue 1, 91-102  []
#
#                                                abstract  \
# 5415                                                nan
# 5416                                                nan
# 5417  This chapter is devoted to the properties and ...
# 5418                                                nan
# 5419                                                nan
#
#                                                     url              doi  \
# 5415  https://econpapers.repec.org/article/oupqjecon...  10.2307/1883107
# 5416  https://econpapers.repec.org/article/oupqjecon...  10.2307/1883108
# 5417  https://econpapers.repec.org/article/oupqjecon...  10.2307/1883111
# 5418  https://econpapers.repec.org/article/oupqjecon...  10.2307/1883112
# 5419  https://econpapers.repec.org/article/oupqjecon...  10.2307/1883113
#
#             date
# 5415  1886-07-01
# 5416  1886-07-01
# 5417  1886-07-01
# 5418  1886-07-01
# 5419  1886-07-01

# %% [markdown]
# ### 4. JPE

# %%
# clean jpe
df_jpe = pd.read_csv("data/journals/raw_data/jpe.csv", encoding = "utf-8-sig").astype("str")
df_jpe["abstract"] = df_jpe["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_jpe["doi"] = df_jpe["doi"].apply(lambda x: x.replace("http://dx.doi.org/",""))
df_jpe_s = select_valid(df_jpe)
freq = cal_freq(df_jpe_s["volume"])

dates = []
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_jpe_s.loc[idx,"volume"],freq[year]))

df_jpe_s["date"] = dates

# modify date for 2023
for idx in df_jpe_s.index:
    year = int(df_jpe_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_jpe_s.loc[idx, "date"] = conv_volume_to_date(df_jpe_s.loc[idx,"volume"],12)

df_jpe_s.tail()
# Out:
#                            journal  \
# 3324  Journal of Political Economy
# 3325  Journal of Political Economy
# 3326  Journal of Political Economy
# 3327  Journal of Political Economy
# 3328  Journal of Political Economy
#
#                                                   title  \
# 3324              Some Evidence on the Demand for Money
# 3325                        Paul Baran: An Appreciation
# 3326  Walras' Law and the Patinkin Paradox: A Qualit...
# 3327  Factor-Intensity Reversals in International Co...
# 3328            Testing Economic Assumptions: A Comment
#
#                       authors                         volume jel  \
# 3324        ['David Laidler']  1966, vol. 74, issue 1, 55-68  []
# 3325    ['M. Bronfenbrenner']  1966, vol. 74, issue 1, 69-71  []
# 3326  ['James G. Witte, Jr.']  1966, vol. 74, issue 1, 72-76  []
# 3327  ['David Stafford Ball']  1966, vol. 74, issue 1, 77-80  []
# 3328      ['T. W. Hutchison']  1966, vol. 74, issue 1, 81-83  []
#
#                                                abstract  \
# 3324  I ALTHOUGH the demand function for money balan...
# 3325  HTEN Joseph Dorfman's monumental W Economic Mi...
# 3326  TN HIS Money, Interest, and Prices Patinkin (1...
# 3327  THE role of two assumptions inthe factorpropor...
# 3328  Hutchison is responsible for considerable conf...
#
#                                                     url             doi  \
# 3324  https://econpapers.repec.org/article/ucpjpolec...  10.1086/259109
# 3325  https://econpapers.repec.org/article/ucpjpolec...  10.1086/259110
# 3326  https://econpapers.repec.org/article/ucpjpolec...  10.1086/259111
# 3327  https://econpapers.repec.org/article/ucpjpolec...  10.1086/259112
# 3328  https://econpapers.repec.org/article/ucpjpolec...  10.1086/259113
#
#             date
# 3324  1966-07-01
# 3325  1966-07-01
# 3326  1966-07-01
# 3327  1966-07-01
# 3328  1966-07-01

# %% [markdown]
# ### 5. E

# %%
# clean e
df_e = pd.read_csv("data/journals/raw_data/e.csv", encoding = "utf-8-sig").astype("str")
df_e["abstract"] = df_e["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_e["doi"] = df_e["doi"].apply(lambda x: x.replace("https://doi.org/",""))
df_e_s = select_valid(df_e)
freq = cal_freq(df_e_s["volume"])

dates = []
for idx in df_e_s.index:
    year = int(df_e_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_e_s.loc[idx,"volume"],freq[year]))

df_e_s["date"] = dates

# modify date for 2023
for idx in df_e_s.index:
    year = int(df_e_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_e_s.loc[idx, "date"] = conv_volume_to_date(df_e_s.loc[idx,"volume"],6)

df_e_s.tail()
# Out:
#            journal                                              title  \
# 1000  Econometrica  Higher Order Properties of Gmm and Generalized...
# 1001  Econometrica      Random Matching Under Dichotomous Preferences
# 1002  Econometrica           Notes and Comments the Amsterdam Auction
# 1003  Econometrica  Random Effects Estimators with many Instrument...
# 1004  Econometrica  The Econometric Society Annual Reports Report ...
#
#                                                 authors  \
# 1000                 ['Whitney Newey', 'Richard Smith']
# 1001               ['Anna Bogomolnaia', 'Herve Moulin']
# 1002                  ['Jacob Goeree', 'Theo Offerman']
# 1003               ['Gary Chamberlain', 'Guido Imbens']
# 1004  ['Eddie Dekel', 'Glenn Ellison', 'Joel Horowit...
#
#                                volume jel  \
# 1000  2004, vol. 72, issue 1, 219-255  []
# 1001  2004, vol. 72, issue 1, 257-279  []
# 1002  2004, vol. 72, issue 1, 281-294  []
# 1003  2004, vol. 72, issue 1, 295-306  []
# 1004  2004, vol. 72, issue 1, 336-338  []
#
#                                                abstract  \
# 1000  In an effort to improve the small sample prope...
# 1001  We consider bilateral matching problems where ...
# 1002  The Amsterdam auction has been used to sell re...
# 1003  In this paper we propose a new estimator for a...
# 1004                                                nan
#
#                                                     url  \
# 1000  https://econpapers.repec.org/article/ecmemetrp...
# 1001  https://econpapers.repec.org/article/ecmemetrp...
# 1002  https://econpapers.repec.org/article/ecmemetrp...
# 1003  https://econpapers.repec.org/article/ecmemetrp...
# 1004  https://econpapers.repec.org/article/ecmemetrp...
#
#                                    doi        date
# 1000  10.1111/j.1468-0262.2004.00482.x  2004-02-01
# 1001  10.1111/j.1468-0262.2004.00483.x  2004-02-01
# 1002  10.1111/j.1468-0262.2004.00484.x  2004-02-01
# 1003  10.1111/j.1468-0262.2004.00485.x  2004-02-01
# 1004  10.1111/j.1468-0262.2004.00490.x  2004-02-01

# %% [markdown]
# ### 6. AER

# %%
# clean aer
df_aer = pd.read_csv("data/journals/raw_data/aer.csv", encoding = "utf-8-sig").astype("str")
df_aer["journal"] = df_aer["journal"].apply(lambda x: "American Economic Review")
df_aer["abstract"] = df_aer["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_aer["volume"] = df_aer["volume"].apply(lambda x: x.replace("\n","").replace("\t","").strip())
df_aer["doi"] = df_aer["doi"].apply(lambda x: x.strip())
df_aer = df_aer[df_aer["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_aer.index:
    date_text = df_aer.loc[idx,"volume"].split(",")[2].strip()
    year = date_text.split(" ")[1]
    month_text = date_text.split(" ")[0]
    if month_text == "January":
        month = "01"
    elif month_text == "February":
        month = "02"
    elif month_text == "March":
        month = "03"
    elif month_text == "April":
        month = "04"
    elif month_text == "May":
        month = "05"
    elif month_text == "June":
        month = "06"
    elif month_text == "July":
        month = "07"
    elif month_text == "August":
        month = "08"
    elif month_text == "September":
        month = "09"
    elif month_text == "October":
        month = "10"
    elif month_text == "November":
        month = "11"
    elif month_text == "December":
        month = "12"

    dates.append(year+"-"+month+"-"+"15")

df_aer["date"] = dates
df_aer_s = df_aer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_aer_s.tail()
# Out:
#                        journal  \
# 4799  American Economic Review
# 4800  American Economic Review
# 4801  American Economic Review
# 4802  American Economic Review
# 4803  American Economic Review
#
#                                                   title  \
# 4799  Enabling or Limiting Cognitive Flexibility? Ev...
# 4800  Droughts, Deluges, and (River) Diversions: Val...
# 4801                 Technology Gaps, Trade, and Income
# 4802  Electronic Food Vouchers: Evidence from an At-...
# 4803                       The Voice of Monetary Policy
#
#                                                 authors  \
# 4799  ['\n         Silvia Saccardo    ', '\n        ...
# 4800                      ['\n         Will Rafey    ']
# 4801                  ['\n         Thomas Sampson    ']
# 4802  ['\n         Abhijit Banerjee    ', '\n       ...
# 4803  ['\n         Yuriy Gorodnichenko    ', '\n    ...
#
#                                                  volume  \
# 4799  American Economic Review \r\r\rvol. 113,\rno. ...
# 4800  American Economic Review \r\r\rvol. 113,\rno. ...
# 4801  American Economic Review \r\r\rvol. 113,\rno. ...
# 4802  American Economic Review \r\r\rvol. 113,\rno. ...
# 4803  American Economic Review \r\r\rvol. 113,\rno. ...
#
#                                                     jel  \
# 4799  [('C91', 'Design of Experiments: Laboratory, I...
# 4800  [('D23', 'Organizational Behavior; Transaction...
# 4801  [('D21', 'Firm Behavior: Theory'), ('D24', 'Pr...
# 4802  [('H53', 'National Government Expenditures and...
# 4803  [('D83', 'Search; Learning; Information and Kn...
#
#                                                abstract  \
# 4799  Moral behavior is more prevalent when individu...
# 4800  This paper develops and applies a method to va...
# 4801  This paper quantifies the contribution of tech...
# 4802  We compare how in-kind food assistance and an ...
# 4803  We develop a deep learning model to detect emo...
#
#                                                     url                   doi  \
# 4799  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201333
# 4800  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201434
# 4801  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20201940
# 4802  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20210461
# 4803  https://www.aeaweb.org/articles?id=10.1257/aer...  10.1257/aer.20220129
#
#             date
# 4799  2023-02-15
# 4800  2023-02-15
# 4801  2023-02-15
# 4802  2023-02-15
# 4803  2023-02-15

# %% [markdown]
# ### 7. JF

# %%
# clean jf
df_jf = pd.read_csv("data/journals/raw_data/jf.csv", encoding = "utf-8-sig").astype("str")
df_jf["abstract"] = df_jf["abstract"].apply(lambda x: x.replace("Abstract: ",""))
df_jf["doi"] = df_jf["doi"].apply(lambda x: x.replace("https://doi.org/",""))
df_jf_s = select_valid(df_jf)
freq = cal_freq(df_jf_s["volume"])

dates = []
for idx in df_jf_s.index:
    year = int(df_jf_s.loc[idx,"volume"].split(", ")[0])
    dates.append(conv_volume_to_date(df_jf_s.loc[idx,"volume"],freq[year]))

df_jf_s["date"] = dates

# modify date for 2023
for idx in df_jf_s.index:
    year = int(df_jf_s.loc[idx,"volume"].split(", ")[0])
    if year == 2023:
        df_jf_s.loc[idx, "date"] = conv_volume_to_date(df_jf_s.loc[idx,"volume"],6)

df_jf_s.head()
# Out:
#               journal                                              title  \
# 0  Journal of Finance                Optimal Financial Transaction Taxes
# 1  Journal of Finance  Less Mainstream Credit, More Payday Borrowing?...
# 2  Journal of Finance                      Disruption and Credit Markets
# 3  Journal of Finance               How Risky Are U.S. Corporate Assets?
# 4  Journal of Finance    International Yield Curves and Currency Puzzles
#
#                                              authors  \
# 0                                 ['Eduardo Dávila']
# 1                                  ['Julia Fonseca']
# 2                 ['Bo Becker', 'Victoria Ivashina']
# 3  ['Tetiana Davydiuk', 'Scott Richard', 'Ivan Sh...
# 4                  ['Mikhail Chernov', 'Drew Creal']
#
#                             volume jel  \
# 0     2023, vol. 78, issue 1, 5-61  []
# 1   2023, vol. 78, issue 1, 63-103  []
# 2  2023, vol. 78, issue 1, 105-139  []
# 3  2023, vol. 78, issue 1, 141-208  []
# 4  2023, vol. 78, issue 1, 209-245  []
#
#                                             abstract  \
# 0  This paper characterizes the optimal transacti...
# 1  Governments regulate debt collectors to protec...
# 2  We show that over the past half‐century, innov...
# 3  We use market data on corporate bonds and equi...
# 4  The currency depreciation rate is often comput...
#
#                                                  url                 doi  \
# 0  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13188
# 1  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13189
# 2  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13187
# 3  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13196
# 4  https://econpapers.repec.org/article/blajfinan...  10.1111/jofi.13191
#
#          date
# 0  2023-02-01
# 1  2023-02-01
# 2  2023-02-01
# 3  2023-02-01
# 4  2023-02-01

# %% [markdown]
# ## 8. JEP

# %%
# clean jep
df_jep = pd.read_csv("data/journals/raw_data/jep.csv", encoding = "utf-8-sig").astype("str")
df_jep["journal"] = df_jep["journal"].apply(lambda x: "Journal of Economic Perspectives")
df_jep["abstract"] = df_jep["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jep["volume"] = df_jep["volume"].apply(lambda x: x.replace("\n","").replace("\t","").strip())
df_jep["doi"] = df_jep["doi"].apply(lambda x: x.strip())
df_jep = df_jep[df_jep["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_jep.index:
    date_text = df_jep.loc[idx,"volume"].lower().split(" ")
    season = date_text[0]
    year = date_text[1]
    if season == "spring":
        md = "02-15"
    elif season == "summer":
        md = "05-15"
    elif season == "fall":
        md = "08-15"
    elif month_text == "winter":
        md = "11-15"

    dates.append(year+"-"+md)

df_jep["date"] = dates
df_jep_s = df_jep.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jep_s.tail()
# Out:
#                                journal  \
# 1830  Journal of Economic Perspectives
# 1831  Journal of Economic Perspectives
# 1832  Journal of Economic Perspectives
# 1833  Journal of Economic Perspectives
# 1834  Journal of Economic Perspectives
#
#                                                   title  \
# 1830  Emerging Market Sovereign Debt in the Aftermat...
# 1831  Popular Personal Financial Advice versus the P...
# 1832  A Linear Panel Model with Heterogeneous Coeffi...
# 1833  Sadie T. M. Alexander: Black Women and a "Tast...
# 1834                Recommendations for Further Reading
#
#                                                 authors  \
# 1830                  ['\n         Kenneth Rogoff    ']
# 1831                   ['\n         James J. Choi    ']
# 1832  ['\n         Liyang Sun    ', '\n         Jess...
# 1833                      ['\n         Nina Banks    ']
# 1834                  ['\n         Timothy Taylor    ']
#
#                           volume  \
# 1830  Fall 2022 (Vol. 36, No.4 )
# 1831  Fall 2022 (Vol. 36, No.4 )
# 1832  Fall 2022 (Vol. 36, No.4 )
# 1833  Fall 2022 (Vol. 36, No.4 )
# 1834  Fall 2022 (Vol. 36, No.4 )
#
#                                                     jel  \
# 1830  [('E23', 'Macroeconomics: Production'), ('E62'...
# 1831  [('D15', 'Intertemporal Household Choice; Life...
# 1832  [('C23', 'Single Equation Models; Single Varia...
# 1833  [('B31', 'History of Economic Thought: Individ...
# 1834        [('Y50', 'Further Reading (unclassified)')]
#
#                                                abstract  \
# 1830  For emerging markets, fiscal space is a very r...
# 1831  I survey the advice given by the fifty most po...
# 1832  Linear panel models featuring unit and time fi...
# 1833  The employment history of African American wom...
# 1834                                                N\A
#
#                                                     url                   doi  \
# 1830  https://www.aeaweb.org/articles?id=10.1257/jep...  10.1257/jep.36.4.147
# 1831  https://www.aeaweb.org/articles?id=10.1257/jep...  10.1257/jep.36.4.167
# 1832  https://www.aeaweb.org/articles?id=10.1257/jep...  10.1257/jep.36.4.193
# 1833  https://www.aeaweb.org/articles?id=10.1257/jep...  10.1257/jep.36.4.205
# 1834  https://www.aeaweb.org/articles?id=10.1257/jep...  10.1257/jep.36.4.221
#
#             date
# 1830  2022-08-15
# 1831  2022-08-15
# 1832  2022-08-15
# 1833  2022-08-15
# 1834  2022-08-15

# %% [markdown]
# ## 9. AEJM

# %%
# clean aejm
df_aejm = pd.read_csv("data/journals/raw_data/aejm.csv", encoding = "utf-8-sig").astype("str")
df_aejm = df_aejm[df_aejm["volume"].str.contains("pages")]
df_aejm["abstract"] = df_aejm["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_aejm["doi"] = df_aejm["doi"].apply(lambda x: x.strip())
df_aejm = df_aejm[df_aejm["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_aejm.index:
    year = df_aejm.loc[idx,"year"]
    date_text = df_aejm.loc[idx,"volume"]
    month_text = date_text.split(", ")[2].replace(".","")
    if month_text == "January":
        month = "01"
    elif month_text == "February":
        month = "02"
    elif month_text == "March":
        month = "03"
    elif month_text == "April":
        month = "04"
    elif month_text == "May":
        month = "05"
    elif month_text == "June":
        month = "06"
    elif month_text == "July":
        month = "07"
    elif month_text == "August":
        month = "08"
    elif month_text == "September":
        month = "09"
    elif month_text == "October":
        month = "10"
    elif month_text == "November":
        month = "11"
    elif month_text == "December":
        month = "12"

    dates.append(year+"-"+month+"-"+"01")

df_aejm["date"] = dates
df_aejm_s = df_aejm.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_aejm_s.tail()
# Out:
#                                        journal  \
# 476  American Economic Journal: Macroeconomics
# 477  American Economic Journal: Macroeconomics
# 478  American Economic Journal: Macroeconomics
# 479  American Economic Journal: Macroeconomics
# 480  American Economic Journal: Macroeconomics
#
#                                                  title  \
# 476         Civic Virtue and Labor Market Institutions
# 477  Rent Preservation and the Persistence of Under...
# 478  Border Effect or Country Effect? Seattle May N...
# 479  New Keynesian Models: Not Yet Useful for Polic...
# 480     Convergence in Macroeconomics: The Labor Wedge
#
#                                                authors  \
# 476                     ['Pierre Cahuc', 'Yann Algan']
# 477                              ['Raghuram G. Rajan']
# 478          ['Yuriy Gorodnichenko', 'Linda L. Tesar']
# 479  ['V. V. Chari', 'Patrick J. Kehoe', 'Ellen R. ...
# 480                                  ['Robert Shimer']
#
#                             volume  jel  \
# 476  1(1), pages 111-145, January.  N\A
# 477  1(1), pages 178-218, January.  N\A
# 478  1(1), pages 219-241, January.  N\A
# 479  1(1), pages 242-266, January.  N\A
# 480  1(1), pages 280-297, January.  N\A
#
#                                               abstract  \
# 476  We argue civic virtue plays a key role in expl...
# 477  When citizens in a poor constrained society ar...
# 478  This paper reexamines the evidence on the bord...
# 479  Macroeconomists have largely converged on meth...
# 480  I review research on the behavior of the labor...
#
#                                                    url                  doi  \
# 476  https://ideas.repec.org/a/aea/aejmac/v1y2009i1...  10.1257/mac.1.1.111
# 477  https://ideas.repec.org/a/aea/aejmac/v1y2009i1...  10.1257/mac.1.1.178
# 478  https://ideas.repec.org/a/aea/aejmac/v1y2009i1...  10.1257/mac.1.1.219
# 479  https://ideas.repec.org/a/aea/aejmac/v1y2009i1...  10.1257/mac.1.1.242
# 480  https://ideas.repec.org/a/aea/aejmac/v1y2009i1...  10.1257/mac.1.1.280
#
#            date
# 476  2009-01-01
# 477  2009-01-01
# 478  2009-01-01
# 479  2009-01-01
# 480  2009-01-01

# %% [markdown]
# ## 10. EER

# %%
# clean eer
df_eer = pd.read_csv("data/journals/raw_data/eer.csv", encoding = "utf-8-sig").astype("str")
df_eer["abstract"] = df_eer["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_eer = df_eer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_eer["doi"] = df_eer["doi"].apply(lambda x: x.strip())
df_eer = df_eer[df_eer["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

months = ["January","February","March","April","May","June",
          "July","August","September","October","November","December"]
dates = []
for idx in df_eer.index:
    year = df_eer.loc[idx,"year"]
    date_parts = df_eer.loc[idx,"volume"].split("(")
    vol = int(date_parts[0])
    month_text =  date_parts[1].split(", ")[-1].replace(".","")

    if month_text in months:
        if month_text == "January":
            month = "01"
        elif month_text == "February":
            month = "02"
        elif month_text == "March":
            month = "03"
        elif month_text == "April":
            month = "04"
        elif month_text == "May":
            month = "05"
        elif month_text == "June":
            month = "06"
        elif month_text == "July":
            month = "07"
        elif month_text == "August":
            month = "08"
        elif month_text == "September":
            month = "09"
        elif month_text == "October":
            month = "10"
        elif month_text == "November":
            month = "11"
        elif month_text == "December":
            month = "12"
    # 2016-2023
    elif int(year) >= 2016:
        if vol % 10 == 0:
            month = "11"
        elif vol % 10 == 9:
            month = "10"
        elif vol % 10 == 8:
            month = "09"
        elif vol % 10 == 7:
            month = "08"
        elif vol % 10 == 6:
            month = "07"
        elif vol % 10 == 5:
            month = "06"
        elif vol % 10 == 4:
            month = "05"
        elif vol % 10 == 3:
            month = "04"
        elif vol % 10 == 2:
            month = "02"
        elif vol % 10 == 1:
            month = "01"
    # 2013-2015
    elif int(year) >= 2013:
        if vol % 8 == 0:
            month = "11"
        elif vol % 8 == 7:
            month = "10"
        elif vol % 8 == 6:
            month = "08"
        elif vol % 8 == 5:
            month = "07"
        elif vol % 8 == 4:
            month = "05"
        elif vol % 8 == 3:
            month = "04"
        elif vol % 8 == 2:
            month = "02"
        elif vol % 8 == 1:
            month = "01"
    # 2005-2012
    elif int(year) >= 2005:
        issue = int(date_parts[1][0])
        if issue == 8:
            month = "11"
        elif issue == 7:
            month = "10"
        elif issue == 6:
            month = "08"
        elif issue == 5:
            month = "07"
        elif issue == 4:
            month = "05"
        elif issue == 3:
            month = "04"
        elif issue == 2:
            month = "02"
        elif issue == 1:
            month = "01"
    # 2003-2004
    elif int(year) >= 2003:
        issue = int(date_parts[1][0])
        if issue == 6:
            month = "12"
        elif issue == 5:
            month = "10"
        elif issue == 4:
            month = "08"
        elif issue == 3:
            month = "06"
        elif issue == 2:
            month = "04"
        elif issue == 1:
            month = "02"
    # 2000-2002
    elif int(year) == 2002:
        issue = date_parts[1].split(")")[0]
        if issue == "10":
            month = "12"
        elif issue == "9":
            month = "10"
        elif issue == "8":
            month = "09"
        elif issue == "7":
            month = "07"
        elif issue == "6":
            month = "06"
        elif issue == "4-5":
            month = "05"
        elif issue == "3":
            month = "03"
        elif issue == "2":
            month = "02"
        elif issue == "1":
            month = "01"
    elif int(year) == 2001:
        issue = date_parts[1].split(")")[0]
        if issue == "10":
            month = "12"
        elif issue == "9":
            month = "10"
        elif issue == "8":
            month = "08"
        elif issue == "7":
            month = "06"
        elif issue == "4-6":
            month = "05"
        elif issue == "3":
            month = "03"
        elif issue == "2":
            month = "02"
        elif issue == "1":
            month = "01"
    elif int(year) == 2000:
        issue = date_parts[1].split(")")[0]
        if issue == "10":
            month = "12"
        elif issue == "9":
            month = "10"
        elif issue == "8":
            month = "08"
        elif issue == "7":
            month = "06"
        elif issue == "4-6":
            month = "05"
        elif issue == "3":
            month = "03"
        elif issue == "2":
            month = "02"
        elif issue == "1":
            month = "01"
    else:
        issue = date_parts[1][0]
        if issue == "9":
            month = "09"
        elif issue == "8":
            month = "08"
        elif issue == "7":
            month = "07"
        elif issue == "6":
            month = "06"
        elif issue == "5":
            month = "05"
        elif issue == "4":
            month = "04"
        elif issue == "3":
            month = "03"
        elif issue == "2":
            month = "02"
        elif issue == "1":
            month = "01"

    dates.append(year+"-"+month+"-"+"15")

df_eer["date"] = dates
df_eer_s = df_eer.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_eer_s.tail()
# Out:
#                        journal  \
# 1631  European Economic Review
# 1632  European Economic Review
# 1633  European Economic Review
# 1634  European Economic Review
# 1635  European Economic Review
#
#                                                   title  \
# 1631  Intergenerational exchange mobility and econom...
# 1632  The estimation of welfare levels of a cardinal...
# 1633        Earnings and education in Greece, 1960–1977
# 1634  The testing and estimation of complete demand ...
# 1635                   Modelling consumers' expenditure
#
#                                         authors                 volume  jel  \
# 1631                        ['Markandya, Anil']  17(3), pages 307-324.  N\A
# 1632                        ['Buyze, Jeannine']  17(3), pages 325-332.  N\A
# 1633                 ['Psacharopoulos, George']  17(3), pages 333-347.  N\A
# 1634                            ['Ray, Ranjan']  17(3), pages 349-369.  N\A
# 1635  ['Rossi, Nicola', 'Schiantarelli, Fabio']  17(3), pages 371-391.  N\A
#
#                                                abstract  \
# 1631  The concepts of exchange and structural mobili...
# 1632  In order to measure an individual's welfare fu...
# 1633  This paper analyses the structure of earnings ...
# 1634  A recent demand system (AIDS) is extended to i...
# 1635  The purpose of this paper is to model the dyna...
#
#                                                     url  \
# 1631  https://ideas.repec.org/a/eee/eecrev/v17y1982i...
# 1632  https://ideas.repec.org/a/eee/eecrev/v17y1982i...
# 1633  https://ideas.repec.org/a/eee/eecrev/v17y1982i...
# 1634  https://ideas.repec.org/a/eee/eecrev/v17y1982i...
# 1635  https://ideas.repec.org/a/eee/eecrev/v17y1982i...
#
#                                 doi        date
# 1631  10.1016/S0014-2921(82)80066-4  1982-03-15
# 1632  10.1016/S0014-2921(82)80067-6  1982-03-15
# 1633  10.1016/S0014-2921(82)80068-8  1982-03-15
# 1634  10.1016/S0014-2921(82)80069-X  1982-03-15
# 1635  10.1016/S0014-2921(82)80070-6  1982-03-15

# %% [markdown]
# ## 11. EL

# %%
# clean el
df_el = pd.read_csv("data/journals/raw_data/el.csv", encoding = "utf-8-sig").astype("str")
df_el["abstract"] = df_el["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_el = df_el.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_el["doi"] = df_el["doi"].apply(lambda x: x.strip())
df_el = df_el[df_el["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_el.index:
    year = df_el.loc[idx,"year"]
    date_parts = df_el.loc[idx,"volume"].split("(")
    vol = int(date_parts[0])

    # 2015-2023
    if int(year) >= 2015:
        if vol % 12 == 5:
            month = "12"
        elif vol % 12 == 4:
            month = "11"
        elif vol % 12 == 3:
            month = "10"
        elif vol % 12 == 2:
            month = "09"
        elif vol % 12 == 1:
            month = "08"
        elif vol % 12 == 0:
            month = "07"
        elif vol % 12 == 11:
            month = "06"
        elif vol % 12 == 10:
            month = "05"
        elif vol % 12 == 9:
            month = "04"
        elif vol % 12 == 8:
            month = "03"
        elif vol % 12 == 7:
            month = "02"
        elif vol % 12 == 6:
            month = "01"
    else:
        issue = int(date_parts[1][0])
        if vol % 4 == 1 and issue == 3:
            month = "12"
        elif vol % 4 == 1 and issue == 2:
            month = "11"
        elif vol % 4 == 1 and issue == 1:
            month = "10"
        elif vol % 4 == 0 and issue == 3:
            month = "09"
        elif vol % 4 == 0 and issue == 2:
            month = "08"
        elif vol % 4 == 0 and issue == 1:
            month = "07"
        elif vol % 4 == 3 and issue == 3:
            month = "06"
        elif vol % 4 == 3 and issue == 2:
            month = "05"
        elif vol % 4 == 3 and issue == 1:
            month = "04"
        elif vol % 4 == 2 and issue == 3:
            month = "03"
        elif vol % 4 == 2 and issue == 2:
            month = "02"
        elif vol % 4 == 2 and issue == 1:
            month = "01"
            
    dates.append(year+"-"+month+"-"+"15")

df_el["date"] = dates
df_el_s = df_el.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_el_s.tail()
# Out:
#                 journal                                              title  \
# 4938  Economics Letters           A robust test for multivariate normality
# 4939  Economics Letters      A differential measure of the real wage index
# 4940  Economics Letters  Aggregate price indexes, cointegration, and te...
# 4941  Economics Letters  Valuation effects of Canadian stock split anno...
# 4942  Economics Letters                   An index of relative deprivation
#
#                                       authors                  volume  jel  \
# 4938                    ['Jönsson, Kristian']  113(2), pages 199-201.  N\A
# 4939    ['Baye, Michael R.', 'Black, Dan A.']   36(3), pages 295-298.  N\A
# 4940                     ['Johnson, Paul A.']   36(3), pages 305-309.  N\A
# 4941  ['Kryzanowski, Lawrence', 'Zhang, Hao']   36(3), pages 317-322.  N\A
# 4942                          ['Paul, Satya']   36(3), pages 337-341.  N\A
#
#                                                abstract  \
# 4938  The size of the Jarque–Bera test for multivari...
# 4939  In this paper we derive an approximation of th...
# 4940  In this paper I show that cointegration tests ...
# 4941  The abnormal returns for two types of announce...
# 4942  This paper proposes an index of relative depri...
#
#                                                     url  \
# 4938  https://ideas.repec.org/a/eee/ecolet/v113y2011...
# 4939  https://ideas.repec.org/a/eee/ecolet/v36y1991i...
# 4940  https://ideas.repec.org/a/eee/ecolet/v36y1991i...
# 4941  https://ideas.repec.org/a/eee/ecolet/v36y1991i...
# 4942  https://ideas.repec.org/a/eee/ecolet/v36y1991i...
#
#                                 doi        date
# 4938  10.1016/j.econlet.2011.06.018  2011-11-15
# 4939   10.1016/0165-1765(91)90036-K  1991-09-15
# 4940   10.1016/0165-1765(91)90038-M  1991-09-15
# 4941   10.1016/0165-1765(91)90040-R  1991-09-15
# 4942   10.1016/0165-1765(91)90043-K  1991-09-15

# %% [markdown]
# ## 12. EM

# %%
# clean em
df_em = pd.read_csv("data/journals/raw_data/em.csv", encoding = "utf-8-sig").astype("str")
df_em["abstract"] = df_em["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_em = df_em.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_em["doi"] = df_em["doi"].apply(lambda x: x.strip())
df_em = df_em[df_em["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_em.index:
    year = df_em.loc[idx,"year"]
    date_parts = df_em.loc[idx,"volume"].split("(")
    try:
        vol = int(date_parts[0])
    except:
        try:
            date_parts = df_em.loc[idx-1,"volume"].split("(")
            vol = int(date_parts[0])
        except:
            try:
                date_parts = df_em.loc[idx-2,"volume"].split("(")
                vol = int(date_parts[0])
            except:
                date_parts = df_em.loc[idx-3,"volume"].split("(")
                vol = int(date_parts[0])

    # 2021-2023
    if int(year) >= 2021:
        if vol % 12 == 9:
            month = "12"
        elif vol % 12 == 8:
            month = "11"
        elif vol % 12 == 7:
            month = "10"
        elif vol % 12 == 6:
            month = "09"
        elif vol % 12 == 5:
            month = "08"
        elif vol % 12 == 4:
            month = "07"
        elif vol % 12 == 3:
            month = "06"
        elif vol % 12 == 2:
            month = "05"
        elif vol % 12 == 1:
            month = "04"
        elif vol % 12 == 0:
            month = "03"
        elif vol % 12 == 11:
            month = "02"
        elif vol % 12 == 10:
            month = "01"
    # 2020
    elif int(year) == 2020:
        if vol % 10 == 3:
            month = "12"
        elif vol % 10 == 2:
            month = "11"
        elif vol % 10 == 1:
            month = "09"
        elif vol % 10 == 0:
            month = "08"
        elif vol % 10 == 9:
            month = "07"
        elif vol % 10 == 8:
            month = "06"
        elif vol % 10 == 7:
            month = "05"
        elif vol % 10 == 6:
            month = "03"
        elif vol % 10 == 5:
            month = "02"
        elif vol % 10 == 4:
            month = "01"
    # 2015-2019
    elif int(year) >= 2015:
        if vol % 8 == 3:
            month = "12"
        elif vol % 8 == 2:
            month = "11"
        elif vol % 8 == 1:
            month = "09"
        elif vol % 8 == 0:
            month = "08"
        elif vol % 8 == 7:
            month = "06"
        elif vol % 8 == 6:
            month = "04"
        elif vol % 8 == 5:
            month = "02"
        elif vol % 8 == 4:
            month = "01"
    # 2014
    elif int(year) == 2014:
        if vol % 9 == 8 or vol % 9 == 7:
            month = "12"
        elif vol % 9 == 6:
            month = "10"
        elif vol % 9 == 5:
            month = "08"
        elif vol % 9 == 4:
            month = "06"
        elif vol % 9 == 3:
            month = "04"
        elif vol % 9 == 2:
            month = "02"
        elif vol % 9 == 1:
            month = "02"
        elif vol % 9 == 0:
            month = "01"
    # 2013
    elif int(year) == 2013:
        if vol % 6 == 5:
            month = "09"
        elif vol % 6 == 4:
            month = "08"
        elif vol % 6 == 3:
            month = "07"
        elif vol % 6 == 2:
            month = "05"
        elif vol % 6 == 1:
            month = "03"
        elif vol % 6 == 0:
            month = "01"
    else:
        issue = date_parts[1][0]
        if issue == "6":
            month = "11"
        elif issue == "5":
            month = "09"
        elif issue == "4":
            month = "07"
        elif issue == "3":
            month = "05"
        elif issue == "2":
            month = "03"
        elif issue == "1":
            month = "01"
        
    dates.append(year+"-"+month+"-"+"15")

df_em["date"] = dates
df_em_s = df_em.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_em_s.tail()
# Out:
#                  journal                                              title  \
# 3884  Economic Modelling  The effectiveness of the sunshine effect in Ta...
# 3885  Economic Modelling  The optimality of a gulf currency union: Commo...
# 3886  Economic Modelling                  Long-term macroeconometric models
# 3887  Economic Modelling  The effects of the monetary policy regime shif...
# 3888  Economic Modelling  WITHDRAWN: More powerful non-linear panel unit...
#
#                                    authors                 volume  jel  \
# 3884  ['Lee, Yuan-Ming', 'Wang, Kuan-Min']  28(1), pages 710-727.  N\A
# 3885                       ['Rafiq, M.S.']  28(1), pages 728-740.  N\A
# 3886                  ['Welfe, Wladyslaw']  28(1), pages 741-753.  N\A
# 3887              ['Reschreiter, Andreas']  28(1), pages 754-759.  N\A
# 3888              ['Lau, Marco Chi-Keung']  28(1), pages 760-760.  N\A
#
#                                                abstract  \
# 3884  This study constructs a variety of GARCH model...
# 3885  A high degree of shared national elements that...
# 3886  Long-term forecasts and scenario analysis shou...
# 3887  This paper studies the effects of the monetary...
# 3888  This article has been withdrawn at the request...
#
#                                                     url  \
# 3884  https://ideas.repec.org/a/eee/ecmode/v28y2011i...
# 3885  https://ideas.repec.org/a/eee/ecmode/v28y2011i...
# 3886  https://ideas.repec.org/a/eee/ecmode/v28y2011i...
# 3887  https://ideas.repec.org/a/eee/ecmode/v28y2011i...
# 3888  https://ideas.repec.org/a/eee/ecmode/v28y2011i...
#
#                                 doi        date
# 3884  10.1016/j.econmod.2010.05.008  2011-01-15
# 3885  10.1016/j.econmod.2010.05.007  2011-01-15
# 3886  10.1016/j.econmod.2010.05.002  2011-01-15
# 3887  10.1016/j.econmod.2010.04.009  2011-01-15
# 3888  10.1016/j.econmod.2010.06.007  2011-01-15

# %% [markdown]
# ## 13. JDE

# %%
# clean jde
df_jde = pd.read_csv("data/journals/raw_data/jde.csv", encoding = "utf-8-sig").astype("str")
df_jde["abstract"] = df_jde["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jde = df_jde.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jde["doi"] = df_jde["doi"].apply(lambda x: x.strip())
df_jde = df_jde[df_jde["doi"].str[:3] == "10."].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_jde.index:
    year = df_jde.loc[idx,"year"]
    date_parts = df_jde.loc[idx,"volume"].split("(")
    try:
        vol = int(date_parts[0])
    except:
        try:
            date_parts = df_jde.loc[idx-1,"volume"].split("(")
            vol = int(date_parts[0])
        except:
            try:
                date_parts = df_jde.loc[idx-2,"volume"].split("(")
                vol = int(date_parts[0])
            except:
                date_parts = df_jde.loc[idx-3,"volume"].split("(")
                vol = int(date_parts[0])
    
    # 2013-2023
    if int(year) >= 2013:
        if vol % 6 == 3:
            month = "11"
        elif vol % 6 == 2:
            month = "09"
        elif vol % 6 == 1:
            month = "06"
        elif vol % 6 == 0:
            month = "05"
        elif vol % 6 == 5:
            month = "03"
        elif vol % 6 == 4:
            month = "01"
    else:
        issue = date_parts[1][0]
        if vol % 3  == 0 and issue == "2":
            month = "11"
        elif vol % 3 == 0 and issue == "1":
            month = "09"
        elif vol % 3 == 2 and issue == "2":
            month = "07"
        elif vol % 3 == 2 and issue == "1":
            month = "05"
        elif vol % 3 == 1 and issue == "2":
            month = "03"
        elif vol % 3 == 1 and issue == "1":
            month = "01"
        
    dates.append(year+"-"+month+"-"+"15")

df_jde["date"] = dates
df_jde_s = df_jde.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jde_s.tail()
# Out:
#                                journal  \
# 1198  Journal of Development Economics
# 1199  Journal of Development Economics
# 1200  Journal of Development Economics
# 1201  Journal of Development Economics
# 1202  Journal of Development Economics
#
#                                                   title  \
# 1198  Agricultural terms of trade and distributional...
# 1199                Profit, rent and the terms of trade
# 1200                Profit, rent and the terms of trade
# 1201       More on the employment effects of innovation
# 1202       More on the employment effects of innovation
#
#                                  authors                 volume  jel  \
# 1198            ['Andrews, Margaret S.']  17(1), pages 117-129.  N\A
# 1199  ['Gibson, Bill', 'McLeod, Darryl']  17(1), pages 131-139.  N\A
# 1200            ['Andrews, Margaret S.']  17(1), pages 141-149.  N\A
# 1201   ['Hall, P.H.', 'Heffernan, S.A.']  17(1), pages 151-162.  N\A
# 1202               ['Hagen, Everett E.']  17(1), pages 163-173.  N\A
#
#                                                abstract  \
# 1198  The comparative-static effects of a change in ...
# 1199  Andrews (1985) investigates the theoretical co...
# 1200  In response to my article in this issue, Gibso...
# 1201  This paper discusses in the context of a fully...
# 1202  This article argues the lack of relevance to r...
#
#                                                     url  \
# 1198  https://ideas.repec.org/a/eee/deveco/v17y1985i...
# 1199  https://ideas.repec.org/a/eee/deveco/v17y1985i...
# 1200  https://ideas.repec.org/a/eee/deveco/v17y1985i...
# 1201  https://ideas.repec.org/a/eee/deveco/v17y1985i...
# 1202  https://ideas.repec.org/a/eee/deveco/v17y1985i...
#
#                                doi        date
# 1198  10.1016/0304-3878(85)90025-2  1985-05-15
# 1199  10.1016/0304-3878(85)90026-4  1985-05-15
# 1200  10.1016/0304-3878(85)90027-6  1985-05-15
# 1201  10.1016/0304-3878(85)90028-8  1985-05-15
# 1202  10.1016/0304-3878(85)90029-X  1985-05-15

# %% [markdown]
# ## 14. JEEA

# %%
# clean jeea
df_jeea = pd.read_csv("data/journals/raw_data/jeea.csv", encoding = "utf-8-sig").astype("str")
df_jeea["abstract"] = df_jeea["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jeea = df_jeea.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jeea["doi"] = df_jeea["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/",""))
df_jeea = df_jeea[(df_jeea["doi"].str[:3] == "10.") & (df_jeea["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_jeea.index:
    year = df_jeea.loc[idx,"year"]
    date_parts = df_jeea.loc[idx,"volume"].split("(")
    try:
        vol = int(date_parts[0])
    except:
        try:
            date_parts = df_jeea.loc[idx-1,"volume"].split("(")
            vol = int(date_parts[0])
        except:
            try:
                date_parts = df_jeea.loc[idx-2,"volume"].split("(")
                vol = int(date_parts[0])
            except:
                date_parts = df_jeea.loc[idx-3,"volume"].split("(")
                vol = int(date_parts[0])
    
    
    issue = date_parts[1][0]
    if issue == "6":
        month = "12"
    elif issue == "5":
        month = "10"
    elif issue == "4":
        month = "08"
    elif issue == "3":
        month = "06"
    elif issue == "2":
        month = "04"
    elif issue == "1":
        month = "02"
        
    dates.append(year+"-"+month+"-"+"15")

df_jeea["date"] = dates
df_jeea_s = df_jeea.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jeea_s.tail()
# Out:
#                                           journal  \
# 502  Journal of the European Economic Association
# 503  Journal of the European Economic Association
# 504  Journal of the European Economic Association
# 505  Journal of the European Economic Association
# 506  Journal of the European Economic Association
#
#                                                  title  \
# 502                         Do Immigrants Cause Crime?
# 503  Risk Aversion And Expected Utility Theory: An ...
# 504  Can We Infer Hospital Quality From Medical Gra...
# 505  The Relationship Between Child Health, Develop...
# 506  Uninsured Countercyclical Risk: An Aggregation...
#
#                                                authors  \
# 502  ['Milo Bianchi', 'Paolo Buonanno', 'Paolo Pino...
# 503         ['Matilde Bombardini', 'Francesco Trebbi']
# 504  ['Matilde P. Machado', 'Ricardo Mora', 'Antoni...
# 505                   ['Martin Salm', 'Daniel Schunk']
# 506            ['R. Anton Braun', 'Tomoyuki Nakajima']
#
#                                 volume  jel  \
# 502  10(6), pages 1318-1347, December.  N\A
# 503  10(6), pages 1348-1399, December.  N\A
# 504  10(6), pages 1400-1424, December.  N\A
# 505  10(6), pages 1425-1449, December.  N\A
# 506  10(6), pages 1450-1474, December.  N\A
#
#                                               abstract  \
# 502  We examine the empirical relationship between ...
# 503            No abstract is available for this item.
# 504  In this paper, we propose an alternative metho...
# 505            No abstract is available for this item.
# 506  We consider an incomplete markets economy with...
#
#                                                    url  \
# 502  https://ideas.repec.org/a/bla/jeurec/v10y2012i...
# 503  https://ideas.repec.org/a/bla/jeurec/v10y2012i...
# 504  https://ideas.repec.org/a/bla/jeurec/v10y2012i...
# 505  https://ideas.repec.org/a/bla/jeurec/v10y2012i...
# 506  https://ideas.repec.org/a/bla/jeurec/v10y2012i...
#
#                                   doi        date
# 502  10.1111/j.1542-4774.2012.01085.x  2012-12-15
# 503  10.1111/j.1542-4774.2012.01086.x  2012-12-15
# 504  10.1111/j.1542-4774.2012.01087.x  2012-12-15
# 505  10.1111/j.1542-4774.2012.01089.x  2012-12-15
# 506  10.1111/j.1542-4774.2012.01091.x  2012-12-15

# %% [markdown]
# ## 15. JEL

# %%
# clean jel
df_jel = pd.read_csv("data/journals/raw_data/jel.csv", encoding = "utf-8-sig").astype("str")
df_jel["abstract"] = df_jel["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jel = df_jel.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jel["doi"] = df_jel["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/",""))
df_jel = df_jel[(df_jel["doi"].str[:3] == "10.") & (df_jel["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jel["journal"] = df_jel["journal"].apply(lambda x: "Journal of Economic Literature")

dates = []
for idx in df_jel.index:
    year = df_jel.loc[idx,"year"]
    if "(" not in df_jel.loc[idx,"volume"]:
        dates.append(year+"-06-15")
    else:
        date_parts = df_jel.loc[idx,"volume"].split("(")
        issue = date_parts[1][0]
        if issue == "4":
            month = "12"
        elif issue == "3":
            month = "09"
        elif issue == "2":
            month = "06"
        elif issue == "1":
            month = "03"
        else:
            month = "12"
            
        dates.append(year+"-"+month+"-"+"01")

df_jel["date"] = dates
df_jel_s = df_jel.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jel_s.tail()
# Out:
#                             journal  \
# 508  Journal of Economic Literature
# 509  Journal of Economic Literature
# 510  Journal of Economic Literature
# 511  Journal of Economic Literature
# 512  Journal of Economic Literature
#
#                                                  title  \
# 508  The Numerical Reliability of Econometric Software
# 509               The Provision of Incentives in Firms
# 510            Explaining African Economic Performance
# 511                            The New Growth Evidence
# 512  The Young Person's Guide to Writing Economic T...
#
#                                     authors                        volume  \
# 508     ['H. D. Vinod', 'B. D. McCullough']   37(2), pages 633-665, June.
# 509                  ['Canice Prendergast']     37(1), pages 7-63, March.
# 510  ['Jan Willem Gunning', 'Paul Collier']   37(1), pages 64-111, March.
# 511                     ['Jonathan Temple']  37(1), pages 112-156, March.
# 512                     ['William Thomson']  37(1), pages 157-183, March.
#
#      jel                                           abstract  \
# 508  N\A  Numerous examples show that some econometric s...
# 509  N\A  This paper provides an overview of the existin...
# 510  N\A  Africa has had slow growth and a massive exodu...
# 511  N\A  Why do growth rates differ? This paper surveys...
# 512  N\A  I formulate recommendations to young authors f...
#
#                                                    url                   doi  \
# 508  https://ideas.repec.org/a/aea/jeclit/v37y1999i...  10.1257/jel.37.2.633
# 509  https://ideas.repec.org/a/aea/jeclit/v37y1999i...    10.1257/jel.37.1.7
# 510  https://ideas.repec.org/a/aea/jeclit/v37y1999i...   10.1257/jel.37.1.64
# 511  https://ideas.repec.org/a/aea/jeclit/v37y1999i...  10.1257/jel.37.1.112
# 512  https://ideas.repec.org/a/aea/jeclit/v37y1999i...  10.1257/jel.37.1.157
#
#            date
# 508  1999-06-01
# 509  1999-03-01
# 510  1999-03-01
# 511  1999-03-01
# 512  1999-03-01

# %% [markdown]
# ## 16. JIE

# %%
# clean jie
df_jie = pd.read_csv("data/journals/raw_data/jie.csv", encoding = "utf-8-sig").astype("str")
df_jie["abstract"] = df_jie["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jie = df_jie.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jie["doi"] = df_jie["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/",""))
df_jie = df_jie[(df_jie["doi"].str[:3] == "10.") & (df_jie["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_jie.index:
    year = df_jie.loc[idx,"year"]
    date_parts = df_jie.loc[idx,"volume"].split("(")
    try:
        vol = int(date_parts[0])
    except:
        try:
            date_parts = df_jie.loc[idx-1,"volume"].split("(")
            vol = int(date_parts[0])
        except:
            try:
                date_parts = df_jie.loc[idx-2,"volume"].split("(")
                vol = int(date_parts[0])
            except:
                date_parts = df_jie.loc[idx-3,"volume"].split("(")
                vol = int(date_parts[0])
    # 2016-2023
    if int(year) >= 2016:
        if vol % 6 == 1:
            month = "11"
        elif vol % 6 == 0:
            month = "09"
        elif vol % 6 == 5:
            month = "07"
        elif vol % 6 == 4:
            month = "05"
        elif vol % 6 == 3:
            month = "03"
        elif vol % 6 == 2:
            month = "01"
    else:
        issue = date_parts[1][0]
        if vol % 3 == 1 and issue == "2":
            month = "11"
        elif vol % 3 == 1 and issue == "1":
            month = "09"
        elif vol % 3 == 0 and issue == "2":
            month = "07"
        elif vol % 3 == 0 and issue == "1":
            month = "05"
        elif vol % 3 == 2 and issue == "2":
            month = "03"
        elif vol % 3 == 2 and issue == "1":
            month = "01"
        
    dates.append(year+"-"+month+"-"+"15")

df_jie["date"] = dates
df_jie_s = df_jie.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jie_s.tail()
# Out:
#                                  journal  \
# 1009  Journal of International Economics
# 1010  Journal of International Economics
# 1011  Journal of International Economics
# 1012  Journal of International Economics
# 1013  Journal of International Economics
#
#                                                   title  \
# 1009  Transportation, freight rates, and economic ge...
# 1010  The impact of trade liberalization on producti...
# 1011  International real business cycles with endoge...
# 1012  Financial liberalization, structural change, a...
# 1013      Size, productivity, and international banking
#
#                                                 authors  \
# 1009         ['Behrens, Kristian', 'Picard, Pierre M.']
# 1010                               ['Nataraj, Shanthi']
# 1011           ['Davis, J. Scott', 'Huang, Kevin X.D.']
# 1012                ['Meza, Felipe', 'Urrutia, Carlos']
# 1013  ['Buch, Claudia M.', 'Koch, Cathérine T.', 'Ko...
#
#                      volume  jel  \
# 1009  85(2), pages 280-291.  N\A
# 1010  85(2), pages 292-301.  N\A
# 1011  85(2), pages 302-316.  N\A
# 1012  85(2), pages 317-328.  N\A
# 1013  85(2), pages 329-334.  N\A
#
#                                                abstract  \
# 1009  We investigate the role of competitive transpo...
# 1010  Despite a large literature investigating the i...
# 1011  The aggregate impact of decisions made at the ...
# 1012  The last twenty years have witnessed periods o...
# 1013  Heterogeneity in size and productivity is cent...
#
#                                                     url  \
# 1009  https://ideas.repec.org/a/eee/inecon/v85y2011i...
# 1010  https://ideas.repec.org/a/eee/inecon/v85y2011i...
# 1011  https://ideas.repec.org/a/eee/inecon/v85y2011i...
# 1012  https://ideas.repec.org/a/eee/inecon/v85y2011i...
# 1013  https://ideas.repec.org/a/eee/inecon/v85y2011i...
#
#                                 doi        date
# 1009  10.1016/j.jinteco.2011.06.003  2011-11-15
# 1010  10.1016/j.jinteco.2011.07.003  2011-11-15
# 1011  10.1016/j.jinteco.2011.06.004  2011-11-15
# 1012  10.1016/j.jinteco.2011.06.001  2011-11-15
# 1013  10.1016/j.jinteco.2011.07.001  2011-11-15

# %% [markdown]
# ## 17. JME

# %%
# clean jme
df_jme = pd.read_csv("data/journals/raw_data/jme.csv", encoding = "utf-8-sig").astype("str")
df_jme["abstract"] = df_jme["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jme = df_jme.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jme["doi"] = df_jme["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/",""))
df_jme = df_jme[(df_jme["doi"].str[:3] == "10.") & (df_jme["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

dates = []
for idx in df_jme.index:
    year = df_jme.loc[idx,"year"]
    date_parts = df_jme.loc[idx,"volume"].split("(")
    try:
        vol = int(date_parts[0])
    except:
        try:
            date_parts = df_jme.loc[idx-1,"volume"].split("(")
            vol = int(date_parts[0])
        except:
            try:
                date_parts = df_jme.loc[idx-2,"volume"].split("(")
                vol = int(date_parts[0])
            except:
                date_parts = df_jme.loc[idx-3,"volume"].split("(")
                vol = int(date_parts[0])
    # 2014-2023
    if int(year) >= 2014:
        if vol % 8 == 4:
            month = "11"
        elif vol % 8 == 3:
            month = "10"
        elif vol % 8 == 2:
            month = "09"
        elif vol % 8 == 1:
            month = "07"
        elif vol % 8 == 0:
            month = "05"
        elif vol % 8 == 7:
            month = "04"
        elif vol % 8 == 6:
            month = "03"
        elif vol % 8 == 5:
            month = "01"
    else:
        issue = date_parts[1][0]
        if issue == "8":
            month = "11"
        elif issue == "7":
            month = "10"
        elif issue == "6":
            month = "09"
        elif issue == "5":
            month = "07"
        elif issue == "4":
            month = "05"
        elif issue == "3":
            month = "04"
        elif issue == "2":
            month = "03"
        elif issue == "1":
            month = "01"

    dates.append(year+"-"+month+"-"+"15")

df_jme["date"] = dates
df_jme_s = df_jme.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jme_s.tail()
# Out:
#                            journal  \
# 890  Journal of Monetary Economics
# 891  Journal of Monetary Economics
# 892  Journal of Monetary Economics
# 893  Journal of Monetary Economics
# 894  Journal of Monetary Economics
#
#                                                  title  \
# 890  Incomplete information, higher-order beliefs a...
# 891       Imperfect information and the business cycle
# 892     Setting the right prices for the wrong reasons
# 893    Sectoral price data and models of price setting
# 894    Information-constrained state-dependent pricing
#
#                                                authors                 volume  \
# 890     ['Angeletos, George-Marios', 'La’O, Jennifer']    56(S), pages 19-37.
# 891  ['Collard, Fabrice', 'Dellas, Harris', 'Smets,...    56(S), pages 38-56.
# 892     ['Hellwig, Christian', 'Venkateswaran, Venky']    56(S), pages 57-77.
# 893  ['Maćkowiak, Bartosz', 'Moench, Emanuel', 'Wie...    56(S), pages 78-99.
# 894                              ['Woodford, Michael']  56(S), pages 100-124.
#
#      jel                                           abstract  \
# 890  N\A  The question that motivates this paper is how ...
# 891  N\A  Imperfect information has played a prominent r...
# 892  N\A  Nominal price adjustment is studied in an envi...
# 893  N\A  In the median sector, 100 percent of the long-...
# 894  N\A  A model is presented in which decisions about ...
#
#                                                    url  \
# 890  https://ideas.repec.org/a/eee/moneco/v56y2009i...
# 891  https://ideas.repec.org/a/eee/moneco/v56y2009i...
# 892  https://ideas.repec.org/a/eee/moneco/v56y2009i...
# 893  https://ideas.repec.org/a/eee/moneco/v56y2009i...
# 894  https://ideas.repec.org/a/eee/moneco/v56y2009i...
#
#                                doi        date
# 890  10.1016/j.jmoneco.2009.07.001  2009-04-15
# 891  10.1016/j.jmoneco.2009.06.011  2009-04-15
# 892  10.1016/j.jmoneco.2009.06.013  2009-04-15
# 893  10.1016/j.jmoneco.2009.06.012  2009-04-15
# 894  10.1016/j.jmoneco.2009.06.014  2009-04-15

# %% [markdown]
# ## 18. EJ

# %%
# clean ej
df_ej = pd.read_csv("data/journals/raw_data/ej.csv", encoding = "utf-8-sig").astype("str")
df_ej["abstract"] = df_ej["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_ej = df_ej.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_ej["doi"] = df_ej["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/",""))
df_ej = df_ej[(df_ej["doi"].str[:3] == "10.") & (df_ej["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

months = ["January","February","March","April","May","June",
          "July","August","September","October","November","December"]

dates = []
for idx in df_ej.index:
    year = df_ej.loc[idx,"year"]
    found = False
    for month in months:
        if month in df_ej.loc[idx, "volume"]:
            dates.append(year+"-"+month+"-01")
            found = True
            break
    if not found:
        dates.append(year+"-06-01")

df_ej["date"] = dates
df_ej_s = df_ej.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_ej_s.tail()
# Out:
#                   journal                                              title  \
# 859  The Economic Journal  The Timing and Persistence of Fiscal Policy Im...
# 860  The Economic Journal        Tax Policy for Economic Recovery and Growth
# 861  The Economic Journal  Destruction and Distress: Using a Quasi‐Experi...
# 862  The Economic Journal  Balancing the Banks: Global Lessons from the F...
# 863  The Economic Journal  Balancing the Banks: Global Lessons from the F...
#
#                                                authors  \
# 859  ['Norman Gemmell', 'Richard Kneller', 'Ismael ...
# 860  ['Jens Matthias Arnold', 'Bert Brys', 'Christo...
# 861  ['Robert Metcalfe', 'Nattavudh Powdthavee', 'P...
# 862                                    ['David Vines']
# 863                                  ['David C. Webb']
#
#                                                 volume  jel  \
# 859  137(1), pages 353-382, November. Pietro F. Per...  N\A
# 860  10(2), pages 107-126, March. Devereux, Michael...  N\A
# 861                  121(550), pages 81-103, February.  N\A
# 862                 121(550), pages 104-111, February.  N\A
# 863                 121(550), pages 111-118, February.  N\A
#
#                                               abstract  \
# 859  The literatures testing for aggregate short-ru...
# 860  This article identifies tax policy that both s...
# 861  Using a longitudinal household panel dataset i...
# 862            No abstract is available for this item.
# 863            No abstract is available for this item.
#
#                                                    url  \
# 859  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 860  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 861  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 862  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 863  https://ideas.repec.org/a/ecj/econjl/v121y2011...
#
#                                   doi              date
# 859  10.1111/j.1468-0297.2010.02414.x  2011-November-01
# 860  10.1111/j.1468-0297.2010.02415.x     2011-March-01
# 861  10.1111/j.1468-0297.2010.02416.x  2011-February-01
# 862  10.1111/j.1468-0297.2010.02417.x  2011-February-01
# 863  10.1111/j.1468-0297.2010.02418.x  2011-February-01

# %% [markdown]
# ## 19. JPET

# %%
# clean jpet
df_jpet = pd.read_csv("data/journals/raw_data/jpet.csv", encoding = "utf-8-sig").astype("str")
df_jpet["abstract"] = df_jpet["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_jpet = df_jpet.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_jpet["doi"] = df_jpet["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/",""))
df_jpet = df_jpet[(df_jpet["doi"].str[:3] == "10.") & (df_jpet["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

months = ["January","February","March","April","May","June",
          "July","August","September","October","November","December"]

dates = []
for idx in df_jpet.index:
    year = df_jpet.loc[idx,"year"]
    found = False
    for month in months:
        if month in df_jpet.loc[idx, "volume"]:
            dates.append(year+"-"+month+"-01")
            found = True
            break
    if not found:
        dates.append(year+"-06-01")

df_jpet["date"] = dates
df_jpet_s = df_jpet.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_jpet_s.tail()
# Out:
#                                journal  \
# 841  Journal of Public Economic Theory
# 842  Journal of Public Economic Theory
# 843  Journal of Public Economic Theory
# 844  Journal of Public Economic Theory
# 845  Journal of Public Economic Theory
#
#                                                  title  \
# 841  School Finance Induced Migration and Stratific...
# 842      Uncertainty, Commitment, and Optimal Taxation
# 843            Systems of Benevolent Utility Functions
# 844  Inductive Game Theory: Discrimination and Prej...
# 845  Economies with Public Goods: An Elementary Geo...
#
#                                   authors  \
# 841                 ['Thomas J. Nechyba']
# 842  ['Helmuth Cremer', 'Firouz Gahvari']
# 843             ['Theodore C. Bergstrom']
# 844   ['Mamoru Kaneko', 'Akihiko Matsui']
# 845                   ['William Thomson']
#
#                                                 volume  jel  \
# 841                         1(1), pages 5-50, January.  N\A
# 842                        1(1), pages 51-70, January.  N\A
# 843  nt Utility Functions," Journal of Public Econo...  N\A
# 844                      1(1), pages 101-137, January.  N\A
# 845                      1(1), pages 139-176, January.  N\A
#
#                                               abstract  \
# 841  This paper introduces a general equilibrium mo...
# 842  This paper examines the optimal tax design pro...
# 843  This paper studies systems of utility function...
# 844  This paper proposes a new theory, which we cal...
# 845  This paper explains how to represent economies...
#
#                                                    url  \
# 841  https://ideas.repec.org/a/bla/jpbect/v1y1999i1...
# 842  https://ideas.repec.org/a/bla/jpbect/v1y1999i1...
# 843  https://ideas.repec.org/a/bla/jpbect/v1y1999i1...
# 844  https://ideas.repec.org/a/bla/jpbect/v1y1999i1...
# 845  https://ideas.repec.org/a/bla/jpbect/v1y1999i1...
#
#                          doi             date
# 841  10.1111/1097-3923.00002  1999-January-01
# 842  10.1111/1097-3923.00003  1999-January-01
# 843  10.1111/1097-3923.00004       1999-06-01
# 844  10.1111/1097-3923.00005  1999-January-01
# 845  10.1111/1097-3923.00006  1999-January-01

# %% [markdown]
# ## 20. RESTAT

# %%
# clean restat
df_restat = pd.read_csv("data/journals/raw_data/restat.csv", encoding = "utf-8-sig").astype("str")
df_restat["abstract"] = df_restat["abstract"].apply(lambda x: x.replace("\n","").replace("\t","").replace("Abstract","").strip())
df_restat = df_restat.drop_duplicates(subset = ["doi"]).reset_index(drop=True)
df_restat["doi"] = df_restat["doi"].apply(lambda x: x.strip().replace("http://hdl.handle.net/","").replace("http://www.mitpressjournals.org/doi/pdf/",""))
df_restat = df_restat[(df_restat["doi"].str[:3] == "10.") & (df_restat["doi"].str.contains("issue") == False)].drop_duplicates(subset = ["doi"]).reset_index(drop=True)

months = ["January","February","March","April","May","June",
          "July","August","September","October","November","December"]

dates = []
for idx in df_restat.index:
    year = df_restat.loc[idx,"year"]
    found = False
    for month in months:
        if month in df_restat.loc[idx, "volume"]:
            dates.append(year+"-"+month+"-01")
            found = True
            break
    if not found:
        dates.append(year+"-06-01")

df_restat["date"] = dates
df_restat_s = df_restat.drop_duplicates(subset = ["doi"]).reset_index(drop=True)[["journal","title","authors","volume","jel","abstract","url","doi","date"]]
df_restat_s.tail()
# Out:
#                                      journal  \
# 1904  The Review of Economics and Statistics
# 1905  The Review of Economics and Statistics
# 1906  The Review of Economics and Statistics
# 1907  The Review of Economics and Statistics
# 1908  The Review of Economics and Statistics
#
#                                                   title  \
# 1904  Market Share Behavior And Mobility: An Analysi...
# 1905  The Response Of Exchange Rate Pass-Through To ...
# 1906  The Skill Bias Of Technological Change In Cana...
# 1907  Another Look At The Impact Of The National Ind...
# 1908  Beer Taxes, Workers' Compensation, And Industr...
#
#                                             authors  \
# 1904                              ['John R. Cable']
# 1905                                 ['Jaewoo Lee']
# 1906                            ['Julian R. Betts']
# 1907                          ['Matthew B. Krepps']
# 1908  ['Robert L. Ohsfeldt', 'Michael A. Morrisey']
#
#                                volume  jel  \
# 1904  79(1), pages 136-141, February.  N\A
# 1905  79(1), pages 142-145, February.  N\A
# 1906  79(1), pages 146-150, February.  N\A
# 1907  79(1), pages 151-154, February.  N\A
# 1908  79(1), pages 155-160, February.  N\A
#
#                                                abstract  \
# 1904  A measure of market share mobility is derived ...
# 1905  This paper finds that domestic market concentr...
# 1906  The paper tests whether technological change h...
# 1907  Alexander's (1994) finding that the National R...
# 1908  The apparent effects of beer taxes, workers' c...
#
#                                                     url  \
# 1904  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 1905  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 1906  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 1907  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 1908  https://ideas.repec.org/a/tpr/restat/v79y1997i...
#
#                           doi              date
# 1904  10.1162/003465397556476  1997-February-01
# 1905  10.1162/003465397556485  1997-February-01
# 1906  10.1162/003465397556494  1997-February-01
# 1907  10.1162/003465397556502  1997-February-01
# 1908  10.1162/003465397556511  1997-February-01

# %%
153 % 6
# Out:
# 3

# %%
for item in df_eer.volume:
    print(item)

# %%
# concatenate journals
df = pd.concat([df_rfs_s,df_res_s,df_qje_s,df_jpe_s,df_e_s,
                df_aer_s,df_jf_s,df_jep_s,df_aejm_s,df_eer_s,
                df_el_s,df_em_s,df_jde_s,df_jeea_s,df_jel_s,
                df_jie_s,df_jme_s,df_ej_s,df_jpet_s,df_restat_s]).reset_index(drop=True)
len(df)
# Out:
# 43405

# %%
df.nunique()
# Out:
# journal        20
# title       42773
# authors     36259
# volume      33692
# jel          5742
# abstract    38854
# url         43405
# doi         43405
# date         1401
# dtype: int64

# %%
df_selected = df[["doi","journal","volume","date","title","abstract","url"]]
df_selected.tail()
# Out:
#                            doi                                 journal  \
# 43400  10.1162/003465397556476  The Review of Economics and Statistics
# 43401  10.1162/003465397556485  The Review of Economics and Statistics
# 43402  10.1162/003465397556494  The Review of Economics and Statistics
# 43403  10.1162/003465397556502  The Review of Economics and Statistics
# 43404  10.1162/003465397556511  The Review of Economics and Statistics
#
#                                 volume              date  \
# 43400  79(1), pages 136-141, February.  1997-February-01
# 43401  79(1), pages 142-145, February.  1997-February-01
# 43402  79(1), pages 146-150, February.  1997-February-01
# 43403  79(1), pages 151-154, February.  1997-February-01
# 43404  79(1), pages 155-160, February.  1997-February-01
#
#                                                    title  \
# 43400  Market Share Behavior And Mobility: An Analysi...
# 43401  The Response Of Exchange Rate Pass-Through To ...
# 43402  The Skill Bias Of Technological Change In Cana...
# 43403  Another Look At The Impact Of The National Ind...
# 43404  Beer Taxes, Workers' Compensation, And Industr...
#
#                                                 abstract  \
# 43400  A measure of market share mobility is derived ...
# 43401  This paper finds that domestic market concentr...
# 43402  The paper tests whether technological change h...
# 43403  Alexander's (1994) finding that the National R...
# 43404  The apparent effects of beer taxes, workers' c...
#
#                                                      url
# 43400  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 43401  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 43402  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 43403  https://ideas.repec.org/a/tpr/restat/v79y1997i...
# 43404  https://ideas.repec.org/a/tpr/restat/v79y1997i...

# %%
# save article
df_selected.to_csv("article.csv", index = False, encoding = "utf-8-sig")
df_selected.to_csv("article_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Clean and update author.csv, email_affiliation.csv, affiliation.csv

# %%
# clean author
df_email = pd.read_csv("email_affiliation.csv", encoding = "utf-8-sig").replace(np.NaN,"")
emaildict = df_email.to_dict("list")
df_au = pd.read_csv("author.csv", encoding = "utf-8-sig")

# %%
# open chrome service
chromedriver_path = "D:/chromedriver.exe"
s = Service(chromedriver_path)
driver = webdriver.Chrome(service=s)

# %%
base_url = "https://scholar.google.com/scholar?hl=zh-CN&q="
start_idx = 1
for i, e in enumerate(sorted(df_au["emailsuffix"].unique())[start_idx:]):
    if e not in emaildict["subemail"]:
        driver.get(base_url+e)
        driver.refresh()
        soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
        try:
            h3 = soup.find("div", class_ = "gs_r").h3
            if h3.text == "以下机构的用户个人学术档案：":
                div = soup.find("div", class_ = "gs_r").div
                name = div.a.text
                email = div.span.text.replace(" - ", "")
                time.sleep(random.randrange(5,10))
            else:
                raise ValueError("x")
        except:
            try:
                h2 = soup.find("div", class_ = "gs_r").h2
                if "显示的是以下查询字词的结果：" in h2.text.strip():
                    driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                    driver.refresh()
                    soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                    div = soup.find("div", class_ = "gs_r").div
                    name = div.a.text
                    email = div.span.text.replace(" - ", "")
                    time.sleep(random.randrange(5,10))
                else:
                    raise ValueError("x")
            except:
                driver.get(base_url+".".join(e.split(".")[1:]))
                driver.refresh()
                soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                try:
                    h3 = soup.find("div", class_ = "gs_r").h3
                    if h3.text == "以下机构的用户个人学术档案：":
                        div = soup.find("div", class_ = "gs_r").div
                        name = div.a.text
                        email = div.span.text.replace(" - ", "")
                        time.sleep(random.randrange(5,10))
                    else:
                        raise ValueError("x")
                except:
                    try:
                        h2 = soup.find("div", class_ = "gs_r").h2
                        if "显示的是以下查询字词的结果：" in h2.text.strip():
                            driver.get("https://scholar.google.com"+soup.find("div", class_ = "gs_r").div.a.get("href"))
                            driver.refresh()
                            soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                            div = soup.find("div", class_ = "gs_r").div
                            name = div.a.text
                            email = div.span.text.replace(" - ", "")
                            time.sleep(random.randrange(5,10))
                        else:
                            raise ValueError("x")
                    except:
                        try:
                            if soup.find("h1").text == "请进行人机身份验证":
                                print("Blocked!!!")
                                break
                            else:
                                name = ""
                                email = ""
                            time.sleep(random.randrange(5,10))
                        except:
                            name = ""
                            email = ""
                            time.sleep(random.randrange(5,10))
        # append info
        try:
            affid = "".join([w[0] for w in name.lower().split(" ")])+"."+email
        except:
            affid = ""

        if "PDF" in affid:
            name = ""
            email = ""
            affid = ""

        emaildict["name"].append(name)
        emaildict["email"].append(email)
        emaildict["subemail"].append(e)
        emaildict["affiliationid"].append(affid)
        print(i+start_idx, e, name, email, affid)

# %%
len(emaildict["name"])
# Out:
# 3459

# %%
df_email = pd.DataFrame(emaildict).drop_duplicates(subset=["subemail"],keep="last")
len(df_email)
# Out:
# 3459

# %%
df_email.nunique()
# Out:
# name             1393
# email            1391
# subemail         3459
# affiliationid    1393
# dtype: int64

# %%
df_aff = df_email[["affiliationid","name","email"]][df_email["affiliationid"]!=""].drop_duplicates()
len(df_aff)
# Out:
# 1392

# %%
# add affiliationid to author
for idx in df_au.index:
    try:
        df_au.loc[idx, "affiliationid"] = df_email.set_index("subemail").loc[df_au.loc[idx, "emailsuffix"],"affiliationid"]
    except:
        df_au.loc[idx, "affiliationid"] = ""

# %%
df_aff = pd.read_csv("affiliation.csv", encoding = "utf-8-sig")

df_email.to_csv("email_affiliation.csv", index = False, encoding = "utf-8-sig")
df_email.to_csv("email_affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation.csv", index = False, encoding = "utf-8-sig")
df_aff.to_csv("affiliation_no_header.csv", index = False, header = False, encoding = "utf-8-sig")
df_au.to_csv("author.csv", index = False, encoding = "utf-8-sig")
df_au.to_csv("author_no_header.csv", index = False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# ## Database

# %%
# use this line to run the script directly in Jupyter
! sqlite3 econtop.db < create-econtop.sql

# %%
conn = sqlite3.connect("econtop.db")
cur = conn.cursor()

# %% [markdown]
# ### University Level

# %%
# select university level of publications
q = """
    SELECT art.journal, art.title, art.abstract, art.date, au.authorname, af.name
    FROM author_article AS aa JOIN author AS au JOIN article AS art JOIN affiliation AS af
    ON aa.authorid = au.authorid AND
    aa.doi = art.doi AND
    au.affiliationid = af.affiliationid
    WHERE art.date >= '1000-01-01' AND
    art.date < '2105-01-01'
    """

# q = " SELECT authorid FROM author"
# generate valid abstracts with dates
df_af_art = pd.read_sql_query(q, conn).drop_duplicates(subset=["abstract"])
df_af_art.head()
# Out:
#                        journal  \
# 0  Review of Financial Studies
# 1  Review of Financial Studies
# 2  Review of Financial Studies
# 4  Review of Financial Studies
# 6  Review of Financial Studies
#
#                                                title  \
# 0     Dynamic Equilibrium with Liquidity Constraints
# 1  Stochastic Discount Factor Bounds with Conditi...
# 2  Delta-Hedged Gains and the Negative Market Vol...
# 4  Differences of Opinion, Short-Sales Constraint...
# 6             Risk Adjustment and Trading Strategies
#
#                                             abstract        date  \
# 0  This article studies an intertemporal economy ...  2003-05-15
# 1  Hansen and Jagannathan (1991) (hereafter HJ) d...  2003-05-15
# 2  We investigate whether the volatility risk pre...  2003-05-15
# 4  We develop a theory of market crashes based on...  2003-05-15
# 6  We assess the profitability of momentum strate...  2003-05-15
#
#             authorname                                  name
# 0      Jerome Detemple                     Boston University
# 1         Wayne Ferson     University of Southern California
# 2       Nikunj Kapadia  University of Massachusetts, Amherst
# 4      Jeremy C. Stein                    Harvard University
# 6  Dong-Hyun Ahn (안동현)             Seoul National University

# %%
df_af_art.nunique()
# Out:
# journal          20
# title         27638
# abstract      27647
# date           1025
# authorname    11830
# name           1267
# dtype: int64

# %%
df_af_art.to_csv("abstract.csv", index = False, encoding = "utf-8-sig")

# %%
# show top appearance
freq = {}
for doi in df_af_art.index:
    try:
        name = df_af_art.loc[doi][1]
        try:
            freq[name] += 1
        except:
            freq[name] = 1
    except:
        df_af_art_new = df_af_art.loc[doi]
        names = set(list(df_af_art_new.name))
        for name in names:
            try:
                freq[name] += 1
            except:
                freq[name] = 1

# %%
freq_sorted = sorted(freq.items(), key=lambda x:x[1], reverse = True)
freq_sorted
# Out:
# [('A Comment on: “State Capacity, Reciprocity, and the Social Contract” by Timothy Besley',
#   3),
#  ('Panel Discussion', 3),
#  ('Returns to Capital in Microenterprises: Evidence from a Field Experiment',
#   2),
#  ('Verifying the Solution from a Nonlinear Solver: A Case Study: Comment', 2),
#  ('Household Finance', 2),
#  ('Entrepreneurship education and teacher training in Rwanda', 2),
#  ('A Review of the Stern Review on the Economics of Climate Change', 2),
#  ('Dynamic Equilibrium with Liquidity Constraints', 1),
#  ('Stochastic Discount Factor Bounds with Conditioning Information', 1),
#  ('Delta-Hedged Gains and the Negative Market Volatility Risk Premium', 1),
#  ('Differences of Opinion, Short-Sales Constraints, and Market Crashes', 1),
#  ('Risk Adjustment and Trading Strategies', 1),
#  ('An Analysis of Covariance Risk and Pricing Anomalies', 1),
#  ('Order Preferencing and Market Quality on U.S. Equity Exchanges', 1),
#  ('Market Making with Costly Monitoring: An Analysis of the SOES Controversy',
#   1),
#  ('Liquidity-Based Competition for Order Flow', 1),
#  ('Underwriter Certification and Japanese Seasoned Equity Issues', 1),
#  ('Information Technology and Financial Services Competition', 1),
#  ('Statistical Arbitrage and Securities Prices', 1),
#  ('Return Distributions and Improved Tests of Asset Pricing Models', 1),
#  ('Nonlinear Mean Reversion in the Short-Term Interest Rate', 1),
#  ('Financial Development and Financing Constraints: International Evidence from the Structural Investment Model',
#   1),
#  ('A New Approach to Measuring Financial Contagion', 1),
#  ('Fundamental Properties of Bond Prices in Models of the Short-Term Rate', 1),
#  ('Raids, Rewards, and Reputations in the Market for Managerial Talent', 1),
#  ('Institutional Liquidity Needs and the Structure of Monitored Finance', 1),
#  ('Cross-Subsidies, External Financing Constraints, and the Contribution of the Internal Capital Market to Firm Value',
#   1),
#  ('Real Flexibility and Financial Structure: An Empirical Analysis', 1),
#  ('Taxes and Corporate Finance: A Review', 1),
#  ('Price Discovery and Trading After Hours', 1),
#  ('Informal Financial Networks: Theory and Evidence', 1),
#  ('Can Managerial Discretion Explain Observed Leverage Ratios?', 1),
#  ('Why the NPV Criterion does not Maximize NPV', 1),
#  ('Institutional Herding', 1),
#  ('The Emergence and Persistence of the Anglo-Saxon and German Financial Systems',
#   1),
#  ('Career Concerns and Resource Allocation in Conglomerates', 1),
#  ("What's In It for Me? CEOs Whose Firms Are Acquired", 1),
#  ('Valuation and Return Dynamics of New Ventures', 1),
#  ('Extreme Value Dependence in Financial Markets: Diagnostics, Models, and Financial Implications',
#   1),
#  ('Multiple Unit Auctions and Short Squeezes', 1),
#  ('On the Timing and Execution of Open Market Repurchases', 1),
#  ('Advertising, Breadth of Ownership, and Liquidity', 1),
#  ('Confronting Information Asymmetries: Evidence from Real Estate Markets', 1),
#  ('Evaluating an Alternative Risk Preference in Affine Term Structure Models',
#   1),
#  ('Conditioning Information and Variance Bounds on Pricing Kernels', 1),
#  ('Strategic Trading, Liquidity, and Information Acquisition', 1),
#  ('Wealth, Information Acquisition, and Portfolio Choice', 1),
#  ('Underpricing and Market Power in Uniform Price Auctions', 1),
#  ('Are IPOs Really Underpriced?', 1),
#  ('The Overseas Listing Decision: New Evidence of Proximity Preference', 1),
#  ('Capital Budgeting in Multidivision Firms: Information, Agency, and Incentives',
#   1),
#  ('Stock Return Predictability and Asset Pricing Models', 1),
#  ('Family Values and the Star Phenomenon: Strategies of Mutual Fund Families',
#   1),
#  ('Adverse Selection and the Required Return', 1),
#  ('Losing Money on Arbitrage: Optimal Dynamic Portfolio Choice in Markets with Arbitrage Opportunities',
#   1),
#  ('Board Composition, Board Effectiveness, and the Observed Form of Takeover Bids',
#   1),
#  ('The Value of Voting Rights to Majority Shareholders: Evidence from Dual-Class Stock Unifications',
#   1),
#  ('Why Does Book Building Drive Out Auction Methods of IPO Issuance? Evidence from Japan',
#   1),
#  ('Bank Competition and Credit Standards', 1),
#  ('Prospect Theory and Mean-Variance Analysis', 1),
#  ('Public Trading and Private Incentives', 1),
#  ('Robust Portfolio Rules and Asset Pricing', 1),
#  ('Whence GARCH? A Preference-Based Explanation for Conditional Volatility',
#   1),
#  ('IPOs with Buy- and Sell-Side Information Production: The Dark Side of Open Sales',
#   1),
#  ('Decision Processes, Agency Problems, and Information: An Economic Analysis of Capital Budgeting Procedures',
#   1),
#  ('Why Do Firms Announce Open-Market Repurchase Programs?', 1),
#  ('Corporate Governance, Incentives, and Industry Consolidations', 1),
#  ('Is Default Event Risk Priced in Corporate Bonds?', 1),
#  ('An Equilibrium Model of Rare-Event Premia and Its Implication for Option Smirks',
#   1),
#  ('An Empirical Analysis of Stock and Bond Market Liquidity', 1),
#  ('Nonparametric Specification Testing for Continuous-Time Models with Applications to Term Structure of Interest Rates',
#   1),
#  ('The Pooling and Tranching of Securities: A Model of Informed Intermediation',
#   1),
#  ('Jackknifing Bond Option Prices', 1),
#  ('A Shrinkage Approach to Model Uncertainty and Asset Allocation', 1),
#  ('Anonymity, Adverse Selection, and the Sorting of Interdealer Trades', 1),
#  ('Short-Term Persistence in Mutual Fund Performance', 1),
#  ('Portfolio Choice in the Presence of Housing', 1),
#  ('Consumption and Portfolio Choice over the Life Cycle', 1),
#  ('Interbank Market Integration under Asymmetric Information', 1),
#  ('Information Leakage and Market Efficiency', 1),
#  ('How Often to Sample a Continuous-Time Process in the Presence of Market Microstructure Noise',
#   1),
#  ('IPO Market Timing', 1),
#  ('Optimal Contracts Under Adverse Selection and Moral Hazard: A Continuous-Time Approach',
#   1),
#  ('Market Frictions, Price Delay, and the Cross-Section of Expected Returns',
#   1),
#  ('Coordination of Expectations in Asset Pricing Experiments', 1),
#  ('Does Risk Seeking Drive Stock Prices? A Stochastic Dominance Analysis of Aggregate Investor Preferences and Beliefs',
#   1),
#  ('Do Heterogeneous Beliefs Matter for Asset Pricing?', 1),
#  ('A Simulation Approach to Dynamic Portfolio Choice with an Application to Learning About Return Predictability',
#   1),
#  ('Do Domestic Investors Have an Edge? The Trading Experience of Foreign Investors in Korea',
#   1),
#  ('Island Goes Dark: Transparency, Fragmentation, and Regulation', 1),
#  ('Household Portfolio Diversification: A Case for Rank-Dependent Preferences',
#   1),
#  ('How Does Industry Affect Firm Financial Structure?', 1),
#  ('Dynamic Consumption and Portfolio Choice with Stochastic Volatility in Incomplete Markets',
#   1),
#  ('Why Do Larger Orders Receive Discounts on the London Stock Exchange?', 1),
#  ('The Model-Free Implied Volatility and Its Information Content', 1),
#  ('Limit Order Book as a Market for Liquidity', 1),
#  ('Fund Families as Delegated Monitors of Money Managers', 1),
#  ("Analysts' Weighting of Private and Public Information", 1),
#  ('Exchange Rates, Equity Prices, and Capital Flows', 1),
#  ('Asset Allocation with a High Dimensional Latent Factor Stochastic Volatility Model',
#   1),
#  ('Competition and Cooperation in Divisible Good Auctions: An Experimental Examination',
#   1),
#  ('Credit Ratings and Stock Liquidity', 1),
#  ('Credit Ratings as Coordination Mechanisms', 1),
#  ('Does the Source of Capital Affect Capital Structure?', 1),
#  ('Labor Income and Predictable Stock Returns', 1),
#  ('Hedging, Familiarity and Portfolio Choice', 1),
#  ("If at First You Don't Succeed: The Effect of the Option to Resolicit on Corporate Takeovers",
#   1),
#  ('Financial Constraints Risk', 1),
#  ('Pricing Options in an Extended Black Scholes Economy with Illiquidity: Theory and Empirical Evidence',
#   1),
#  ('A Trade-Based Analysis of Momentum', 1),
#  ('Evaluating Government Bond Fund Performance with Stochastic Discount Factors',
#   1),
#  ('IPO Underpricing and After-Market Liquidity', 1),
#  ('Innovation, Differentiation, and the Choice of an Underwriter: Evidence from Equity-Linked Securities',
#   1),
#  ('Asset Pricing Models and Financial Market Anomalies', 1),
#  ('Competition and Strategic Information Acquisition in Credit Markets', 1),
#  ('Maximum Likelihood Estimation of Latent Affine Processes', 1),
#  ('The Information in Option Volume for Future Stock Prices', 1),
#  ('Corporate Finance and the Monetary Transmission Mechanism', 1),
#  ('Beauty Contests and Iterated Expectations in Asset Markets', 1),
#  ('Investor Overconfidence and Trading Volume', 1),
#  ('Corporate Diversification and Credit Constraints: Real Effects across the Business Cycle',
#   1),
#  ('Capital Controls, Liberalizations, and Foreign Direct Investment', 1),
#  ('Takeover Contests with Asymmetric Bidders', 1),
#  ("Asset Pricing Implications of Firms' Financing Constraints", 1),
#  ('The Impact of Trades on Daily Volatility', 1),
#  ('Downside Risk', 1),
#  ("Dynamic Portfolio Choice with Parameter Uncertainty and the Economic Value of Analysts' Recommendations",
#   1),
#  ('The Role of Knowhow Acquisition in the Formation and Duration of Joint Ventures',
#   1),
#  ('Agency and Optimal Investment Dynamics', 1),
#  ('Does Motivation Matter When Assessing Trade Performance? An Analysis of Mutual Funds',
#   1),
#  ('Life-Cycle Portfolio Choice with Additive Habit Formation Preferences and Uninsurable Labor Income Risk',
#   1),
#  ('Portfolio Selection with Parameter and Model Uncertainty: A Multi-Prior Approach',
#   1),
#  ('Portfolio Selection in Stochastic Environments', 1),
#  ('Trade Credit: Suppliers as Debt Collectors and Insurance Providers', 1),
#  ('Do Termination Provisions Truncate the Takeover Bidding Process?', 1),
#  ('Approximation and Calibration of Short-Term Implied Volatilities Under Jump-Diffusion Stochastic Volatility',
#   1),
#  ('Imperfect Competition, Information Heterogeneity, and Financial Contagion',
#   1),
#  ('Public Disclosure and Private Decisions: Equity Market Execution Quality and Order Routing',
#   1),
#  ('Financial Intermediation and the Costs of Trading in an Opaque Market', 1),
#  ('Transparency and Liquidity: A Controlled Experiment on Corporate Bonds', 1),
#  ('Good Stewards, Cheap Talkers, or Family Men? The Impact of Mutual Fund Closures on Fund Managers, Flows, Fees, and Performance',
#   1),
#  ('Do Investors Trade More When Stocks Have Performed Well? Evidence from 46 Countries',
#   1),
#  ('Option Market Activity', 1),
#  ('Risk and Return in Fixed-Income Arbitrage: Nickels in Front of a Steamroller?',
#   1),
#  ('Tipping', 1),
#  ('The Cross-Section of Expected Trading Activity', 1),
#  ('Stock Return Predictability: Is it There?', 1),
#  ('Price Informativeness and Investment Sensitivity to Stock Price', 1),
#  ('The Effect of Private-Debt-Underwriting Reputation on Bank Public-Debt Underwriting',
#   1),
#  ('Spin-offs, Divestitures, and Conglomerate Investment', 1),
#  ('Transactions Accounts and Loan Monitoring', 1),
#  ("Information Diffusion Effects in Individual Investors' Common Stock Purchases: Covet Thy Neighbors' Investment Choices",
#   1),
#  ('Financing a Portfolio of Projects', 1),
#  ('Equilibrium Underdiversification and the Preference for Skewness', 1),
#  ('Booms, Busts, and Fraud', 1),
#  ('Asset Prices and Exchange Rates', 1),
#  ('Industry Information Diffusion and the Lead-lag Effect in Stock Returns',
#   1),
#  ('International Evidence on Cash Holdings and Expected Managerial Agency Problems',
#   1),
#  ('Analyst Hype in IPOs: Explaining the Popularity of Bookbuilding', 1),
#  ('Does Anonymity Matter in Electronic Limit Order Markets?', 1),
#  ("When Does Extra Risk Strictly Increase an Option's Value?", 1),
#  ('Optimal Asset Allocation and Risk Shifting in Money Management', 1),
#  ('Asymmetries in Stock Returns: Statistical Tests and Economic Evaluation',
#   1),
#  ('Portfolio Performance Manipulation and Manipulation-proof Performance Measures',
#   1),
#  ('An Equilibrium Model of Investment Under Uncertainty', 1),
#  ('Financial Constraints, Asset Tangibility, and Corporate Investment', 1),
#  ('Can the Trade-off Theory Explain Debt Structure?', 1),
#  ('Governance Mechanisms and Bond Prices', 1),
#  ('Relationship Banking, Fragility, and the Asset-Liability Matching Problem',
#   1),
#  ('Optimal Long-Term Financial Contracting', 1),
#  ('How Do Diversity of Opinion and Information Asymmetry Affect Acquirer Returns?',
#   1),
#  ('Underpricing in the Corporate Bond Market', 1),
#  ('Informed and Strategic Order Flow in the Bond Markets', 1),
#  ('Strategic Cost of Diversification', 1),
#  ('Valuation in Over-the-Counter Markets', 1),
#  ('Insider Trades and Private Information: The Special Case of Delayed-Disclosure Trades',
#   1),
#  ('Liquidity and Expected Returns: Lessons from Emerging Markets', 1),
#  ('Turning over Turnover', 1),
#  ('Stocks or Options? Moral Hazard, Firm Viability, and the Design of Compensation Contracts',
#   1),
#  ('Asset Pricing with Limited Risk Sharing and Heterogeneous Agents', 1),
#  ('Investor Sentiment and Option Prices', 1),
#  ('Two Trees', 1),
#  ('A Dynamic Model for the Forward Curve', 1),
#  ('Estimating the Dynamics of Mutual Fund Alphas and Betas', 1),
#  ('Conditioning Information and Variance Bounds on Pricing Kernels with Higher- Order Moments: Theory and Evidence',
#   1),
#  ('Money Illusion and Housing Frenzies', 1),
#  ('Mutual Funds and Bubbles: The Surprising Role of Contractual Incentives',
#   1),
#  ('Relative Wealth Concerns and Financial Bubbles', 1),
#  ('Bubbles: Some Perspectives (and Loose Talk) from History', 1),
#  ('The Causes and Consequences of Recent Financial Market Bubbles: An Introduction',
#   1),
#  ('Tournaments in Mutual-Fund Families', 1),
#  ('State Dependence Can Explain the Risk Aversion Puzzle', 1),
#  ('Institutional Portfolio Flows and International Investments', 1),
#  ('International asset allocation under regime switching, skew, and kurtosis preferences',
#   1),
#  ('Endogenous Events and Long-Run Returns', 1),
#  ('All That Glitters: The Effect of Attention and News on the Buying Behavior of Individual and Institutional Investors',
#   1),
#  ('Distance Still Matters: Evidence from Municipal Bond Underwriting', 1),
#  ('Where Is the Market? Evidence from Cross-Listings in the United States', 1),
#  ('Analytic Pricing of Employee Stock Options', 1),
#  ('Strategic Alliances and the Boundaries of the Firm', 1),
#  ('The Value of Investor Protection: Firm Evidence from Cross-Border Mergers',
#   1),
#  ('Complex Ownership Structures and Corporate Valuations', 1),
#  ('Production in Entrepreneurial Firms: The Effects of Financial Constraints on Labor and Capital',
#   1),
#  ('Building Relationships Early: Banks in Venture Capital', 1),
#  ('Choosing to Cofinance: Analysis of Project-Specific Alliances in the Movie Industry',
#   1),
#  ('Does Capital Account Liberalization Lead to Growth?', 1),
#  ('Who Monitors the Monitor? The Effect of Board Independence on Executive Compensation and Firm Value',
#   1),
#  ('Forecasting Default with the Merton Distance to Default Model', 1),
#  ('Expected returns, yield spreads, and asset pricing tests', 1),
#  ('Average Idiosyncratic Volatility in G7 Countries', 1),
#  ('A GARCH Option Pricing Model with Filtered Historical Simulation', 1),
#  ('The Spline-GARCH Model for Low-Frequency Volatility and Its Global Macroeconomic Causes',
#   1),
#  ('Excess Comovement of Stock Returns: Evidence from Cross-Sectional Variation in Nikkei 225 Weights',
#   1),
#  ('Small Trades and the Cross-Section of Stock Returns', 1),
#  ('Estimation Risk, Information, and the Conditional CAPM: Theory and Evidence',
#   1),
#  ("How Well Do Institutional Theories Explain Firms' Perceptions of Property Rights?",
#   1),
#  ('Interpreting the Value Effect Through the Q-Theory: An Empirical Investigation',
#   1),
#  ('Why Leverage Affects Pricing', 1),
#  ('The Declining Equity Premium: What Role Does Macroeconomic Risk Play?', 1),
#  ('Reconciling the Return Predictability Evidence', 1),
#  ('The Myth of Long-Horizon Predictability', 1),
#  ('The Dog That Did Not Bark: A Defense of Return Predictability', 1),
#  ('Predicting Excess Stock Returns Out of Sample: Can Anything Beat the Historical Average?',
#   1),
#  ('A Comprehensive Look at The Empirical Performance of Equity Premium Prediction',
#   1),
#  ('Forecasting the Equity Premium: Where We Stand Today', 1),
#  ('A Bayesian Analysis of Return Dynamics with Lévy Jumps', 1),
#  ('Market Discipline and Internal Governance in the Mutual Fund Industry', 1),
#  ('Strong-Form Efficiency with Monopolistic Insiders', 1),
#  ('Biases in Decomposing Holding-Period Portfolio Returns', 1),
#  ('Explaining the Level of Credit Spreads: Option-Implied Jump Risk Premia in a Firm Value Model',
#   1),
#  ('Habit Formation, Incomplete Markets, and the Significance of Regional Risk for Expected Returns',
#   1),
#  ('The Returns on Human Capital: Good News on Wall Street is Bad News on Main Street',
#   1),
#  ('Intragroup Propping: Evidence from the Stock-Price Effects of Earnings Announcements by Korean Business Groups',
#   1),
#  ('Do Sovereign Bonds Benefit Corporate Bonds in Emerging Markets?', 1),
#  ('Contracts and Exits in Venture Capital Finance', 1),
#  ('The Dating Game: Do Managers Designate Option Grant Dates to Increase their Compensation?',
#   1),
#  ('Good IPOs Draw in Bad: Inelastic Banking Capacity and Hot Markets', 1),
#  ('Financial Constraints and Growth: Multinational and Local Firm Responses to Currency Depreciations',
#   1),
#  ('The New Issues Puzzle: Testing the Investment-Based Explanation', 1),
#  ('Shareholder Diversification and the Decision to Go Public', 1),
#  ('Default Risk, Shareholder Advantage, and Stock Returns', 1),
#  ('Cash-in-the-Market Pricing and Optimal Resolution of Bank Failures', 1),
#  ('Monopoly and Information Advantage in the Residential Mortgage Market', 1),
#  ('Can Growth Options Explain the Trend in Idiosyncratic Risk?', 1),
#  ('Learning and Asset Prices Under Ambiguous Information', 1),
#  ('Jumps in Financial Markets: A New Nonparametric Test and Jump Dynamics', 1),
#  ('Inflation Uncertainty, Asset Valuations, and the Credit Spreads Puzzle', 1),
#  ('Momentum Profits, Factor Pricing, and Macroeconomic Risk', 1),
#  ('Unobserved Actions of Mutual Funds', 1),
#  ('Estimating Standard Errors in Finance Panel Data Sets: Comparing Approaches',
#   1),
#  ('Multiple-Predictor Regressions: Hypothesis Testing', 1),
#  ('Are there permanent valuation gains to overseas listing?', 1),
#  ('Multinationals as Arbitrageurs: The Effect of Stock Market Valuations on Foreign Direct Investment',
#   1),
#  ('A Liquidity-Based Theory of Closed-End Funds', 1),
#  ('The Stock Market and Corporate Investment: A Test of Catering Theory', 1),
#  ('Do Retail Trades Move Markets?', 1),
#  ('Financial Contracting with Optimistic Entrepreneurs', 1),
#  ('Disappearing Dividends, Catering, and Risk', 1),
#  ('Bank Debt and Corporate Governance', 1),
#  ('Harming Depositors and Helping Borrowers: The Disparate Impact of Bank Consolidation',
#   1),
#  ('Institutional Investors and Equity Returns: Are Short-term Institutions Better Informed?',
#   1),
#  ('Optimal Executive Compensation when Firm Size Follows Geometric Brownian Motion',
#   1),
#  ('Corporate Governance Transfer and Synergistic Gains from Mergers and Acquisitions',
#   1),
#  ('What Matters in Corporate Governance?', 1),
#  ('Design and Renegotiation of Debt Covenants', 1),
#  ('Consensus in Diverse Corporate Boards', 1),
#  ('Equity and Cash in Intercorporate Asset Sales: Theory and Evidence', 1),
#  ('Market Valuation and Acquisition Quality: Empirical Evidence', 1),
#  ('Just How Much Do Individual Investors Lose by Trading?', 1),
#  ('Short-Sale Strategies and Return Predictability', 1),
#  ('Hedge Funds as Investors of Last Resort?', 1),
#  ('Trading Restrictions and Stock Prices', 1),
#  ('Controlling for Fixed-Income Exposure in Portfolio Evaluation: Evidence from Hybrid Mutual Funds',
#   1),
#  ('Cointegration and Consumption Risks in Asset Returns', 1),
#  ('Variance Risk Premiums', 1),
#  ('Mutual Fund Fees Around the World', 1),
#  ('Loyalty-Based Portfolio Choice', 1),
#  ('Trade-offs in Staying Close: Corporate Decision Making and Geographic Dispersion',
#   1),
#  ('Motivating Entrepreneurial Activity in a Firm', 1),
#  ('Bank Lines of Credit in Corporate Finance: An Empirical Analysis', 1),
#  ('Y2K Options and the Liquidity Premium in Treasury Markets', 1),
#  ('Nondiversification Traps in Catastrophe Insurance Markets', 1),
#  ('Flight-to-Quality or Flight-to-Liquidity? Evidence from the Euro-Area Bond Market',
#   1),
#  ('The Nature and Persistence of Buyback Anomalies', 1),
#  ('The Real Effects of Debt Certification: Evidence from the Introduction of Bank Loan Ratings',
#   1),
#  ('Leasing, Ability to Repossess, and Debt Capacity', 1),
#  ('Strategic Disclosure and Stock Returns: Theory and Evidence from US Cross-Listing',
#   1),
#  ('Asset Salability and Debt Maturity: Evidence from Nineteenth-Century American Railroads',
#   1),
#  ('Do IPOs Affect the Prices of Other Stocks? Evidence from Emerging Markets',
#   1),
#  ('IPO Pricing and Allocation: A Survey of the Views of Institutional Investors',
#   1),
#  ('The Choice of Corporate Liquidity and Corporate Governance', 1),
#  ('Takeovers and the Cross-Section of Returns', 1),
#  ('The Myth of Diffuse Ownership in the United States', 1),
#  ('Margin Trading, Overpricing, and Synchronization Risk', 1),
#  ('A General Stochastic Volatility Model for the Pricing of Interest Rate Derivatives',
#   1),
#  ('Systematic Risk and the Price Structure of Individual Equity Options', 1),
#  ('Failure Is an Option: Impediments to Short Selling and Options Prices', 1),
#  ('Distinguishing the Effect of Overconfidence from Rational Best-Response on Information Aggregation',
#   1),
#  ('Insider Trading Laws and Stock Price Informativeness', 1),
#  ('Ambiguity and Nonparticipation: The Role of Regulation', 1),
#  ('Incentives and Mutual Fund Performance: Higher Performance or Just Higher Risk Taking?',
#   1),
#  ('Dividends and Corporate Shareholders', 1),
#  ('The Long-Term Effects of Cross-Listing, Investor Recognition, and Ownership Structure on Valuation',
#   1),
#  ('Investment, Financing Constraints, and Internal Capital Markets: Evidence from the Advertising Expenditures of Multinational Firms',
#   1),
#  ('Do Politically Connected Boards Affect Firm Value?', 1),
#  ('The Effect of Introducing a Non-Redundant Derivative on the Volatility of Stock-Market Returns When Agents Differ in Risk Aversion',
#   1),
#  ('How Noise Trading Affects Markets: An Experimental Analysis', 1),
#  ('Asset Returns and the Listing Choice of Firms', 1),
#  ('Market Liquidity and Funding Liquidity', 1),
#  ('The Economics of Fraudulent Accounting', 1),
#  ('Big Business Owners in Politics', 1),
#  ('Corruption, Political Connections, and Municipal Finance', 1),
#  ('On Loan Sales, Loan Contracting, and Lending Relationships', 1),
#  ('Time-Varying Risk Premiums and the Output Gap', 1),
#  ('Optimal Filtering of Jump Diffusions: Extracting Latent States from Asset Prices',
#   1),
#  ('Testing Portfolio Efficiency with Conditioning Information', 1),
#  ('Risk Shifting versus Risk Management: Investment Policy in Corporate Pension Plans',
#   1),
#  ('The "Wall Street Walk" and Shareholder Activism: Exit as a Form of Voice',
#   1),
#  ('Liquidity and Market Crashes', 1),
#  ('New Measures for Performance Evaluation', 1),
#  ('How Smart Are the Smart Guys? A Unique View from Hedge Fund Stock Holdings',
#   1),
#  ('Are "Market Neutral" Hedge Funds Really Market Neutral?', 1),
#  ('The Effects and Unintended Consequences of the Sarbanes-Oxley Act on the Supply and Demand for Directors',
#   1),
#  ('Do Foreigners Invest Less in Poorly Governed Firms?', 1),
#  ('Does Asymmetric Information Drive Capital Structure Decisions?', 1),
#  ('The Euro and Corporate Valuations', 1),
#  ('Differences in Governance Practices between U.S. and Foreign Firms: Measurement, Causes, and Consequences',
#   1),
#  ('Returns to Shareholder Activism: Evidence from a Clinical Study of the Hermes UK Focus Fund',
#   1),
#  ('How Are U.S. Family Firms Controlled?', 1),
#  ('Entrepreneurial Learning, the IPO Decision, and the Post-IPO Drop in Firm Profitability',
#   1),
#  ('Do Shareholder Rights Affect the Cost of Bank Loans?', 1),
#  ('Strategic Financial Innovation in Segmented Markets', 1),
#  ('Government Control of Privatized Firms', 1),
#  ('Bank Liquidity Creation', 1),
#  ('The Effectiveness of Reputation as a Disciplinary Mechanism in Sell-Side Research',
#   1),
#  ('Price Drift as an Outcome of Differences in Higher-Order Beliefs', 1),
#  ('Simulation-Based Estimation of Contingent-Claims Prices', 1),
#  ('Theory-Based Illiquidity and Asset Pricing', 1),
#  ('Information in Equity Markets with Ambiguity-Averse Investors', 1),
#  ('Institutional Investors and the Informational Efficiency of Prices', 1),
#  ('The Geography of Hedge Funds', 1),
#  ('An Economic Evaluation of Empirical Exchange Rate Models', 1),
#  ('Model Comparison Using the Hansen-Jagannathan Distance', 1),
#  ('Parametric Portfolio Policies: Exploiting Characteristics in the Cross-Section of Equity Returns',
#   1),
#  ('On the Relation Between the Credit Spread Puzzle and the Equity Premium Puzzle',
#   1),
#  ('How Active Is Your Fund Manager? A New Measure That Predicts Performance',
#   1),
#  ('Demand-Based Option Pricing', 1),
#  ('Measuring Abnormal Bond Performance', 1),
#  ('Conflicts of Interest and Stock Recommendations: The Effects of the Global Settlement and Related Regulations',
#   1),
#  ('Ambiguity Aversion and the Term Structure of Interest Rates', 1),
#  ('Assessing the Costs and Benefits of Brokers in the Mutual Fund Industry',
#   1),
#  ('Pension Reform, Ownership Structure, and Corporate Governance: Evidence from a Natural Experiment',
#   1),
#  ('Estimating the Effect of Hierarchies on Information Use', 1),
#  ('Ownership: Evolution and Regulation', 1),
#  ('Scaling the Hierarchy: How and Why Investment Banks Compete for Syndicate Co-management Appointments',
#   1),
#  ('Large Shareholders and Corporate Policies', 1),
#  ('Liquidity and Manipulation of Executive Compensation Schemes', 1),
#  ('Disagreement and Learning in a Dynamic Contracting Model', 1),
#  ('The Limitations of Industry Concentration Measures Constructed with Compustat Data: Implications for Finance Research',
#   1),
#  ('Option Backdating and Board Interlocks', 1),
#  ('The Sale of Multiple Assets with Private Information', 1),
#  ('A Reexamination of Corporate Governance and Equity Prices', 1),
#  ('On the Growth Effect of Stock Market Liberalizations', 1),
#  ('Incentive Contracts in Delegated Portfolio Management', 1),
#  ("Size and Focus of a Venture Capitalist's Portfolio", 1),
#  ('A Dynamic Model of the Limit Order Book', 1),
#  ('Benchmarking Money Manager Performance: Issues and Evidence', 1),
#  ('Understanding Index Option Returns', 1),
#  ('Expected Stock Returns and Variance Risk Premia', 1),
#  ('Unspanned Stochastic Volatility and the Pricing of Commodity Derivatives',
#   1),
#  ('Nonparametric Estimation of State-Price Densities Implicit in Interest Rate Cap Prices',
#   1),
#  ('Anomalies', 1),
#  ('Expected Returns and the Business Cycle: Heterogeneous Goods and Time-Varying Risk Aversion',
#   1),
#  ('Brokerage Commissions and Institutional Trading Patterns', 1),
#  ('Basis Assets', 1),
#  ('Explaining Credit Default Swap Spreads with the Equity Volatility and Jump Risks of Individual Firms',
#   1),
#  ('Empirical Analysis of Corporate Credit Lines', 1),
#  ('Macro Factors in Bond Risk Premia', 1),
#  ('Investment Banks as Insiders and the Market for Corporate Control', 1),
#  ('Bankruptcy Codes and Innovation', 1),
#  ("Empire-Building or Bridge-Building? Evidence from New CEOs' Internal Capital Allocation Decisions",
#   1),
#  ('A Multiplicative Model of Optimal CEO Incentives in Market Equilibrium', 1),
#  ('Tunnel-Proofing the Executive Suite: Transparency, Temptation, and the Design of Executive Compensation',
#   1),
#  ('Expanding Credit Access: Using Randomized Supply Decisions to Estimate the Impacts',
#   1),
#  ('The Effects of Marital Status and Children on Savings and Portfolio Choice',
#   1),
#  ('Variance Risk-Premium Dynamics: The Role of Jumps', 1),
#  ('Growth or Glamour? Fundamentals and Systematic Risk in Stock Returns', 1),
#  ('Ex-dividend Arbitrage in Option Markets', 1),
#  ('Financial Constraints, Investment, and the Value of Cash Holdings', 1),
#  ('Information Linkages and Correlated Trading', 1),
#  ('Expected Idiosyncratic Skewness', 1),
#  ('Dynamic Investment and Financing under Personal Taxation', 1),
#  ('Dynamic Asset Allocation: Portfolio Decomposition Formula and Applications',
#   1),
#  ('Portfolio Performance and Agency', 1),
#  ('Do Analysts Herd? An Analysis of Recommendations and Market Reactions', 1),
#  ('The Idiosyncratic Volatility Puzzle: Time Trend or Speculative Episodes?',
#   1),
#  ('Out-of-Sample Equity Premium Prediction: Combination Forecasts and Links to the Real Economy',
#   1),
#  ('Market-Based Corrective Actions', 1),
#  ('When Can Life Cycle Investors Benefit from Time-Varying Bond Risk Premia?',
#   1),
#  ('Learning by Trading', 1),
#  ('The Levered Equity Risk Premium and Credit Spreads: A Unified Framework',
#   1),
#  ('Shareholders at the Gate? Institutional Investors and Cross-Border Mergers and Acquisitions',
#   1),
#  ('Evidence on the Dark Side of Internal Capital Markets', 1),
#  ('How Law Affects Lending', 1),
#  ('Do Envious CEOs Cause Merger Waves?', 1),
#  ('How Do Pensions Affect Corporate Capital Structure Decisions?', 1),
#  ('Internal Governance Mechanisms and Operational Performance: Evidence from Index Mutual Funds',
#   1),
#  ('The Evolution of Corporate Ownership after IPO: The Impact of Investor Protection',
#   1),
#  ('Endogenous Entry and Partial Adjustment in IPO Auctions: Are Institutional Investors Better Informed?',
#   1),
#  ('Lending Relationships and Information Rents: Do Banks Exploit Their Information Advantages?',
#   1),
#  ('Managerial Agency and Bond Covenants', 1),
#  ('Investor Protection and Interest Group Politics', 1),
#  ('Wall Street and Main Street: What Contributes to the Rise in the Highest Incomes?',
#   1),
#  ('What Do Independent Directors Know? Evidence from Their Trading', 1),
#  ('The State of Corporate Governance Research', 1),
#  ('The Value of Control in Emerging Markets', 1),
#  ('Excess Comovement in International Equity Markets: Evidence from Cross-border Mergers',
#   1),
#  ('Do Demand Curves for Currencies Slope Down? Evidence from the MSCI Global Index Change',
#   1),
#  ('Asset Return Dynamics and Learning', 1),
#  ('The Market Price of Aggregate Risk and the Wealth Distribution', 1),
#  ('Insider Trades and Demand by Institutional and Individual Investors', 1),
#  ('Equilibrium Asset Pricing and Portfolio Choice Under Asymmetric Information',
#   1),
#  ('Improved Estimates of Higher-Order Comoments and Implications for Portfolio Selection',
#   1),
#  ('Heterogeneous Expectations and Bond Markets', 1),
#  ('Why Does the Law of One Price Fail? An Experiment on Index Mutual Funds',
#   1),
#  ('Investment under Uncertainty, Heterogeneous Beliefs, and Agency Conflicts',
#   1),
#  ('Ambiguity in Asset Markets: Theory and Experiment', 1),
#  ('Discrete-Time Affine-super-ℚ Term Structure Models with Generalized Market Prices of Risk',
#   1),
#  ('Option Valuation with Conditional Heteroskedasticity and Nonnormality', 1),
#  ('Executive Compensation: A New View from a Long-Term Perspective, 1936--2005',
#   1),
#  ('Strategic Flexibility and the Optimality of Pay for Sector Performance', 1),
#  ('The Economic Consequences of IPO Spinning', 1),
#  ('Repeated Signaling and Firm Dynamics', 1),
#  ('Which Firms Follow the Market? An Analysis of Corporate Investment Decisions',
#   1),
#  ('New Evidence on Measuring Financial Constraints: Moving Beyond the KZ Index',
#   1),
#  ('The Going-Public Decision and the Product Market', 1),
#  ('Performance-Sensitive Debt', 1),
#  ('Why Do Firms Use Private Equity to Opt Out of Public Markets?', 1),
#  ('Information, the Cost of Credit, and Operational Eﬃciency: An Empirical Study of Microfinance',
#   1),
#  ('Is Default Risk Negatively Related to Stock Returns?', 1),
#  ('Convertible Bond Arbitrageurs as Suppliers of Capital', 1),
#  ('The Market Portfolio May Be Mean/Variance Efficient After All', 1),
#  ('Information Immobility and Foreign Portfolio Investment', 1),
#  ('The Determinants of Stock and Bond Return Comovements', 1),
#  ('Side-by-Side Management of Hedge Funds and Mutual Funds', 1),
#  ('The Economics of Private Equity Funds', 1),
#  ('Corporate Real Estate Holdings and the Cross-Section of Stock Returns', 1),
#  ('Acquisition Values and Optimal Financial (In)Flexibility', 1),
#  ('The Information Content of IPO Prospectuses', 1),
#  ('Distance and Private Information in Lending', 1),
#  ('The "Dominant Bank Effect:" How High Lender Reputation Affects the Information Content and Terms of Bank Loans',
#   1),
#  ('On Correlation and Default Clustering in Credit Markets', 1),
#  ('The Design of Corporate Debt Structure and Bankruptcy', 1),
#  ('Temporary versus Permanent Shocks: Explaining Corporate Financial Policies',
#   1),
#  ('Long-Run Risk through Consumption Smoothing', 1),
#  ('Volatility Dynamics for the S&P500: Evidence from Realized Volatility, Daily Returns, and Option Prices',
#   1),
#  ('Optimal Mortgage Design', 1),
#  ('Formal versus Informal Finance: Evidence from China', 1),
#  ('The Representative Agent of an Economy with External Habit Formation and Heterogeneous Risk Aversion',
#   1),
#  ('Dynamic Mean-Variance Asset Allocation', 1),
#  ('CEO Replacement Under Private Information', 1),
#  ('Originator Performance, CMBS Structures, and the Risk of Commercial Mortgages',
#   1),
#  ('Does Public Financial News Resolve Asymmetric Information?', 1),
#  ('Expected Returns and Expected Growth in Rents of Commercial Real Estate',
#   1),
#  ('A Financing-Based Misvaluation Factor and the Cross-Section of Expected Returns',
#   1),
#  ('Solving Consumption and Portfolio Choice Problems: The State Variable Decomposition Method',
#   1),
#  ('Reward for Luck in a Dynamic Agency Model', 1),
#  ('Measurement Errors in Investment Equations', 1),
#  ('Stock and Option Grants with Performance-based Vesting Provisions', 1),
#  ('Pay (Be)for(e) Performance: The Signing Bonus as an Incentive Device', 1),
#  ('Product Market Synergies and Competition in Mergers and Acquisitions: A Text-Based Analysis',
#   1),
#  ('Risk and Return Characteristics of Venture Capital-Backed Entrepreneurial Companies',
#   1),
#  ('The Information Content of Bank Loan Covenants', 1),
#  ('Does Competition Reduce the Risk of Bank Failure?', 1),
#  ('When Shareholders Are Creditors: Effects of the Simultaneous Holding of Equity and Debt by Non-commercial Banking Institutions',
#   1),
#  ('Incentives, Targeting, and Firm Performance: An Analysis of Non-executive Stock Options',
#   1),
#  ('Judicial Discretion in Corporate Bankruptcy', 1),
#  ('SEO Risk Dynamics', 1),
#  ('Event Study Testing with Cross-sectional Correlation of Abnormal Returns',
#   1),
#  ('Stock Market Liquidity and the Long-run Stock Performance of Debt Issuers',
#   1),
#  ('Why Do Household Portfolio Shares Rise in Wealth?', 1),
#  ('The Effects of Price Risk on Housing Demand: Empirical Evidence from U.S. Markets',
#   1),
#  ('The Role of Institutional Investors in Initial Public Offerings', 1),
#  ('Dividend Stickiness and Strategic Pooling', 1),
#  ('Interim News and the Role of Proxy Voting Advice', 1),
#  ('Short Selling Around Seasoned Equity Offerings', 1),
#  ('Entrepreneurial Finance and Nondiversifiable Risk', 1),
#  ("Do Regulations Based on Credit Ratings Affect a Firm's Cost of Capital?",
#   1),
#  ('Dollars Dollars Everywhere, Nor Any Dime to Lend: Credit Limit Constraints on Financial Sector Absorptive Capacity',
#   1),
#  ('Capital Structure and Debt Structure', 1),
#  ('The Aggregate Dynamics of Capital Structure and Macroeconomic Risk', 1),
#  ('How Deep Is the Annuity Market Participation Puzzle?', 1),
#  ('Collateral Values by Asset Class: Evidence from Primary Securities Dealers',
#   1),
#  ('Expectations, Bond Yields, and Monetary Policy', 1),
#  ('Relative Wealth Concerns and Complementarities in Information Acquisition',
#   1),
#  ('Do the Best Hedge Funds Hedge?', 1),
#  ('Generalized Disappointment Aversion, Long-run Volatility Risk, and Asset Prices',
#   1),
#  ('News--Good or Bad--and Its Impact on Volatility Predictions over Multiple Horizons',
#   1),
#  ('When Are Analyst Recommendation Changes Influential?', 1),
#  ('Shareholder Activism and CEO Pay', 1),
#  ('Fuzzy Math, Disclosure Regulation, and Market Outcomes: Evidence from Truth-in-Lending Reform',
#   1),
#  ('A Simple Robust Link Between American Puts and Credit Protection', 1),
#  ('Pay for Performance? CEO Compensation and Acquirer Returns in BHCs', 1),
#  ('Are U.S. CEOs Paid More Than U.K. CEOs? Inferences from Risk-adjusted Pay',
#   1),
#  ('Internal Capital Markets and Corporate Politics in a Banking Group', 1),
#  ('When Do Banks Listen to Their Analysts? Evidence from Mergers and Acquisitions',
#   1),
#  ('A New Perspective on Gaussian Dynamic Term Structure Models', 1),
#  ('The Price Impact of Institutional Herding', 1),
#  ('Do Peso Problems Explain the Returns to the Carry Trade?', 1),
#  ('Price Efficiency and Short Selling', 1),
#  ('Inheriting Losers', 1),
#  ('Obfuscation, Learning, and the Evolution of Investor Sophistication', 1),
#  ('Market Liquidity and Flow-driven Risk', 1),
#  ('Impatient Trading, Liquidity Provision, and Stock Selection by Mutual Funds',
#   1),
#  ('Revisiting Asset Pricing Puzzles in an Exchange Economy', 1),
#  ('Too Many to Fail? Evidence of Regulatory Forbearance When the Banking Sector Is Weak',
#   1),
#  ('Interbank Contagion at Work: Evidence from a Natural Experiment', 1),
#  ('What You Sell Is What You Lend? Explaining Trade Credit Contracts', 1),
#  ('The Impact of a Strong Bank-Firm Relationship on the Borrowing Firm', 1),
#  ('Lending Relationships and Loan Contract Terms', 1),
#  ('Staying, Dropping, or Switching: The Impacts of Bank Mergers on Small Firms',
#   1),
#  ('The Effect of Bank Mergers on Loan Prices: Evidence from the United States',
#   1),
#  ('Bank Capital and Value in the Cross-Section', 1),
#  ('Credit Market Competition and Capital Regulation', 1),
#  ('The Value of Bank Capital and the Structure of the Banking Industry', 1),
#  ("The Impact of Hedge Fund Activism on the Target Firm's Existing Bondholders",
#   1),
#  ('Hedge Funds: Pricing Controls and the Smoothing of Self-reported Returns',
#   1),
#  ('Participation Constraints in the Stock Market: Evidence from Unexpected Inheritance Due to Sudden Death',
#   1),
#  ('Why Do (Some) Households Trade So Much?', 1),
#  ('Liquidity Biases and the Pricing of Cross-sectional Idiosyncratic Volatility',
#   1),
#  ('Do Investors Learn from Experience? Evidence from Frequent IPO Investors',
#   1),
#  ('Do Behavioral Biases Adversely Affect the Macro-economy?', 1),
#  ("All the News That's Fit to Reprint: Do Investors React to Stale Information?",
#   1),
#  ('Informed and Uninformed Investment in Housing: The Downside of Diversification',
#   1),
#  ('Stochastic House Appreciation and Optimal Mortgage Lending', 1),
#  ('Crisis Resolution and Bank Liquidity', 1),
#  ('Bank Risk-taking, Securitization, Supervision, and Low Interest Rates: Evidence from the Euro-area and the U.S. Lending Standards',
#   1),
#  ('Competition, Risk-shifting, and Public Bail-out Policies', 1),
#  ('Effects of Central Bank Intervention on the Interbank Market During the Subprime Crisis',
#   1),
#  ('The Composition Matters: Capital Inflows and Liquidity Crunch During a Global Economic Crisis',
#   1),
#  ('Margin-based Asset Pricing and Deviations from the Law of One Price', 1),
#  ('Liquidity Management and Corporate Investment During a Financial Crisis',
#   1),
#  ('Bank Corporate Loan Pricing Following the Subprime Crisis', 1),
#  ('Originate-to-distribute Model and the Subprime Mortgage Crisis', 1),
#  ('Understanding the Subprime Mortgage Crisis', 1),
#  ('Securitization and Mortgage Renegotiation: Evidence from the Great Depression',
#   1),
#  ("The Influence of the Home Owners' Loan Corporation on Housing Markets During the 1930s",
#   1),
#  ('The Academic Analysis of the 2008 Financial Crisis: Round 1', 1),
#  ('Privatization and Risk Sharing: Evidence from the Split Share Structure Reform in China',
#   1),
#  ('The Private Equity Advantage: Leveraged Buyout Firms and Relationship Banking',
#   1),
#  ('Short Arbitrage, Return Asymmetry, and the Accrual Anomaly', 1),
#  ('Governance Through Trading and Intervention: A Theory of Multiple Blockholders',
#   1),
#  ('Corporate Governance Propagation through Overlapping Directors', 1),
#  ('Implications of Data Screens on Merger and Acquisition Analysis: A Large Sample Study of Mergers and Acquisitions from 1992 to 2009',
#   1),
#  ('Do Investment Banks Matter for M&A Returns?', 1),
#  ('Anticipation, Acquisitions, and Bidder Returns: Industry Shocks and the Transfer of Information across Rivals',
#   1),
#  ('Mergers, Spinoffs, and Employee Incentives', 1),
#  ('The Effect of Risk on the CEO Market', 1),
#  ('Growing Out of Trouble? Corporate Responses to Liability Risk', 1),
#  ('Learning and Asset-price Jumps', 1),
#  ('Does Government Ownership Affect the Cost of Debt? Evidence from Privatization',
#   1),
#  ('Bank Liquidity, Interbank Markets, and Monetary Policy', 1),
#  ('Credit Default Swaps and the Empty Creditor Problem', 1),
#  ('Risk Shifting and Mutual Fund Performance', 1),
#  ('What Factors Drive Global Stock Returns?', 1),
#  ('Erratum', 1),
#  ('Recourse and Residential Mortgage Default: Evidence from US States 1', 1),
#  ('Can VCs Time the Market? An Analysis of Exit Choice for Venture-backed Firms',
#   1),
#  ('Information Sales and Strategic Trading', 1),
#  ('Learning from Prices and the Dispersion in Beliefs', 1),
#  ('The Good or the Bad? Which Mutual Fund Managers Join Hedge Funds?', 1),
#  ('Financial Constraints, R&D Investment, and Stock Returns', 1),
#  ('Dividend Policies in an Unregulated Market: The London Stock Exchange, 1895--1905',
#   1),
#  ('Information in (and not in) the Term Structure', 1),
#  ('Tractability in Incentive Contracting', 1),
#  ('Former CEO Directors: Lingering CEOs or Valuable Resources?', 1),
#  ('Managerial Autonomy, Allocation of Control Rights, and Optimal Capital Structure',
#   1),
#  ('Optimal Property Rights in Financial Contracting', 1),
#  ('A Theory of Debt Market Illiquidity and Leverage Cyclicality', 1),
#  ('The Economics of Super Managers', 1),
#  ('Do Hedge Funds Manage Their Reported Returns?', 1),
#  ("The Bear's Lair: Index Credit Default Swaps and the Subprime Mortgage Crisis",
#   1),
#  ('Determinants of Dividend Smoothing: Empirical Evidence', 1),
#  ("Investor Reactions to CEOs' Inside Debt Incentives", 1),
#  ('A Model of Portfolio Delegation and Strategic Trading', 1),
#  ('Common Risk Factors in Currency Markets', 1),
#  ('Conglomerates and Industry Distress', 1),
#  ('Large Shareholder Diversification and Corporate Risk-Taking', 1),
#  ('Family Business Groups around the World: Financing Advantages, Control Motivations, and Organizational Choices',
#   1),
#  ('Self-fulfilling Credit Market Freezes', 1),
#  ('Bond Ladders and Optimal Portfolios', 1),
#  ('The Costs of Being Private: Evidence from the Loan Market', 1),
#  ('How Does Venture Capital Financing Improve Efficiency in Private Firms? A Look Beneath the Surface',
#   1),
#  ('Real Options Signaling Games with Applications to Corporate Finance', 1),
#  ('How Important Is the Financial Media in Global Markets?', 1),
#  ('The Inventory Growth Spread', 1),
#  ('Takeovers and Divergence of Investor Opinion', 1),
#  ('Corporate Governance Objectives of Labor Union Shareholders: Evidence from Proxy Voting',
#   1),
#  ('Managerial Attributes and Executive Compensation', 1),
#  ('The Road Less Traveled: Strategy Distinctiveness and Hedge Fund Performance',
#   1),
#  ('Level 3 Assets: Booking Profits and Concealing Losses', 1),
#  ('Hedge Fund Stock Trading in the Financial Crisis of 2007--2009', 1),
#  ('Commodity Liquidity Measurement and Transaction Costs', 1),
#  ('Performance of Institutional Trading Desks: An Analysis of Persistence in Trading Costs',
#   1),
#  ('Optimal Corporate Governance and Compensation in a Dynamic World', 1),
#  ('Jumps and Information Flow in Financial Markets', 1),
#  ('Do Country-level Investor Protections Affect Security-level Contract Design? Evidence from Foreign Bond Covenants',
#   1),
#  ('Assessing TARP', 1),
#  ('Macroeconomic Conditions and Capital Raising', 1),
#  ('Are Corporate Default Probabilities Consistent with the Static Trade-off Theory?',
#   1),
#  ('Tournament Behavior in Hedge Funds: High-water Marks, Fund Liquidation, and Managerial Stake',
#   1),
#  ('Mutual Fund Tournaments: The Sorting Bias and New Evidence', 1),
#  ('Financing Constraints and the Cost of Capital: Evidence from the Funding of Corporate Pension Plans',
#   1),
#  ('Trade Credit Contracts', 1),
#  ('Corporate Liquidity and Capital Structure', 1),
#  ('Optimal Priority Structure, Capital Structure, and Investment', 1),
#  ('Corporate Dividend Policies: Lessons from Private Firms', 1),
#  ('Snow and Leverage', 1),
#  ('Journalists and the Stock Market', 1),
#  ("Treating Measurement Error in Tobin's q", 1),
#  ('Finding a Good Price in Opaque Over-the-Counter Markets', 1),
#  ('Bond Liquidity Premia', 1),
#  ('Precarious Politics and Return Volatility', 1),
#  ('The Hazards of Debt: Rollover Freezes, Incentives, and Bailouts', 1),
#  ('Financial Leverage, Corporate Investment, and Stock Returns', 1),
#  ('Is Unbiased Financial Advice to Retail Investors Sufficient? Answers from a Large Field Study',
#   1),
#  ('Skewness in Stock Returns: Reconciling the Evidence on Firm Versus Aggregate Returns',
#   1),
#  ('Inflation Expectations, Real Rates, and Risk Premia: Evidence from Inflation Swaps',
#   1),
#  ('Why Does Financial Strength Forecast Stock Returns? Evidence from Subsequent Demand by Institutional Investors',
#   1),
#  ('Dynamic Compensation Contracts with Private Savings', 1),
#  ('Flow Toxicity and Liquidity in a High-frequency World', 1),
#  ('Lack of Anonymity and the Inference from Order Flow', 1),
#  ('Testing Asymmetric-Information Asset Pricing Models', 1),
#  ('Liquidity and Asset Returns Under Asymmetric Information and Imperfect Competition',
#   1),
#  ('Reviewing Less--Progressing More', 1),
#  ('Executive Compensation and the Role for Corporate Governance Regulation',
#   1),
#  ('Fiduciary Duties and Equity-debtholder Conflicts', 1),
#  ('Debt Financing and Financial Flexibility Evidence from Proactive Leverage Increases',
#   1),
#  ('Dynamic Hedging in Incomplete Markets: A Simple Solution', 1),
#  ('Dynamic Debt Runs', 1),
#  ('A Reexamination of Tunneling and Business Groups: New Data and New Methods',
#   1),
#  ('Creditor Control Rights, Corporate Governance, and Firm Value', 1),
#  ('The Life Cycle of Family Ownership: International Evidence', 1),
#  ('Agency Problems and Endogenous Investment Fluctuations', 1),
#  ('Strategic Ownership Structure and the Cost of Debt', 1),
#  ('Generalized Transform Analysis of Affine Processes and Applications in Finance',
#   1),
#  ('Rare Disasters and Risk Sharing with Heterogeneous Beliefs', 1),
#  ('Examining the Dark Side of Financial Markets: Do Institutions Trade on Information from Investment Bank Connections?',
#   1),
#  ('Asymmetric Information, Portfolio Managers, and Home Bias', 1),
#  ('Lender Screening and the Role of Securitization: Evidence from Prime and Subprime Mortgage Markets',
#   1),
#  ('The Real Consequences of Market Segmentation', 1),
#  ('Evaporating Liquidity', 1),
#  ('How Do Retirees Value Life Annuities? Evidence from Public Employees', 1),
#  ('No Place Like Home: Familiarity in Mutual Fund Manager Portfolio Choice',
#   1),
#  ('Educational Networks, Mutual Fund Voting Patterns, and CEO Compensation',
#   1),
#  ('Are Investors Really Reluctant to Realize Their Losses? Trading Responses to Past Returns and the Disposition Effect',
#   1),
#  ('Securitization, Transparency, and Liquidity', 1),
#  ('Loan Prospecting', 1),
#  ('Bank Bailouts and Moral Hazard: Evidence from Germany', 1),
#  ('Identifying Expectation Errors in Value/Glamour Strategies: A Fundamental Analysis Approach',
#   1),
#  ('Does Beta Move with News? Firm-Specific Information Flows and Learning about Profitability',
#   1),
#  ('Does Idiosyncratic Volatility Proxy for Risk Exposure?', 1),
#  ('Universal Banks and Corporate Control: Evidence from the Global Syndicated Loan Market',
#   1),
#  ('Suspicious Patterns in Hedge Fund Returns and the Risk of Fraud', 1),
#  ('Fiscal Policies and Asset Prices', 1),
# ...
#  ('Optimal Portfolio Choice with Predictability in House Prices and Transaction Costs',
#   1),
#  ('Expected Returns and Dividend Growth Rates Implied by Derivative Markets',
#   1),
#  ('Do Dark Pools Harm Price Discovery?', 1),
#  ('Expectations of Returns and Expected Returns', 1),
#  ('Bond Supply and Excess Bond Returns', 1),
#  ('The Growth and Limits of Arbitrage: Evidence from Short Interest', 1),
#  ('Opaque Trading, Disclosure, and Asset Prices: Implications for Hedge Fund Regulation',
#   1),
#  ('Resource Allocation within Firms and Financial Market Dislocation: Evidence from Diversified Conglomerates',
#   1),
#  ('Internal Capital Market and Dividend Policies: Evidence From Business Groups',
#   1),
#  ('Financial Flexibility, Risk Management, and Payout Choice', 1),
#  ('Stock Return Serial Dependence and Out-of-Sample Portfolio Performance', 1),
#  ('Limited and Varying Consumer Attention: Evidence from Shocks to the Salience of Bank Overdraft Fees',
#   1),
#  ('Repo Runs', 1),
#  ('The Year-End Trading Activities of Institutional Investors: Evidence from Daily Trades',
#   1),
#  ('Board Expertise: Do Directors from Related Industries Help Bridge the Information Gap?',
#   1),
#  ('Communication and Decision-Making in Corporate Boards', 1),
#  ('Liquidity Shocks and Stock Market Reactions', 1),
#  ('Investor Networks in the Stock Market', 1),
#  ('Do Security Analysts Speak in Two Tongues?', 1),
#  ('Financial Market Dislocations', 1),
#  ('Heterogeneity and Stability: Bolster the Strong, Not the Weak', 1),
#  ('Attracting Investor Attention through Advertising', 1),
#  ('Co-opted Boards', 1),
#  ('Frictions in Shadow Banking: Evidence from the Lending Behavior of Money Market Mutual Funds',
#   1),
#  ("Investors' and Central Bank's Uncertainty Embedded in Index Options", 1),
#  ('Illiquidity Contagion and Liquidity Crashes', 1),
#  ('The Variety of Maturities Offered by Firms and Institutional Investment in Corporate Bonds',
#   1),
#  ('Frog in the Pan: Continuous Information and Momentum', 1),
#  ('Misspecification-Robust Inference in Linear Asset-Pricing Models with Irrelevant Risk Factors',
#   1),
#  ('Microprudential Regulation in a Dynamic Model of Banking', 1),
#  ('Risk Choice under High-Water Marks', 1),
#  ('Smart Money? The Effect of Education on Financial Outcomes', 1),
#  ('Valuing Private Equity', 1),
#  ('Do Going-Private Transactions Affect Plant Efficiency and Investment?', 1),
#  ('Prior Client Performance and the Choice of Investment Bank Advisors in Corporate Acquisitions',
#   1),
#  ('Corporate Venture Capital, Value Creation, and Innovation', 1),
#  ('Does Stock Liquidity Affect Incentives to Monitor? Evidence from Corporate Takeovers',
#   1),
#  ('Do Lenders Still Monitor When They Can Securitize Loans?', 1),
#  ('The Swaption Cube', 1),
#  ('High-Frequency Trading and Price Discovery', 1),
#  ("In Harm's Way? Payday Loan Access and Military Personnel Performance", 1),
#  ('Referee Recommendations', 1),
#  ('Real Estate Prices and Firm Capital Structure', 1),
#  ('Repossession and the Democratization of Credit', 1),
#  ('Nationalism and Economic Exchange: Evidence from Shocks to Sino-Japanese Relations',
#   1),
#  ('The Ownership of Japanese Corporations in the 20th Century', 1),
#  ("Editor's Choice The Labor Market for Bankers and Regulators", 1),
#  ('Ambiguity Aversion and Asset Prices in Production Economies', 1),
#  ('Learning from Stock Prices and Economic Growth', 1),
#  ('Collateral-Motivated Financial Innovation', 1),
#  ('Does the Tail Wag the Dog?: The Effect of Credit Default Swaps on Credit Risk',
#   1),
#  ('Complex Securities and Underwriter Reputation: Do Reputable Underwriters Produce Better Securities?',
#   1),
#  ("Editor's Choice Tail Risk and Asset Prices", 1),
#  ('Mutual Funds and Information Diffusion: The Role of Country-Level Governance',
#   1),
#  ('Debtholder Responses to Shareholder Activism: Evidence from Hedge Fund Interventions',
#   1),
#  ('Asset Prices and Real Exchange Rates with Deep Habits', 1),
#  ('Aggregate Investment and Investor Sentiment', 1),
#  ('Peer Effects in Risk Aversion and Trust', 1),
#  ('Trading for Status', 1),
#  ('Window Dressing in Mutual Funds', 1),
#  ("Editor's Choice Fooling Some of the People All of the Time: The Inefficient Performance and Persistence of Commodity Trading Advisors",
#   1),
#  ('Money Left on the Table: An Analysis of Participation in Employee Stock Purchase Plans',
#   1),
#  ('Cash-Flow Sensitivities and the Allocation of Internal Cash Flow', 1),
#  ('What Happens in Nevada? Self-Selecting into Lax Law', 1),
#  ('Strategic Complementarity, Fragility, and Regulation', 1),
#  ('Media Makes Momentum', 1),
#  ("Does Media Coverage of Stocks Affect Mutual Funds' Trading and Performance?",
#   1),
#  ("Editor's Choice No News Is News: Do Markets Underreact to Nothing?", 1),
#  ('Regression Discontinuity and the Price Effects of Stock Market Indexing',
#   1),
#  ('Securitization and the Fixed-Rate Mortgage', 1),
#  ('Shadow Banking and Bank Capital Regulation', 1),
#  ('The Implicit Costs of Trade Credit Borrowing by Large Firms', 1),
#  ('Weather-Induced Mood, Institutional Investors, and Stock Returns', 1),
#  ('Investor Attention and Stock Market Volatility', 1),
#  ("Editor's Choice The Sum of All FEARS Investor Sentiment and Asset Prices",
#   1),
#  ('Agency Problems of Corporate Philanthropy', 1),
#  ('Labor Protection and Leverage', 1),
#  ('Ownership Structure, Voting, and Risk', 1),
#  ('Liquidity and Shareholder Activism', 1),
#  ('Are Mutual Funds Active Voters?', 1),
#  ('Capital Supply Uncertainty, Cash Holdings, and Investment', 1),
#  ('Corporate Investment and Stock Market Listing: A Puzzle?', 1),
#  ('Can Housing Risk Be Diversified? A Cautionary Tale from the Housing Boom and Bust',
#   1),
#  ('Self-Exciting Jumps, Learning, and Asset Pricing Implications', 1),
#  ('Cognitive Limitation and Investment Performance: Evidence from Limit Order Clustering',
#   1),
#  ('Investor Sentiment Aligned: A Powerful Predictor of Stock Returns', 1),
#  ('Investor Information, Long-Run Risk, and the Term Structure of Equity', 1),
#  ("Editor's Choice Digesting Anomalies: An Investment Approach", 1),
#  ("Editor's Choice Editorial: Cosmetic Surgery in the Academic Review Process",
#   1),
#  ('Post-Earnings-Announcement Drift in Global Markets: Evidence from an Information Shock',
#   1),
#  ('Predictable Corporate Distributions and Stock Returns', 1),
#  ('The Geography of Funding Markets and Limits to Arbitrage', 1),
#  ('The Costs of Closing Failed Banks: A Structural Estimation of Regulatory Incentives',
#   1),
#  ('The Worst, the Best, Ignoring All the Rest: The Rank Effect and Trading Behavior',
#   1),
#  ('Money Creation and the Shadow Banking System', 1),
#  ('Robust Econometric Inference for Stock Return Predictability', 1),
#  ('Monotonicity of the Stochastic Discount Factor and Expected Option Returns',
#   1),
#  ("Modeling Covariance Risk in Merton's ICAPM", 1),
#  ('The Informational Role of Stock and Bond Volume', 1),
#  ('Dynamics of Innovation and Risk', 1),
#  ("Editor's Choice New Evidence on the Financialization of Commodity Markets",
#   1),
#  ('Financial Distress, Stock Returns, and the 1978 Bankruptcy Reform Act', 1),
#  ('Does Financing Spur Small Business Productivity? Evidence from a Natural Experiment',
#   1),
#  ('The Real Effects of Short-Selling Constraints', 1),
#  ('The Invisible Hand of Short Selling: Does Short Selling Discipline Earnings Management?',
#   1),
#  ('When Less Is More: The Benefits of Limits on Executive Pay', 1),
#  ('Learning About CEO Ability and Stock Return Volatility', 1),
#  ('Does Takeover Activity Cause Managerial Discipline? Evidence from International M&A Laws',
#   1),
#  ("Editor's Choice Capital Account Opening and Wage Inequality", 1),
#  ('Do Individual Investors Treat Trading as a Fun and Exciting Gambling Activity? Evidence from Repeated Natural Experiments',
#   1),
#  ('Competition for Order Flow with Fast and Slow Traders', 1),
#  ('Rumor Has It: Sensationalism in Financial Media', 1),
#  ('Home away from Home: Geography of Information and Local Investors', 1),
#  ('Modeling Credit Contagion via the Updating of Fragile Beliefs', 1),
#  ('Differences of Opinion, Endogenous Liquidity, and Asset Prices', 1),
#  ('Learning About Unstable, Publicly Unobservable Payoffs', 1),
#  ("Editor's Choice Confusion of Confusions: A Test of the Disposition Effect and Momentum",
#   1),
#  ('Testing for Information Asymmetries in Real Estate Markets', 1),
#  ('Can "High Costs" Justify Weak Demand for the Home Equity Conversion Mortgage?',
#   1),
#  ('Information Management in Banking Crises', 1),
#  ('Territorial Tax System Reform and Corporate Financial Policies', 1),
#  ('The Bright Side of Corporate Diversification: Evidence from Internal Labor Markets',
#   1),
#  ("Editor's Choice Shareholder Voting and Corporate Governance Around the World",
#   1),
#  ('Optimal Tax Timing with Asymmetric Long-Term/Short-Term Capital Gains Tax',
#   1),
#  ('Why Are University Endowments Large and Risky?', 1),
#  ('On Bounding Credit-Event Risk Premia', 1),
#  ('Valuation, Adverse Selection, and Market Collapses', 1),
#  ('A Theory of Income Smoothing When Insiders Know More Than Outsiders', 1),
#  ('Capital Structure, Investment, and Fire Sales', 1),
#  ("Editor's Choice Financing Constraints and the Amplification of Aggregate Downturns",
#   1),
#  ('Dynamic Thin Markets', 1),
#  ('Exploring Return Dynamics via Corridor Implied Volatility', 1),
#  ('Expected Returns in Treasury Bonds', 1),
#  ('Restraining Overconfident CEOs through Improved Governance: Evidence from the Sarbanes-Oxley Act',
#   1),
#  ('Board Structure and Monitoring: New Evidence from CEO Turnovers', 1),
#  ("Editor's Choice The Real Effects of Hedge Fund Activism: Productivity, Asset Allocation, and Labor Outcomes",
#   1),
#  ('Valuing Changes in Political Networks: Evidence from Campaign Contributions to Close Congressional Elections',
#   1),
#  ('Information, Analysts, and Stock Return Comovement', 1),
#  ("Thinking Outside the Borders: Investors' Underreaction to Foreign Operations Information",
#   1),
#  ('Understanding FX Liquidity', 1),
#  ('How Important Are Foreign Ownership Linkages for International Stock Returns?',
#   1),
#  ("Editor's Choice The Sovereign Wealth Fund Discount: Evidence from Public Equity Investments",
#   1),
#  ("Playing the Devil's Advocate: The Causal Effect of Risk Management on Loan Quality",
#   1),
#  ('CEO Assessment and the Structure of Newly Formed Boards', 1),
#  ('Synthetic or Real? The Equilibrium Effects of Credit Default Swaps on Bond Markets',
#   1),
#  ('Risk and Expected Returns of Private Equity Investments: Evidence Based on Market Prices',
#   1),
#  ('Durable Goods, Inflation Risk, and Equilibrium Asset Prices', 1),
#  ('Wage Rigidity: A Quantitative Solution to Several Asset Pricing Puzzles',
#   1),
#  ('A Taxonomy of Anomalies and Their Trading Costs', 1),
#  ("Editor's Choice … and the Cross-Section of Expected Returns", 1),
#  ('The Cross-Section of Expected Returns: Where We Stand Today', 1),
#  ('Misinformed Speculators and Mispricing in the Housing Market', 1),
#  ('Does the Market Understand Rating Shopping? Predicting MBS Losses with Initial Yields',
#   1),
#  ('Who Should Pay for Credit Ratings and How?', 1),
#  ("Editor's Choice Who Facilitated Misreporting in Securitized Loans?", 1),
#  ('Enlarging the Contracting Space: Collateral Menus, Access to Credit, and Economic Activity',
#   1),
#  ('Do U.S. Firms Hold More Cash than Foreign Firms Do?', 1),
#  ('Do Measures of Financial Constraints Measure Financial Constraints?', 1),
#  ('Asset Pricing When Traders Sell Extreme Winners and Losers', 1),
#  ('Disclosure Standards and the Sensitivity of Returns to Mood', 1),
#  ('The Fetal Origins Hypothesis in Finance: Prenatal Environment, the Gender Gap, and Investor Behavior',
#   1),
#  ('Dividends as Reference Points: A Behavioral Signaling Approach', 1),
#  ('Reputation Concerns of Independent Directors: Evidence from Individual Director Voting',
#   1),
#  ('Equity Market Misvaluation, Financing, and Investment', 1),
#  ("Looking in the Rearview Mirror: The Effect of Managers' Professional Experience on Corporate Financial Policy",
#   1),
#  ("Editor's Choice Policy Uncertainty and Corporate Investment", 1),
#  ('Estimating Security Betas Using Prior Information Based on Firm Fundamentals',
#   1),
#  ('The Corporate Value of (Corrupt) Lobbying', 1),
#  ('Does it Pay to Invest in Art? A Selection-Corrected Returns Perspective',
#   1),
#  ('How Family Status and Social Security Claiming Options Shape Optimal Life Cycle Portfolios',
#   1),
#  ('Whom Do You Trust?: Investor-Advisor Relationships and Mutual Fund Flows',
#   1),
#  ("Editor's Choice Financial Attention", 1),
#  ('Robust Bayesian Portfolio Choices', 1),
#  ('Information Spillovers, Gains from Trade, and Interventions in Frozen Markets',
#   1),
#  ('Secondary Market Liquidity and Security Design: Theory and Evidence from ABS Markets',
#   1),
#  ('Mortgage Risk and the Yield Curve', 1),
#  ('Measuring Liquidity in Bond Markets', 1),
#  ("Editor's Choice Rare Booms and Disasters in a Multisector Endowment Economy",
#   1),
#  ('Executive Compensation Incentives Contingent on Long-Term Accounting Performance',
#   1),
#  ('Out-of-the-Money CEOs: Private Control Premium and Option Exercises', 1),
#  ('Production Flexibility, Product Markets, and Capital Structure Decisions',
#   1),
#  ('Collateral, Taxes, and Leverage', 1),
#  ('Buying High and Selling Low: Stock Repurchases and Persistent Asymmetric Information',
#   1),
#  ("Editor's Choice The Effect of Institutional Ownership on Payout Policy: Evidence from Index Thresholds",
#   1),
#  ('Competition and Bank Opacity', 1),
#  ('Interbank Market Freezes and Creditor Runs', 1),
#  ("Why Don't All Banks Practice Regulatory Arbitrage? Evidence from Usage of Trust-Preferred Securities",
#   1),
#  ('The Shadow Cost of Bank Capital Requirements', 1),
#  ('The Euro Interbank Repo Market', 1),
#  ('Bank Ratings and Lending Supply: Evidence from Sovereign Downgrades', 1),
#  ('Did Dubious Mortgage Origination Practices Distort House Prices?', 1),
#  ("Editor's Choice Loan Originations and Defaults in the Mortgage Crisis: The Role of the Middle Class",
#   1),
#  ('Horizon Effects in Average Returns: The Role of Slow Information Diffusion',
#   1),
#  ('Can Changes in the Cost of Carry Explain the Dynamics of Corporate "Cash" Holdings?',
#   1),
#  ('Currency Premia and Global Imbalances', 1),
#  ('Commodities as Collateral', 1),
#  ('Skewness in Expected Macro Fundamentals and the Predictability of Equity Returns: Evidence and Theory',
#   1),
#  ('Asset Pricing in the Frequency Domain: Theory and Empirics', 1),
#  ('How Constraining Are Limits to Arbitrage?', 1),
#  ("Editor's Choice Commonality in Liquidity: A Demand-Side Explanation", 1),
#  ('The Human Capital That Matters: Expected Returns and High-Income Households',
#   1),
#  ('Financial Education and the Debt Behavior of the Young', 1),
#  ('Private Equity and Workersâ€™ Career Paths: The Role of Technological Change',
#   1),
#  ('Posturing and Holdup in Innovation', 1),
#  ('The Operational Consequences of Private Equity Buyouts: Evidence from the Restaurant Industry',
#   1),
#  ('Financing from Family and Friends', 1),
#  ('Experimentation and the Returns to Entrepreneurship', 1),
#  ("Editor's Choice The Importance of Trust for Investment: Evidence from Venture Capital",
#   1),
#  ('The Effect of Negative Equity on Mortgage Default: Evidence From HAMPâ€™s Principal Reduction Alternative',
#   1),
#  ('Insolvency Resolution and the Missing High-Yield Bond Markets', 1),
#  ('Do Debt Contract Enforcement Costs Affect Financing and Asset Structure?',
#   1),
#  ('Does Credit Crunch Investment Down? New Evidence on the Real Effects of the Bank-Lending Channel',
#   1),
#  ('Dynamic Debt Maturity', 1),
#  ('Relationship and Transaction Lending in a Crisis', 1),
#  ('Which Factors Matter to Investors? Evidence from Mutual Fund Flows', 1),
#  ('Seeking Alpha: Excess Risk Taking and Competition for Managerial Talent',
#   1),
#  ('Peer Pressure: Social Interaction and the Disposition Effect', 1),
#  ('Loss-Averse Preferences, Performance, and Career Success of Institutional Investors',
#   1),
#  ('Neural Evidence of Regret and Its Implications for Investor Behavior', 1),
#  ...]

# %%
# collaboration freq
id_pair = {}
name_pair = {}

for doi in df_af_art.index:
    try:
        df_af_art.loc[doi][0]
    except:
        df_af_art_new = df_af_art.loc[doi].sort_values("affiliationid")
        length = len(df_af_art_new)
        for i in range(length-1):
            for j in range(length-1-i):
                try:
                    id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] += 1
                    name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] += 1
                except:
                    id_pair[df_af_art_new["affiliationid"][i]+"+"+df_af_art_new["affiliationid"][i+j+1]] = 1
                    name_pair[df_af_art_new["name"][i]+"+"+df_af_art_new["name"][i+j+1]] = 1

# %%
name_pair_sorted = sorted(name_pair.items(), key=lambda x:x[1], reverse = True)
name_pair_sorted

# %%
conn.close()
