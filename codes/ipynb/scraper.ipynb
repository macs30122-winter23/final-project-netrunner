# %% [markdown]
# # A Scraper for Top Econ Journal Ariticles

# %%
import pandas as pd
import bs4
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
import random
import csv
import winsound

# %% [markdown]
# ## 1. The Review of Financial Studies

# %%
# set selenium service
chromedrive_path = "D:\chromedriver.exe"
s = Service(chromedrive_path)
# open driver
driver = webdriver.Chrome(service=s)

# %%
# for pages
base_url = "https://econpapers.repec.org/article/ouprfinst/default"
pages = [".htm"]
for i in range(25):
    pages.append(str(i+1)+".htm")

# set attrs
attrs = ["journal","title","authors","volume","jel","abstract","url","doi"]
dict = {}
for attr in attrs:
    dict[attr] = []

# prefix for article link
prefix = "https://econpapers.repec.org/article/ouprfinst/"

for p, page in enumerate(pages):
    print("Start: Page", p+1)
    driver.get(base_url+page)
    driver.refresh()
    # load into soup
    soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
    links = [prefix+dttag.a.get("href") for dttag in soup.find_all("dt") if dttag.a != None]
    for i, link in enumerate(links):
        # load page
        driver.get(link)
        driver.refresh()
        # load into soup
        soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
        # get url
        url = link
        # get title
        title = soup.find("h1").text
        if soup.find("h2") != None:
            h = soup.find("h2") 
        else:
            h = soup.find("h1")
        # get authors
        authorstag = h.next_sibling.next_sibling
        authors = [itag.text for itag in authorstag.find_all("i")]
        # get journal and volume
        publishtag = authorstag.next_sibling
        publish_text = publishtag.text.strip().split(", ")
        journal = publish_text[0]
        volume = ", ".join(publish_text[1:])
        # get abstract
        abstracttag = publishtag.next_sibling
        abstract = abstracttag.text.replace("\n"," ").strip()
        # get jel
        jel = [atag.text for atag in abstracttag.next_sibling.find_all("a") if "/scripts/search.pf?jel=" in atag.get("href")]
        # get doi
        doi = abstracttag.next_sibling.next_sibling.a.text.replace("http://hdl.handle.net/","")
        # append to dict
        dict["journal"].append(journal)
        dict["title"].append(title)
        dict["authors"].append(authors)
        dict["volume"].append(volume)
        dict["abstract"].append(abstract)
        dict["jel"].append(jel)
        dict["url"].append(url)
        dict["doi"].append(doi)
        
        print("Finished:", i+1)

# %%
df = pd.DataFrame(dict)
df.head()
# Out:
#                        journal  \
# 0  Review of Financial Studies
# 1  Review of Financial Studies
# 2  Review of Financial Studies
# 3  Review of Financial Studies
# 4  Review of Financial Studies
#
#                                                title  \
# 0                      New Perspectives on Insurance
# 1                      Trust and Insurance Contracts
# 2  Conflicting Interests and the Effect of Fiduci...
# 3  Can Risk Be Shared across Investor Cohorts? Ev...
# 4  Regulatory Forbearance in the U.S. Insurance I...
#
#                                              authors  \
# 0                  [Ralph S J Koijen, Motohiro Yogo]
# 1  [Nicola Gennaioli, Rafael La Porta, Florencio ...
# 2                  [Mark Egan, Shan Ge, Johnny Tang]
# 3                    [Johan Hombert, Victor Lyonnet]
# 4            [Bo Becker, Marcus M Opp, Farzad Saidi]
#
#                                volume                        jel  \
# 0  2022, vol. 35, issue 12, 5275-5286       [G22, G52, I13, J65]
# 1  2022, vol. 35, issue 12, 5287-5333       [D23, G22, L14, Z13]
# 2  2022, vol. 35, issue 12, 5334-5386  [D14, D18, G22, G24, G28]
# 3  2022, vol. 35, issue 12, 5387-5437                 [G22, G52]
# 4  2022, vol. 35, issue 12, 5438-5482       [G20, G22, G23, G28]
#
#                                             abstract  \
# 0  Abstract: This special issue originates from a...
# 1  Abstract: We assemble homeowner insurance clai...
# 2  Abstract: We examine the variable annuity mark...
# 3  Abstract: We study how retail savings products...
# 4  Abstract: We analyze the effects of a reform o...
#
#                                                  url                  doi
# 0  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhac063
# 1  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhab112
# 2  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhac047
# 3  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhac054
# 4  https://econpapers.repec.org/article/ouprfinst...  10.1093/rfs/hhab102

# %%
df.to_csv("data/journals/rfs.csv", index = False, encoding = "utf-8-sig")

# %%
# define function to scrape
def scrape_articles(journalabbr, page_num, output_filename):
    # for pages
    base_url = "https://econpapers.repec.org/article/"+journalabbr+"/default"
    pages = [".htm"]
    for i in range(page_num):
        pages.append(str(i+1)+".htm")

    # set attrs
    attrs = ["journal","title","authors","volume","jel","abstract","url","doi"]
    dict = {}
    for attr in attrs:
        dict[attr] = []

    # prefix for article link
    prefix = "https://econpapers.repec.org/article/"+journalabbr+"/"

    for p, page in enumerate(pages):
        driver.get(base_url+page)
        driver.refresh()
        # load into soup
        soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
        links = [prefix+dttag.a.get("href") for dttag in soup.find_all("dt") if dttag.a != None]
        for i, link in enumerate(links):
            # load page
            driver.get(link)
            driver.refresh()
            # load into soup
            soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
            # get url
            url = link
            # get title
            title = soup.find("h1").text
            if soup.find("h2") != None:
                h = soup.find("h2") 
            else:
                h = soup.find("h1")
            # get authors
            authorstag = h.next_sibling.next_sibling
            authors = [itag.text for itag in authorstag.find_all("i")]
            # get journal and volume
            publishtag = authorstag.next_sibling
            publish_text = publishtag.text.strip().split(", ")
            journal = publish_text[0]
            volume = ", ".join(publish_text[1:])
            # get abstract
            abstracttag = publishtag.next_sibling
            abstract = abstracttag.text.replace("\n"," ").strip()
            if 'type="main">' in abstract:
                abstracttag = abstracttag.next_sibling
                abstract = "Abstract: "+abstracttag.text.replace("\n"," ").strip()
            # get jel
            jel = [atag.text for atag in abstracttag.next_sibling.find_all("a") if "/scripts/search.pf?jel=" in atag.get("href")]
            # get doi
            if "Abstract" in abstract:
                doi = abstracttag.next_sibling.next_sibling.a.text.replace("http://hdl.handle.net/","")
            else:
                doi = abstracttag.next_sibling.a.text.replace("http://hdl.handle.net/","")
            if "issue-" in doi[-8:]:
                doi = ""
            # append to dict
            dict["journal"].append(journal)
            dict["title"].append(title)
            dict["authors"].append(authors)
            dict["volume"].append(volume)
            dict["abstract"].append(abstract)
            dict["jel"].append(jel)
            dict["url"].append(url)
            dict["doi"].append(doi)
            
            print("Finished: Page ", p+1, "-",i+1,doi)

    # save to csv
    df = pd.DataFrame(dict)
    df.to_csv(output_filename, index = False, encoding = "utf-8-sig")

# %%
t = "casdca.issue-17"
t[-8:]
# Out:
# 'issue-17'

# %% [markdown]
# ## 2. The Quarterly Journal of Economics

# %%
scrape_articles("oupqjecon",75,"data/journals/qje.csv")

# %% [markdown]
# ## 3. Journal of Political Economy

# %%
scrape_articles("ucpjpolec", 82, "data/journals/jpe.csv")

# %% [markdown]
# ## 4. Journal of Finance

# %%
scrape_articles("blajfinan", 68, "data/journals/jf.csv")

# %% [markdown]
# ## 5. The Review of Economic Studies

# %%
scrape_articles("ouprestud", 52, "data/journals/res.csv")

# %% [markdown]
# ## 6. Econometrica

# %%
scrape_articles("wlyemetrp", 8, "data/journals/e.csv")

# %%
df_old = pd.read_csv("data/journals/e.csv", encoding="utf-8-sig")
df_old.head()

# %%
df_new = scrape_articles("ecmemetrp",43,"x")

# %% [markdown]
# # Scrape author_article linkage and author google scholar htmls (save to local)

# %%
# set selenium service and open driver
chromedrive_path = "D:/chromedriver.exe"
s = Service(chromedrive_path)
driver = webdriver.Chrome(service = s)

# %%
df = pd.read_csv("data/journals/raw_data/restat.csv", encoding = "utf-8-sig").astype("str")
df["doi"] = df["doi"].apply(lambda x: x.strip().replace("http://dx.doi.org/","").replace("https://doi.org/","").replace("http://hdl.handle.net/","").replace("http://www.mitpressjournals.org/doi/pdf/",""))
df.tail()
# Out:
#                                      journal  \
# 4368  The Review of Economics and Statistics
# 4369  The Review of Economics and Statistics
# 4370  The Review of Economics and Statistics
# 4371  The Review of Economics and Statistics
# 4372  The Review of Economics and Statistics
#
#                                                   title  \
# 4368  Comment on the "H" Concentration Measure as a ...
# 4369  Import Constraints and Development: Causes of ...
# 4370        Import Constraints and Development: A Reply
# 4371  Profitability and Size of Firm: Some Further E...
# 4372  Effect of the Length of the Time Period on Ser...
#
#                                      authors  \
# 4368                        ['Adelman, M A']
# 4369  ['Bergsman, Joel', 'Morley, Samuel A']
# 4370                   ['Leff, Nathaniel H']
# 4371                   ['Marcus, Matityahu']
# 4372                         ['Rayner, A C']
#
#                                      abstract  \
# 4368  No abstract is available for this item.
# 4369  No abstract is available for this item.
# 4370  No abstract is available for this item.
# 4371  No abstract is available for this item.
# 4372  No abstract is available for this item.
#
#                                                    cite  jel  \
# 4368  Adelman, M A, 1969. "Comment on the "H" Concen...  N\A
# 4369  Bergsman, Joel & Morley, Samuel A, 1969. "Impo...  N\A
# 4370  Leff, Nathaniel H, 1969. "Import Constraints a...  N\A
# 4371  Marcus, Matityahu, 1969. "Profitability and Si...  N\A
# 4372  Rayner, A C, 1969. "Effect of the Length of th...  N\A
#
#                                                     url  \
# 4368  https://ideas.repec.org/a/tpr/restat/v51y1969i...
# 4369  https://ideas.repec.org/a/tpr/restat/v51y1969i...
# 4370  https://ideas.repec.org/a/tpr/restat/v51y1969i...
# 4371  https://ideas.repec.org/a/tpr/restat/v51y1969i...
# 4372  https://ideas.repec.org/a/tpr/restat/v51y1969i...
#
#                                volume  \
# 4368   51(1), pages 99-101, February.
# 4369  51(1), pages 101-102, February.
# 4370  51(1), pages 102-104, February.
# 4371  51(1), pages 104-107, February.
# 4372  51(1), pages 107-108, February.
#
#                                                     doi  year
# 4368  http://links.jstor.org/sici?sici=0034-6535%281...  1969
# 4369  http://links.jstor.org/sici?sici=0034-6535%281...  1969
# 4370  http://links.jstor.org/sici?sici=0034-6535%281...  1969
# 4371  http://links.jstor.org/sici?sici=0034-6535%281...  1969
# 4372  http://links.jstor.org/sici?sici=0034-6535%281...  1969

# %%
for d in df["doi"]:
    print(d)

# %%
authorids = []
articleids = []

base_url = "https://scholar.google.com/scholar?hl=zh-CN&q="
start_idx = 1532
existing_doi = list(pd.read_csv("author_article.csv", encoding = "utf-8-sig")["doi"])

for i, doi in enumerate(df["doi"][start_idx:]):
    if ("10." == doi[:3]) and (doi not in existing_doi) and ("issue" not in doi):
        try:
            driver.get(base_url+doi)
            driver.refresh()
            soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
            authordiv = soup.find("div", "gs_a")
            authorlinks = ["https://scholar.google.com/"+tag.get("href") for tag in authordiv.find_all("a")]
            if authorlinks != []:
                for link in authorlinks:
                    # get authorid
                    authorid = link.split("user=")[1].split("&")[0]
                    driver.get(link)
                    driver.refresh()
                    soup = bs4.BeautifulSoup(driver.page_source, "html.parser")
                    # save to html
                    with open("data/authors/html/"+authorid+".html", "w", encoding = "utf-8-sig") as file:
                        file.write(str(soup))
                    file.close()
                    # append authorid
                    authorids.append(authorid)
                    # append articleid
                    articleids.append(doi)
                    print(str(i+start_idx)+","+authorid+","+doi)
                    time.sleep(random.randrange(1,10))
            else:
                time.sleep(random.randrange(1,10))
        except:
            try:
                time.sleep(random.randrange(1,10))
                res = soup.find("div", id = "gs_res_ccl_top").text
            except:
                with open("author_article.csv", "a", newline="") as file:
                    writer = csv.writer(file)
                    for j in range(len(authorids)):
                        writer.writerow([authorids[j],articleids[j]])
                file.close()
                print("Blocked!!!")
                winsound.Beep(2500,1000)
                break
# Out:
# 1532,GpVUFVMAAAAJ,10.1162/003465302320259484
# 1532,upFspGoAAAAJ,10.1162/003465302320259484
# 1533,zQAhyTsAAAAJ,10.1162/003465302320259493
# 1533,8rjowPQAAAAJ,10.1162/003465302320259493
# 1533,ueDpb64AAAAJ,10.1162/003465302320259493
# 1536,61QM_esAAAAJ,10.1162/003465302320259529
# 1538,ok06MuMAAAAJ,10.1162/003465302320259547
# 1540,KW_synoAAAAJ,10.1162/003465302317411479
# 1540,TIfa3okAAAAJ,10.1162/003465302317411479
# 1541,Wo7OPBQAAAAJ,10.1162/003465302317411488
# 1542,m1-SRZwAAAAJ,10.1162/003465302317411497
# 1542,RRevF6oAAAAJ,10.1162/003465302317411497
# 1544,uEhRnHIAAAAJ,10.1162/003465302317411514
# 1544,5rI7fxYAAAAJ,10.1162/003465302317411514
# 1546,9Vkps6sAAAAJ,10.1162/003465302317411532
# 1546,TAj2jqAAAAAJ,10.1162/003465302317411532
# 1547,NYk0FcgAAAAJ,10.1162/003465302317411541
# 1547,hZN95ZgAAAAJ,10.1162/003465302317411541
# 1548,T88Gev4AAAAJ,10.1162/003465302317411550
# 1549,sY_KmtUAAAAJ,10.1162/003465302317411569
# 1550,lIV7LhIAAAAJ,10.1162/003465302317411578
# 1550,DTbePNAAAAAJ,10.1162/003465302317411578
# 1552,rOxximUAAAAJ,10.1162/003465302317411596
# 1554,Fo2uD2UAAAAJ,10.1162/003465302317331883
# 1554,ddYUi6IAAAAJ,10.1162/003465302317331883
# 1554,mJf2-XIAAAAJ,10.1162/003465302317331883
# 1558,oj6Z1J4AAAAJ,10.1162/003465302317331928
# 1558,lZ_ER4sAAAAJ,10.1162/003465302317331928
# 1559,nMtHiQsAAAAJ,10.1162/003465302317331937
# 1559,rtXHmjEAAAAJ,10.1162/003465302317331937
# 1562,ayRFFGAAAAAJ,10.1162/003465302317331964
# 1563,-lqU10oAAAAJ,10.1162/003465302317331973
# 1564,-lqU10oAAAAJ,10.1162/003465302317331982
# 1565,MfoYc0UAAAAJ,10.1162/003465302317331991
# 1568,CjY21_oAAAAJ,10.1162/003465301753237650
# 1872,1j3SqmIAAAAJ,10.1162/003465397556683
# 1872,5-5LnscAAAAJ,10.1162/003465397556683
# 1872,QW4Xka0AAAAJ,10.1162/003465397556683
# 1875,W2OkFFUAAAAJ,10.1162/003465397556773
# 1876,FVJSG5MAAAAJ,10.1162/003465397556782
# 1877,7Thi13kAAAAJ,10.1162/003465397556791
# 1877,0bThpp8AAAAJ,10.1162/003465397556791
# 1878,ziWn8NAAAAAJ,10.1162/003465397556809
# 1879,lnOcC3cAAAAJ,10.1162/003465397556818
# 1880,Fk2TEREAAAAJ,10.1162/003465397556584
# 1881,yVH2iwIAAAAJ,10.1162/003465397556593
# 1882,_bsRAXwAAAAJ,10.1162/003465397556601
# 1882,HdEPV0IAAAAJ,10.1162/003465397556601
# 1883,mXiIK5cAAAAJ,10.1162/003465397556610
# 1884,MNfbJQ4AAAAJ,10.1162/003465397556629
# 1884,Jee3d3EAAAAJ,10.1162/003465397556629
# 1886,CJJ_SGsAAAAJ,10.1162/003465397556647
# 1886,fEtfLCAAAAAJ,10.1162/003465397556647
# 1887,3z3n-y4AAAAJ,10.1162/003465397556656
# 1887,-W22HSwAAAAJ,10.1162/003465397556656
# 1888,lvF8SOoAAAAJ,10.1162/003465397556665
# 1888,c37JI8UAAAAJ,10.1162/003465397556665
# 1890,VYmrCV0AAAAJ,10.1162/003465397556692
# 1891,POJBZMAAAAAJ,10.1162/003465397556700
# 1891,y6EDPWoAAAAJ,10.1162/003465397556700
# 1892,eYqjMLMAAAAJ,10.1162/003465397556719
# 1892,0rDYQwkAAAAJ,10.1162/003465397556719
# 1893,HH8KaAIAAAAJ,10.1162/003465397556728
# 1894,20iXQSYAAAAJ,10.1162/003465397556737
# 1895,xqxDlyEAAAAJ,10.1162/rest.1997.79.2.348
# 1896,Y6AyJ64AAAAJ,10.1162/003465397556421
# 1897,ROe8lxYAAAAJ,10.1162/003465397750160158
# 1898,HofARQ8AAAAJ,10.1162/003465397750160167
# 1898,XVBVPzoAAAAJ,10.1162/003465397750160167
# 1899,iChOX9YAAAAJ,10.1162/003465397750160176
# 1900,b66aqMsAAAAJ,10.1162/003465397556520
# 1900,OdlDJb8AAAAJ,10.1162/003465397556520
# 1901,i2_7ytoAAAAJ,10.1162/003465397556539
# 1902,mpaVyFgAAAAJ,10.1162/003465397556548
# 1904,jR9wPu8AAAAJ,10.1162/003465397556566
# 1905,2Nkxy10AAAAJ,10.1162/003465397556430
# 1907,7IfK9-AAAAAJ,10.1162/003465397556458
# 1907,leWI3UMAAAAJ,10.1162/003465397556458
# 1907,OqulN6UAAAAJ,10.1162/003465397556458
# 1908,egUlDFQAAAAJ,10.1162/003465397556467
# 1908,Cw2-qDoAAAAJ,10.1162/003465397556467
# 1908,XUx0YIgAAAAJ,10.1162/003465397556467
# 1911,_JUKxIEAAAAJ,10.1162/003465397556494
# 1913,AdaWt-gAAAAJ,10.1162/003465397556511
# 1913,Yb6mQ80AAAAJ,10.1162/003465397556511

# %%
i+start_idx
# Out:
# 1532

# %%
with open("author_article.csv", "a", newline="") as file:
    writer = csv.writer(file)
    for j in range(len(authorids)):
        writer.writerow([authorids[j],articleids[j]])
file.close()
