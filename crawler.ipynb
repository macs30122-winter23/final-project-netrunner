# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %%
def read_one_page(url):
    '''
    Crawl the paper title and paper url in one page of the journal database.

    Inputs:
        url(str): The url of one page of the journal database.

    Outputs:
        Volume(Dictionary): The dict record the title and url for each paper.
    '''
    
    Volume = {"Title":[],"Link":[]}
    # Read the journal database page and find all the paper links.
    response = requests.get(url)
    soup = BeautifulSoup(response.text,"html")
    papers = soup.find_all("li", class_ = "list-group-item downgate")
    papers.extend(soup.find_all("li", class_ = "list-group-item downfree"))
    papers.extend(soup.find_all("li", class_ = "list-group-item downnone"))
    # Record all the papers title and link in Volume.
    for paper in papers:
        title = paper.a.text
        href = paper.a.get("href")
        Volume["Title"].append(title)
        Volume["Link"].append("https://ideas.repec.org" + href)
    
    return Volume

# %%
def find_url_list(start_url, page_number):
    '''
    Get the papers url list for all the journal database/

    Inputs:
        start_url(str): The url of the first page of the journal database.
        page_number(int): The number of pages of the journal database.

    Outputs:
        Volume(DataFrame): A DataFrame record the title and url for all\
            papers of a specified journal.
    '''
    Volume = {}
    Volume = read_one_page(start_url)

    for i in range(2, page_number):
        url = start_url[:-5]
        page = "{}.html".format(i)
        url = url + page
        Volume_one_page = read_one_page(start_url)
        Volume["Title"].extend(Volume_one_page["Title"])
        Volume["Link"].extend(Volume_one_page["Link"])

    Volume = pd.DataFrame(data=Volume)
    return Volume

# %%
def obtain_articles_infos(url):
    '''
    Obtain and record the article's journal name, title, authors, abstract,\
        cite, url, vol, publish time and the doi on the page of a single url.
        (This code is designed for The Economic Journal in ideas.repec.org\
        database as an example, we also crawl the other journals in other databases)
    
        
    Inputs:
        url(str): The string of the URL we want to crawl.

    Outputs:
        info(DataFrame): The DataFrame with all the recorded information we\
                         said above.
    '''
    
    # Define the structure of the DataFrame.
    info = {"journal":[], "title":[],"authors":[],"abstract":[], "cite":[],\
            "JEL":[],"url":[],"vol":[], "doi":[], "year":[]}
    journal = "The Economic Journal"

    # Request the url and get the soup.
    response = requests.get(url)
    soup = BeautifulSoup(response.text,"html")

    # Crawl the title of the journal
    title = soup.find("h1").text
    
    # ideas.repec.org have three type of keyword in cite and vol, try each keyword.
    try:
        cite = soup.find("li", class_="list-group-item downgate").text
    except:
        try:
            cite = soup.find("li", class_="list-group-item downfree").text
        except:
            try:
                cite = soup.find("li", class_="list-group-item downnone").text
            except:
                cite = "N\A"
                vol = "N\A"

    # If we crawl the cite successfully, clean and record cite and vol.
    if cite != "N\A":
        vol = re.split(r"vol.", cite)[1]
        cite = re.sub('(\t|\n)'," ",cite)
        cite = re.sub('\s+'," ",cite).strip()
        vol = re.sub('(\t|\n)'," ",vol)
        vol = re.sub('\s+'," ",vol).strip()
        vol.strip(".")

    # Crawl, clean and record the author names.
    try:
        authors = soup.find_all("li", class_="authorname")
        authors = [author.text for author in authors]
    except:
        authors = []        

    # Crawl, clean and record the Abstract.
    try:
        abstract = soup.find("div", id="abstract-body").text
    except:
        abstract = "N\A"

    # Crawl, clean and record the doi.
    try:
        doi = soup.find("div", id="biblio-body").text
        [doi] = re.findall(r"DOI:...+", doi)
        doi = re.sub(r"DOI:","", doi)
    except:
        doi = "N\A"

    # If there no "doi" in ideas.repec.org, record the url of the offical website.
    if doi == "N\A":
        try:
            doi = soup.find("span", style="word-break:break-all").text
        except:
            doi = "N\A"

    # Crawl, clean and record the publish time.
    try:
        year = soup.find("i", style="word-break:break-all").text
        [year] = re.findall(r"y:....", year)
        year = re.sub("y:","",year)
    except:
        year = "N\A"

    # Only journals in AEA(American Economic Association) have JEL.
    jel = "N\A"

    # Make all the information into DataFrame.
    info["journal"].append(journal)
    info["title"].append(title)
    info["authors"].append(authors)
    info["abstract"].append(abstract)
    info["cite"].append(cite)
    info["JEL"].append(jel)
    info["url"].append(url)
    info["vol"].append(vol)
    info["doi"].append(doi)
    info["year"].append(year)
    info = pd.DataFrame(info)

    return info

# %%
def crawl_all_url(Volume, start = None, end = None, sleep_time = 0.5):
    '''
    Crawl all the paper informations recorded in the Volume.

    Inputs:
        Volume(DataFrame): A DataFrame record the title and url for all\
            papers of a specified journal.
        start(int): The start Volume index of the paper we want to start to crawl.
        end(int): The end Volume index of the paper we want to end the crawl.
        sleep_time(int): The seelp time for the crawl for each papaer.

    Outputs:
        df(DataFrame): The DataFrame record all the crawl information for all\
            papers in the journal.
    '''

    df = pd.DataFrame({"journal":[], "title":[],"authors":[],"abstract":[],\
                       "cite":[], "JEL":[],"url":[],"vol":[], "doi":[], "year":[]})
    count = start
    # Iterate over all volumes
    for index, row in Volume.iloc[start: end].iterrows():
        title, link = row["Title"], row["Link"]
        print(count, "Currently at", title, "link =", link)

        # Iterate over articles of the volumes
        article = obtain_articles_infos(link)
        df = pd.concat([df, article],ignore_index=True)
        time.sleep(sleep_time)
        count += 1
    
    return df

# %%
# Get the url for all the papers in one journal.
Volume = find_url_list("https://ideas.repec.org/s/ecj/econjl.html", 3)
print(Volume)
# Out:
#                                                  Title  \
# 0    Optimal Monetary Policy in a Model of the Cred...
# 1    Gender Differences in Market Competitiveness i...
# 2    Identification of Peer Effects with Missing Pe...
# 3    Reaction to Public Information in Markets: How...
# 4         Financial Contagion and Attention Allocation
# ..                                                 ...
# 393  Information Cascades and Revolutionary Regime ...
# 394  Unionisation Triggers Tax Incentives to Attrac...
# 395  A Model of Public Consultation: Why is Binary ...
# 396  Classification, Detection and Consequences of ...
# 397  Are Children Decision‐Makers within the Househ...
#
#                                                   Link
# 0    https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 1    https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 2    https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 3    https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 4    https://ideas.repec.org/a/ecj/econjl/v123y2013...
# ..                                                 ...
# 393  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 394  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 395  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 396  https://ideas.repec.org/a/ecj/econjl/v121y2011...
# 397  https://ideas.repec.org/a/ecj/econjl/v121y2011...
#
# [398 rows x 2 columns]

# %%
# Crawl the information of a certain papers in the journal. (the first 10 papers)
df = crawl_all_url(Volume, start = 0, end = 10, sleep_time = 0.5)
df
# Out:
# 0 Currently at Optimal Monetary Policy in a Model of the Credit Channel link = https://ideas.repec.org/a/ecj/econjl/v123y2013i571p906-931.html
# 1 Currently at Gender Differences in Market Competitiveness in a Real Workplace: Evidence from Performance‐based Pay Tournaments among Teachers link = https://ideas.repec.org/a/ecj/econjl/v123y2013i569p540-573.html
https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 1  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 2  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 3  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 4  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 5  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 6  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 7  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 8  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 9  https://ideas.repec.org/a/ecj/econjl/v123y2013...
#
#                                    vol                             doi  year
# 0  123(571), pages 906-931, September.  http://hdl.handle.net/10.1111/  2013
# 1       123(569), pages 540-573, June.  http://hdl.handle.net/10.1111/  2013
# 2       123(569), pages 574-605, June.  http://hdl.handle.net/10.1111/  2013
# 3       123(569), pages 699-737, June.  http://hdl.handle.net/10.1111/  2013
# 4        123(568), pages 429-454, May.  http://hdl.handle.net/10.1111/  2013
# 5        123(568), pages 491-513, May.  http://hdl.handle.net/10.1111/  2013
# 6         123(567), pages 1-37, March.  http://hdl.handle.net/10.1111/  2013
# 7        123(567), pages 38-76, March.  http://hdl.handle.net/10.1111/  2013
# 8       123(567), pages 96-130, March.  http://hdl.handle.net/10.1111/  2013
# 9      123(567), pages 131-161, March.  http://hdl.handle.net/10.1111/  2013

# %%
# Write the DataFrame to .csv
df.to_csv("The Economic Journal_test.csv", encoding="utf-8")

# %%
# If we crawl a journal more than one times and get multiple csv,\
# merge them into one file and write
csv_1 = pd.read_csv("The Economic Journal23_19.csv")
csv_2 = pd.read_csv("The Economic Journal18_08.csv")
csv_3 = pd.read_csv("The Economic Journal13_1.csv")
csv_4 = pd.read_csv("The Economic Journal13_2.csv")
csv = pd.concat([csv_1, csv_2, csv_3, csv_4])
csv = csv.reset_index()
csv = csv.drop(columns = "index")
csv = csv.drop(columns = "Unnamed: 0")
csv.to_csv("The Economic Journal.csv", encoding="utf-8")

# %%
# Check the csv is write correctly.
pd.read_csv("The Economic Journal.csv")
# Out:
#       Unnamed: 0               journal  \
# 0              0  The Economic Journal
# 1              1  The Economic Journal
# 2              2  The Economic Journal
# 3              3  The Economic Journal
# 4              4  The Economic Journal
# ...          ...                   ...
# 3150        3150  The Economic Journal
# 3151        3151  The Economic Journal
# 3152        3152  The Economic Journal
# 3153        3153  The Economic Journal
# 3154        3154  The Economic Journal
#
#                                                   title  \
# 0     The Central Bank Strikes Back! Credibility of ...
# 1     Spatial Polarisation[‘Skills, tasks and techno...
# 2     Trading Favours through the Revolving Door: Ev...
# 3     Policy Uncertainty and Information Flows: Evid...
# 4     Estimating Cross-Industry Cross-Country Intera...
# ...                                                 ...
# 3150  Do Prediction Markets Produce Well‐Calibrated ...
# 3151                               Optimal Bank Capital
# 3152          Social Learning and Monetary Policy Rules
# 3153  Testing for Asymmetric Information in Private ...
# 3154  Market Power in the Global Economy: The Exhaus...
#
#                                                 authors  \
# 0                  ['Antoine Camous', 'Dmitry Matveev']
# 1     ['Fabio Cerina', 'Elisa Dienesch', 'Alessio Mo...
# 2     ['Ting Chen', 'Li Han', 'James Kung', 'Jiaxin ...
# 3     ['Emanuele Ciani', 'Adeline Delavande', 'Ben E...
# 4              ['Antonio Ciccone', 'Elias Papaioannou']
# ...                                                 ...
# 3150                ['Lionel Page', 'Robert T. Clemen']
# 3151  ['David Miles', 'Jing Yang', 'Gilberto Marcheg...
# 3152  ['Jasmina Arifovic', 'James Bullard', 'Olena K...
# 3153          ['Pau Olivella', 'Marcos Vera‐Hernández']
# 3154                                    ['Kamal Saggi']
#
#                                                abstract  \
# 0     How should independent central banks react if ...
# 1     We document the emergence of spatial polarisat...
# 2     By matching data on land transactions in China...
# 3     We examine how workers’ expectations about pen...
# 4     Cross-industry cross-country models are used t...
# ...                                                 ...
# 3150            No abstract is available for this item.
# 3151  This paper reports estimates of the long-run c...
# 3152  We analyze the effects of social learning in a...
# 3153            No abstract is available for this item.
# 3154  This paper analyzes economic linkages between ...
#
#                                                    cite  JEL  \
# 0     Antoine Camous & Dmitry Matveev, 2023. "The Ce...  N\A
# 1     Fabio Cerina & Elisa Dienesch & Alessio Moro &...  N\A
# 2     Ting Chen & Li Han & James Kung & Jiaxin Xie, ...  N\A
# 3     Emanuele Ciani & Adeline Delavande & Ben Ether...  N\A
# 4     Antonio Ciccone & Elias Papaioannou, 2023. "Es...  N\A
# ...                                                 ...  ...
# 3150  Lionel Page & Robert T. Clemen, 2013. "Do Pred...  N\A
# 3151  David Miles & Jing Yang & Gilberto Marcheggian...  N\A
# 3152  Jasmina Arifovic & James Bullard & Olena Kosty...  N\A
# 3153  Pau Olivella & Marcos Vera‐Hernández, 2013. "T...  N\A
# 3154  Kamal Saggi, 2013. "Market Power in the Global...  N\A
#
#                                                     url  \
# 0     https://ideas.repec.org/a/oup/econjl/v133y2023...
# 1     https://ideas.repec.org/a/oup/econjl/v133y2023...
# 2     https://ideas.repec.org/a/oup/econjl/v133y2023...
# 3     https://ideas.repec.org/a/oup/econjl/v133y2023...
# 4     https://ideas.repec.org/a/oup/econjl/v133y2023...
# ...                                                 ...
# 3150  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 3151  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 3152  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 3153  https://ideas.repec.org/a/ecj/econjl/v123y2013...
# 3154  https://ideas.repec.org/a/ecj/econjl/v123y2013...
#
#                                                     vol  \
# 0                                 133(649), pages 1-29.
# 1                                133(649), pages 30-69.
# 2     ing Door: Evidence from China’s Primary Land M...
# 3                               133(649), pages 98-129.
# 4                              133(649), pages 130-158.
# ...                                                 ...
# 3150                      123(568), pages 491-513, May.
# 3151                       123(567), pages 1-37, March.
# 3152                      123(567), pages 38-76, March.
# 3153                     123(567), pages 96-130, March.
# 3154                    123(567), pages 131-161, March.
#
#                                            doi  year
# 0     http://hdl.handle.net/10.1093/ej/ueac055  2023
# 1     http://hdl.handle.net/10.1093/ej/ueac040  2023
# 2     http://hdl.handle.net/10.1093/ej/ueac060  2023
# 3     http://hdl.handle.net/10.1093/ej/ueac050  2023
# 4     http://hdl.handle.net/10.1093/ej/ueac047  2023
# ...                                        ...   ...
# 3150            http://hdl.handle.net/10.1111/  2013
# 3151            http://hdl.handle.net/10.1111/  2013
# 3152            http://hdl.handle.net/10.1111/  2013
# 3153            http://hdl.handle.net/10.1111/  2013
# 3154            http://hdl.handle.net/10.1111/  2013
#
# [3155 rows x 11 columns]
